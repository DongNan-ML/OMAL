# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from modAL.models import ActiveLearner, CommitteeRegressor
from modAL.disagreement import vote_entropy_sampling, max_std_sampling
import matplotlib.pyplot as plt
import torch
from torch.nn import MSELoss
from skorch.regressor import NeuralNetRegressor
from copy import deepcopy
from skorch.dataset import ValidSplit
from skorch.callbacks import EarlyStopping
from sklearn.cluster import DBSCAN, OPTICS, cluster_optics_dbscan, Birch, SpectralClustering
from sklearn.neighbors import NearestNeighbors
from sklearn import metrics
import matplotlib.gridspec as gridspec
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from torch.nn import Linear
from torch.nn import Sigmoid, ReLU
from torch.nn import Module
from sklearn.metrics import r2_score
import copy
from scipy.spatial import distance
from scipy.spatial.distance import euclidean
from torch import tensor
from sklearn.metrics import mean_squared_error
from scipy.spatial.distance import cdist
from sklearn.ensemble import RandomForestRegressor
from torch.nn.init import xavier_uniform_
from model import MLP
import random
from skorch.callbacks import EarlyStopping, LRScheduler, Freezer, Unfreezer
from torch.optim.lr_scheduler import CyclicLR, ReduceLROnPlateau
from skorch.regressor import NeuralNetRegressor, NeuralNet
from modAL.utils.selection import multi_argmax

# %%
# Hyper-params:
query_number = 20          # The number of the AL Iterations in each Exp
iteration = 20             # Total number of the Exps
batch_size = 10
total_initail_size = 10
initial_size = 5
n_members = 3
    
seed_rf = np.load(file="..\..\seed2.npy")
seed_initial = np.load(file="..\..\seed3.npy")

seed_nn1 = np.load(file="..\..\seed4.npy")
seed_nn2 = np.load(file="..\..\seed4.npy")
seed_nn3 = np.load(file="..\..\seed5.npy")
seed_nn4 = np.load(file="..\..\seed5.npy")
seed_nn5 = np.load(file="..\..\seed6.npy")
seed_nn6 = np.load(file="..\..\seed6.npy")

seed_predictor = np.load(file="..\..\seed7.npy")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def Committee_Prediction(learner_list, X_test, y_test):
    initial_pred=[]
    for i in learner_list:
        initial_pred.append(r2_score(y_test, i.predict(X_test)))
    initial_pred=np.array(initial_pred)
    
    return initial_pred.mean()

# %%
def query_QBC(unlebeled_samples, learner_list, n_instances=batch_size):
    initial_pred=np.empty(shape=(n_members, unlebeled_samples.shape[0]))
    for i in range(n_members):
        initial_pred[i,:] = learner_list[i].predict(unlebeled_samples).reshape(1, -1)
    std = np.std(initial_pred, axis=0)
    return multi_argmax(std, n_instances=n_instances)

# %%
def main_function(query_number, iters):
# For saving results:
    rf_model_training_r2 = []
    rf_model_training_mse = []
    rf_model_testing_r2 = []
    rf_model_testing_mse = []
    
    # Number of member in committee:
    learner_list = []
    
    # The model for evaluation:
    rf_model = RandomForestRegressor(random_state=seed_rf[iters], n_estimators=100)
    
    # Load the data:
    name1 = "..\..\Datasets\Silver\X_train" + str(iters) + ".npy"
    name2 = "..\..\Datasets\Silver\X_test" + str(iters) + ".npy"
    name3 = "..\..\Datasets\Silver\y_train" + str(iters) + ".npy"
    name4 = "..\..\Datasets\Silver\y_test" + str(iters) + ".npy"
    
    X_train = np.load(name1, allow_pickle=True).astype(np.float32)
    X_test = np.load(name2, allow_pickle=True).astype(np.float32)
    y_train = np.load(name3, allow_pickle=True).astype(np.float32).reshape(-1, 1)
    y_test = np.load(name4, allow_pickle=True).astype(np.float32).reshape(-1, 1)
    
    # Feature Dim
    X = X_train.shape[1]
    # The unlabeled pool
    X_index = np.arange(X_train.shape[0])
    
    # Queried samples and labels
    used_data = np.empty(shape=(0, X))
    used_label = np.empty(shape=(0)).reshape(-1, 1)
    
    # Initial samples and labels
    X_initial = np.empty(shape=(0,X))
    y_initial = np.empty(shape=(0)).reshape(-1, 1)

    # Initial Stage 1:
    np.random.seed(seed_initial[iters])
    idx = np.random.choice(range(len(X_index)), size=initial_size, replace=False)
    train_idx = X_index[idx]

    X_initial = X_train[train_idx]
    y_initial = y_train[train_idx].reshape(-1, 1)

    used_data = np.append(used_data, X_initial, axis=0).astype(np.float32)
    used_label = np.append(used_label, y_initial, axis=0).astype(np.float32).reshape(-1, 1)
    X_index = np.delete(X_index, idx, axis=0)
    
    # Initial Sagte 2:
    rest_initial_X = np.empty(shape=(0,X))
    rest_initial_y = np.empty(shape=(0)).reshape(-1, 1)
    
    np.random.seed(seed_initial[iters])
    idx = np.random.choice(range(len(X_index)), size=total_initail_size-initial_size, replace=False)
    train_idx = X_index[idx]
    
    rest_initial_X = np.append(rest_initial_X, X_train[train_idx], axis=0).astype(np.float32)
    rest_initial_y = np.append(rest_initial_y, y_train[train_idx], axis=0).astype(np.float32).reshape(-1, 1)

    X_index = np.delete(X_index, idx, axis=0)
    
    used_data = np.append(used_data, rest_initial_X, axis=0).astype(np.float32)
    used_label = np.append(used_label, rest_initial_y, axis=0).astype(np.float32).reshape(-1, 1)
    
    # Finished the Initialization Stages:
    # RF Regressor for evaluation:
    rf_model.fit(used_data, used_label.ravel())
    # Training Scores:
    rf_training_r2 = r2_score(used_label, rf_model.predict(used_data))
    rf_training_mse = mean_squared_error(used_label, rf_model.predict(used_data))
    rf_model_training_r2.append(rf_training_r2)
    rf_model_training_mse.append(rf_training_mse)
    
    # Test Scores:
    rf_model_r2 = r2_score(y_test, rf_model.predict(X_test))
    rf_model_mse = mean_squared_error(y_test, rf_model.predict(X_test))
    rf_model_testing_r2.append(rf_model_r2)
    rf_model_testing_mse.append(rf_model_mse)

    print("After Initialization RF R2:", rf_model_r2)

    used_data = torch.from_numpy(used_data).to(device)
    used_label = torch.from_numpy(used_label).to(device)
    for member_idx in range(n_members):
        
        if member_idx == 0:
            np.random.seed(seed_nn1[iters])
            torch.manual_seed(seed_nn2[iters])
        if member_idx == 1:
            np.random.seed(seed_nn3[iters])
            torch.manual_seed(seed_nn4[iters])
        if member_idx == 2:
            np.random.seed(seed_nn5[iters])
            torch.manual_seed(seed_nn6[iters])
            
        regressor = NeuralNetRegressor(MLP(X),
                                   criterion=MSELoss(),
                                   optimizer=torch.optim.Adam,
                                   verbose=0,
                                   max_epochs=100,
                                   lr=0.001,
                                   # Used for the batch AL
                                   callbacks=[EarlyStopping(patience=20), ('lr_scheduler', LRScheduler(policy=ReduceLROnPlateau))],
                                   train_split=ValidSplit(cv=5),
                                   warm_start=False,
                                   device='cuda',
                                   batch_size = 200
                                   )
        regressor.fit(used_data, used_label)
        learner_list.append(regressor)
    
    print("NN Test R2 after Initialization", Committee_Prediction(learner_list, X_test, y_test))
    print('NN R2', Committee_Prediction(learner_list, X_test, y_test))

    for idx in range(query_number):
        print('Query no. %d' % (idx+1))

        idx = query_QBC(X_train[X_index], learner_list, n_instances=batch_size)

        # Query the new sample:
        X_train_index = X_index[idx]

        new_X = X_train[X_train_index].reshape(batch_size, -1)
        new_y = y_train[X_train_index].reshape(batch_size, -1)

        # Adding the used data to the used_data pool
        used_data = used_data.cpu().numpy()
        used_label = used_label.cpu().numpy()
        used_data = np.append(used_data, new_X, axis=0).astype(np.float32)
        used_label = np.append(used_label, new_y, axis=0).astype(np.float32).reshape(-1, 1)
        
        # RF Evaluation
        rf_model.fit(used_data, used_label.ravel())
        
        # Training Evaluation:
        rf_training_r2 = r2_score(used_label, rf_model.predict(used_data))
        rf_training_mse = mean_squared_error(used_label, rf_model.predict(used_data))
        rf_model_training_r2.append(rf_training_r2)
        rf_model_training_mse.append(rf_training_mse)
        
        # Test Evaluation:
        rf_model_r2 = r2_score(y_test, rf_model.predict(X_test))
        rf_model_mse = mean_squared_error(y_test, rf_model.predict(X_test))
        rf_model_testing_r2.append(rf_model_r2)
        rf_model_testing_mse.append(rf_model_mse)

        print(np.unique(used_data, axis=0).shape)
        print("RF R2:", rf_model_r2)
        print("Remaining:", X_index.shape[0])

        # remove queried instance from pool
        X_index = np.delete(X_index, idx, axis=0)
        
        used_data = torch.from_numpy(used_data).to(device)
        used_label = torch.from_numpy(used_label).to(device)
        
        # Retrain the committee:
        for l in learner_list:
            l.fit(used_data, used_label)
            
        # print('NN R2', Committee_Prediction(learner_list, X_test, y_test))
    
    rf_model_testing_r2 = np.array(rf_model_testing_r2)
    rf_model_testing_mse = np.array(rf_model_testing_mse)
    rf_model_training_r2 = np.array(rf_model_training_r2)
    rf_model_training_mse = np.array(rf_model_training_mse)
    
    # Used_data and Unsed_label:
    used_data = used_data.cpu().numpy()
    used_label = used_label.cpu().numpy()
    np.save(file="..\..\Results\Res_Silver\QBC\Summary\\used_data" + str(iters) + ".npy", arr=used_data)
    np.save(file="..\..\Results\Res_Silver\QBC\Summary\\used_labels" + str(iters) + ".npy", arr=used_label)

    np.save(file="..\..\Results\Res_Silver\QBC\Summary\\testing_rf_r2_" + str(iters) + ".npy", arr=rf_model_testing_r2)
    np.save(file="..\..\Results\Res_Silver\QBC\Summary\\testing_rf_mse_" + str(iters) + ".npy", arr=rf_model_testing_mse)
    np.save(file="..\..\Results\Res_Silver\QBC\Summary\\training_rf_r2_" + str(iters) + ".npy", arr=rf_model_training_r2)
    np.save(file="..\..\Results\Res_Silver\QBC\Summary\\training_rf_mse_" + str(iters) + ".npy", arr=rf_model_training_mse)

# %%
for i in range(iteration):
    print("The Iteration is ", i)
    main_function(query_number, i)
# Out:
# The Iteration is  0
# After Initialization RF R2: 0.7380871956759357
# NN Test R2 after Initialization 0.3861939194157675
# NN R2 0.3861939194157675
# Query no. 1
# (20, 106)
# RF R2: 0.7772191913570301
# Remaining: 330
# Query no. 2
# (30, 106)
# RF R2: 0.9526060609387396
# Remaining: 320
# Query no. 3
# (40, 106)
# RF R2: 0.9621884510092327
# Remaining: 310
# Query no. 4
# (50, 106)
# RF R2: 0.9680824698840169
# Remaining: 300
# Query no. 5
# (60, 106)
# RF R2: 0.9729361963975373
# Remaining: 290
# Query no. 6
# (70, 106)
# RF R2: 0.973645684672025
# Remaining: 280
# Query no. 7
# (80, 106)
# RF R2: 0.9780750987693756
# Remaining: 270
# Query no. 8
# (90, 106)
# RF R2: 0.9795293098998568
# Remaining: 260
# Query no. 9
# (100, 106)
# RF R2: 0.9809533566249807
# Remaining: 250
# Query no. 10
# (110, 106)
# RF R2: 0.9833926609323231
# Remaining: 240
# Query no. 11
# (120, 106)
# RF R2: 0.9831142693859746
# Remaining: 230
# Query no. 12
# (130, 106)
# RF R2: 0.9765284911217029
# Remaining: 220
# Query no. 13
# (140, 106)
# RF R2: 0.9812005121628432
# Remaining: 210
# Query no. 14
# (150, 106)
# RF R2: 0.9795298131047723
# Remaining: 200
# Query no. 15
# (160, 106)
# RF R2: 0.9790573068913742
# Remaining: 190
# Query no. 16
# (170, 106)
# RF R2: 0.9787100592282101
# Remaining: 180
# Query no. 17
# (180, 106)
# RF R2: 0.9807578744250708
# Remaining: 170
# Query no. 18
# (190, 106)
# RF R2: 0.9835559697512062
# Remaining: 160
# Query no. 19
# (200, 106)
# RF R2: 0.9847969930188317
# Remaining: 150
# Query no. 20
# (210, 106)
# RF R2: 0.9851701305966859
# Remaining: 140
# The Iteration is  1
# After Initialization RF R2: 0.71865031156084
# NN Test R2 after Initialization -1.2953516218488585
# NN R2 -1.2953516218488585
# Query no. 1
# (20, 106)
# RF R2: 0.9393956539239698
# Remaining: 330
# Query no. 2
# (30, 106)
# RF R2: 0.9381690030306583
# Remaining: 320
# Query no. 3
# (40, 106)
# RF R2: 0.9334620918174024
# Remaining: 310
# Query no. 4
# (50, 106)
# RF R2: 0.970179805169522
# Remaining: 300
# Query no. 5
# (60, 106)
# RF R2: 0.965160785831759
# Remaining: 290
# Query no. 6
# (70, 106)
# RF R2: 0.9692360625038018
# Remaining: 280
# Query no. 7
# (80, 106)
# RF R2: 0.974165732829706
# Remaining: 270
# Query no. 8
# (90, 106)
# RF R2: 0.9732499957405338
# Remaining: 260
# Query no. 9
# (100, 106)
# RF R2: 0.973983978598916
# Remaining: 250
# Query no. 10
# (110, 106)
# RF R2: 0.9768940483401525
# Remaining: 240
# Query no. 11
# (120, 106)
# RF R2: 0.975659232631706
# Remaining: 230
# Query no. 12
# (130, 106)
# RF R2: 0.9754838318114052
# Remaining: 220
# Query no. 13
# (140, 106)
# RF R2: 0.9745448970729308
# Remaining: 210
# Query no. 14
# (150, 106)
# RF R2: 0.9759563852544371
# Remaining: 200
# Query no. 15
# (160, 106)
# RF R2: 0.9737561730998324
# Remaining: 190
# Query no. 16
# (170, 106)
# RF R2: 0.9746818286829344
# Remaining: 180
# Query no. 17
# (180, 106)
# RF R2: 0.9782392536796439
# Remaining: 170
# Query no. 18
# (190, 106)
# RF R2: 0.9789446916653868
# Remaining: 160
# Query no. 19
# (200, 106)
# RF R2: 0.9794436237052637
# Remaining: 150
# Query no. 20
# (210, 106)
# RF R2: 0.9794033270128609
# Remaining: 140
# The Iteration is  2
# After Initialization RF R2: 0.6402942067050355
# NN Test R2 after Initialization -3.0193775243275423
# NN R2 -3.0193775243275423
# Query no. 1
# (20, 106)
# RF R2: 0.8779003826890985
# Remaining: 330
# Query no. 2
# (30, 106)
# RF R2: 0.9305073832918863
# Remaining: 320
# Query no. 3
# (40, 106)
# RF R2: 0.9436725500842518
# Remaining: 310
# Query no. 4
# (50, 106)
# RF R2: 0.9383771370336933
# Remaining: 300
# Query no. 5
# (60, 106)
# RF R2: 0.9396506431699927
# Remaining: 290
# Query no. 6
# (70, 106)
# RF R2: 0.9499573459883386
# Remaining: 280
# Query no. 7
# (80, 106)
# RF R2: 0.9593409597599154
# Remaining: 270
# Query no. 8
# (90, 106)
# RF R2: 0.9618285908258625
# Remaining: 260
# Query no. 9
# (100, 106)
# RF R2: 0.9602605772725724
# Remaining: 250
# Query no. 10
# (110, 106)
# RF R2: 0.9625584256070329
# Remaining: 240
# Query no. 11
# (120, 106)
# RF R2: 0.9618326177729914
# Remaining: 230
# Query no. 12
# (130, 106)
# RF R2: 0.9634636226922666
# Remaining: 220
# Query no. 13
# (140, 106)
# RF R2: 0.9632675175328886
# Remaining: 210
# Query no. 14
# (150, 106)
# RF R2: 0.9663816003085207
# Remaining: 200
# Query no. 15
# (160, 106)
# RF R2: 0.966686654635175
# Remaining: 190
# Query no. 16
# (170, 106)
# RF R2: 0.9695539943869862
# Remaining: 180
# Query no. 17
# (180, 106)
# RF R2: 0.9688105977864641
# Remaining: 170
# Query no. 18
# (190, 106)
# RF R2: 0.9698407628004899
# Remaining: 160
# Query no. 19
# (200, 106)
# RF R2: 0.97052811680914
# Remaining: 150
# Query no. 20
# (210, 106)
# RF R2: 0.9698029849346822
# Remaining: 140
# The Iteration is  3
# After Initialization RF R2: 0.6481537558546087
# NN Test R2 after Initialization -1.359245465802455
# NN R2 -1.359245465802455
# Query no. 1
# (20, 106)
# RF R2: 0.9401701503550579
# Remaining: 330
# Query no. 2
# (30, 106)
# RF R2: 0.9530002649225489
# Remaining: 320
# Query no. 3
# (40, 106)
# RF R2: 0.9646045942680939
# Remaining: 310
# Query no. 4
# (50, 106)
# RF R2: 0.9699618138074805
# Remaining: 300
# Query no. 5
# (60, 106)
# RF R2: 0.9677762973918304
# Remaining: 290
# Query no. 6
# (70, 106)
# RF R2: 0.9738304685266654
# Remaining: 280
# Query no. 7
# (80, 106)
# RF R2: 0.9768106380648414
# Remaining: 270
# Query no. 8
# (90, 106)
# RF R2: 0.9790114945240675
# Remaining: 260
# Query no. 9
# (100, 106)
# RF R2: 0.9797870366662046
# Remaining: 250
# Query no. 10
# (110, 106)
# RF R2: 0.9776822105868196
# Remaining: 240
# Query no. 11
# (120, 106)
# RF R2: 0.9794789554575206
# Remaining: 230
# Query no. 12
# (130, 106)
# RF R2: 0.9831736204223317
# Remaining: 220
# Query no. 13
# (140, 106)
# RF R2: 0.9847840917064465
# Remaining: 210
# Query no. 14
# (150, 106)
# RF R2: 0.9829209395451106
# Remaining: 200
# Query no. 15
# (160, 106)
# RF R2: 0.9839480389589755
# Remaining: 190
# Query no. 16
# (170, 106)
# RF R2: 0.9854948218541327
# Remaining: 180
# Query no. 17
# (180, 106)
# RF R2: 0.9868517137566946
# Remaining: 170
# Query no. 18
# (190, 106)
# RF R2: 0.9867189257227474
# Remaining: 160
# Query no. 19
# (200, 106)
# RF R2: 0.9863433237953131
# Remaining: 150
# Query no. 20
# (210, 106)
# RF R2: 0.9866375306799869
# Remaining: 140
# The Iteration is  4
# After Initialization RF R2: 0.4703527207040865
# NN Test R2 after Initialization 0.4724805267941367
# NN R2 0.4724805267941367
# Query no. 1
# (20, 106)
# RF R2: 0.8780731476319383
# Remaining: 330
# Query no. 2
# (30, 106)
# RF R2: 0.8823254340847297
# Remaining: 320
# Query no. 3
# (40, 106)
# RF R2: 0.8934468863230681
# Remaining: 310
# Query no. 4
# (50, 106)
# RF R2: 0.951423226283094
# Remaining: 300
# Query no. 5
# (60, 106)
# RF R2: 0.9782140918829222
# Remaining: 290
# Query no. 6
# (70, 106)
# RF R2: 0.9780445225653418
# Remaining: 280
# Query no. 7
# (80, 106)
# RF R2: 0.983339516418469
# Remaining: 270
# Query no. 8
# (90, 106)
# RF R2: 0.9863783846672451
# Remaining: 260
# Query no. 9
# (100, 106)
# RF R2: 0.9850391239453786
# Remaining: 250
# Query no. 10
# (110, 106)
# RF R2: 0.9839436173457223
# Remaining: 240
# Query no. 11
# (120, 106)
# RF R2: 0.9833960354451071
# Remaining: 230
# Query no. 12
# (130, 106)
# RF R2: 0.9818997252999502
# Remaining: 220
# Query no. 13
# (140, 106)
# RF R2: 0.9845132114470391
# Remaining: 210
# Query no. 14
# (150, 106)
# RF R2: 0.9857142982120652
# Remaining: 200
# Query no. 15
# (160, 106)
# RF R2: 0.9845970579387555
# Remaining: 190
# Query no. 16
# (170, 106)
# RF R2: 0.9854934302284952
# Remaining: 180
# Query no. 17
# (180, 106)
# RF R2: 0.9837123456997136
# Remaining: 170
# Query no. 18
# (190, 106)
# RF R2: 0.9851268042175696
# Remaining: 160
# Query no. 19
# (200, 106)
# RF R2: 0.9837669352513895
# Remaining: 150
# Query no. 20
# (210, 106)
# RF R2: 0.9842678660285942
# Remaining: 140
# The Iteration is  5
# After Initialization RF R2: 0.7536751337271996
# NN Test R2 after Initialization -3.193873136110712
# NN R2 -3.193873136110712
# Query no. 1
# (20, 106)
# RF R2: 0.8119876680357738
# Remaining: 330
# Query no. 2
# (30, 106)
# RF R2: 0.8664027336017044
# Remaining: 320
# Query no. 3
# (40, 106)
# RF R2: 0.9292248568512993
# Remaining: 310
# Query no. 4
# (50, 106)
# RF R2: 0.9414280841777338
# Remaining: 300
# Query no. 5
# (60, 106)
# RF R2: 0.9401816920195776
# Remaining: 290
# Query no. 6
# (70, 106)
# RF R2: 0.9566054264272745
# Remaining: 280
# Query no. 7
# (80, 106)
# RF R2: 0.9492919492592345
# Remaining: 270
# Query no. 8
# (90, 106)
# RF R2: 0.9517236696920399
# Remaining: 260
# Query no. 9
# (100, 106)
# RF R2: 0.9480308838644608
# Remaining: 250
# Query no. 10
# (110, 106)
# RF R2: 0.9623266269988275
# Remaining: 240
# Query no. 11
# (120, 106)
# RF R2: 0.9669847737552588
# Remaining: 230
# Query no. 12
# (130, 106)
# RF R2: 0.9657826883709315
# Remaining: 220
# Query no. 13
# (140, 106)
# RF R2: 0.9701542799767156
# Remaining: 210
# Query no. 14
# (150, 106)
# RF R2: 0.9710047178626942
# Remaining: 200
# Query no. 15
# (160, 106)
# RF R2: 0.9713573523006409
# Remaining: 190
# Query no. 16
# (170, 106)
# RF R2: 0.971136534913686
# Remaining: 180
# Query no. 17
# (180, 106)
# RF R2: 0.974404576885655
# Remaining: 170
# Query no. 18
# (190, 106)
# RF R2: 0.9741853253941993
# Remaining: 160
# Query no. 19
# (200, 106)
# RF R2: 0.9759628400916692
# Remaining: 150
# Query no. 20
# (210, 106)
# RF R2: 0.9761559124838909
# Remaining: 140
# The Iteration is  6
# After Initialization RF R2: 0.8352669223333685
# NN Test R2 after Initialization -0.7393804797347289
# NN R2 -0.7393804797347289
# Query no. 1
# (20, 106)
# RF R2: 0.8132376211097122
# Remaining: 330
# Query no. 2
# (30, 106)
# RF R2: 0.9488331370983152
# Remaining: 320
# Query no. 3
# (40, 106)
# RF R2: 0.9652142941717636
# Remaining: 310
# Query no. 4
# (50, 106)
# RF R2: 0.9635799411804791
# Remaining: 300
# Query no. 5
# (60, 106)
# RF R2: 0.9731859367291359
# Remaining: 290
# Query no. 6
# (70, 106)
# RF R2: 0.9826899050420044
# Remaining: 280
# Query no. 7
# (80, 106)
# RF R2: 0.9850018726369466
# Remaining: 270
# Query no. 8
# (90, 106)
# RF R2: 0.9851836102428052
# Remaining: 260
# Query no. 9
# (100, 106)
# RF R2: 0.9856342667234004
# Remaining: 250
# Query no. 10
# (110, 106)
# RF R2: 0.9837526450222677
# Remaining: 240
# Query no. 11
# (120, 106)
# RF R2: 0.986519141946955
# Remaining: 230
# Query no. 12
# (130, 106)
# RF R2: 0.9874147307803078
# Remaining: 220
# Query no. 13
# (140, 106)
# RF R2: 0.9882700565082749
# Remaining: 210
# Query no. 14
# (150, 106)
# RF R2: 0.9867384113040416
# Remaining: 200
# Query no. 15
# (160, 106)
# RF R2: 0.9889350370306688
# Remaining: 190
# Query no. 16
# (170, 106)
# RF R2: 0.9894407524041174
# Remaining: 180
# Query no. 17
# (180, 106)
# RF R2: 0.9902448251295255
# Remaining: 170
# Query no. 18
# (190, 106)
# RF R2: 0.9893851724083252
# Remaining: 160
# Query no. 19
# (200, 106)
# RF R2: 0.9890813968294628
# Remaining: 150
# Query no. 20
# (210, 106)
# RF R2: 0.9897035346461036
# Remaining: 140
# The Iteration is  7
# After Initialization RF R2: 0.17791194164509938
# NN Test R2 after Initialization -0.8128599651291649
# NN R2 -0.8128599651291649
# Query no. 1
# (20, 106)
# RF R2: 0.7690208372068689
# Remaining: 330
# Query no. 2
# (30, 106)
# RF R2: 0.9278502539966709
# Remaining: 320
# Query no. 3
# (40, 106)
# RF R2: 0.9460866194928037
# Remaining: 310
# Query no. 4
# (50, 106)
# RF R2: 0.9699448553537996
# Remaining: 300
# Query no. 5
# (60, 106)
# RF R2: 0.96919329866093
# Remaining: 290
# Query no. 6
# (70, 106)
# RF R2: 0.9816365539585408
# Remaining: 280
# Query no. 7
# (80, 106)
# RF R2: 0.9828802180136117
# Remaining: 270
# Query no. 8
# (90, 106)
# RF R2: 0.9820534412439943
# Remaining: 260
# Query no. 9
# (100, 106)
# RF R2: 0.9866816988365176
# Remaining: 250
# Query no. 10
# (110, 106)
# RF R2: 0.9858348622476893
# Remaining: 240
# Query no. 11
# (120, 106)
# RF R2: 0.9867300124705837
# Remaining: 230
# Query no. 12
# (130, 106)
# RF R2: 0.9883753618496476
# Remaining: 220
# Query no. 13
# (140, 106)
# RF R2: 0.9892318498820514
# Remaining: 210
# Query no. 14
# (150, 106)
# RF R2: 0.9887541153187583
# Remaining: 200
# Query no. 15
# (160, 106)
# RF R2: 0.9892204465317967
# Remaining: 190
# Query no. 16
# (170, 106)
# RF R2: 0.9894630106091159
# Remaining: 180
# Query no. 17
# (180, 106)
# RF R2: 0.9891072492955764
# Remaining: 170
# Query no. 18
# (190, 106)
# RF R2: 0.9889658123670858
# Remaining: 160
# Query no. 19
# (200, 106)
# RF R2: 0.989549873040626
# Remaining: 150
# Query no. 20
# (210, 106)
# RF R2: 0.9900286517540364
# Remaining: 140
# The Iteration is  8
# After Initialization RF R2: 0.6095709529770197
# NN Test R2 after Initialization -2.858046267957482
# NN R2 -2.858046267957482
# Query no. 1
# (20, 106)
# RF R2: 0.8085384084853489
# Remaining: 330
# Query no. 2
# (30, 106)
# RF R2: 0.9120805397348338
# Remaining: 320
# Query no. 3
# (40, 106)
# RF R2: 0.9524446764919615
# Remaining: 310
# Query no. 4
# (50, 106)
# RF R2: 0.9557971349919852
# Remaining: 300
# Query no. 5
# (60, 106)
# RF R2: 0.9684239486868756
# Remaining: 290
# Query no. 6
# (70, 106)
# RF R2: 0.9707220638561667
# Remaining: 280
# Query no. 7
# (80, 106)
# RF R2: 0.9707961738686837
# Remaining: 270
# Query no. 8
# (90, 106)
# RF R2: 0.9750523766756383
# Remaining: 260
# Query no. 9
# (100, 106)
# RF R2: 0.9764804780885004
# Remaining: 250
# Query no. 10
# (110, 106)
# RF R2: 0.9728153697220926
# Remaining: 240
# Query no. 11
# (120, 106)
# RF R2: 0.9801133904321147
# Remaining: 230
# Query no. 12
# (130, 106)
# RF R2: 0.9819029820892322
# Remaining: 220
# Query no. 13
# (140, 106)
# RF R2: 0.9816213695974846
# Remaining: 210
# Query no. 14
# (150, 106)
# RF R2: 0.9820397899069164
# Remaining: 200
# Query no. 15
# (160, 106)
# RF R2: 0.9818419268432472
# Remaining: 190
# Query no. 16
# (170, 106)
# RF R2: 0.9826307676820115
# Remaining: 180
# Query no. 17
# (180, 106)
# RF R2: 0.9831250983051569
# Remaining: 170
# Query no. 18
# (190, 106)
# RF R2: 0.9828773298278042
# Remaining: 160
# Query no. 19
# (200, 106)
# RF R2: 0.9840525783331436
# Remaining: 150
# Query no. 20
# (210, 106)
# RF R2: 0.983929310333312
# Remaining: 140
# The Iteration is  9
# After Initialization RF R2: 0.43834763970417767
# NN Test R2 after Initialization -0.17652559125980485
# NN R2 -0.17652559125980485
# Query no. 1
# (20, 106)
# RF R2: 0.4732795015037524
# Remaining: 330
# Query no. 2
# (30, 106)
# RF R2: 0.9637965095512304
# Remaining: 320
# Query no. 3
# (40, 106)
# RF R2: 0.9624472436857328
# Remaining: 310
# Query no. 4
# (50, 106)
# RF R2: 0.958830241420917
# Remaining: 300
# Query no. 5
# (60, 106)
# RF R2: 0.9666501626007826
# Remaining: 290
# Query no. 6
# (70, 106)
# RF R2: 0.9729472612842194
# Remaining: 280
# Query no. 7
# (80, 106)
# RF R2: 0.9782773460411123
# Remaining: 270
# Query no. 8
# (90, 106)
# RF R2: 0.9833070741984897
# Remaining: 260
# Query no. 9
# (100, 106)
# RF R2: 0.9850050861853433
# Remaining: 250
# Query no. 10
# (110, 106)
# RF R2: 0.984880081039349
# Remaining: 240
# Query no. 11
# (120, 106)
# RF R2: 0.9846186407930352
# Remaining: 230
# Query no. 12
# (130, 106)
# RF R2: 0.9885124181078486
# Remaining: 220
# Query no. 13
# (140, 106)
# RF R2: 0.9887265504673668
# Remaining: 210
# Query no. 14
# (150, 106)
# RF R2: 0.9883782738211073
# Remaining: 200
# Query no. 15
# (160, 106)
# RF R2: 0.9899996290229812
# Remaining: 190
# Query no. 16
# (170, 106)
# RF R2: 0.989478695002844
# Remaining: 180
# Query no. 17
# (180, 106)
# RF R2: 0.9900542296949502
# Remaining: 170
# Query no. 18
# (190, 106)
# RF R2: 0.9905785224980171
# Remaining: 160
# Query no. 19
# (200, 106)
# RF R2: 0.9892265273794996
# Remaining: 150
# Query no. 20
# (210, 106)
# RF R2: 0.9890741778368912
# Remaining: 140
# The Iteration is  10
# After Initialization RF R2: 0.8494354111694181
# NN Test R2 after Initialization -2.2185690757452545
# NN R2 -2.2185690757452545
# Query no. 1
# (20, 106)
# RF R2: 0.9352118252945569
# Remaining: 330
# Query no. 2
# (30, 106)
# RF R2: 0.9406857068658917
# Remaining: 320
# Query no. 3
# (40, 106)
# RF R2: 0.9497038629127085
# Remaining: 310
# Query no. 4
# (50, 106)
# RF R2: 0.9745301419535133
# Remaining: 300
# Query no. 5
# (60, 106)
# RF R2: 0.9738047360479296
# Remaining: 290
# Query no. 6
# (70, 106)
# RF R2: 0.9779656283726401
# Remaining: 280
# Query no. 7
# (80, 106)
# RF R2: 0.9774894952102002
# Remaining: 270
# Query no. 8
# (90, 106)
# RF R2: 0.9805117894704578
# Remaining: 260
# Query no. 9
# (100, 106)
# RF R2: 0.979139073526261
# Remaining: 250
# Query no. 10
# (110, 106)
# RF R2: 0.9794335564625068
# Remaining: 240
# Query no. 11
# (120, 106)
# RF R2: 0.9792192048739412
# Remaining: 230
# Query no. 12
# (130, 106)
# RF R2: 0.979970036183161
# Remaining: 220
# Query no. 13
# (140, 106)
# RF R2: 0.9805577252476627
# Remaining: 210
# Query no. 14
# (150, 106)
# RF R2: 0.9822912636080032
# Remaining: 200
# Query no. 15
# (160, 106)
# RF R2: 0.9805471617587621
# Remaining: 190
# Query no. 16
# (170, 106)
# RF R2: 0.9843368438161364
# Remaining: 180
# Query no. 17
# (180, 106)
# RF R2: 0.9851092929831656
# Remaining: 170
# Query no. 18
# (190, 106)
# RF R2: 0.9845995251783363
# Remaining: 160
# Query no. 19
# (200, 106)
# RF R2: 0.9847797761436187
# Remaining: 150
# Query no. 20
# (210, 106)
# RF R2: 0.9853909549550807
# Remaining: 140
# The Iteration is  11
# After Initialization RF R2: 0.6638646239409132
# NN Test R2 after Initialization 0.24482339874916448
# NN R2 0.24482339874916448
# Query no. 1
# (20, 106)
# RF R2: 0.9215202594846141
# Remaining: 330
# Query no. 2
# (30, 106)
# RF R2: 0.9451414388002872
# Remaining: 320
# Query no. 3
# (40, 106)
# RF R2: 0.9749924835204711
# Remaining: 310
# Query no. 4
# (50, 106)
# RF R2: 0.9784555508033054
# Remaining: 300
# Query no. 5
# (60, 106)
# RF R2: 0.98102508379293
# Remaining: 290
# Query no. 6
# (70, 106)
# RF R2: 0.9849786628222786
# Remaining: 280
# Query no. 7
# (80, 106)
# RF R2: 0.9863672039140597
# Remaining: 270
# Query no. 8
# (90, 106)
# RF R2: 0.9882734596016025
# Remaining: 260
# Query no. 9
# (100, 106)
# RF R2: 0.9836124933773334
# Remaining: 250
# Query no. 10
# (110, 106)
# RF R2: 0.987049109156151
# Remaining: 240
# Query no. 11
# (120, 106)
# RF R2: 0.9850663450255263
# Remaining: 230
# Query no. 12
# (130, 106)
# RF R2: 0.9884470025885158
# Remaining: 220
# Query no. 13
# (140, 106)
# RF R2: 0.9883957685070273
# Remaining: 210
# Query no. 14
# (150, 106)
# RF R2: 0.9902106623084814
# Remaining: 200
# Query no. 15
# (160, 106)
# RF R2: 0.9905246140601827
# Remaining: 190
# Query no. 16
# (170, 106)
# RF R2: 0.9906730630980974
# Remaining: 180
# Query no. 17
# (180, 106)
# RF R2: 0.9901642306413846
# Remaining: 170
# Query no. 18
# (190, 106)
# RF R2: 0.9915710510700186
# Remaining: 160
# Query no. 19
# (200, 106)
# RF R2: 0.9910693634955119
# Remaining: 150
# Query no. 20
# (210, 106)
# RF R2: 0.9912740199757502
# Remaining: 140
# The Iteration is  12
# After Initialization RF R2: 0.6466958150069699
# NN Test R2 after Initialization -0.7158271818851446
# NN R2 -0.7158271818851446
# Query no. 1
# (20, 106)
# RF R2: 0.8241232873029991
# Remaining: 330
# Query no. 2
# (30, 106)
# RF R2: 0.8505753710432616
# Remaining: 320
# Query no. 3
# (40, 106)
# RF R2: 0.9421000361685181
# Remaining: 310
# Query no. 4
# (50, 106)
# RF R2: 0.9693374843753005
# Remaining: 300
# Query no. 5
# (60, 106)
# RF R2: 0.9695791981937282
# Remaining: 290
# Query no. 6
# (70, 106)
# RF R2: 0.973223609177385
# Remaining: 280
# Query no. 7
# (80, 106)
# RF R2: 0.9798375762506742
# Remaining: 270
# Query no. 8
# (90, 106)
# RF R2: 0.985448831419886
# Remaining: 260
# Query no. 9
# (100, 106)
# RF R2: 0.9867201775831561
# Remaining: 250
# Query no. 10
# (110, 106)
# RF R2: 0.9856933201598677
# Remaining: 240
# Query no. 11
# (120, 106)
# RF R2: 0.9883072820127126
# Remaining: 230
# Query no. 12
# (130, 106)
# RF R2: 0.9843964521984808
# Remaining: 220
# Query no. 13
# (140, 106)
# RF R2: 0.9851128897417695
# Remaining: 210
# Query no. 14
# (150, 106)
# RF R2: 0.9855678637190664
# Remaining: 200
# Query no. 15
# (160, 106)
# RF R2: 0.985615466813695
# Remaining: 190
# Query no. 16
# (170, 106)
# RF R2: 0.9882011785835763
# Remaining: 180
# Query no. 17
# (180, 106)
# RF R2: 0.9860316361171663
# Remaining: 170
# Query no. 18
# (190, 106)
# RF R2: 0.9861751632201703
# Remaining: 160
# Query no. 19
# (200, 106)
# RF R2: 0.9877473533104848
# Remaining: 150
# Query no. 20
# (210, 106)
# RF R2: 0.9887343215883632
# Remaining: 140
# The Iteration is  13
# After Initialization RF R2: 0.5674278885439886
# NN Test R2 after Initialization -2.3170355695103204
# NN R2 -2.3170355695103204
# Query no. 1
# (20, 106)
# RF R2: 0.8936314526455281
# Remaining: 330
# Query no. 2
# (30, 106)
# RF R2: 0.9125687719935287
# Remaining: 320
# Query no. 3
# (40, 106)
# RF R2: 0.9253693742799322
# Remaining: 310
# Query no. 4
# (50, 106)
# RF R2: 0.9616444029174867
# Remaining: 300
# Query no. 5
# (60, 106)
# RF R2: 0.9665915639402919
# Remaining: 290
# Query no. 6
# (70, 106)
# RF R2: 0.9703497473364566
# Remaining: 280
# Query no. 7
# (80, 106)
# RF R2: 0.9785225088109973
# Remaining: 270
# Query no. 8
# (90, 106)
# RF R2: 0.9827967753397602
# Remaining: 260
# Query no. 9
# (100, 106)
# RF R2: 0.9843150972113238
# Remaining: 250
# Query no. 10
# (110, 106)
# RF R2: 0.9843874213293122
# Remaining: 240
# Query no. 11
# (120, 106)
# RF R2: 0.9847228787685757
# Remaining: 230
# Query no. 12
# (130, 106)
# RF R2: 0.984781335032227
# Remaining: 220
# Query no. 13
# (140, 106)
# RF R2: 0.9871919210895975
# Remaining: 210
# Query no. 14
# (150, 106)
# RF R2: 0.9870402574899246
# Remaining: 200
# Query no. 15
# (160, 106)
# RF R2: 0.9859211384048239
# Remaining: 190
# Query no. 16
# (170, 106)
# RF R2: 0.9867804920588253
# Remaining: 180
# Query no. 17
# (180, 106)
# RF R2: 0.9876931173732965
# Remaining: 170
# Query no. 18
# (190, 106)
# RF R2: 0.9875762227350408
# Remaining: 160
# Query no. 19
# (200, 106)
# RF R2: 0.9883405207777928
# Remaining: 150
# Query no. 20
# (210, 106)
# RF R2: 0.9882095883057028
# Remaining: 140
# The Iteration is  14
# After Initialization RF R2: 0.7921076302914161
# NN Test R2 after Initialization -0.004928833717009547
# NN R2 -0.004928833717009547
# Query no. 1
# (20, 106)
# RF R2: 0.9181645332705203
# Remaining: 330
# Query no. 2
# (30, 106)
# RF R2: 0.9227104546860033
# Remaining: 320
# Query no. 3
# (40, 106)
# RF R2: 0.9676891343296486
# Remaining: 310
# Query no. 4
# (50, 106)
# RF R2: 0.9684059229582412
# Remaining: 300
# Query no. 5
# (60, 106)
# RF R2: 0.9706990354520434
# Remaining: 290
# Query no. 6
# (70, 106)
# RF R2: 0.9518312839500567
# Remaining: 280
# Query no. 7
# (80, 106)
# RF R2: 0.9426616421033205
# Remaining: 270
# Query no. 8
# (90, 106)
# RF R2: 0.9678387471062831
# Remaining: 260
# Query no. 9
# (100, 106)
# RF R2: 0.9695930992635137
# Remaining: 250
# Query no. 10
# (110, 106)
# RF R2: 0.9673993884970721
# Remaining: 240
# Query no. 11
# (120, 106)
# RF R2: 0.9656113561540267
# Remaining: 230
# Query no. 12
# (130, 106)
# RF R2: 0.9774709328680514
# Remaining: 220
# Query no. 13
# (140, 106)
# RF R2: 0.9781674645453052
# Remaining: 210
# Query no. 14
# (150, 106)
# RF R2: 0.9764319346499728
# Remaining: 200
# Query no. 15
# (160, 106)
# RF R2: 0.9751009141084488
# Remaining: 190
# Query no. 16
# (170, 106)
# RF R2: 0.976825724830357
# Remaining: 180
# Query no. 17
# (180, 106)
# RF R2: 0.9855177725665715
# Remaining: 170
# Query no. 18
# (190, 106)
# RF R2: 0.9846665640020207
# Remaining: 160
# Query no. 19
# (200, 106)
# RF R2: 0.9858928813373278
# Remaining: 150
# Query no. 20
# (210, 106)
# RF R2: 0.985896953494225
# Remaining: 140
# The Iteration is  15
# After Initialization RF R2: 0.753942088976388
# NN Test R2 after Initialization -4.089654076183772
# NN R2 -4.089654076183772
# Query no. 1
# (20, 106)
# RF R2: 0.9280455804993628
# Remaining: 330
# Query no. 2
# (30, 106)
# RF R2: 0.9275464304939384
# Remaining: 320
# Query no. 3
# (40, 106)
# RF R2: 0.955793212767961
# Remaining: 310
# Query no. 4
# (50, 106)
# RF R2: 0.9723371016189635
# Remaining: 300
# Query no. 5
# (60, 106)
# RF R2: 0.9711387091924236
# Remaining: 290
# Query no. 6
# (70, 106)
# RF R2: 0.9760050032327001
# Remaining: 280
# Query no. 7
# (80, 106)
# RF R2: 0.9802576235412724
# Remaining: 270
# Query no. 8
# (90, 106)
# RF R2: 0.9775455398500295
# Remaining: 260
# Query no. 9
# (100, 106)
# RF R2: 0.9760114108988418
# Remaining: 250
# Query no. 10
# (110, 106)
# RF R2: 0.9807285394651303
# Remaining: 240
# Query no. 11
# (120, 106)
# RF R2: 0.9822824416898097
# Remaining: 230
# Query no. 12
# (130, 106)
# RF R2: 0.9810901240707869
# Remaining: 220
# Query no. 13
# (140, 106)
# RF R2: 0.9838418574549306
# Remaining: 210
# Query no. 14
# (150, 106)
# RF R2: 0.9846704638376569
# Remaining: 200
# Query no. 15
# (160, 106)
# RF R2: 0.9841412921881499
# Remaining: 190
# Query no. 16
# (170, 106)
# RF R2: 0.9847919284502431
# Remaining: 180
# Query no. 17
# (180, 106)
# RF R2: 0.9850600834631872
# Remaining: 170
# Query no. 18
# (190, 106)
# RF R2: 0.9869219149057574
# Remaining: 160
# Query no. 19
# (200, 106)
# RF R2: 0.9855497112045923
# Remaining: 150
# Query no. 20
# (210, 106)
# RF R2: 0.985617734184824
# Remaining: 140
# The Iteration is  16
# After Initialization RF R2: 0.8111726626583708
# NN Test R2 after Initialization -3.734404998378134
# NN R2 -3.734404998378134
# Query no. 1
# (20, 106)
# RF R2: 0.8983391550480089
# Remaining: 330
# Query no. 2
# (30, 106)
# RF R2: 0.9038293021094758
# Remaining: 320
# Query no. 3
# (40, 106)
# RF R2: 0.9441578693959304
# Remaining: 310
# Query no. 4
# (50, 106)
# RF R2: 0.9555671550643114
# Remaining: 300
# Query no. 5
# (60, 106)
# RF R2: 0.9710692470099405
# Remaining: 290
# Query no. 6
# (70, 106)
# RF R2: 0.9686607620590476
# Remaining: 280
# Query no. 7
# (80, 106)
# RF R2: 0.974137557400592
# Remaining: 270
# Query no. 8
# (90, 106)
# RF R2: 0.9745493143479383
# Remaining: 260
# Query no. 9
# (100, 106)
# RF R2: 0.9695149878269878
# Remaining: 250
# Query no. 10
# (110, 106)
# RF R2: 0.9764456668814006
# Remaining: 240
# Query no. 11
# (120, 106)
# RF R2: 0.9780771603067593
# Remaining: 230
# Query no. 12
# (130, 106)
# RF R2: 0.9793658019517669
# Remaining: 220
# Query no. 13
# (140, 106)
# RF R2: 0.9754107355876808
# Remaining: 210
# Query no. 14
# (150, 106)
# RF R2: 0.9741423330949528
# Remaining: 200
# Query no. 15
# (160, 106)
# RF R2: 0.9750732622742201
# Remaining: 190
# Query no. 16
# (170, 106)
# RF R2: 0.9773343551973712
# Remaining: 180
# Query no. 17
# (180, 106)
# RF R2: 0.9758678861240948
# Remaining: 170
# Query no. 18
# (190, 106)
# RF R2: 0.9794246971950236
# Remaining: 160
# Query no. 19
# (200, 106)
# RF R2: 0.9751504494122234
# Remaining: 150
# Query no. 20
# (210, 106)
# RF R2: 0.9776638357602226
# Remaining: 140
# The Iteration is  17
# After Initialization RF R2: 0.39199152726614717
# NN Test R2 after Initialization -2.644687921808389
# NN R2 -2.644687921808389
# Query no. 1
# (20, 106)
# RF R2: 0.9010824569371194
# Remaining: 330
# Query no. 2
# (30, 106)
# RF R2: 0.925650086224243
# Remaining: 320
# Query no. 3
# (40, 106)
# RF R2: 0.9660961255371827
# Remaining: 310
# Query no. 4
# (50, 106)
# RF R2: 0.9627214252145524
# Remaining: 300
# Query no. 5
# (60, 106)
# RF R2: 0.9627434231961891
# Remaining: 290
# Query no. 6
# (70, 106)
# RF R2: 0.9705912353599406
# Remaining: 280
# Query no. 7
# (80, 106)
# RF R2: 0.9759703811678743
# Remaining: 270
# Query no. 8
# (90, 106)
# RF R2: 0.973811658165258
# Remaining: 260
# Query no. 9
# (100, 106)
# RF R2: 0.974817464087248
# Remaining: 250
# Query no. 10
# (110, 106)
# RF R2: 0.9736291164187916
# Remaining: 240
# Query no. 11
# (120, 106)
# RF R2: 0.9736764140702843
# Remaining: 230
# Query no. 12
# (130, 106)
# RF R2: 0.9730215093292872
# Remaining: 220
# Query no. 13
# (140, 106)
# RF R2: 0.9765703624335869
# Remaining: 210
# Query no. 14
# (150, 106)
# RF R2: 0.9791053994945901
# Remaining: 200
# Query no. 15
# (160, 106)
# RF R2: 0.9804164782454667
# Remaining: 190
# Query no. 16
# (170, 106)
# RF R2: 0.978742299489544
# Remaining: 180
# Query no. 17
# (180, 106)
# RF R2: 0.980202436466213
# Remaining: 170
# Query no. 18
# (190, 106)
# RF R2: 0.9816823563901343
# Remaining: 160
# Query no. 19
# (200, 106)
# RF R2: 0.9807092847033823
# Remaining: 150
# Query no. 20
# (210, 106)
# RF R2: 0.9810879127440049
# Remaining: 140
# The Iteration is  18
# After Initialization RF R2: 0.09404685958280257
# NN Test R2 after Initialization -0.49173870362153943
# NN R2 -0.49173870362153943
# Query no. 1
# (20, 106)
# RF R2: 0.8736851433851316
# Remaining: 330
# Query no. 2
# (30, 106)
# RF R2: 0.8795344333790879
# Remaining: 320
# Query no. 3
# (40, 106)
# RF R2: 0.8708587233777636
# Remaining: 310
# Query no. 4
# (50, 106)
# RF R2: 0.875247425599062
# Remaining: 300
# Query no. 5
# (60, 106)
# RF R2: 0.8796009773801017
# Remaining: 290
# Query no. 6
# (70, 106)
# RF R2: 0.8926884424624693
# Remaining: 280
# Query no. 7
# (80, 106)
# RF R2: 0.8854179557130749
# Remaining: 270
# Query no. 8
# (90, 106)
# RF R2: 0.8888146237980276
# Remaining: 260
# Query no. 9
# (100, 106)
# RF R2: 0.8983560090720534
# Remaining: 250
# Query no. 10
# (110, 106)
# RF R2: 0.8954332785716352
# Remaining: 240
# Query no. 11
# (120, 106)
# RF R2: 0.8995795533249082
# Remaining: 230
# Query no. 12
# (130, 106)
# RF R2: 0.9029531336225975
# Remaining: 220
# Query no. 13
# (140, 106)
# RF R2: 0.8994255277872756
# Remaining: 210
# Query no. 14
# (150, 106)
# RF R2: 0.9035974889288737
# Remaining: 200
# Query no. 15
# (160, 106)
# RF R2: 0.9081677506487789
# Remaining: 190
# Query no. 16
# (170, 106)
# RF R2: 0.9096419906065824
# Remaining: 180
# Query no. 17
# (180, 106)
# RF R2: 0.90649436753885
# Remaining: 170
# Query no. 18
# (190, 106)
# RF R2: 0.9070906026007844
# Remaining: 160
# Query no. 19
# (200, 106)
# RF R2: 0.9067879309099948
# Remaining: 150
# Query no. 20
# (210, 106)
# RF R2: 0.9072940473799834
# Remaining: 140
# The Iteration is  19
# After Initialization RF R2: 0.5694356525358997
# NN Test R2 after Initialization -4.587897088723148
# NN R2 -4.587897088723148
# Query no. 1
# (20, 106)
# RF R2: 0.734227271969855
# Remaining: 330
# Query no. 2
# (30, 106)
# RF R2: 0.94754675901054
# Remaining: 320
# Query no. 3
# (40, 106)
# RF R2: 0.9331245110234002
# Remaining: 310
# Query no. 4
# (50, 106)
# RF R2: 0.9638195787544078
# Remaining: 300
# Query no. 5
# (60, 106)
# RF R2: 0.9627015544760031
# Remaining: 290
# Query no. 6
# (70, 106)
# RF R2: 0.9671318176021363
# Remaining: 280
# Query no. 7
# (80, 106)
# RF R2: 0.9699605811284757
# Remaining: 270
# Query no. 8
# (90, 106)
# RF R2: 0.973701057177493
# Remaining: 260
# Query no. 9
# (100, 106)
# RF R2: 0.9738317497152508
# Remaining: 250
# Query no. 10
# (110, 106)
# RF R2: 0.9756102513604215
# Remaining: 240
# Query no. 11
# (120, 106)
# RF R2: 0.9792710527837385
# Remaining: 230
# Query no. 12
# (130, 106)
# RF R2: 0.9779303631742934
# Remaining: 220
# Query no. 13
# (140, 106)
# RF R2: 0.9819559077337376
# Remaining: 210
# Query no. 14
# (150, 106)
# RF R2: 0.9797604031560099
# Remaining: 200
# Query no. 15
# (160, 106)
# RF R2: 0.9783612142079311
# Remaining: 190
# Query no. 16
# (170, 106)
# RF R2: 0.9790745173785458
# Remaining: 180
# Query no. 17
# (180, 106)
# RF R2: 0.9817168242058301
# Remaining: 170
# Query no. 18
# (190, 106)
# RF R2: 0.9821946118125535
# Remaining: 160
# Query no. 19
# (200, 106)
# RF R2: 0.9820015364224401
# Remaining: 150
# Query no. 20
# (210, 106)
# RF R2: 0.9819344122925318
# Remaining: 140
