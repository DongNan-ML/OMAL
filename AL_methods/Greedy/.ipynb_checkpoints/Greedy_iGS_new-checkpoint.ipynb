# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from modAL.models import ActiveLearner, CommitteeRegressor
from modAL.disagreement import vote_entropy_sampling, max_std_sampling
import matplotlib.pyplot as plt
import torch
from torch.nn import MSELoss
from skorch.regressor import NeuralNetRegressor
from copy import deepcopy
from skorch.dataset import ValidSplit
from skorch.callbacks import EarlyStopping
from sklearn.cluster import DBSCAN, OPTICS, cluster_optics_dbscan, Birch, SpectralClustering
from sklearn.neighbors import NearestNeighbors
from sklearn import metrics
import matplotlib.gridspec as gridspec
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from torch.nn import Linear
from torch.nn import Sigmoid, ReLU
from torch.nn import Module
from sklearn.metrics import r2_score
import copy
from scipy.spatial import distance
from scipy.spatial.distance import euclidean
from torch import tensor
from sklearn.metrics import mean_squared_error
from scipy.spatial.distance import cdist
from sklearn.ensemble import RandomForestRegressor
from torch.nn.init import xavier_uniform_
from model import MLP
import random
from skorch.callbacks import EarlyStopping, LRScheduler, Freezer, Unfreezer
from torch.optim.lr_scheduler import CyclicLR, ReduceLROnPlateau
from skorch.regressor import NeuralNetRegressor, NeuralNet
from modAL.utils.selection import multi_argmax
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin_min

# %%
query_number = 20          # The number of the AL Iterations in each Exp
iteration = 20             # Total number of the Exps
batch_size = 10
total_initail_size = 10
initial_size = 5

seed_rf = np.load(file="..\..\Datasets\Diabetes\seed_for_RF.npy")
seed_initial = np.load(file="..\..\Datasets\Diabetes\seed_for_initialSamples.npy")

seed_nn1 = np.load(file="..\..\Results\Res_Diabetes\Greedy\seed_for_nn1.npy")
seed_nn2 = np.load(file="..\..\Results\Res_Diabetes\Greedy\seed_for_nn2.npy")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def get_closest_dist(unlabeled_data, labeled_data):

    # Should be global info instead of within the clusters
    d = cdist(unlabeled_data, labeled_data, 'euclidean')
    d_x_min = d.min(axis=1)

    return d_x_min

def get_closest_dist_xy(unlabeled_predictions, labeled_data_label, unlabeled_data, labeled_data):

    d_y = cdist(np.array(unlabeled_predictions).reshape(-1, 1), labeled_data_label, 'euclidean')
    d_x = cdist(unlabeled_data, labeled_data, 'euclidean')
    d_xy = np.multiply(d_x, d_y)
    d_xy_min = d_xy.min(axis=1)

    return d_xy_min

def custom_query_strategy(used_data, X_pool, prediction_, used_label, n_instances):
    d_xy = get_closest_dist_xy(prediction_, used_label, X_pool, used_data)
    utility = d_xy
    return multi_argmax(utility, n_instances=n_instances)

# %%
def main_function(query_number, iters):
    # For saving results:
    rf_model_training_r2 = []
    rf_model_training_mse = []
    rf_model_testing_r2 = []
    rf_model_testing_mse = []
    
    # The model for evaluation:
    rf_model = RandomForestRegressor(random_state=seed_rf[iters], n_estimators=100)

    # Load the data:
    name1 = "..\..\Datasets\Diabetes\X_train" + str(iters) + ".npy"
    name2 = "..\..\Datasets\Diabetes\X_test" + str(iters) + ".npy"
    name3 = "..\..\Datasets\Diabetes\y_train" + str(iters) + ".npy"
    name4 = "..\..\Datasets\Diabetes\y_test" + str(iters) + ".npy"
    
    X_train = np.load(name1, allow_pickle=True).astype(np.float32)
    X_test = np.load(name2, allow_pickle=True).astype(np.float32)
    y_train = np.load(name3, allow_pickle=True).astype(np.float32).reshape(-1, 1)
    y_test = np.load(name4, allow_pickle=True).astype(np.float32).reshape(-1, 1)
    
    # Feature Dim；
    X = X_train.shape[1]
    # The unlabeled pool
    X_index = np.arange(X_train.shape[0])
    
    # Queried samples and labels
    used_data = np.empty(shape=(0, X))
    used_label = np.empty(shape=(0)).reshape(-1, 1)
    
    # Initial samples and labels
    X_initial = np.empty(shape=(0,X))
    y_initial = np.empty(shape=(0)).reshape(-1, 1)

    # Initial Stage 1:
    np.random.seed(seed_initial[iters])
    idx = np.random.choice(range(len(X_index)), size=initial_size, replace=False)
    train_idx = X_index[idx]

    X_initial = X_train[train_idx]
    y_initial = y_train[train_idx].reshape(-1, 1)

    used_data = np.append(used_data, X_initial, axis=0).astype(np.float32)
    used_label = np.append(used_label, y_initial, axis=0).astype(np.float32).reshape(-1, 1)
    X_index = np.delete(X_index, idx, axis=0)
    
    # Initial Sagte 2:
    rest_initial_X = np.empty(shape=(0,X))
    rest_initial_y = np.empty(shape=(0)).reshape(-1, 1)
    
    np.random.seed(seed_initial[iters])
    idx = np.random.choice(range(len(X_index)), size=total_initail_size-initial_size, replace=False)
    train_idx = X_index[idx]
    
    rest_initial_X = np.append(rest_initial_X, X_train[train_idx], axis=0).astype(np.float32)
    rest_initial_y = np.append(rest_initial_y, y_train[train_idx], axis=0).astype(np.float32).reshape(-1, 1)

    X_index = np.delete(X_index, idx, axis=0)
    
    used_data = np.append(used_data, rest_initial_X, axis=0).astype(np.float32)
    used_label = np.append(used_label, rest_initial_y, axis=0).astype(np.float32).reshape(-1, 1)
    
    # Finished the Initialization Stages:
    # RF Regressor for evaluation:
    rf_model.fit(used_data, used_label.ravel())
    # Training Scores:
    rf_training_r2 = r2_score(used_label, rf_model.predict(used_data))
    rf_training_mse = mean_squared_error(used_label, rf_model.predict(used_data))
    rf_model_training_r2.append(rf_training_r2)
    rf_model_training_mse.append(rf_training_mse)
    
    # Test Scores:
    rf_model_r2 = r2_score(y_test, rf_model.predict(X_test))
    rf_model_mse = mean_squared_error(y_test, rf_model.predict(X_test))
    rf_model_testing_r2.append(rf_model_r2)
    rf_model_testing_mse.append(rf_model_mse)
    
    np.random.seed(seed_nn1[iters])
    torch.manual_seed(seed_nn2[iters])
    predictor = NeuralNetRegressor(MLP(X),
                                   criterion=MSELoss(),
                                   optimizer=torch.optim.Adam,
                                   verbose=0,
                                   max_epochs=100,
                                   lr=0.001,
                                   # Used for the batch AL
                                   callbacks=[EarlyStopping(patience=20), ('lr_scheduler', LRScheduler(policy=ReduceLROnPlateau))],
                                   train_split=ValidSplit(cv=5),
                                   warm_start=False,
                                   device='cuda',
                                   batch_size = -1
                                   )
    used_data = torch.from_numpy(used_data).to(device)
    used_label = torch.from_numpy(used_label).to(device)
    # Train:
    predictor.fit(used_data, used_label)
    print("NN Initialization Scores:", r2_score(y_test, predictor.predict(X_test)))
    
    print("After Initialization RF R2:", rf_model_r2)

    for idx in range(query_number):
        np.random.seed(None)
        
        print('Query no. %d' % (idx+1))
        
        used_data = used_data.cpu().numpy()
        used_label = used_label.cpu().numpy()
        predictions = predictor.predict(torch.from_numpy(X_train[X_index]).to(device))
        idx = custom_query_strategy(used_data, X_train[X_index], predictions, used_label, batch_size)

        # Query the new sample:
        X_train_index = X_index[idx]

        new_X = X_train[X_train_index].reshape(batch_size, -1)
        new_y = y_train[X_train_index].reshape(batch_size, -1)

        # Adding the used data to the used_data pool
        
        used_data = np.append(used_data, new_X, axis=0).astype(np.float32)
        used_label = np.append(used_label, new_y, axis=0).astype(np.float32).reshape(-1, 1)

        # RF Evaluation
        rf_model.fit(used_data, used_label.ravel())
        
        # Training Evaluation:
        rf_training_r2 = r2_score(used_label, rf_model.predict(used_data))
        rf_training_mse = mean_squared_error(used_label, rf_model.predict(used_data))
        rf_model_training_r2.append(rf_training_r2)
        rf_model_training_mse.append(rf_training_mse)
        
        # Test Evaluation:
        rf_model_r2 = r2_score(y_test, rf_model.predict(X_test))
        rf_model_mse = mean_squared_error(y_test, rf_model.predict(X_test))
        rf_model_testing_r2.append(rf_model_r2)
        rf_model_testing_mse.append(rf_model_mse)

        # remove queried instance from pool
        X_index = np.delete(X_index, idx, axis=0)
        
        print(np.unique(used_data, axis=0).shape)
        print("RF R2:", rf_model_r2)
        print("Remaining:", X_index.shape[0])
        
        used_data = torch.from_numpy(used_data).to(device)
        used_label = torch.from_numpy(used_label).to(device)
        predictor.fit(used_data, used_label)


    # RF
    rf_model_testing_r2 = np.array(rf_model_testing_r2)
    rf_model_testing_mse = np.array(rf_model_testing_mse)
    rf_model_training_r2 = np.array(rf_model_training_r2)
    rf_model_training_mse = np.array(rf_model_training_mse)
    
    used_data = used_data.cpu().numpy()
    used_label = used_label.cpu().numpy()
    # Used_data and Unsed_label:
    np.save(file="..\..\Results\Res_Diabetes\Greedy2\Summary\\used_data" + str(iters) + ".npy", arr=used_data)
    np.save(file="..\..\Results\Res_Diabetes\Greedy2\Summary\\used_labels" + str(iters) + ".npy", arr=used_label)

    np.save(file="..\..\Results\Res_Diabetes\Greedy2\Summary\\testing_rf_r2_" + str(iters) + ".npy", arr=rf_model_testing_r2)
    np.save(file="..\..\Results\Res_Diabetes\Greedy2\Summary\\testing_rf_mse_" + str(iters) + ".npy", arr=rf_model_testing_mse)
    np.save(file="..\..\Results\Res_Diabetes\Greedy2\Summary\\training_rf_r2_" + str(iters) + ".npy", arr=rf_model_training_r2)
    np.save(file="..\..\Results\Res_Diabetes\Greedy2\Summary\\training_rf_mse_" + str(iters) + ".npy", arr=rf_model_training_mse)

# %%
for i in range(iteration):
    print("The Iteration is ", i)
    main_function(query_number, i)
# Out:
# The Iteration is  0
# NN Initialization Scores: -3.2422731860502036
# After Initialization RF R2: 0.01017105099476967
# Query no. 1
# (20, 10)
# RF R2: 0.48304157895085165
# Remaining: 333
# Query no. 2
# (30, 10)
# RF R2: 0.5714862872658582
# Remaining: 323
# Query no. 3
# (40, 10)
# RF R2: 0.5949979996593167
# Remaining: 313
# Query no. 4
# (50, 10)
# RF R2: 0.5693127008570722
# Remaining: 303
# Query no. 5
# (60, 10)
# RF R2: 0.5461208839730671
# Remaining: 293
# Query no. 6
# (70, 10)
# RF R2: 0.594414152203385
# Remaining: 283
# Query no. 7
# (80, 10)
# RF R2: 0.5205894756324336
# Remaining: 273
# Query no. 8
# (90, 10)
# RF R2: 0.507962002242406
# Remaining: 263
# Query no. 9
# (100, 10)
# RF R2: 0.5255922619405471
# Remaining: 253
# Query no. 10
# (110, 10)
# RF R2: 0.5298628136891241
# Remaining: 243
# Query no. 11
# (120, 10)
# RF R2: 0.5612654882332793
# Remaining: 233
# Query no. 12
# (130, 10)
# RF R2: 0.5406164416936843
# Remaining: 223
# Query no. 13
# (140, 10)
# RF R2: 0.559307287297435
# Remaining: 213
# Query no. 14
# (150, 10)
# RF R2: 0.535225759674288
# Remaining: 203
# Query no. 15
# (160, 10)
# RF R2: 0.5403395615081096
# Remaining: 193
# Query no. 16
# (170, 10)
# RF R2: 0.5307429374229975
# Remaining: 183
# Query no. 17
# (180, 10)
# RF R2: 0.5114446896505325
# Remaining: 173
# Query no. 18
# (190, 10)
# RF R2: 0.507020786141865
# Remaining: 163
# Query no. 19
# (200, 10)
# RF R2: 0.5124429582297099
# Remaining: 153
# Query no. 20
# (210, 10)
# RF R2: 0.5559576410936523
# Remaining: 143
# The Iteration is  1
# NN Initialization Scores: -3.233442004943111
# After Initialization RF R2: 0.20844341964741697
# Query no. 1
# (20, 10)
# RF R2: 0.3530320211636263
# Remaining: 333
# Query no. 2
# (30, 10)
# RF R2: 0.34166737163911187
# Remaining: 323
# Query no. 3
# (40, 10)
# RF R2: 0.37448946862965926
# Remaining: 313
# Query no. 4
# (50, 10)
# RF R2: 0.33907086689843724
# Remaining: 303
# Query no. 5
# (60, 10)
# RF R2: 0.43174820419554116
# Remaining: 293
# Query no. 6
# (70, 10)
# RF R2: 0.4449699210115624
# Remaining: 283
# Query no. 7
# (80, 10)
# RF R2: 0.4395839893236455
# Remaining: 273
# Query no. 8
# (90, 10)
# RF R2: 0.47605083967125406
# Remaining: 263
# Query no. 9
# (100, 10)
# RF R2: 0.45645053547306214
# Remaining: 253
# Query no. 10
# (110, 10)
# RF R2: 0.44208662934101706
# Remaining: 243
# Query no. 11
# (120, 10)
# RF R2: 0.4547620464828669
# Remaining: 233
# Query no. 12
# (130, 10)
# RF R2: 0.446257566607682
# Remaining: 223
# Query no. 13
# (140, 10)
# RF R2: 0.4482180129690905
# Remaining: 213
# Query no. 14
# (150, 10)
# RF R2: 0.45543900699366335
# Remaining: 203
# Query no. 15
# (160, 10)
# RF R2: 0.44950940876366585
# Remaining: 193
# Query no. 16
# (170, 10)
# RF R2: 0.4839971771229533
# Remaining: 183
# Query no. 17
# (180, 10)
# RF R2: 0.46941150612420546
# Remaining: 173
# Query no. 18
# (190, 10)
# RF R2: 0.4832067628495894
# Remaining: 163
# Query no. 19
# (200, 10)
# RF R2: 0.4976672246845192
# Remaining: 153
# Query no. 20
# (210, 10)
# RF R2: 0.4961344120274477
# Remaining: 143
# The Iteration is  2
# NN Initialization Scores: -3.63361462224222
# After Initialization RF R2: 0.2925063658507443
# Query no. 1
# (20, 10)
# RF R2: 0.34992103118768125
# Remaining: 333
# Query no. 2
# (30, 10)
# RF R2: 0.46138115555406367
# Remaining: 323
# Query no. 3
# (40, 10)
# RF R2: 0.48174900374337304
# Remaining: 313
# Query no. 4
# (50, 10)
# RF R2: 0.4452688468220254
# Remaining: 303
# Query no. 5
# (60, 10)
# RF R2: 0.4374944207041219
# Remaining: 293
# Query no. 6
# (70, 10)
# RF R2: 0.4478795884287715
# Remaining: 283
# Query no. 7
# (80, 10)
# RF R2: 0.4517686350070741
# Remaining: 273
# Query no. 8
# (90, 10)
# RF R2: 0.47205834725361406
# Remaining: 263
# Query no. 9
# (100, 10)
# RF R2: 0.474295029491382
# Remaining: 253
# Query no. 10
# (110, 10)
# RF R2: 0.46773492397929906
# Remaining: 243
# Query no. 11
# (120, 10)
# RF R2: 0.4737368094824369
# Remaining: 233
# Query no. 12
# (130, 10)
# RF R2: 0.4357740478095983
# Remaining: 223
# Query no. 13
# (140, 10)
# RF R2: 0.4365429452961126
# Remaining: 213
# Query no. 14
# (150, 10)
# RF R2: 0.43772927098840264
# Remaining: 203
# Query no. 15
# (160, 10)
# RF R2: 0.45186371432169503
# Remaining: 193
# Query no. 16
# (170, 10)
# RF R2: 0.44321475994617654
# Remaining: 183
# Query no. 17
# (180, 10)
# RF R2: 0.47185007238401167
# Remaining: 173
# Query no. 18
# (190, 10)
# RF R2: 0.44646641097184236
# Remaining: 163
# Query no. 19
# (200, 10)
# RF R2: 0.4098637210441949
# Remaining: 153
# Query no. 20
# (210, 10)
# RF R2: 0.45010617152366295
# Remaining: 143
# The Iteration is  3
# NN Initialization Scores: -4.197653991544949
# After Initialization RF R2: 0.36481536421176197
# Query no. 1
# (20, 10)
# RF R2: 0.35766898807853154
# Remaining: 333
# Query no. 2
# (30, 10)
# RF R2: 0.3047221730025008
# Remaining: 323
# Query no. 3
# (40, 10)
# RF R2: 0.4259097935848781
# Remaining: 313
# Query no. 4
# (50, 10)
# RF R2: 0.32487312359695164
# Remaining: 303
# Query no. 5
# (60, 10)
# RF R2: 0.32679862763264544
# Remaining: 293
# Query no. 6
# (70, 10)
# RF R2: 0.4360856953545562
# Remaining: 283
# Query no. 7
# (80, 10)
# RF R2: 0.42106016152179593
# Remaining: 273
# Query no. 8
# (90, 10)
# RF R2: 0.4497428936623017
# Remaining: 263
# Query no. 9
# (100, 10)
# RF R2: 0.4430439229153913
# Remaining: 253
# Query no. 10
# (110, 10)
# RF R2: 0.4654975741443945
# Remaining: 243
# Query no. 11
# (120, 10)
# RF R2: 0.5017088780980311
# Remaining: 233
# Query no. 12
# (130, 10)
# RF R2: 0.49075102920431257
# Remaining: 223
# Query no. 13
# (140, 10)
# RF R2: 0.4514493532826833
# Remaining: 213
# Query no. 14
# (150, 10)
# RF R2: 0.4797143808092704
# Remaining: 203
# Query no. 15
# (160, 10)
# RF R2: 0.523830178670838
# Remaining: 193
# Query no. 16
# (170, 10)
# RF R2: 0.491542701467361
# Remaining: 183
# Query no. 17
# (180, 10)
# RF R2: 0.5009753942345713
# Remaining: 173
# Query no. 18
# (190, 10)
# RF R2: 0.4942732506646268
# Remaining: 163
# Query no. 19
# (200, 10)
# RF R2: 0.5200140252769543
# Remaining: 153
# Query no. 20
# (210, 10)
# RF R2: 0.5192762569965124
# Remaining: 143
# The Iteration is  4
# NN Initialization Scores: -3.9552292105514315
# After Initialization RF R2: 0.2647513237024165
# Query no. 1
# (20, 10)
# RF R2: 0.39331542806800335
# Remaining: 333
# Query no. 2
# (30, 10)
# RF R2: 0.4122139789153384
# Remaining: 323
# Query no. 3
# (40, 10)
# RF R2: 0.4867306079230992
# Remaining: 313
# Query no. 4
# (50, 10)
# RF R2: 0.5176165575071587
# Remaining: 303
# Query no. 5
# (60, 10)
# RF R2: 0.48562260138434354
# Remaining: 293
# Query no. 6
# (70, 10)
# RF R2: 0.5142574311745952
# Remaining: 283
# Query no. 7
# (80, 10)
# RF R2: 0.4808102445489565
# Remaining: 273
# Query no. 8
# (90, 10)
# RF R2: 0.4600914433524661
# Remaining: 263
# Query no. 9
# (100, 10)
# RF R2: 0.5217711363801607
# Remaining: 253
# Query no. 10
# (110, 10)
# RF R2: 0.5583439324455017
# Remaining: 243
# Query no. 11
# (120, 10)
# RF R2: 0.5543497140768769
# Remaining: 233
# Query no. 12
# (130, 10)
# RF R2: 0.5674656571286734
# Remaining: 223
# Query no. 13
# (140, 10)
# RF R2: 0.5691056333438996
# Remaining: 213
# Query no. 14
# (150, 10)
# RF R2: 0.5828195759513557
# Remaining: 203
# Query no. 15
# (160, 10)
# RF R2: 0.566150671670967
# Remaining: 193
# Query no. 16
# (170, 10)
# RF R2: 0.5752100878826927
# Remaining: 183
# Query no. 17
# (180, 10)
# RF R2: 0.5552883744372913
# Remaining: 173
# Query no. 18
# (190, 10)
# RF R2: 0.5684127848364849
# Remaining: 163
# Query no. 19
# (200, 10)
# RF R2: 0.5866018249205192
# Remaining: 153
# Query no. 20
# (210, 10)
# RF R2: 0.5427242917958748
# Remaining: 143
# The Iteration is  5
# NN Initialization Scores: -2.434103946087288
# After Initialization RF R2: 0.21088154412423232
# Query no. 1
# (20, 10)
# RF R2: 0.3402183477000197
# Remaining: 333
# Query no. 2
# (30, 10)
# RF R2: 0.4503339844972598
# Remaining: 323
# Query no. 3
# (40, 10)
# RF R2: 0.502343918597387
# Remaining: 313
# Query no. 4
# (50, 10)
# RF R2: 0.5318795374306629
# Remaining: 303
# Query no. 5
# (60, 10)
# RF R2: 0.5565872608992869
# Remaining: 293
# Query no. 6
# (70, 10)
# RF R2: 0.5575237279203988
# Remaining: 283
# Query no. 7
# (80, 10)
# RF R2: 0.5401259410918309
# Remaining: 273
# Query no. 8
# (90, 10)
# RF R2: 0.5288259093189848
# Remaining: 263
# Query no. 9
# (100, 10)
# RF R2: 0.5235503377514167
# Remaining: 253
# Query no. 10
# (110, 10)
# RF R2: 0.5121491540440453
# Remaining: 243
# Query no. 11
# (120, 10)
# RF R2: 0.5440578455589256
# Remaining: 233
# Query no. 12
# (130, 10)
# RF R2: 0.5561784699954526
# Remaining: 223
# Query no. 13
# (140, 10)
# RF R2: 0.5677392647434144
# Remaining: 213
# Query no. 14
# (150, 10)
# RF R2: 0.5627489395341292
# Remaining: 203
# Query no. 15
# (160, 10)
# RF R2: 0.5252269458574137
# Remaining: 193
# Query no. 16
# (170, 10)
# RF R2: 0.5215088103655747
# Remaining: 183
# Query no. 17
# (180, 10)
# RF R2: 0.48126406745621353
# Remaining: 173
# Query no. 18
# (190, 10)
# RF R2: 0.4851515250442181
# Remaining: 163
# Query no. 19
# (200, 10)
# RF R2: 0.4783438967263425
# Remaining: 153
# Query no. 20
# (210, 10)
# RF R2: 0.4519122185761546
# Remaining: 143
# The Iteration is  6
# NN Initialization Scores: -3.961998831073788
# After Initialization RF R2: 0.2874004649780366
# Query no. 1
# (20, 10)
# RF R2: 0.3378748442423116
# Remaining: 333
# Query no. 2
# (30, 10)
# RF R2: 0.33831415165765144
# Remaining: 323
# Query no. 3
# (40, 10)
# RF R2: 0.3746079408882387
# Remaining: 313
# Query no. 4
# (50, 10)
# RF R2: 0.3744135321238907
# Remaining: 303
# Query no. 5
# (60, 10)
# RF R2: 0.4484677486345098
# Remaining: 293
# Query no. 6
# (70, 10)
# RF R2: 0.4394175501795664
# Remaining: 283
# Query no. 7
# (80, 10)
# RF R2: 0.42292629772921075
# Remaining: 273
# Query no. 8
# (90, 10)
# RF R2: 0.41623548216146966
# Remaining: 263
# Query no. 9
# (100, 10)
# RF R2: 0.46824078263343294
# Remaining: 253
# Query no. 10
# (110, 10)
# RF R2: 0.45709741134431525
# Remaining: 243
# Query no. 11
# (120, 10)
# RF R2: 0.46760137882270125
# Remaining: 233
# Query no. 12
# (130, 10)
# RF R2: 0.48396003656960485
# Remaining: 223
# Query no. 13
# (140, 10)
# RF R2: 0.48035486679509
# Remaining: 213
# Query no. 14
# (150, 10)
# RF R2: 0.4313738114226905
# Remaining: 203
# Query no. 15
# (160, 10)
# RF R2: 0.435210283597949
# Remaining: 193
# Query no. 16
# (170, 10)
# RF R2: 0.41031961798485905
# Remaining: 183
# Query no. 17
# (180, 10)
# RF R2: 0.39924781342461557
# Remaining: 173
# Query no. 18
# (190, 10)
# RF R2: 0.38323621600798163
# Remaining: 163
# Query no. 19
# (200, 10)
# RF R2: 0.40640166382015486
# Remaining: 153
# Query no. 20
# (210, 10)
# RF R2: 0.4102747839659523
# Remaining: 143
# The Iteration is  7
# NN Initialization Scores: -4.436599354980024
# After Initialization RF R2: 0.19370117539677523
# Query no. 1
# (20, 10)
# RF R2: 0.19773382787997773
# Remaining: 333
# Query no. 2
# (30, 10)
# RF R2: -0.05140524093305898
# Remaining: 323
# Query no. 3
# (40, 10)
# RF R2: -0.28994060902026564
# Remaining: 313
# Query no. 4
# (50, 10)
# RF R2: 0.017406158579956976
# Remaining: 303
# Query no. 5
# (60, 10)
# RF R2: 0.21452748017104883
# Remaining: 293
# Query no. 6
# (70, 10)
# RF R2: 0.31703552737637863
# Remaining: 283
# Query no. 7
# (80, 10)
# RF R2: 0.36114970483366116
# Remaining: 273
# Query no. 8
# (90, 10)
# RF R2: 0.3502806646805309
# Remaining: 263
# Query no. 9
# (100, 10)
# RF R2: 0.37622641134618073
# Remaining: 253
# Query no. 10
# (110, 10)
# RF R2: 0.38143155904602466
# Remaining: 243
# Query no. 11
# (120, 10)
# RF R2: 0.39824349664023984
# Remaining: 233
# Query no. 12
# (130, 10)
# RF R2: 0.3827850998809509
# Remaining: 223
# Query no. 13
# (140, 10)
# RF R2: 0.4111851446329805
# Remaining: 213
# Query no. 14
# (150, 10)
# RF R2: 0.4041793738049624
# Remaining: 203
# Query no. 15
# (160, 10)
# RF R2: 0.3916271777921543
# Remaining: 193
# Query no. 16
# (170, 10)
# RF R2: 0.40024690865226564
# Remaining: 183
# Query no. 17
# (180, 10)
# RF R2: 0.41734885392359156
# Remaining: 173
# Query no. 18
# (190, 10)
# RF R2: 0.40440059946996687
# Remaining: 163
# Query no. 19
# (200, 10)
# RF R2: 0.40066361837051523
# Remaining: 153
# Query no. 20
# (210, 10)
# RF R2: 0.3653088113828926
# Remaining: 143
# The Iteration is  8
# NN Initialization Scores: -2.5540409523775915
# After Initialization RF R2: 0.37592722084430563
# Query no. 1
# (20, 10)
# RF R2: 0.3109897393481198
# Remaining: 333
# Query no. 2
# (30, 10)
# RF R2: 0.36319846858509963
# Remaining: 323
# Query no. 3
# (40, 10)
# RF R2: 0.38825509672950964
# Remaining: 313
# Query no. 4
# (50, 10)
# RF R2: 0.3552866347035135
# Remaining: 303
# Query no. 5
# (60, 10)
# RF R2: 0.4585329872420304
# Remaining: 293
# Query no. 6
# (70, 10)
# RF R2: 0.5137188558694253
# Remaining: 283
# Query no. 7
# (80, 10)
# RF R2: 0.534422849173217
# Remaining: 273
# Query no. 8
# (90, 10)
# RF R2: 0.5256958793857718
# Remaining: 263
# Query no. 9
# (100, 10)
# RF R2: 0.5007934040017443
# Remaining: 253
# Query no. 10
# (110, 10)
# RF R2: 0.5004149589410724
# Remaining: 243
# Query no. 11
# (120, 10)
# RF R2: 0.5347253585399647
# Remaining: 233
# Query no. 12
# (130, 10)
# RF R2: 0.5272918100305322
# Remaining: 223
# Query no. 13
# (140, 10)
# RF R2: 0.5359530912824435
# Remaining: 213
# Query no. 14
# (150, 10)
# RF R2: 0.5829573863565612
# Remaining: 203
# Query no. 15
# (160, 10)
# RF R2: 0.5860668945956293
# Remaining: 193
# Query no. 16
# (170, 10)
# RF R2: 0.5810373917542709
# Remaining: 183
# Query no. 17
# (180, 10)
# RF R2: 0.6106851602035427
# Remaining: 173
# Query no. 18
# (190, 10)
# RF R2: 0.5720221031949366
# Remaining: 163
# Query no. 19
# (200, 10)
# RF R2: 0.6046647332983297
# Remaining: 153
# Query no. 20
# (210, 10)
# RF R2: 0.6177304432549873
# Remaining: 143
# The Iteration is  9
# NN Initialization Scores: -3.3879402698587313
# After Initialization RF R2: 0.035649981461895575
# Query no. 1
# (20, 10)
# RF R2: 0.0608486254790509
# Remaining: 333
# Query no. 2
# (30, 10)
# RF R2: 0.1796641757245352
# Remaining: 323
# Query no. 3
# (40, 10)
# RF R2: 0.22517769190064085
# Remaining: 313
# Query no. 4
# (50, 10)
# RF R2: 0.24897522487998913
# Remaining: 303
# Query no. 5
# (60, 10)
# RF R2: 0.3275823404662308
# Remaining: 293
# Query no. 6
# (70, 10)
# RF R2: 0.19188301724390044
# Remaining: 283
# Query no. 7
# (80, 10)
# RF R2: 0.2738990209248897
# Remaining: 273
# Query no. 8
# (90, 10)
# RF R2: 0.30841997746173966
# Remaining: 263
# Query no. 9
# (100, 10)
# RF R2: 0.370046003377133
# Remaining: 253
# Query no. 10
# (110, 10)
# RF R2: 0.3723427173500049
# Remaining: 243
# Query no. 11
# (120, 10)
# RF R2: 0.35269853404720175
# Remaining: 233
# Query no. 12
# (130, 10)
# RF R2: 0.3922672763254742
# Remaining: 223
# Query no. 13
# (140, 10)
# RF R2: 0.3930761662821184
# Remaining: 213
# Query no. 14
# (150, 10)
# RF R2: 0.37287672497355295
# Remaining: 203
# Query no. 15
# (160, 10)
# RF R2: 0.4281965878446423
# Remaining: 193
# Query no. 16
# (170, 10)
# RF R2: 0.44824996081852564
# Remaining: 183
# Query no. 17
# (180, 10)
# RF R2: 0.41271978223149974
# Remaining: 173
# Query no. 18
# (190, 10)
# RF R2: 0.40030019249283677
# Remaining: 163
# Query no. 19
# (200, 10)
# RF R2: 0.4028858515723053
# Remaining: 153
# Query no. 20
# (210, 10)
# RF R2: 0.4196323567849872
# Remaining: 143
# The Iteration is  10
# NN Initialization Scores: -2.6535156596985274
# After Initialization RF R2: 0.23162437973863492
# Query no. 1
# (20, 10)
# RF R2: 0.4054740722275272
# Remaining: 333
# Query no. 2
# (30, 10)
# RF R2: 0.3832309571772845
# Remaining: 323
# Query no. 3
# (40, 10)
# RF R2: 0.41027754683981843
# Remaining: 313
# Query no. 4
# (50, 10)
# RF R2: 0.3876425985015124
# Remaining: 303
# Query no. 5
# (60, 10)
# RF R2: 0.4090166056489384
# Remaining: 293
# Query no. 6
# (70, 10)
# RF R2: 0.4618709380939632
# Remaining: 283
# Query no. 7
# (80, 10)
# RF R2: 0.5039010090165503
# Remaining: 273
# Query no. 8
# (90, 10)
# RF R2: 0.5171338288938132
# Remaining: 263
# Query no. 9
# (100, 10)
# RF R2: 0.47430071931906825
# Remaining: 253
# Query no. 10
# (110, 10)
# RF R2: 0.491987267010199
# Remaining: 243
# Query no. 11
# (120, 10)
# RF R2: 0.4945193900865432
# Remaining: 233
# Query no. 12
# (130, 10)
# RF R2: 0.4884932392056146
# Remaining: 223
# Query no. 13
# (140, 10)
# RF R2: 0.48809141948146484
# Remaining: 213
# Query no. 14
# (150, 10)
# RF R2: 0.474498756420071
# Remaining: 203
# Query no. 15
# (160, 10)
# RF R2: 0.49950691300121774
# Remaining: 193
# Query no. 16
# (170, 10)
# RF R2: 0.4909988073215539
# Remaining: 183
# Query no. 17
# (180, 10)
# RF R2: 0.48348542813168505
# Remaining: 173
# Query no. 18
# (190, 10)
# RF R2: 0.5170030143691784
# Remaining: 163
# Query no. 19
# (200, 10)
# RF R2: 0.4692558388614063
# Remaining: 153
# Query no. 20
# (210, 10)
# RF R2: 0.48718265445205666
# Remaining: 143
# The Iteration is  11
# NN Initialization Scores: -3.7967862981349336
# After Initialization RF R2: 0.21259635230652096
# Query no. 1
# (20, 10)
# RF R2: 0.25489156361674437
# Remaining: 333
# Query no. 2
# (30, 10)
# RF R2: 0.31679776166848894
# Remaining: 323
# Query no. 3
# (40, 10)
# RF R2: 0.2309157144661631
# Remaining: 313
# Query no. 4
# (50, 10)
# RF R2: 0.3944137662093965
# Remaining: 303
# Query no. 5
# (60, 10)
# RF R2: 0.3509628068839693
# Remaining: 293
# Query no. 6
# (70, 10)
# RF R2: 0.3146636238419812
# Remaining: 283
# Query no. 7
# (80, 10)
# RF R2: 0.3263756043096194
# Remaining: 273
# Query no. 8
# (90, 10)
# RF R2: 0.34286544311844047
# Remaining: 263
# Query no. 9
# (100, 10)
# RF R2: 0.3361547611457809
# Remaining: 253
# Query no. 10
# (110, 10)
# RF R2: 0.3481507432017673
# Remaining: 243
# Query no. 11
# (120, 10)
# RF R2: 0.34110323351279237
# Remaining: 233
# Query no. 12
# (130, 10)
# RF R2: 0.3229729064397242
# Remaining: 223
# Query no. 13
# (140, 10)
# RF R2: 0.3652652807410225
# Remaining: 213
# Query no. 14
# (150, 10)
# RF R2: 0.3599885598727781
# Remaining: 203
# Query no. 15
# (160, 10)
# RF R2: 0.37634671454891444
# Remaining: 193
# Query no. 16
# (170, 10)
# RF R2: 0.4074435743362762
# Remaining: 183
# Query no. 17
# (180, 10)
# RF R2: 0.38535026025345387
# Remaining: 173
# Query no. 18
# (190, 10)
# RF R2: 0.39027697929932914
# Remaining: 163
# Query no. 19
# (200, 10)
# RF R2: 0.3951530878159014
# Remaining: 153
# Query no. 20
# (210, 10)
# RF R2: 0.38941938455278924
# Remaining: 143
# The Iteration is  12
# NN Initialization Scores: -3.5930228792788936
# After Initialization RF R2: 0.06185382460298916
# Query no. 1
# (20, 10)
# RF R2: 0.2885080538000314
# Remaining: 333
# Query no. 2
# (30, 10)
# RF R2: 0.31131937047939706
# Remaining: 323
# Query no. 3
# (40, 10)
# RF R2: 0.34667064084398047
# Remaining: 313
# Query no. 4
# (50, 10)
# RF R2: 0.27354053557679114
# Remaining: 303
# Query no. 5
# (60, 10)
# RF R2: 0.17187838199419292
# Remaining: 293
# Query no. 6
# (70, 10)
# RF R2: 0.27977383293204505
# Remaining: 283
# Query no. 7
# (80, 10)
# RF R2: 0.3541798247851504
# Remaining: 273
# Query no. 8
# (90, 10)
# RF R2: 0.31874097433558646
# Remaining: 263
# Query no. 9
# (100, 10)
# RF R2: 0.38353696652221214
# Remaining: 253
# Query no. 10
# (110, 10)
# RF R2: 0.3957362570181683
# Remaining: 243
# Query no. 11
# (120, 10)
# RF R2: 0.4209803954883503
# Remaining: 233
# Query no. 12
# (130, 10)
# RF R2: 0.3957407334340787
# Remaining: 223
# Query no. 13
# (140, 10)
# RF R2: 0.3941776155263901
# Remaining: 213
# Query no. 14
# (150, 10)
# RF R2: 0.4050159955392939
# Remaining: 203
# Query no. 15
# (160, 10)
# RF R2: 0.3897128032356575
# Remaining: 193
# Query no. 16
# (170, 10)
# RF R2: 0.38582140196150105
# Remaining: 183
# Query no. 17
# (180, 10)
# RF R2: 0.36982175189099764
# Remaining: 173
# Query no. 18
# (190, 10)
# RF R2: 0.387057024178611
# Remaining: 163
# Query no. 19
# (200, 10)
# RF R2: 0.43172681646715316
# Remaining: 153
# Query no. 20
# (210, 10)
# RF R2: 0.41466597180498566
# Remaining: 143
# The Iteration is  13
# NN Initialization Scores: -3.4037143612848038
# After Initialization RF R2: 0.10976834507123645
# Query no. 1
# (20, 10)
# RF R2: 0.3727893292041419
# Remaining: 333
# Query no. 2
# (30, 10)
# RF R2: 0.3995921299677274
# Remaining: 323
# Query no. 3
# (40, 10)
# RF R2: 0.39329668681800634
# Remaining: 313
# Query no. 4
# (50, 10)
# RF R2: 0.46563467470704756
# Remaining: 303
# Query no. 5
# (60, 10)
# RF R2: 0.43762683586097084
# Remaining: 293
# Query no. 6
# (70, 10)
# RF R2: 0.462625868014766
# Remaining: 283
# Query no. 7
# (80, 10)
# RF R2: 0.5119896539155515
# Remaining: 273
# Query no. 8
# (90, 10)
# RF R2: 0.4500400300021118
# Remaining: 263
# Query no. 9
# (100, 10)
# RF R2: 0.4953960520789926
# Remaining: 253
# Query no. 10
# (110, 10)
# RF R2: 0.45981068301717776
# Remaining: 243
# Query no. 11
# (120, 10)
# RF R2: 0.4454492410714218
# Remaining: 233
# Query no. 12
# (130, 10)
# RF R2: 0.47596369124746407
# Remaining: 223
# Query no. 13
# (140, 10)
# RF R2: 0.45579024303331606
# Remaining: 213
# Query no. 14
# (150, 10)
# RF R2: 0.4649665782419251
# Remaining: 203
# Query no. 15
# (160, 10)
# RF R2: 0.4373612736905401
# Remaining: 193
# Query no. 16
# (170, 10)
# RF R2: 0.42268663620554026
# Remaining: 183
# Query no. 17
# (180, 10)
# RF R2: 0.37016990681189843
# Remaining: 173
# Query no. 18
# (190, 10)
# RF R2: 0.3848944390183636
# Remaining: 163
# Query no. 19
# (200, 10)
# RF R2: 0.3774575976804796
# Remaining: 153
# Query no. 20
# (210, 10)
# RF R2: 0.35733599902637503
# Remaining: 143
# The Iteration is  14
# NN Initialization Scores: -2.579372897532444
# After Initialization RF R2: 0.21875949583564513
# Query no. 1
# (20, 10)
# RF R2: 0.3098402313791997
# Remaining: 333
# Query no. 2
# (30, 10)
# RF R2: 0.3206217581694475
# Remaining: 323
# Query no. 3
# (40, 10)
# RF R2: 0.26105950712182024
# Remaining: 313
# Query no. 4
# (50, 10)
# RF R2: 0.3507766007375369
# Remaining: 303
# Query no. 5
# (60, 10)
# RF R2: 0.4547619690975433
# Remaining: 293
# Query no. 6
# (70, 10)
# RF R2: 0.4586372384539573
# Remaining: 283
# Query no. 7
# (80, 10)
# RF R2: 0.4484524295950165
# Remaining: 273
# Query no. 8
# (90, 10)
# RF R2: 0.4683192341912382
# Remaining: 263
# Query no. 9
# (100, 10)
# RF R2: 0.45932075703286224
# Remaining: 253
# Query no. 10
# (110, 10)
# RF R2: 0.45348325533668876
# Remaining: 243
# Query no. 11
# (120, 10)
# RF R2: 0.4608778444505427
# Remaining: 233
# Query no. 12
# (130, 10)
# RF R2: 0.4496977571693854
# Remaining: 223
# Query no. 13
# (140, 10)
# RF R2: 0.44760674876980133
# Remaining: 213
# Query no. 14
# (150, 10)
# RF R2: 0.4788000966677264
# Remaining: 203
# Query no. 15
# (160, 10)
# RF R2: 0.4423527346445594
# Remaining: 193
# Query no. 16
# (170, 10)
# RF R2: 0.4752681983876835
# Remaining: 183
# Query no. 17
# (180, 10)
# RF R2: 0.46621765951793004
# Remaining: 173
# Query no. 18
# (190, 10)
# RF R2: 0.4496251590480904
# Remaining: 163
# Query no. 19
# (200, 10)
# RF R2: 0.44188184024614086
# Remaining: 153
# Query no. 20
# (210, 10)
# RF R2: 0.4430585954393579
# Remaining: 143
# The Iteration is  15
# NN Initialization Scores: -3.7841494150162305
# After Initialization RF R2: 0.20777385009743188
# Query no. 1
# (20, 10)
# RF R2: -0.10370476172181986
# Remaining: 333
# Query no. 2
# (30, 10)
# RF R2: 0.1761837042924469
# Remaining: 323
# Query no. 3
# (40, 10)
# RF R2: 0.1711702342999124
# Remaining: 313
# Query no. 4
# (50, 10)
# RF R2: 0.1299878293222546
# Remaining: 303
# Query no. 5
# (60, 10)
# RF R2: 0.11633131621803838
# Remaining: 293
# Query no. 6
# (70, 10)
# RF R2: 0.18535922056812015
# Remaining: 283
# Query no. 7
# (80, 10)
# RF R2: 0.20414809101663678
# Remaining: 273
# Query no. 8
# (90, 10)
# RF R2: 0.217294197431822
# Remaining: 263
# Query no. 9
# (100, 10)
# RF R2: 0.23478526858505977
# Remaining: 253
# Query no. 10
# (110, 10)
# RF R2: 0.22759507435298176
# Remaining: 243
# Query no. 11
# (120, 10)
# RF R2: 0.31525459583585014
# Remaining: 233
# Query no. 12
# (130, 10)
# RF R2: 0.2614760591502503
# Remaining: 223
# Query no. 13
# (140, 10)
# RF R2: 0.3456982647493737
# Remaining: 213
# Query no. 14
# (150, 10)
# RF R2: 0.38044574548743915
# Remaining: 203
# Query no. 15
# (160, 10)
# RF R2: 0.3757075469590778
# Remaining: 193
# Query no. 16
# (170, 10)
# RF R2: 0.39002234171205097
# Remaining: 183
# Query no. 17
# (180, 10)
# RF R2: 0.3824000928155499
# Remaining: 173
# Query no. 18
# (190, 10)
# RF R2: 0.4024563448171862
# Remaining: 163
# Query no. 19
# (200, 10)
# RF R2: 0.3969722698576732
# Remaining: 153
# Query no. 20
# (210, 10)
# RF R2: 0.4098915250368207
# Remaining: 143
# The Iteration is  16
# NN Initialization Scores: -3.381098700859943
# After Initialization RF R2: 0.3788951332013627
# Query no. 1
# (20, 10)
# RF R2: 0.4379215222892361
# Remaining: 333
# Query no. 2
# (30, 10)
# RF R2: 0.45691769245739466
# Remaining: 323
# Query no. 3
# (40, 10)
# RF R2: 0.4244134798425815
# Remaining: 313
# Query no. 4
# (50, 10)
# RF R2: 0.3834793587172517
# Remaining: 303
# Query no. 5
# (60, 10)
# RF R2: 0.41252694695452585
# Remaining: 293
# Query no. 6
# (70, 10)
# RF R2: 0.4442189042813267
# Remaining: 283
# Query no. 7
# (80, 10)
# RF R2: 0.4116084125127848
# Remaining: 273
# Query no. 8
# (90, 10)
# RF R2: 0.43055775425698417
# Remaining: 263
# Query no. 9
# (100, 10)
# RF R2: 0.352671819877159
# Remaining: 253
# Query no. 10
# (110, 10)
# RF R2: 0.35320228979435864
# Remaining: 243
# Query no. 11
# (120, 10)
# RF R2: 0.4043541230105413
# Remaining: 233
# Query no. 12
# (130, 10)
# RF R2: 0.4585966189487407
# Remaining: 223
# Query no. 13
# (140, 10)
# RF R2: 0.45573611278322945
# Remaining: 213
# Query no. 14
# (150, 10)
# RF R2: 0.47029774924542944
# Remaining: 203
# Query no. 15
# (160, 10)
# RF R2: 0.48084975134115615
# Remaining: 193
# Query no. 16
# (170, 10)
# RF R2: 0.5019016902227489
# Remaining: 183
# Query no. 17
# (180, 10)
# RF R2: 0.49044699693580296
# Remaining: 173
# Query no. 18
# (190, 10)
# RF R2: 0.44278238468524767
# Remaining: 163
# Query no. 19
# (200, 10)
# RF R2: 0.4961231720333974
# Remaining: 153
# Query no. 20
# (210, 10)
# RF R2: 0.5208756569281379
# Remaining: 143
# The Iteration is  17
# NN Initialization Scores: -2.826418533906574
# After Initialization RF R2: 0.27409988635854254
# Query no. 1
# (20, 10)
# RF R2: 0.4004933595207869
# Remaining: 333
# Query no. 2
# (30, 10)
# RF R2: 0.45099902430522043
# Remaining: 323
# Query no. 3
# (40, 10)
# RF R2: 0.42495231176324333
# Remaining: 313
# Query no. 4
# (50, 10)
# RF R2: 0.4275062980136275
# Remaining: 303
# Query no. 5
# (60, 10)
# RF R2: 0.39894290891717965
# Remaining: 293
# Query no. 6
# (70, 10)
# RF R2: 0.3917310051728258
# Remaining: 283
# Query no. 7
# (80, 10)
# RF R2: 0.35190492283151487
# Remaining: 273
# Query no. 8
# (90, 10)
# RF R2: 0.3189583142068668
# Remaining: 263
# Query no. 9
# (100, 10)
# RF R2: 0.3708065083886023
# Remaining: 253
# Query no. 10
# (110, 10)
# RF R2: 0.39748181476574196
# Remaining: 243
# Query no. 11
# (120, 10)
# RF R2: 0.4289918947307886
# Remaining: 233
# Query no. 12
# (130, 10)
# RF R2: 0.380753213333492
# Remaining: 223
# Query no. 13
# (140, 10)
# RF R2: 0.3637348722421735
# Remaining: 213
# Query no. 14
# (150, 10)
# RF R2: 0.4051036899752062
# Remaining: 203
# Query no. 15
# (160, 10)
# RF R2: 0.4363691696713813
# Remaining: 193
# Query no. 16
# (170, 10)
# RF R2: 0.4496227443599833
# Remaining: 183
# Query no. 17
# (180, 10)
# RF R2: 0.4049728881504929
# Remaining: 173
# Query no. 18
# (190, 10)
# RF R2: 0.3923029896184873
# Remaining: 163
# Query no. 19
# (200, 10)
# RF R2: 0.3924574675401049
# Remaining: 153
# Query no. 20
# (210, 10)
# RF R2: 0.399680331601854
# Remaining: 143
# The Iteration is  18
# NN Initialization Scores: -3.5729884736003523
# After Initialization RF R2: 0.19165785697079374
# Query no. 1
# (20, 10)
# RF R2: 0.1896088862151315
# Remaining: 333
# Query no. 2
# (30, 10)
# RF R2: 0.17027855537509695
# Remaining: 323
# Query no. 3
# (40, 10)
# RF R2: 0.26865456819103795
# Remaining: 313
# Query no. 4
# (50, 10)
# RF R2: 0.26265337949178447
# Remaining: 303
# Query no. 5
# (60, 10)
# RF R2: 0.2513415245545969
# Remaining: 293
# Query no. 6
# (70, 10)
# RF R2: 0.22621119655833688
# Remaining: 283
# Query no. 7
# (80, 10)
# RF R2: 0.25119824953395486
# Remaining: 273
# Query no. 8
# (90, 10)
# RF R2: 0.26905735245044304
# Remaining: 263
# Query no. 9
# (100, 10)
# RF R2: 0.26523668444096815
# Remaining: 253
# Query no. 10
# (110, 10)
# RF R2: 0.29578881539527646
# Remaining: 243
# Query no. 11
# (120, 10)
# RF R2: 0.2577246098029723
# Remaining: 233
# Query no. 12
# (130, 10)
# RF R2: 0.1922052905529794
# Remaining: 223
# Query no. 13
# (140, 10)
# RF R2: 0.21784545118103205
# Remaining: 213
# Query no. 14
# (150, 10)
# RF R2: 0.2314062360065302
# Remaining: 203
# Query no. 15
# (160, 10)
# RF R2: 0.24753808012015321
# Remaining: 193
# Query no. 16
# (170, 10)
# RF R2: 0.25525259151107094
# Remaining: 183
# Query no. 17
# (180, 10)
# RF R2: 0.27985475083986167
# Remaining: 173
# Query no. 18
# (190, 10)
# RF R2: 0.23985152396563048
# Remaining: 163
# Query no. 19
# (200, 10)
# RF R2: 0.2554610917596306
# Remaining: 153
# Query no. 20
# (210, 10)
# RF R2: 0.2727162667804396
# Remaining: 143
# The Iteration is  19
# NN Initialization Scores: -3.662248909528598
# After Initialization RF R2: 0.2592937559558306
# Query no. 1
# (20, 10)
# RF R2: 0.2304127033872001
# Remaining: 333
# Query no. 2
# (30, 10)
# RF R2: 0.28284814132905933
# Remaining: 323
# Query no. 3
# (40, 10)
# RF R2: 0.23807776331718833
# Remaining: 313
# Query no. 4
# (50, 10)
# RF R2: 0.208544631632264
# Remaining: 303
# Query no. 5
# (60, 10)
# RF R2: 0.18789944507866174
# Remaining: 293
# Query no. 6
# (70, 10)
# RF R2: 0.19444586827799093
# Remaining: 283
# Query no. 7
# (80, 10)
# RF R2: 0.18421456246334278
# Remaining: 273
# Query no. 8
# (90, 10)
# RF R2: 0.2379700848260674
# Remaining: 263
# Query no. 9
# (100, 10)
# RF R2: 0.23524383531192938
# Remaining: 253
# Query no. 10
# (110, 10)
# RF R2: 0.2336865222667336
# Remaining: 243
# Query no. 11
# (120, 10)
# RF R2: 0.24975831867493936
# Remaining: 233
# Query no. 12
# (130, 10)
# RF R2: 0.24136865789042594
# Remaining: 223
# Query no. 13
# (140, 10)
# RF R2: 0.25638208826131603
# Remaining: 213
# Query no. 14
# (150, 10)
# RF R2: 0.2722433769972078
# Remaining: 203
# Query no. 15
# (160, 10)
# RF R2: 0.291308577802596
# Remaining: 193
# Query no. 16
# (170, 10)
# RF R2: 0.2686940329132588
# Remaining: 183
# Query no. 17
# (180, 10)
# RF R2: 0.3018773656121988
# Remaining: 173
# Query no. 18
# (190, 10)
# RF R2: 0.29746625939870386
# Remaining: 163
# Query no. 19
# (200, 10)
# RF R2: 0.3084013380585128
# Remaining: 153
# Query no. 20
# (210, 10)
# RF R2: 0.2903970185112096
# Remaining: 143
