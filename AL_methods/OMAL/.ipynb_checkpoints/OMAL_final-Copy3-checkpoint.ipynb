# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from modAL.models import ActiveLearner, CommitteeRegressor
from modAL.disagreement import vote_entropy_sampling, max_std_sampling
import matplotlib.pyplot as plt
import torch
from torch.nn import MSELoss
from skorch.regressor import NeuralNetRegressor
from copy import deepcopy
from skorch.dataset import ValidSplit
from skorch.callbacks import EarlyStopping
from sklearn.cluster import DBSCAN, OPTICS, cluster_optics_dbscan, Birch, SpectralClustering
from sklearn.neighbors import NearestNeighbors
from sklearn import metrics
import matplotlib.gridspec as gridspec
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from torch.nn import Linear
from torch.nn import Sigmoid, ReLU
from torch.nn import Module
from sklearn.metrics import r2_score
import copy
from scipy.spatial import distance
from scipy.spatial.distance import euclidean
from torch import tensor
from sklearn.metrics import mean_squared_error
from scipy.spatial.distance import cdist
from sklearn.ensemble import RandomForestRegressor
from torch.nn.init import xavier_uniform_
from model import MLP
from model_state import get_model_params, get_input_for_hidden_layers, get_model_params_gradientNorm
from functions_batch1 import get_variance, qbc, normalization, error_reduct_fuc, total_disagrement, grad_norm, averaged_grad_norm, get_avg_grad_norm, training_loss
import random
from skorch.callbacks import EarlyStopping, LRScheduler, Freezer, Unfreezer
from torch.optim.lr_scheduler import CyclicLR, ReduceLROnPlateau
from skorch.regressor import NeuralNetRegressor, NeuralNet
from model_state import features_concat, learning_state_features_concat
import gc
import warnings
from modAL.utils.selection import multi_argmax
warnings.filterwarnings("ignore")

# %%
# Hyper-params:
query_number = 20          # The number of the AL Iterations in each Exp
iteration = 20             # Total number of the Exps
batch_size = 10
total_initail_size = 10
initial_size = 5
dimensions = 18   # Total dimension of the data features + model states

seed_rf = np.load(file="..\..\Datasets\Diabetes\seed_for_RF.npy")
seed_initial = np.load(file="..\..\Datasets\Diabetes\seed_for_initialSamples.npy")

seed_nn1 = np.random.randint(10000, size=100)
seed_nn2 = np.random.randint(10000, size=100)
seed_nn3 = np.random.randint(10000, size=100)
seed_nn4 = np.random.randint(10000, size=100)
seed_nn5 = np.random.randint(10000, size=100)
seed_nn6 = np.random.randint(10000, size=100)
seed_predictor = np.random.randint(10000, size=100)

np.save(file="..\..\Results\Res_Diabetes\OMAL4\seed_for_nn1.npy", arr=seed_nn1)
np.save(file="..\..\Results\Res_Diabetes\OMAL4\seed_for_nn2.npy", arr=seed_nn2)
np.save(file="..\..\Results\Res_Diabetes\OMAL4\seed_for_nn3.npy", arr=seed_nn3)
np.save(file="..\..\Results\Res_Diabetes\OMAL4\seed_for_nn4.npy", arr=seed_nn4)
np.save(file="..\..\Results\Res_Diabetes\OMAL4\seed_for_nn5.npy", arr=seed_nn5)
np.save(file="..\..\Results\Res_Diabetes\OMAL4\seed_for_nn6.npy", arr=seed_nn6)

np.save(file="..\..\Results\Res_Diabetes\OMAL4\seed_predictor.npy", arr=seed_predictor)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def Committee_Prediction(learner_list, X_test, y_test):
    initial_pred=[]
    for i in learner_list:
        initial_pred.append(r2_score(y_test, i.predict(X_test)))
    initial_pred=np.array(initial_pred)
    
    return initial_pred.mean()

# %%
def main_function(query_number, iters):
    # For saving results:
    rf_model_training_r2 = []
    rf_model_training_mse = []
    rf_model_testing_r2 = []
    rf_model_testing_mse = []
    
    # Number of member in committee:
    n_members = 3
    learner_list = []
    
    # The model for evaluation:
    rf_model = RandomForestRegressor(random_state=seed_rf[iters], n_estimators=100)
    gradient_norms = np.empty(shape=(0, 0))
    
    # Load the data:
    name1 = "..\..\Datasets\Diabetes\X_train" + str(iters) + ".npy"
    name2 = "..\..\Datasets\Diabetes\X_test" + str(iters) + ".npy"
    name3 = "..\..\Datasets\Diabetes\y_train" + str(iters) + ".npy"
    name4 = "..\..\Datasets\Diabetes\y_test" + str(iters) + ".npy"
    
    X_train = np.load(name1, allow_pickle=True).astype(np.float32)
    X_test = np.load(name2, allow_pickle=True).astype(np.float32)
    y_train = np.load(name3, allow_pickle=True).astype(np.float32).reshape(-1, 1)
    y_test = np.load(name4, allow_pickle=True).astype(np.float32).reshape(-1, 1)
    
    # Dimensionality of data:
    X = X_train.shape[1]
    # The index of the unlabeled pool:
    X_index = np.arange(X_train.shape[0])

    used_data = np.empty(shape=(0, X))
    used_label = np.empty(shape=(0)).reshape(-1, 1)

    X_initial = np.empty(shape=(0,X))
    y_initial = np.empty(shape=(0)).reshape(-1, 1)
    
    # Initial Stage 1:
    np.random.seed(seed_initial[iters])
    idx = np.random.choice(range(len(X_index)), size=initial_size, replace=False)
    train_idx = X_index[idx]

    X_initial = X_train[train_idx]
    y_initial = y_train[train_idx].reshape(-1, 1)

    used_data = np.append(used_data, X_initial, axis=0).astype(np.float32)
    used_label = np.append(used_label, y_initial, axis=0).astype(np.float32).reshape(-1, 1)
    X_index = np.delete(X_index, idx, axis=0)

    
    used_data = torch.from_numpy(used_data).to(device)
    used_label = torch.from_numpy(used_label).to(device)
    for member_idx in range(n_members):
        if member_idx == 0:
            np.random.seed(seed_nn1[iters])
            torch.manual_seed(seed_nn2[iters])
        if member_idx == 1:
            np.random.seed(seed_nn3[iters])
            torch.manual_seed(seed_nn4[iters])
        if member_idx == 2:
            np.random.seed(seed_nn5[iters])
            torch.manual_seed(seed_nn6[iters])
            
        regressor = NeuralNetRegressor(MLP(X),
                                   criterion=MSELoss(),
                                   optimizer=torch.optim.Adam,
                                   verbose=0,
                                   max_epochs=30,
                                   lr=0.001,
                                   # Used for the batch AL
                                   callbacks=[EarlyStopping(patience=5), ('lr_scheduler', LRScheduler(policy=ReduceLROnPlateau))],
                                   train_split=ValidSplit(cv=5),
                                   warm_start=True,
                                   device='cuda',
                                   batch_size = -1
                                   )
        regressor.fit(used_data, used_label)
        learner_list.append(regressor)
    
    print("NN Test R2 with 5 samples", Committee_Prediction(learner_list, X_test, y_test))

    # Number of LAL features:
    learning_state_features = np.empty(shape=(0, dimensions))
    loss_reduction_target = np.empty(shape=(0)).reshape(-1, 1)

    # other random samples:
    rest_initial_X = np.empty(shape=(0, X))
    rest_initial_y = np.empty(shape=(0)).reshape(-1, 1)

    # LAL Initialization: Stage 2
    predictor = RandomForestRegressor(n_estimators=500, random_state=seed_predictor[iters])
    np.random.seed(seed_initial[iters])
    idx = np.random.choice(range(len(X_index)), size=total_initail_size-initial_size, replace=False)
    train_idx = X_index[idx]
    
    rest_initial_X = np.append(rest_initial_X, X_train[train_idx], axis=0).astype(np.float32)
    rest_initial_y = np.append(rest_initial_y, y_train[train_idx], axis=0).astype(np.float32).reshape(-1, 1)

    X_index = np.delete(X_index, idx, axis=0)

    for i in range(rest_initial_X.shape[0]):

        single_X = rest_initial_X[i],
        single_y = rest_initial_y[i].reshape(1, -1)
        single_X = single_X[0].reshape(1, -1)
        
        single_X = torch.from_numpy(single_X).to(device)
        single_y = torch.from_numpy(single_y).to(device)

        # Model params
        model_params = get_model_params_gradientNorm(learner_list)

        # updated data
        used_data = torch.cat((used_data, single_X), 0)
        used_label = torch.cat((used_label, single_y), 0)

        # Retrain the model:
        for l in learner_list:
            l.fit(X=used_data,y=used_label)
            
        single_X = single_X.cpu().numpy()
        single_y = single_y.cpu().numpy()
            
        index = train_idx[i]

        # The training sample:
        data_params = X_train[index]
      
        LALfeatures = features_concat(model_params, data_params)

        loss_reduction = get_avg_grad_norm(learner_list, single_X, single_y)
        
        learning_state_features = learning_state_features_concat(learning_state_features, LALfeatures)
        loss_reduction_target = np.append(loss_reduction_target, np.array([loss_reduction]).reshape(-1, 1), axis=0).astype(np.float32).reshape(-1, 1)

        
    used_data = used_data.cpu().numpy()
    used_label = used_label.cpu().numpy()

    # Finished the Initialization Stages:
    # RF Regressor for evaluation:
    rf_model.fit(used_data, used_label.ravel())
    # Training Scores:
    rf_training_r2 = r2_score(used_label, rf_model.predict(used_data))
    rf_training_mse = mean_squared_error(used_label, rf_model.predict(used_data))
    rf_model_training_r2.append(rf_training_r2)
    rf_model_training_mse.append(rf_training_mse)
    
    # Test Scores:
    rf_model_r2 = r2_score(y_test, rf_model.predict(X_test))
    rf_model_mse = mean_squared_error(y_test, rf_model.predict(X_test))
    rf_model_testing_r2.append(rf_model_r2)
    rf_model_testing_mse.append(rf_model_mse)
    
    print("After Initialization RF R2:", rf_model_r2)
    print("NN Test R2 after Initialization", Committee_Prediction(learner_list, X_test, y_test))

    print(np.unique(used_data, axis=0).shape)
    for idx in range(query_number):
        np.random.seed(None)
        print('Query no. %d' % (idx+1))

        Error_reduction_list, training_score = error_reduct_fuc(X_train, X_index, learner_list, learning_state_features, loss_reduction_target, X_index.shape[0], predictor)

        idx = multi_argmax(np.array(Error_reduction_list), n_instances=batch_size)
       
        X_train_indices = X_index[idx]
        
        # Update
        X_index = np.delete(X_index, idx, axis=0)

        for X_train_index in X_train_indices:

            new_X = X_train[X_train_index].reshape(1, -1)
            new_y = y_train[X_train_index].reshape(1, -1)
            
            used_data = np.append(used_data, new_X, axis=0).astype(np.float32)
            used_label = np.append(used_label, new_y, axis=0).astype(np.float32).reshape(-1, 1)
            
            used_data = torch.from_numpy(used_data).to(device)
            used_label = torch.from_numpy(used_label).to(device)

            # Model params
            model_params = get_model_params_gradientNorm(learner_list)
            data_params = X_train[X_train_index]
            LALfeatures = features_concat(model_params, data_params)
            
            for l in learner_list:
                l.fit(used_data, used_label)
            
            used_data = used_data.cpu().numpy()
            used_label = used_label.cpu().numpy()

            loss_reduction = get_avg_grad_norm(learner_list, new_X, new_y)  
            gradient_norms = np.append(gradient_norms, loss_reduction)
            
            learning_state_features = learning_state_features_concat(learning_state_features, LALfeatures)
            loss_reduction_target = np.append(loss_reduction_target, np.array([loss_reduction]).reshape(-1, 1), axis=0).astype(np.float32).reshape(-1, 1)
        

        # RF Evaluation
        rf_model.fit(used_data, used_label.ravel())
        
        # Training Evaluation:
        rf_training_r2 = r2_score(used_label, rf_model.predict(used_data))
        rf_training_mse = mean_squared_error(used_label, rf_model.predict(used_data))
        rf_model_training_r2.append(rf_training_r2)
        rf_model_training_mse.append(rf_training_mse)
        
        # Test Evaluation:
        rf_model_r2 = r2_score(y_test, rf_model.predict(X_test))
        rf_model_mse = mean_squared_error(y_test, rf_model.predict(X_test))
        rf_model_testing_r2.append(rf_model_r2)
        rf_model_testing_mse.append(rf_model_mse)

        print(np.unique(used_data, axis=0).shape)
        print("RF R2:", rf_model_r2)
        print("Remaining:", X_index.shape[0])
        # print('NN R2', Committee_Prediction(learner_list, X_test, y_test))

    # RF
    rf_model_testing_r2 = np.array(rf_model_testing_r2)
    rf_model_testing_mse = np.array(rf_model_testing_mse)
    rf_model_training_r2 = np.array(rf_model_training_r2)
    rf_model_training_mse = np.array(rf_model_training_mse)
    
    # Used_data and Unsed_label:
    np.save(file="..\..\Results\Res_Diabetes\OMAL4\Summary\\used_data" + str(iters) + ".npy", arr=used_data)
    np.save(file="..\..\Results\Res_Diabetes\OMAL4\Summary\\used_labels" + str(iters) + ".npy", arr=used_label)

    np.save(file="..\..\Results\Res_Diabetes\OMAL4\Summary\\testing_rf_r2_" + str(iters) + ".npy", arr=rf_model_testing_r2)
    np.save(file="..\..\Results\Res_Diabetes\OMAL4\Summary\\testing_rf_mse_" + str(iters) + ".npy", arr=rf_model_testing_mse)
    np.save(file="..\..\Results\Res_Diabetes\OMAL4\Summary\\training_rf_r2_" + str(iters) + ".npy", arr=rf_model_training_r2)
    np.save(file="..\..\Results\Res_Diabetes\OMAL4\Summary\\training_rf_mse_" + str(iters) + ".npy", arr=rf_model_training_mse)

# %%
for i in range(iteration):
    print("The Iteration is ", i)
    main_function(query_number, i)
# Out:
# The Iteration is  0
# NN Test R2 with 5 samples -3.282536053905696
# After Initialization RF R2: 0.01017105099476967
# NN Test R2 after Initialization -2.228283986281242
# (10, 10)
# Query no. 1
# Embeddings training score: 0.9204437912716656
# (20, 10)
# RF R2: 0.21811132183635729
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.7831554814328421
# (30, 10)
# RF R2: 0.5356913843247845
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8746153936746729
# (40, 10)
# RF R2: 0.48970129105948157
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8683564549559666
# (50, 10)
# RF R2: 0.48806901619275134
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8811961122808505
# (60, 10)
# RF R2: 0.4373805751139379
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8761004123181985
# (70, 10)
# RF R2: 0.4987859842669736
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8785109353103423
# (80, 10)
# RF R2: 0.5460116922962551
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8785257486146121
# (90, 10)
# RF R2: 0.505493897093658
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.88181720662132
# (100, 10)
# RF R2: 0.48812475753730145
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8788496361656151
# (110, 10)
# RF R2: 0.4678038002364414
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8600526058274116
# (120, 10)
# RF R2: 0.5137918035130895
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8640327604953122
# (130, 10)
# RF R2: 0.4766040139377413
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.862726985248089
# (140, 10)
# RF R2: 0.49714285770839994
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8643230658965684
# (150, 10)
# RF R2: 0.5292666418117417
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8667484005795485
# (160, 10)
# RF R2: 0.4903317509078037
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8716266851389481
# (170, 10)
# RF R2: 0.5187466966125553
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8633303431134315
# (180, 10)
# RF R2: 0.5344209497583954
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.862312631258084
# (190, 10)
# RF R2: 0.5307892218451802
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.863187713199996
# (200, 10)
# RF R2: 0.5397078011294741
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8656583001720333
# (210, 10)
# RF R2: 0.5282916252151051
# Remaining: 143
# The Iteration is  1
# NN Test R2 with 5 samples -3.73851464599398
# After Initialization RF R2: 0.20844341964741697
# NN Test R2 after Initialization -0.5822922011470901
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8408545921837103
# (20, 10)
# RF R2: 0.28119028926261946
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.9324723325066419
# (30, 10)
# RF R2: 0.3083912013446808
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8699969137028896
# (40, 10)
# RF R2: 0.29284965642673455
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8699424044323096
# (50, 10)
# RF R2: 0.35993066029173837
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8808528800773633
# (60, 10)
# RF R2: 0.3748577476768705
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8605475394351231
# (70, 10)
# RF R2: 0.38638047428778965
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8640648452560025
# (80, 10)
# RF R2: 0.42053862962097444
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8610074392127
# (90, 10)
# RF R2: 0.40364678269298826
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8605850622935884
# (100, 10)
# RF R2: 0.41951042820916584
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8651661912401352
# (110, 10)
# RF R2: 0.4121903811511345
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8573934103704706
# (120, 10)
# RF R2: 0.4143285600557016
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8597872992634101
# (130, 10)
# RF R2: 0.43794592884253947
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8662314540650646
# (140, 10)
# RF R2: 0.44496928386512313
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8655970205523432
# (150, 10)
# RF R2: 0.4465759163482267
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8598840989841996
# (160, 10)
# RF R2: 0.46841680599084634
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.861971411917096
# (170, 10)
# RF R2: 0.47624068870926106
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8604399425958819
# (180, 10)
# RF R2: 0.4959683879153547
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.86533945969487
# (190, 10)
# RF R2: 0.4992503811395391
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8614457514741496
# (200, 10)
# RF R2: 0.5208605084056996
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8580203160890845
# (210, 10)
# RF R2: 0.47797657852690023
# Remaining: 143
# The Iteration is  2
# NN Test R2 with 5 samples -3.6582795859288324
# After Initialization RF R2: 0.2925063658507443
# NN Test R2 after Initialization -3.6049624418028308
# (10, 10)
# Query no. 1
# Embeddings training score: 0.9145750336607154
# (20, 10)
# RF R2: 0.31105183002067505
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8725493195777347
# (30, 10)
# RF R2: 0.3838066503622455
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.844820695471177
# (40, 10)
# RF R2: 0.36040543719935025
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.836492951531205
# (50, 10)
# RF R2: 0.39337960124130744
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8437262856681185
# (60, 10)
# RF R2: 0.32622125692402726
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8438541861874629
# (70, 10)
# RF R2: 0.3675873453876547
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8394282670781043
# (80, 10)
# RF R2: 0.36400863143798656
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8308026591424735
# (90, 10)
# RF R2: 0.37413708484254715
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.834065670961572
# (100, 10)
# RF R2: 0.39679988088243867
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8346509713094197
# (110, 10)
# RF R2: 0.3977969476438784
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8392977593299441
# (120, 10)
# RF R2: 0.40018493845001757
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8492469876901164
# (130, 10)
# RF R2: 0.4195958859324853
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.842482765889785
# (140, 10)
# RF R2: 0.4183665591688589
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8446453139302523
# (150, 10)
# RF R2: 0.42637619878682853
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8439997226679814
# (160, 10)
# RF R2: 0.3784601354225855
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8404186824616373
# (170, 10)
# RF R2: 0.4044238566145706
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8460160994031175
# (180, 10)
# RF R2: 0.4088419046150653
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8463333632765722
# (190, 10)
# RF R2: 0.44200216935458236
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8488510601615524
# (200, 10)
# RF R2: 0.4282135916179909
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8492560499276818
# (210, 10)
# RF R2: 0.41593166594437747
# Remaining: 143
# The Iteration is  3
# NN Test R2 with 5 samples -4.171813868903855
# After Initialization RF R2: 0.36481536421176197
# NN Test R2 after Initialization -3.8342633375930277
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8638874579450935
# (20, 10)
# RF R2: 0.40744928842807715
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8217127489493979
# (30, 10)
# RF R2: 0.39668030538688837
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8414514708732446
# (40, 10)
# RF R2: 0.40125802192593174
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8625670471416945
# (50, 10)
# RF R2: 0.49347454710609817
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.865838958522629
# (60, 10)
# RF R2: 0.4713678330526784
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8650081920385447
# (70, 10)
# RF R2: 0.4643553155192971
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8604179084155952
# (80, 10)
# RF R2: 0.5174188505759487
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8497611494177075
# (90, 10)
# RF R2: 0.43978239496969473
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8549331671919009
# (100, 10)
# RF R2: 0.46153776399938495
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8524587496187667
# (110, 10)
# RF R2: 0.48542284952531645
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8609452554288876
# (120, 10)
# RF R2: 0.46991220077769436
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8569994672569355
# (130, 10)
# RF R2: 0.4724975580636003
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8570246954737208
# (140, 10)
# RF R2: 0.49220064308039846
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8563907068174383
# (150, 10)
# RF R2: 0.4598620511056588
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8694501062155684
# (160, 10)
# RF R2: 0.4202875877936211
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8671698958967329
# (170, 10)
# RF R2: 0.416946791355744
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.873170962774546
# (180, 10)
# RF R2: 0.46007673809172067
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8796700512298563
# (190, 10)
# RF R2: 0.4397307864737776
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8848434139506607
# (200, 10)
# RF R2: 0.47262201782031144
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8729676644397119
# (210, 10)
# RF R2: 0.47977826654403666
# Remaining: 143
# The Iteration is  4
# NN Test R2 with 5 samples -3.9650951178957783
# After Initialization RF R2: 0.2647513237024165
# NN Test R2 after Initialization -3.7397893930601853
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8388686945605823
# (20, 10)
# RF R2: 0.33025243437194984
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8684913978590454
# (30, 10)
# RF R2: 0.3766926798641259
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.9118191064381047
# (40, 10)
# RF R2: 0.3541182301156395
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8900807619232155
# (50, 10)
# RF R2: 0.5493745191976904
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8855778403586055
# (60, 10)
# RF R2: 0.5482460220207064
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8850659458718577
# (70, 10)
# RF R2: 0.5573845651888555
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8747998283274709
# (80, 10)
# RF R2: 0.5421282091249914
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8750513667099613
# (90, 10)
# RF R2: 0.573491216361075
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8674728746003637
# (100, 10)
# RF R2: 0.571808009324395
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8711144931985957
# (110, 10)
# RF R2: 0.5554063803114492
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8688067212621076
# (120, 10)
# RF R2: 0.5683305760111117
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8705142531974162
# (130, 10)
# RF R2: 0.5530545418157351
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8723718201113424
# (140, 10)
# RF R2: 0.5211569769259525
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8793843370191622
# (150, 10)
# RF R2: 0.5113356348983378
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.878150226500065
# (160, 10)
# RF R2: 0.5212460761853808
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8793581479000993
# (170, 10)
# RF R2: 0.4842161628412175
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8764333174364853
# (180, 10)
# RF R2: 0.46873309874079505
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8732591012233322
# (190, 10)
# RF R2: 0.47058271919714467
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8718624682048841
# (200, 10)
# RF R2: 0.5254059899355357
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8735773839650842
# (210, 10)
# RF R2: 0.5299262295387335
# Remaining: 143
# The Iteration is  5
# NN Test R2 with 5 samples -4.003595500069585
# After Initialization RF R2: 0.21088154412423232
# NN Test R2 after Initialization -1.1440074318963693
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8266345444414684
# (20, 10)
# RF R2: 0.23011278120003043
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8819976164171361
# (30, 10)
# RF R2: 0.23549292092111007
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8507102714320156
# (40, 10)
# RF R2: 0.29528230792046173
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8176463334971225
# (50, 10)
# RF R2: 0.3953307022820004
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8322846886314743
# (60, 10)
# RF R2: 0.462087131723493
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8369245351803917
# (70, 10)
# RF R2: 0.4960740552506564
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8367856220029427
# (80, 10)
# RF R2: 0.4500034154957009
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8456302849157535
# (90, 10)
# RF R2: 0.4930753673341035
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8381076717830043
# (100, 10)
# RF R2: 0.47621260360152196
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8417328107419388
# (110, 10)
# RF R2: 0.4763091082747475
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8454446342683982
# (120, 10)
# RF R2: 0.4888119572067372
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8407544206324195
# (130, 10)
# RF R2: 0.4912655245256933
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8483147875738893
# (140, 10)
# RF R2: 0.49146242211379465
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.841651828461652
# (150, 10)
# RF R2: 0.5070660488167043
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.843254039184907
# (160, 10)
# RF R2: 0.4838676077255202
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8414566645589101
# (170, 10)
# RF R2: 0.5054923007547256
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8618130213489238
# (180, 10)
# RF R2: 0.5013223995781239
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8632292518443778
# (190, 10)
# RF R2: 0.4957762365146835
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.869002224747718
# (200, 10)
# RF R2: 0.5177086769703141
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8660777483292853
# (210, 10)
# RF R2: 0.5115257151578657
# Remaining: 143
# The Iteration is  6
# NN Test R2 with 5 samples -4.6164374724668775
# After Initialization RF R2: 0.2874004649780366
# NN Test R2 after Initialization -1.3103681681843802
# (10, 10)
# Query no. 1
# Embeddings training score: 0.776066172348578
# (20, 10)
# RF R2: 0.347637072309923
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8665570702521059
# (30, 10)
# RF R2: 0.31383240819174796
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8485132643353763
# (40, 10)
# RF R2: 0.3501215502061862
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8486437173468132
# (50, 10)
# RF R2: 0.3290291219651915
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8453153595650389
# (60, 10)
# RF R2: 0.33668175046012017
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8358712574406513
# (70, 10)
# RF R2: 0.27428183824490515
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8481187275911785
# (80, 10)
# RF R2: 0.29332059054657056
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8502104328533675
# (90, 10)
# RF R2: 0.3572798576822742
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8553107788058787
# (100, 10)
# RF R2: 0.390505057571258
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8404564326693322
# (110, 10)
# RF R2: 0.431173403391496
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8399471747815972
# (120, 10)
# RF R2: 0.4276228134181146
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8410450834706945
# (130, 10)
# RF R2: 0.4336875297804621
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8402511871524527
# (140, 10)
# RF R2: 0.3906961158620188
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8429204456170281
# (150, 10)
# RF R2: 0.39329977390648696
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8475334991293768
# (160, 10)
# RF R2: 0.41955772971892713
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8493912035620294
# (170, 10)
# RF R2: 0.42891923879103877
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8497299450600447
# (180, 10)
# RF R2: 0.42773493522641115
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8516232725926796
# (190, 10)
# RF R2: 0.40239533569474695
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8523746389731963
# (200, 10)
# RF R2: 0.4096648640562417
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8546335434452156
# (210, 10)
# RF R2: 0.40371345984878015
# Remaining: 143
# The Iteration is  7
# NN Test R2 with 5 samples -4.933883468459245
# After Initialization RF R2: 0.19370117539677523
# NN Test R2 after Initialization -4.101933548411667
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8274456568444256
# (20, 10)
# RF R2: 0.2007600840369903
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8937781514300936
# (30, 10)
# RF R2: 0.24088555962593994
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8783432715633265
# (40, 10)
# RF R2: 0.21427641109422269
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8542440155870217
# (50, 10)
# RF R2: 0.3908279650073613
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8530390953508441
# (60, 10)
# RF R2: 0.41056668573104815
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8534884136413937
# (70, 10)
# RF R2: 0.4044290149490938
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8651980845256824
# (80, 10)
# RF R2: 0.4027156882606837
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8587701981605997
# (90, 10)
# RF R2: 0.3652451935366158
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8622025072075028
# (100, 10)
# RF R2: 0.39576742746122195
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8667173809080382
# (110, 10)
# RF R2: 0.38346293165432754
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8691622672383797
# (120, 10)
# RF R2: 0.394624318305022
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.862047574049964
# (130, 10)
# RF R2: 0.3502924911857982
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8679743155390557
# (140, 10)
# RF R2: 0.3999888188502535
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8684910173677363
# (150, 10)
# RF R2: 0.4062065039069642
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8650912341710374
# (160, 10)
# RF R2: 0.41771757114487695
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8662648530429868
# (170, 10)
# RF R2: 0.42909608368022056
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8642938226180219
# (180, 10)
# RF R2: 0.42079751492315476
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8650877569087139
# (190, 10)
# RF R2: 0.40713868745392345
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8637584828600883
# (200, 10)
# RF R2: 0.40945398640221675
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8620491035912325
