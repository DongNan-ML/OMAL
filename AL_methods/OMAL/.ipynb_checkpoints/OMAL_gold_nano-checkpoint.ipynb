# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from modAL.models import ActiveLearner, CommitteeRegressor
from modAL.disagreement import vote_entropy_sampling, max_std_sampling
import matplotlib.pyplot as plt
import torch
from torch.nn import MSELoss
from skorch.regressor import NeuralNetRegressor
from copy import deepcopy
from skorch.dataset import ValidSplit
from skorch.callbacks import EarlyStopping
from sklearn.cluster import DBSCAN, OPTICS, cluster_optics_dbscan, Birch, SpectralClustering
from sklearn.neighbors import NearestNeighbors
from sklearn import metrics
import matplotlib.gridspec as gridspec
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from torch.nn import Linear
from torch.nn import Sigmoid, ReLU
from torch.nn import Module
from sklearn.metrics import r2_score
import copy
from scipy.spatial import distance
from scipy.spatial.distance import euclidean
from torch import tensor
from sklearn.metrics import mean_squared_error
from scipy.spatial.distance import cdist
from sklearn.ensemble import RandomForestRegressor
from torch.nn.init import xavier_uniform_
from model import MLP
from model_state import get_model_params, get_input_for_hidden_layers, get_model_params_gradientNorm
from functions_batch1 import get_variance, qbc, normalization, error_reduct_fuc, total_disagrement, grad_norm, averaged_grad_norm, get_avg_grad_norm, training_loss
import random
from skorch.callbacks import EarlyStopping, LRScheduler, Freezer, Unfreezer
from torch.optim.lr_scheduler import CyclicLR, ReduceLROnPlateau
from skorch.regressor import NeuralNetRegressor, NeuralNet
from model_state import features_concat, learning_state_features_concat
import gc
import warnings
from modAL.utils.selection import multi_argmax
warnings.filterwarnings("ignore")

# %%
# Hyper-params:
query_number = 20     # The number of the AL Iterations in each Exp
iteration = 20         # Total number of the Exps
batch_size = 40
total_initail_size = 96
initial_size = 5
dimensions = 190   # Total dimension of the data features + model states

seed_rf = np.load(file="..\..\seed2.npy")
seed_initial = np.load(file="..\..\seed3.npy")

seed_nn1 = np.load(file="..\..\seed4.npy")
seed_nn2 = np.load(file="..\..\seed4.npy")
seed_nn3 = np.load(file="..\..\seed5.npy")
seed_nn4 = np.load(file="..\..\seed5.npy")
seed_nn5 = np.load(file="..\..\seed6.npy")
seed_nn6 = np.load(file="..\..\seed6.npy")

seed_predictor = np.load(file="..\..\seed7.npy")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def Committee_Prediction(learner_list, X_test, y_test):
    initial_pred=[]
    for i in learner_list:
        initial_pred.append(r2_score(y_test, i.predict(X_test)))
    initial_pred=np.array(initial_pred)
    
    return initial_pred.mean()

# %%
def main_function(query_number, iters):
    # For saving results:
    rf_model_training_r2 = []
    rf_model_training_mse = []
    rf_model_testing_r2 = []
    rf_model_testing_mse = []
    
    # Number of member in committee:
    n_members = 3
    learner_list = []
    
    # The model for evaluation:
    rf_model = RandomForestRegressor(random_state=seed_rf[iters], n_estimators=100)
    gradient_norms = np.empty(shape=(0, 0))
    
    # Load the data:
    name1 = "..\..\Datasets\Gold_Nano\X_train" + str(iters) + ".npy"
    name2 = "..\..\Datasets\Gold_Nano\X_test" + str(iters) + ".npy"
    name3 = "..\..\Datasets\Gold_Nano\y_train" + str(iters) + ".npy"
    name4 = "..\..\Datasets\Gold_Nano\y_test" + str(iters) + ".npy"
    
    X_train = np.load(name1, allow_pickle=True).astype(np.float32)
    X_test = np.load(name2, allow_pickle=True).astype(np.float32)
    y_train = np.load(name3, allow_pickle=True).astype(np.float32).reshape(-1, 1)
    y_test = np.load(name4, allow_pickle=True).astype(np.float32).reshape(-1, 1)
    
    # Dimensionality of data:
    X = X_train.shape[1]
    # The index of the unlabeled pool:
    X_index = np.arange(X_train.shape[0])

    used_data = np.empty(shape=(0, X))
    used_label = np.empty(shape=(0)).reshape(-1, 1)

    X_initial = np.empty(shape=(0,X))
    y_initial = np.empty(shape=(0)).reshape(-1, 1)
    
    # Initial Stage 1:
    np.random.seed(seed_initial[iters])
    idx = np.random.choice(range(len(X_index)), size=initial_size, replace=False)
    train_idx = X_index[idx]

    X_initial = X_train[train_idx]
    y_initial = y_train[train_idx].reshape(-1, 1)

    used_data = np.append(used_data, X_initial, axis=0).astype(np.float32)
    used_label = np.append(used_label, y_initial, axis=0).astype(np.float32).reshape(-1, 1)
    X_index = np.delete(X_index, idx, axis=0)

    
    used_data = torch.from_numpy(used_data).to(device)
    used_label = torch.from_numpy(used_label).to(device)
    for member_idx in range(n_members):
        if member_idx == 0:
            np.random.seed(seed_nn1[iters])
            torch.manual_seed(seed_nn2[iters])
        if member_idx == 1:
            np.random.seed(seed_nn3[iters])
            torch.manual_seed(seed_nn4[iters])
        if member_idx == 2:
            np.random.seed(seed_nn5[iters])
            torch.manual_seed(seed_nn6[iters])
            
        regressor = NeuralNetRegressor(MLP(X),
                                   criterion=MSELoss(),
                                   optimizer=torch.optim.Adam,
                                   verbose=0,
                                   max_epochs=30,
                                   lr=0.001,
                                   # Used for the batch AL
                                   callbacks=[EarlyStopping(patience=5), ('lr_scheduler', LRScheduler(policy=ReduceLROnPlateau))],
                                   train_split=ValidSplit(cv=5),
                                   warm_start=True,
                                   device='cuda',
                                   batch_size = 200
                                   )
        regressor.fit(used_data, used_label)
        learner_list.append(regressor)
    
    print("NN Test R2 with 5 samples", Committee_Prediction(learner_list, X_test, y_test))

    # Number of LAL features:
    learning_state_features = np.empty(shape=(0, dimensions))
    loss_reduction_target = np.empty(shape=(0)).reshape(-1, 1)

    # other random samples:
    rest_initial_X = np.empty(shape=(0, X))
    rest_initial_y = np.empty(shape=(0)).reshape(-1, 1)

    # LAL Initialization: Stage 2
    predictor = RandomForestRegressor(n_estimators=1000, random_state=seed_predictor[iters])
    np.random.seed(seed_initial[iters])
    idx = np.random.choice(range(len(X_index)), size=total_initail_size-initial_size, replace=False)
    train_idx = X_index[idx]
    
    rest_initial_X = np.append(rest_initial_X, X_train[train_idx], axis=0).astype(np.float32)
    rest_initial_y = np.append(rest_initial_y, y_train[train_idx], axis=0).astype(np.float32).reshape(-1, 1)

    X_index = np.delete(X_index, idx, axis=0)

    for i in range(rest_initial_X.shape[0]):

        single_X = rest_initial_X[i],
        single_y = rest_initial_y[i].reshape(1, -1)
        single_X = single_X[0].reshape(1, -1)
        
        single_X = torch.from_numpy(single_X).to(device)
        single_y = torch.from_numpy(single_y).to(device)

        # Model params
        model_params = get_model_params_gradientNorm(learner_list)

        # updated data
        used_data = torch.cat((used_data, single_X), 0)
        used_label = torch.cat((used_label, single_y), 0)

        # Retrain the model:
        for l in learner_list:
            l.fit(X=used_data,y=used_label)
            
        single_X = single_X.cpu().numpy()
        single_y = single_y.cpu().numpy()
            
        index = train_idx[i]

        # The training sample:
        data_params = X_train[index]
      
        LALfeatures = features_concat(model_params, data_params)

        loss_reduction = get_avg_grad_norm(learner_list, single_X, single_y)
        
        learning_state_features = learning_state_features_concat(learning_state_features, LALfeatures)
        loss_reduction_target = np.append(loss_reduction_target, np.array([loss_reduction]).reshape(-1, 1), axis=0).astype(np.float32).reshape(-1, 1)

        
    used_data = used_data.cpu().numpy()
    used_label = used_label.cpu().numpy()

    # Finished the Initialization Stages:
    # RF Regressor for evaluation:
    rf_model.fit(used_data, used_label.ravel())
    # Training Scores:
    rf_training_r2 = r2_score(used_label, rf_model.predict(used_data))
    rf_training_mse = mean_squared_error(used_label, rf_model.predict(used_data))
    rf_model_training_r2.append(rf_training_r2)
    rf_model_training_mse.append(rf_training_mse)
    
    # Test Scores:
    rf_model_r2 = r2_score(y_test, rf_model.predict(X_test))
    rf_model_mse = mean_squared_error(y_test, rf_model.predict(X_test))
    rf_model_testing_r2.append(rf_model_r2)
    rf_model_testing_mse.append(rf_model_mse)
    
    print("After Initialization RF R2:", rf_model_r2)
    print("NN Test R2 after Initialization", Committee_Prediction(learner_list, X_test, y_test))

    print(np.unique(used_data, axis=0).shape)
    for idx in range(query_number):
        np.random.seed(None)
        print('Query no. %d' % (idx+1))

        Error_reduction_list, training_score = error_reduct_fuc(X_train, X_index, learner_list, learning_state_features, loss_reduction_target, X_index.shape[0], predictor)

        idx = multi_argmax(np.array(Error_reduction_list), n_instances=batch_size)
       
        X_train_indices = X_index[idx]
        
        # Update
        X_index = np.delete(X_index, idx, axis=0)

        for X_train_index in X_train_indices:

            new_X = X_train[X_train_index].reshape(1, -1)
            new_y = y_train[X_train_index].reshape(1, -1)
            
            used_data = np.append(used_data, new_X, axis=0).astype(np.float32)
            used_label = np.append(used_label, new_y, axis=0).astype(np.float32).reshape(-1, 1)
            
            used_data = torch.from_numpy(used_data).to(device)
            used_label = torch.from_numpy(used_label).to(device)

            # Model params
            model_params = get_model_params_gradientNorm(learner_list)
            data_params = X_train[X_train_index]
            LALfeatures = features_concat(model_params, data_params)
            
            for l in learner_list:
                l.fit(used_data, used_label)
            
            used_data = used_data.cpu().numpy()
            used_label = used_label.cpu().numpy()

            loss_reduction = get_avg_grad_norm(learner_list, new_X, new_y)  
            gradient_norms = np.append(gradient_norms, loss_reduction)
            
            learning_state_features = learning_state_features_concat(learning_state_features, LALfeatures)
            loss_reduction_target = np.append(loss_reduction_target, np.array([loss_reduction]).reshape(-1, 1), axis=0).astype(np.float32).reshape(-1, 1)
        

        # RF Evaluation
        rf_model.fit(used_data, used_label.ravel())
        
        # Training Evaluation:
        rf_training_r2 = r2_score(used_label, rf_model.predict(used_data))
        rf_training_mse = mean_squared_error(used_label, rf_model.predict(used_data))
        rf_model_training_r2.append(rf_training_r2)
        rf_model_training_mse.append(rf_training_mse)
        
        # Test Evaluation:
        rf_model_r2 = r2_score(y_test, rf_model.predict(X_test))
        rf_model_mse = mean_squared_error(y_test, rf_model.predict(X_test))
        rf_model_testing_r2.append(rf_model_r2)
        rf_model_testing_mse.append(rf_model_mse)

        print(np.unique(used_data, axis=0).shape)
        print("RF R2:", rf_model_r2)
        print("Remaining:", X_index.shape[0])
        # print('NN R2', Committee_Prediction(learner_list, X_test, y_test))

    # RF
    rf_model_testing_r2 = np.array(rf_model_testing_r2)
    rf_model_testing_mse = np.array(rf_model_testing_mse)
    rf_model_training_r2 = np.array(rf_model_training_r2)
    rf_model_training_mse = np.array(rf_model_training_mse)
    
    # Used_data and Unsed_label:
    np.save(file="..\..\Results\Res_Gold\OMAL\Summary\\used_data" + str(iters) + ".npy", arr=used_data)
    np.save(file="..\..\Results\Res_Gold\OMAL\Summary\\used_labels" + str(iters) + ".npy", arr=used_label)

    np.save(file="..\..\Results\Res_Gold\OMAL\Summary\\testing_rf_r2_" + str(iters) + ".npy", arr=rf_model_testing_r2)
    np.save(file="..\..\Results\Res_Gold\OMAL\Summary\\testing_rf_mse_" + str(iters) + ".npy", arr=rf_model_testing_mse)
    np.save(file="..\..\Results\Res_Gold\OMAL\Summary\\training_rf_r2_" + str(iters) + ".npy", arr=rf_model_training_r2)
    np.save(file="..\..\Results\Res_Gold\OMAL\Summary\\training_rf_mse_" + str(iters) + ".npy", arr=rf_model_training_mse)

# %%
for i in range(iteration):
    print("The Iteration is ", i)
    main_function(query_number, i)
# Out:
# The Iteration is  5
# NN Test R2 with 5 samples -1.2319027962509865
# After Initialization RF R2: 0.8859922033066735
# NN Test R2 after Initialization 0.8933287559272814
# (96, 182)
# Query no. 1
# Embeddings training score: 0.9160192953758828
# (136, 182)
# RF R2: 0.9178874517954428
# Remaining: 3063
# Query no. 2
# Embeddings training score: 0.9008496738021728
# (176, 182)
# RF R2: 0.9584593509736558
# Remaining: 3023
# Query no. 3
# Embeddings training score: 0.9216605693063261
# (216, 182)
# RF R2: 0.9696069932637223
# Remaining: 2983
# Query no. 4
# Embeddings training score: 0.9036361380696244
# (256, 182)
# RF R2: 0.9762337174779263
# Remaining: 2943
# Query no. 5
# Embeddings training score: 0.8926583872787357
# (296, 182)
# RF R2: 0.9765314215407285
# Remaining: 2903
# Query no. 6
# Embeddings training score: 0.881891716198192
# (336, 182)
# RF R2: 0.9775030869520012
# Remaining: 2863
# Query no. 7
# Embeddings training score: 0.8840523879303799
# (376, 182)
# RF R2: 0.9803985976020582
# Remaining: 2823
# Query no. 8
# Embeddings training score: 0.8879002016048978
# (416, 182)
# RF R2: 0.9851380442787478
# Remaining: 2783
# Query no. 9
# Embeddings training score: 0.8870841756377621
# (456, 182)
# RF R2: 0.9850364735273818
# Remaining: 2743
# Query no. 10
# Embeddings training score: 0.8861488920451344
# (496, 182)
# RF R2: 0.9857537989773836
# Remaining: 2703
# Query no. 11
# Embeddings training score: 0.8898908521619859
# (536, 182)
# RF R2: 0.9848886340264701
# Remaining: 2663
# Query no. 12
# Embeddings training score: 0.8873623131308156
# (576, 182)
# RF R2: 0.9841874089060706
# Remaining: 2623
# Query no. 13
# Embeddings training score: 0.8888783144777697
# (616, 182)
# RF R2: 0.9845800931225909
# Remaining: 2583
# Query no. 14
# Embeddings training score: 0.8903333148697667
# (656, 182)
# RF R2: 0.9846044761187205
# Remaining: 2543
# Query no. 15
# Embeddings training score: 0.8925615471460174
# (696, 182)
# RF R2: 0.9855836942711891
# Remaining: 2503
# Query no. 16
# Embeddings training score: 0.8946629257917951
# (736, 182)
# RF R2: 0.9870674900392342
# Remaining: 2463
# Query no. 17
# Embeddings training score: 0.8954571452005732
# (776, 182)
# RF R2: 0.986354144160865
# Remaining: 2423
# Query no. 18
# Embeddings training score: 0.8956093294823414
# (816, 182)
# RF R2: 0.9873491991867039
# Remaining: 2383
# Query no. 19
# Embeddings training score: 0.897102548460185
# (856, 182)
# RF R2: 0.9868174638617745
# Remaining: 2343
# Query no. 20
# Embeddings training score: 0.8969494110890748
# (896, 182)
# RF R2: 0.9868205808122023
# Remaining: 2303
# The Iteration is  6
# NN Test R2 with 5 samples -1.2221040754307728
# After Initialization RF R2: 0.887956907895902
# NN Test R2 after Initialization 0.8042721261004028
# (96, 182)
# Query no. 1
# Embeddings training score: 0.9207232169625786
# (136, 182)
# RF R2: 0.9427660974789077
# Remaining: 3063
# Query no. 2
# Embeddings training score: 0.9024512618049075
# (176, 182)
# RF R2: 0.9576306666205973
# Remaining: 3023
# Query no. 3
# Embeddings training score: 0.9027379711732179
# (216, 182)
# RF R2: 0.9271426854119869
# Remaining: 2983
# Query no. 4
# Embeddings training score: 0.8988497609027576
# (256, 182)
# RF R2: 0.9278055242332991
# Remaining: 2943
# Query no. 5
# Embeddings training score: 0.8984830327501406
# (296, 182)
# RF R2: 0.9231824782342658
# Remaining: 2903
# Query no. 6
# Embeddings training score: 0.8969342472131976
# (336, 182)
# RF R2: 0.9687048248315833
# Remaining: 2863
# Query no. 7
# Embeddings training score: 0.9170379364587627
# (376, 182)
# RF R2: 0.9734127700070774
# Remaining: 2823
# Query no. 8
# Embeddings training score: 0.9269918121714891
# (416, 182)
# RF R2: 0.972037765322617
# Remaining: 2783
# Query no. 9
# Embeddings training score: 0.9281176406135732
# (456, 182)
# RF R2: 0.9752421386136825
# Remaining: 2743
# Query no. 10
# Embeddings training score: 0.9263881530947948
# (496, 182)
# RF R2: 0.9802560526969731
# Remaining: 2703
# Query no. 11
# Embeddings training score: 0.9270438251387657
# (536, 182)
# RF R2: 0.9812842719597328
# Remaining: 2663
# Query no. 12
# Embeddings training score: 0.9251829359686825
# (576, 182)
# RF R2: 0.9818477743234485
# Remaining: 2623
# Query no. 13
# Embeddings training score: 0.927135162886013
# (616, 182)
# RF R2: 0.9827642500442987
# Remaining: 2583
# Query no. 14
# Embeddings training score: 0.9262222492423976
# (656, 182)
# RF R2: 0.9834556161678494
# Remaining: 2543
# Query no. 15
# Embeddings training score: 0.9275367794799383
# (696, 182)
# RF R2: 0.9835421588109653
# Remaining: 2503
# Query no. 16
# Embeddings training score: 0.9279617351248804
# (736, 182)
# RF R2: 0.9843352903991281
# Remaining: 2463
# Query no. 17
# Embeddings training score: 0.9287609768350842
# (776, 182)
# RF R2: 0.9846219761752054
# Remaining: 2423
# Query no. 18
# Embeddings training score: 0.9302218994122599
# (816, 182)
# RF R2: 0.984493046856187
# Remaining: 2383
# Query no. 19
# Embeddings training score: 0.9306145151286446
# (856, 182)
# RF R2: 0.9874668618721927
# Remaining: 2343
# Query no. 20
# Embeddings training score: 0.9321569208650136
# (896, 182)
# RF R2: 0.9876008632399117
# Remaining: 2303
# The Iteration is  7
# NN Test R2 with 5 samples -1.1656007851021102
# After Initialization RF R2: 0.78183891626151
# NN Test R2 after Initialization 0.25186835560864373
# (96, 182)
# Query no. 1
# Embeddings training score: 0.8779105114148249
# (136, 182)
# RF R2: 0.9039370006852818
# Remaining: 3063
# Query no. 2
# Embeddings training score: 0.8885614675228526
# (176, 182)
# RF R2: 0.9252184427901631
# Remaining: 3023
# Query no. 3
# Embeddings training score: 0.8607053159571256
# (216, 182)
# RF R2: 0.9743247754433639
# Remaining: 2983
# Query no. 4
# Embeddings training score: 0.8833444204095577
# (256, 182)
# RF R2: 0.9786685934252534
# Remaining: 2943
# Query no. 5
# Embeddings training score: 0.9023998858081707
# (296, 182)
# RF R2: 0.9787335085694818
# Remaining: 2903
# Query no. 6
# Embeddings training score: 0.8969176536341453
# (336, 182)
# RF R2: 0.9833076184983474
# Remaining: 2863
# Query no. 7
# Embeddings training score: 0.8979523162740206
# (376, 182)
# RF R2: 0.9812215889455905
# Remaining: 2823
# Query no. 8
# Embeddings training score: 0.8977854283113875
# (416, 182)
# RF R2: 0.9833855045819033
# Remaining: 2783
# Query no. 9
# Embeddings training score: 0.8960613792403064
# (456, 182)
# RF R2: 0.9838097426049403
# Remaining: 2743
# Query no. 10
# Embeddings training score: 0.8956006076572731
# (496, 182)
# RF R2: 0.9863419301743811
# Remaining: 2703
# Query no. 11
# Embeddings training score: 0.8972105157904366
# (536, 182)
# RF R2: 0.98513657219442
# Remaining: 2663
# Query no. 12
# Embeddings training score: 0.9004016153580069
# (576, 182)
# RF R2: 0.9864363032160329
# Remaining: 2623
# Query no. 13
# Embeddings training score: 0.9025776579387982
# (616, 182)
# RF R2: 0.9874414554921258
# Remaining: 2583
# Query no. 14
# Embeddings training score: 0.9015930236964287
# (656, 182)
# RF R2: 0.9871491763794691
# Remaining: 2543
# Query no. 15
# Embeddings training score: 0.9024605871096988
# (696, 182)
# RF R2: 0.9874749444305926
# Remaining: 2503
# Query no. 16
# Embeddings training score: 0.9034715910805862
# (736, 182)
# RF R2: 0.986795536102309
# Remaining: 2463
# Query no. 17
# Embeddings training score: 0.9038638369404124
# (776, 182)
# RF R2: 0.9866146712947453
# Remaining: 2423
# Query no. 18
# Embeddings training score: 0.9052999729717865
# (816, 182)
# RF R2: 0.9876154768523032
# Remaining: 2383
# Query no. 19
# Embeddings training score: 0.9053808577624314
# (856, 182)
# RF R2: 0.9864989599477724
# Remaining: 2343
# Query no. 20
# Embeddings training score: 0.9073108482877617
# (896, 182)
# RF R2: 0.9868040763855866
# Remaining: 2303
# The Iteration is  8
# NN Test R2 with 5 samples -1.2395556489785107
# After Initialization RF R2: 0.8696319136625977
# NN Test R2 after Initialization 0.7284998742206817
# (96, 182)
# Query no. 1
# Embeddings training score: 0.9116771483369512
# (136, 182)
# RF R2: 0.904779358993507
# Remaining: 3063
# Query no. 2
# Embeddings training score: 0.8937179231934876
# (176, 182)
# RF R2: 0.9379114400145411
# Remaining: 3023
# Query no. 3
# Embeddings training score: 0.8857956165344051
# (216, 182)
# RF R2: 0.9512075698753871
# Remaining: 2983
# Query no. 4
# Embeddings training score: 0.880412179330362
# (256, 182)
# RF R2: 0.961607651295829
# Remaining: 2943
# Query no. 5
# Embeddings training score: 0.8869771314295793
# (296, 182)
# RF R2: 0.968363506457138
# Remaining: 2903
# Query no. 6
# Embeddings training score: 0.8901253976914418
# (336, 182)
# RF R2: 0.964834550064307
# Remaining: 2863
# Query no. 7
# Embeddings training score: 0.8945135118667493
# (376, 182)
# RF R2: 0.9692829302173713
# Remaining: 2823
# Query no. 8
# Embeddings training score: 0.8973842212973788
# (416, 182)
# RF R2: 0.9712591228601355
# Remaining: 2783
# Query no. 9
# Embeddings training score: 0.9122776054437937
# (456, 182)
# RF R2: 0.9739341406322806
# Remaining: 2743
# Query no. 10
# Embeddings training score: 0.91149092826222
# (496, 182)
# RF R2: 0.9748290282921058
# Remaining: 2703
# Query no. 11
# Embeddings training score: 0.9107488691522587
# (536, 182)
# RF R2: 0.9768940642219663
# Remaining: 2663
# Query no. 12
# Embeddings training score: 0.9093442844224058
# (576, 182)
# RF R2: 0.9813058961085371
# Remaining: 2623
# Query no. 13
# Embeddings training score: 0.9102154879854698
# (616, 182)
# RF R2: 0.9817870674249747
# Remaining: 2583
# Query no. 14
# Embeddings training score: 0.9108028467995359
# (656, 182)
# RF R2: 0.9823359379697727
# Remaining: 2543
# Query no. 15
# Embeddings training score: 0.911373974897637
# (696, 182)
# RF R2: 0.9831990618684296
# Remaining: 2503
# Query no. 16
# Embeddings training score: 0.9132759379680947
# (736, 182)
# RF R2: 0.984143277694798
# Remaining: 2463
# Query no. 17
# Embeddings training score: 0.9146422664599102
# (776, 182)
# RF R2: 0.9848552032248056
# Remaining: 2423
# Query no. 18
# Embeddings training score: 0.9158517157044136
# (816, 182)
# RF R2: 0.9852348473141117
# Remaining: 2383
# Query no. 19
# Embeddings training score: 0.9173048173876731
# (856, 182)
# RF R2: 0.9871919305052159
# Remaining: 2343
# Query no. 20
# Embeddings training score: 0.9179786498176582
# (896, 182)
# RF R2: 0.9873224709219884
# Remaining: 2303
# The Iteration is  9
# NN Test R2 with 5 samples -1.2602636324943943
# After Initialization RF R2: 0.9071154224145173
# NN Test R2 after Initialization 0.8332263968184185
# (96, 182)
# Query no. 1
# Embeddings training score: 0.9135204267182063
# (136, 182)
# RF R2: 0.953987394845881
# Remaining: 3063
# Query no. 2
# Embeddings training score: 0.869437949827571
# (176, 182)
# RF R2: 0.9558064143508139
# Remaining: 3023
# Query no. 3
# Embeddings training score: 0.8763148007492292
# (216, 182)
# RF R2: 0.9774159683132333
# Remaining: 2983
# Query no. 4
# Embeddings training score: 0.9020683495306389
# (256, 182)
# RF R2: 0.9700329738587926
# Remaining: 2943
# Query no. 5
# Embeddings training score: 0.8940788753314651
# (296, 182)
# RF R2: 0.9758803908501398
# Remaining: 2903
# Query no. 6
# Embeddings training score: 0.8859824458679915
# (336, 182)
# RF R2: 0.9785613449421852
# Remaining: 2863
# Query no. 7
# Embeddings training score: 0.8881622912783842
# (376, 182)
# RF R2: 0.9792480671693838
# Remaining: 2823
# Query no. 8
# Embeddings training score: 0.8860560369660061
# (416, 182)
# RF R2: 0.9810112921591319
# Remaining: 2783
# Query no. 9
# Embeddings training score: 0.8875854516200163
# (456, 182)
# RF R2: 0.9819620564721254
# Remaining: 2743
# Query no. 10
# Embeddings training score: 0.8904087331061653
# (496, 182)
# RF R2: 0.9790920600456973
# Remaining: 2703
# Query no. 11
# Embeddings training score: 0.8885326906667018
# (536, 182)
# RF R2: 0.9799781968440063
# Remaining: 2663
# Query no. 12
# Embeddings training score: 0.8854055459450668
# (576, 182)
# RF R2: 0.9787613397870676
# Remaining: 2623
# Query no. 13
# Embeddings training score: 0.8866650875812492
# (616, 182)
# RF R2: 0.9798379384507382
# Remaining: 2583
# Query no. 14
# Embeddings training score: 0.8843653621849022
# (656, 182)
# RF R2: 0.9782116910017417
# Remaining: 2543
# Query no. 15
# Embeddings training score: 0.8861594514953499
# (696, 182)
# RF R2: 0.98011439881939
# Remaining: 2503
# Query no. 16
# Embeddings training score: 0.8869002055812426
# (736, 182)
# RF R2: 0.9801355913999868
# Remaining: 2463
# Query no. 17
# Embeddings training score: 0.8876628177454712
# (776, 182)
# RF R2: 0.981899081940439
# Remaining: 2423
# Query no. 18
# Embeddings training score: 0.888781737516978
# (816, 182)
# RF R2: 0.9836091108502654
# Remaining: 2383
# Query no. 19
# Embeddings training score: 0.8908456333308923
# (856, 182)
# RF R2: 0.9871852695898767
# Remaining: 2343
# Query no. 20
# Embeddings training score: 0.8923239565788189
# (896, 182)
# RF R2: 0.9890553789670997
# Remaining: 2303
# The Iteration is  10
# NN Test R2 with 5 samples -1.208123383282614
# After Initialization RF R2: 0.8729936160104628
# NN Test R2 after Initialization 0.48573604066686515
# (96, 182)
# Query no. 1
# Embeddings training score: 0.9016192050613028
# (136, 182)
# RF R2: 0.9059074385426674
# Remaining: 3063
# Query no. 2
# Embeddings training score: 0.8946889583002289
# (176, 182)
# RF R2: 0.933375970378949
# Remaining: 3023
# Query no. 3
# Embeddings training score: 0.8954729534034818
# (216, 182)
# RF R2: 0.9566125368906963
# Remaining: 2983
# Query no. 4
# Embeddings training score: 0.9110983671812884
# (256, 182)
# RF R2: 0.9741487131904583
# Remaining: 2943
# Query no. 5
# Embeddings training score: 0.9030000650201738
# (296, 182)
# RF R2: 0.9736032068299129
# Remaining: 2903
# Query no. 6
# Embeddings training score: 0.9016795119777274
# (336, 182)
# RF R2: 0.9732692999463635
# Remaining: 2863
# Query no. 7
# Embeddings training score: 0.8995744379233133
# (376, 182)
# RF R2: 0.9738236052343916
# Remaining: 2823
# Query no. 8
# Embeddings training score: 0.898898216437445
# (416, 182)
# RF R2: 0.9748932834535896
# Remaining: 2783
# Query no. 9
# Embeddings training score: 0.8985147770847414
# (456, 182)
# RF R2: 0.9713476541438986
# Remaining: 2743
# Query no. 10
# Embeddings training score: 0.8986385580268296
# (496, 182)
# RF R2: 0.9716807625613938
# Remaining: 2703
# Query no. 11
# Embeddings training score: 0.8997019023546754
# (536, 182)
# RF R2: 0.9702489310337311
# Remaining: 2663
# Query no. 12
# Embeddings training score: 0.8982248841999833
# (576, 182)
# RF R2: 0.974181224329998
# Remaining: 2623
# Query no. 13
# Embeddings training score: 0.8985622747830596
# (616, 182)
# RF R2: 0.9772223950404002
# Remaining: 2583
# Query no. 14
# Embeddings training score: 0.8986483654982377
# (656, 182)
# RF R2: 0.9774617316707553
# Remaining: 2543
# Query no. 15
# Embeddings training score: 0.8996111307962369
# (696, 182)
# RF R2: 0.9802493814641547
# Remaining: 2503
# Query no. 16
# Embeddings training score: 0.9007694203560775
# (736, 182)
# RF R2: 0.9805355300377684
# Remaining: 2463
# Query no. 17
# Embeddings training score: 0.9006247979372268
# (776, 182)
# RF R2: 0.9814554920214266
# Remaining: 2423
# Query no. 18
# Embeddings training score: 0.9015517435714931
# (816, 182)
# RF R2: 0.9817309150626822
# Remaining: 2383
# Query no. 19
# Embeddings training score: 0.9029451020716046
# (856, 182)
# RF R2: 0.9830267370279285
# Remaining: 2343
# Query no. 20
# Embeddings training score: 0.9046617010631639
# (896, 182)
# RF R2: 0.984613145950161
# Remaining: 2303
# The Iteration is  11
# NN Test R2 with 5 samples -1.2922122633938324
# After Initialization RF R2: 0.9048614279033528
# NN Test R2 after Initialization -0.24721245234688816
# (96, 182)
# Query no. 1
# Embeddings training score: 0.8948447816152605
# (136, 182)
# RF R2: 0.9184845094447852
# Remaining: 3063
# Query no. 2
# Embeddings training score: 0.8666532200016915
# (176, 182)
# RF R2: 0.9386321085418339
# Remaining: 3023
# Query no. 3
# Embeddings training score: 0.852080017134366
# (216, 182)
# RF R2: 0.9618778187339404
# Remaining: 2983
# Query no. 4
# Embeddings training score: 0.9210983245621664
# (256, 182)
# RF R2: 0.9615135037477602
# Remaining: 2943
# Query no. 5
# Embeddings training score: 0.920748298207452
# (296, 182)
# RF R2: 0.9576205961941051
# Remaining: 2903
# Query no. 6
# Embeddings training score: 0.9197775479771043
# (336, 182)
# RF R2: 0.9561169891789731
# Remaining: 2863
# Query no. 7
# Embeddings training score: 0.9195775578106202
# (376, 182)
# RF R2: 0.9751258159168279
# Remaining: 2823
# Query no. 8
# Embeddings training score: 0.9172136277620908
# (416, 182)
# RF R2: 0.9745148118014503
# Remaining: 2783
# Query no. 9
# Embeddings training score: 0.9168373228060157
# (456, 182)
# RF R2: 0.9718578944075696
# Remaining: 2743
# Query no. 10
# Embeddings training score: 0.9161614375907953
# (496, 182)
# RF R2: 0.977441372207246
# Remaining: 2703
# Query no. 11
# Embeddings training score: 0.9169456868244589
# (536, 182)
# RF R2: 0.9755526085653982
# Remaining: 2663
# Query no. 12
# Embeddings training score: 0.9183924852241194
# (576, 182)
# RF R2: 0.979049572516457
# Remaining: 2623
# Query no. 13
# Embeddings training score: 0.9170855190873474
# (616, 182)
# RF R2: 0.9784947091380531
# Remaining: 2583
# Query no. 14
# Embeddings training score: 0.9160307524266137
# (656, 182)
# RF R2: 0.9831151080309262
# Remaining: 2543
# Query no. 15
# Embeddings training score: 0.9176234100518215
# (696, 182)
# RF R2: 0.9826840337100623
# Remaining: 2503
# Query no. 16
# Embeddings training score: 0.9190071936710257
# (736, 182)
# RF R2: 0.9857856391492007
# Remaining: 2463
# Query no. 17
# Embeddings training score: 0.9188410770890527
# (776, 182)
# RF R2: 0.9857342451370182
# Remaining: 2423
# Query no. 18
# Embeddings training score: 0.920402674517181
# (816, 182)
# RF R2: 0.986316789627577
# Remaining: 2383
# Query no. 19
# Embeddings training score: 0.9205104519372187
# (856, 182)
# RF R2: 0.9893426522325843
# Remaining: 2343
# Query no. 20
# Embeddings training score: 0.9203041941591418
# (896, 182)
# RF R2: 0.9895565456361709
# Remaining: 2303
# The Iteration is  12
# NN Test R2 with 5 samples -1.1437947546654257
# After Initialization RF R2: 0.865642126336077
# NN Test R2 after Initialization 0.6849461787735246
# (96, 182)
# Query no. 1
# Embeddings training score: 0.9103982789452921
# (136, 182)
# RF R2: 0.9175061543809532
# Remaining: 3063
# Query no. 2
# Embeddings training score: 0.8955885187781276
# (176, 182)
# RF R2: 0.9585780118852658
# Remaining: 3023
# Query no. 3
# Embeddings training score: 0.8854519401104689
# (216, 182)
# RF R2: 0.9603289929807208
# Remaining: 2983
# Query no. 4
# Embeddings training score: 0.8743355922039151
# (256, 182)
# RF R2: 0.9745162176025701
# Remaining: 2943
# Query no. 5
# Embeddings training score: 0.876663924339406
# (296, 182)
# RF R2: 0.977076344943479
# Remaining: 2903
# Query no. 6
# Embeddings training score: 0.8863655607046843
# (336, 182)
# RF R2: 0.9792890543865048
# Remaining: 2863
# Query no. 7
# Embeddings training score: 0.8903153708423074
# (376, 182)
# RF R2: 0.9820015359812293
# Remaining: 2823
# Query no. 8
# Embeddings training score: 0.8891931358848821
# (416, 182)
# RF R2: 0.9834569645713518
# Remaining: 2783
# Query no. 9
# Embeddings training score: 0.8911033069763702
# (456, 182)
# RF R2: 0.9840861493017384
# Remaining: 2743
# Query no. 10
# Embeddings training score: 0.8937917811212446
# (496, 182)
# RF R2: 0.984931944572356
# Remaining: 2703
# Query no. 11
# Embeddings training score: 0.8947458995552771
# (536, 182)
# RF R2: 0.9849222992079489
# Remaining: 2663
# Query no. 12
# Embeddings training score: 0.8898571381001265
# (576, 182)
# RF R2: 0.9863358464880663
# Remaining: 2623
# Query no. 13
# Embeddings training score: 0.8904724761079009
# (616, 182)
# RF R2: 0.9872531909976482
# Remaining: 2583
# Query no. 14
# Embeddings training score: 0.891150832763869
# (656, 182)
# RF R2: 0.9874851452326754
# Remaining: 2543
# Query no. 15
# Embeddings training score: 0.8936471508253178
# (696, 182)
# RF R2: 0.9882771351217499
# Remaining: 2503
# Query no. 16
# Embeddings training score: 0.8942585822577418
# (736, 182)
# RF R2: 0.988637441645184
# Remaining: 2463
# Query no. 17
# Embeddings training score: 0.8953684801800819
# (776, 182)
# RF R2: 0.9887202220973875
# Remaining: 2423
# Query no. 18
# Embeddings training score: 0.8959874156423271
# (816, 182)
# RF R2: 0.989284732867043
# Remaining: 2383
# Query no. 19
# Embeddings training score: 0.8978000225866263
# (856, 182)
# RF R2: 0.9895694544834908
# Remaining: 2343
# Query no. 20
# Embeddings training score: 0.8971510596472079
# (896, 182)
# RF R2: 0.9899872219366398
# Remaining: 2303
# The Iteration is  13
# NN Test R2 with 5 samples -1.271236322264812
# After Initialization RF R2: 0.8903542183594455
# NN Test R2 after Initialization 0.653866075691644
# (96, 182)
# Query no. 1
# Embeddings training score: 0.8703144180264147
# (136, 182)
# RF R2: 0.9535318837723695
# Remaining: 3063
# Query no. 2
# Embeddings training score: 0.8979724212284137
# (176, 182)
# RF R2: 0.9301153600061537
# Remaining: 3023
# Query no. 3
# Embeddings training score: 0.9039053810843451
# (216, 182)
# RF R2: 0.9590204146016043
# Remaining: 2983
# Query no. 4
# Embeddings training score: 0.9020376044271472
# (256, 182)
# RF R2: 0.9672858163593687
# Remaining: 2943
# Query no. 5
# Embeddings training score: 0.8970945679778197
# (296, 182)
# RF R2: 0.968093928649416
# Remaining: 2903
# Query no. 6
# Embeddings training score: 0.8908005890066633
# (336, 182)
# RF R2: 0.9682339837814667
# Remaining: 2863
# Query no. 7
# Embeddings training score: 0.8920920258791647
# (376, 182)
# RF R2: 0.9686360125362675
# Remaining: 2823
# Query no. 8
# Embeddings training score: 0.8845484608710267
# (416, 182)
# RF R2: 0.9716896982963398
# Remaining: 2783
# Query no. 9
# Embeddings training score: 0.8837887076276609
# (456, 182)
# RF R2: 0.9720367954442777
# Remaining: 2743
# Query no. 10
# Embeddings training score: 0.8838293643712417
# (496, 182)
# RF R2: 0.9750032067575064
# Remaining: 2703
# Query no. 11
# Embeddings training score: 0.8845031990859531
# (536, 182)
# RF R2: 0.9782842205478209
# Remaining: 2663
# Query no. 12
# Embeddings training score: 0.8876655177639778
# (576, 182)
# RF R2: 0.9782253676099898
# Remaining: 2623
# Query no. 13
# Embeddings training score: 0.8889416592321516
# (616, 182)
# RF R2: 0.9806470005245992
# Remaining: 2583
# Query no. 14
# Embeddings training score: 0.8880150008553909
# (656, 182)
# RF R2: 0.9804726935762629
# Remaining: 2543
# Query no. 15
# Embeddings training score: 0.8889635586605134
# (696, 182)
# RF R2: 0.9804443284314828
# Remaining: 2503
# Query no. 16
# Embeddings training score: 0.8900005203570015
# (736, 182)
# RF R2: 0.9821061676164439
# Remaining: 2463
# Query no. 17
# Embeddings training score: 0.8896829941043889
# (776, 182)
# RF R2: 0.9822484984941666
# Remaining: 2423
# Query no. 18
# Embeddings training score: 0.8896901004209093
# (816, 182)
# RF R2: 0.9849374113910142
# Remaining: 2383
# Query no. 19
# Embeddings training score: 0.8890309584690201
# (856, 182)
# RF R2: 0.9855187574446272
# Remaining: 2343
# Query no. 20
# Embeddings training score: 0.8902673756456648
# (896, 182)
# RF R2: 0.9861121091979131
# Remaining: 2303
# The Iteration is  14
# NN Test R2 with 5 samples -1.158318865301606
# After Initialization RF R2: 0.8088875291423109
# NN Test R2 after Initialization 0.20121280240489467
# (96, 182)
# Query no. 1
# Embeddings training score: 0.9097235412781766
# (136, 182)
# RF R2: 0.9144241193494751
# Remaining: 3063
# Query no. 2
# Embeddings training score: 0.900031742047266
# (176, 182)
# RF R2: 0.9269445353908662
# Remaining: 3023
# Query no. 3
# Embeddings training score: 0.8973594154007696
# (216, 182)
# RF R2: 0.9511071120663623
# Remaining: 2983
# Query no. 4
# Embeddings training score: 0.8982303674372363
# (256, 182)
# RF R2: 0.9580581010356229
# Remaining: 2943
# Query no. 5
# Embeddings training score: 0.8963698743641508
# (296, 182)
# RF R2: 0.9565657505222267
# Remaining: 2903
# Query no. 6
# Embeddings training score: 0.8882814100351833
# (336, 182)
# RF R2: 0.9688702215569669
# Remaining: 2863
# Query no. 7
# Embeddings training score: 0.8978602022810472
# (376, 182)
# RF R2: 0.9746519194081501
# Remaining: 2823
# Query no. 8
# Embeddings training score: 0.8968309802386774
# (416, 182)
# RF R2: 0.9725805816304186
# Remaining: 2783
# Query no. 9
# Embeddings training score: 0.8962812952417465
# (456, 182)
# RF R2: 0.9771624801938039
# Remaining: 2743
# Query no. 10
# Embeddings training score: 0.8963399942335339
# (496, 182)
# RF R2: 0.9765598111540376
# Remaining: 2703
# Query no. 11
# Embeddings training score: 0.8975558629588285
# (536, 182)
# RF R2: 0.9798943443816263
# Remaining: 2663
# Query no. 12
# Embeddings training score: 0.8970634879886594
# (576, 182)
# RF R2: 0.9818114641357755
# Remaining: 2623
# Query no. 13
# Embeddings training score: 0.8980750265200548
# (616, 182)
# RF R2: 0.9819322204297947
# Remaining: 2583
# Query no. 14
# Embeddings training score: 0.8994107299558002
# (656, 182)
# RF R2: 0.9827511090529559
# Remaining: 2543
# Query no. 15
# Embeddings training score: 0.8999108015495726
# (696, 182)
# RF R2: 0.982383230058487
# Remaining: 2503
# Query no. 16
# Embeddings training score: 0.9012176555953194
# (736, 182)
# RF R2: 0.9837607857905833
# Remaining: 2463
# Query no. 17
# Embeddings training score: 0.9020573959633039
# (776, 182)
# RF R2: 0.984803311732409
# Remaining: 2423
# Query no. 18
# Embeddings training score: 0.9024340675748481
# (816, 182)
# RF R2: 0.9858970016385908
# Remaining: 2383
# Query no. 19
# Embeddings training score: 0.9037412423033788
# (856, 182)
# RF R2: 0.9895713608606456
# Remaining: 2343
# Query no. 20
# Embeddings training score: 0.9045500499461994
# (896, 182)
# RF R2: 0.9901696403642263
# Remaining: 2303
# The Iteration is  15
# NN Test R2 with 5 samples -1.1929959453516918
# After Initialization RF R2: 0.9152224402517226
# NN Test R2 after Initialization 0.9268857779725135
# (96, 182)
# Query no. 1
# Embeddings training score: 0.9266248010432319
# (136, 182)
# RF R2: 0.9478176393783229
# Remaining: 3063
# Query no. 2
# Embeddings training score: 0.9044600557897193
# (176, 182)
# RF R2: 0.9523538878485989
# Remaining: 3023
# Query no. 3
# Embeddings training score: 0.9053304623030893
# (216, 182)
# RF R2: 0.9675941313061418
# Remaining: 2983
# Query no. 4
# Embeddings training score: 0.9087707440993289
# (256, 182)
# RF R2: 0.958882113953304
# Remaining: 2943
# Query no. 5
# Embeddings training score: 0.9074359834079149
# (296, 182)
# RF R2: 0.9698821689323618
# Remaining: 2903
# Query no. 6
# Embeddings training score: 0.9098494494994117
# (336, 182)
# RF R2: 0.9718966632481727
# Remaining: 2863
# Query no. 7
# Embeddings training score: 0.9108151861786857
# (376, 182)
# RF R2: 0.9775383735686215
# Remaining: 2823
# Query no. 8
# Embeddings training score: 0.9137091633342043
# (416, 182)
# RF R2: 0.9795491745908785
# Remaining: 2783
# Query no. 9
# Embeddings training score: 0.9134544945521276
# (456, 182)
# RF R2: 0.9837460282591977
# Remaining: 2743
# Query no. 10
# Embeddings training score: 0.9151283250920476
# (496, 182)
# RF R2: 0.9848459843283258
# Remaining: 2703
# Query no. 11
# Embeddings training score: 0.916097443497003
# (536, 182)
# RF R2: 0.9825925756003768
# Remaining: 2663
# Query no. 12
# Embeddings training score: 0.9197541233933009
# (576, 182)
# RF R2: 0.9822302469457597
# Remaining: 2623
# Query no. 13
# Embeddings training score: 0.9196108234788886
# (616, 182)
# RF R2: 0.9843553351038135
# Remaining: 2583
# Query no. 14
# Embeddings training score: 0.919105570593408
# (656, 182)
# RF R2: 0.9849930401797501
# Remaining: 2543
# Query no. 15
# Embeddings training score: 0.9190621429660398
# (696, 182)
# RF R2: 0.9853465170727855
# Remaining: 2503
# Query no. 16
# Embeddings training score: 0.9204031379620455
# (736, 182)
# RF R2: 0.9856784771270557
# Remaining: 2463
# Query no. 17
# Embeddings training score: 0.9178379348390177
# (776, 182)
# RF R2: 0.9870064554834642
# Remaining: 2423
# Query no. 18
# Embeddings training score: 0.91992673843624
# (816, 182)
# RF R2: 0.9873873757757298
# Remaining: 2383
# Query no. 19
# Embeddings training score: 0.919921895361517
# (856, 182)
# RF R2: 0.990614895760639
# Remaining: 2343
# Query no. 20
# Embeddings training score: 0.9197758917813004
# (896, 182)
# RF R2: 0.9905270902165745
# Remaining: 2303
# The Iteration is  16
# NN Test R2 with 5 samples -1.24606261498773
# After Initialization RF R2: 0.914087507496619
# NN Test R2 after Initialization 0.7728386550673286
# (96, 182)
# Query no. 1
# Embeddings training score: 0.9323856898946029
# (136, 182)
# RF R2: 0.9199248791960069
# Remaining: 3063
# Query no. 2
# Embeddings training score: 0.9048369154800633
# (176, 182)
# RF R2: 0.9187503116413722
# Remaining: 3023
# Query no. 3
# Embeddings training score: 0.9030890840800918
# (216, 182)
# RF R2: 0.9425299496966096
# Remaining: 2983
# Query no. 4
# Embeddings training score: 0.8920338769577913
# (256, 182)
# RF R2: 0.9507398228128525
# Remaining: 2943
# Query no. 5
# Embeddings training score: 0.8954027856413458
# (296, 182)
# RF R2: 0.9621237914453498
# Remaining: 2903
# Query no. 6
# Embeddings training score: 0.9099384369520281
# (336, 182)
# RF R2: 0.970358781089806
# Remaining: 2863
# Query no. 7
# Embeddings training score: 0.9375788829056283
# (376, 182)
# RF R2: 0.9728404853255487
# Remaining: 2823
# Query no. 8
# Embeddings training score: 0.9472290462176542
# (416, 182)
# RF R2: 0.9724542533909102
# Remaining: 2783
# Query no. 9
# Embeddings training score: 0.9516569865900005
# (456, 182)
# RF R2: 0.9674935368826025
# Remaining: 2743
# Query no. 10
# Embeddings training score: 0.9502805645632513
# (496, 182)
# RF R2: 0.9783626596043467
# Remaining: 2703
# Query no. 11
# Embeddings training score: 0.950407151131476
# (536, 182)
# RF R2: 0.9805668935764116
# Remaining: 2663
# Query no. 12
# Embeddings training score: 0.9509091990434595
# (576, 182)
# RF R2: 0.9795924166808984
# Remaining: 2623
# Query no. 13
# Embeddings training score: 0.9466886129541853
# (616, 182)
# RF R2: 0.9795851073764587
# Remaining: 2583
# Query no. 14
# Embeddings training score: 0.9437425096264914
# (656, 182)
# RF R2: 0.9819394877764576
# Remaining: 2543
# Query no. 15
# Embeddings training score: 0.9442699863326214
# (696, 182)
# RF R2: 0.983223536803968
# Remaining: 2503
# Query no. 16
# Embeddings training score: 0.9445498979925002
# (736, 182)
# RF R2: 0.9838555890910939
# Remaining: 2463
# Query no. 17
# Embeddings training score: 0.9445337460662592
# (776, 182)
# RF R2: 0.9849002265730871
# Remaining: 2423
# Query no. 18
# Embeddings training score: 0.9433336129681633
# (816, 182)
# RF R2: 0.9847203293133039
# Remaining: 2383
# Query no. 19
# Embeddings training score: 0.9444785575275783
# (856, 182)
# RF R2: 0.9852995306845996
# Remaining: 2343
# Query no. 20
# Embeddings training score: 0.9439041472595031
# (896, 182)
# RF R2: 0.9857151187246118
# Remaining: 2303
# The Iteration is  17
# NN Test R2 with 5 samples -1.1879371427034033
# After Initialization RF R2: 0.849784666598927
# NN Test R2 after Initialization 0.2830955337886365
# (96, 182)
# Query no. 1
# Embeddings training score: 0.8697422363777629
# (136, 182)
# RF R2: 0.8770123709925658
# Remaining: 3063
# Query no. 2
# Embeddings training score: 0.9070338476387692
# (176, 182)
# RF R2: 0.907320880139128
# Remaining: 3023
# Query no. 3
# Embeddings training score: 0.8944205524036083
# (216, 182)
# RF R2: 0.9375504753871047
# Remaining: 2983
# Query no. 4
# Embeddings training score: 0.8930811005774363
# (256, 182)
# RF R2: 0.939309526594721
# Remaining: 2943
# Query no. 5
# Embeddings training score: 0.8816604833525183
# (296, 182)
# RF R2: 0.9699431581280638
# Remaining: 2903
# Query no. 6
# Embeddings training score: 0.8872987156810143
# (336, 182)
# RF R2: 0.9776142835367069
# Remaining: 2863
# Query no. 7
# Embeddings training score: 0.8867499434046275
# (376, 182)
# RF R2: 0.978006486284811
# Remaining: 2823
# Query no. 8
# Embeddings training score: 0.8904087646359825
# (416, 182)
# RF R2: 0.9779818552954874
# Remaining: 2783
# Query no. 9
# Embeddings training score: 0.8907163988777673
# (456, 182)
# RF R2: 0.9779164018257316
# Remaining: 2743
# Query no. 10
# Embeddings training score: 0.8928951343053904
# (496, 182)
# RF R2: 0.979064619573449
# Remaining: 2703
# Query no. 11
# Embeddings training score: 0.8950430417478883
# (536, 182)
# RF R2: 0.9812781403136661
# Remaining: 2663
# Query no. 12
# Embeddings training score: 0.8970985751924723
# (576, 182)
# RF R2: 0.9817681427659348
# Remaining: 2623
# Query no. 13
# Embeddings training score: 0.8991773735008255
# (616, 182)
# RF R2: 0.9843385070006082
# Remaining: 2583
# Query no. 14
# Embeddings training score: 0.8981025491319666
# (656, 182)
# RF R2: 0.9860503752643607
# Remaining: 2543
# Query no. 15
# Embeddings training score: 0.9023991240028293
# (696, 182)
# RF R2: 0.98478755610354
# Remaining: 2503
# Query no. 16
# Embeddings training score: 0.9027301130342371
# (736, 182)
# RF R2: 0.9848695640556862
# Remaining: 2463
# Query no. 17
# Embeddings training score: 0.9023864830850066
# (776, 182)
# RF R2: 0.9853369008056735
# Remaining: 2423
# Query no. 18
# Embeddings training score: 0.9034583181845535
# (816, 182)
# RF R2: 0.9862078192258945
# Remaining: 2383
# Query no. 19
# Embeddings training score: 0.9041858611875954
# (856, 182)
# RF R2: 0.9872473983123563
# Remaining: 2343
# Query no. 20
# Embeddings training score: 0.904847959859687
# (896, 182)
# RF R2: 0.9885796522307988
# Remaining: 2303
# The Iteration is  18
# NN Test R2 with 5 samples -1.2166945073955344
# After Initialization RF R2: 0.9046711623355272
# NN Test R2 after Initialization 0.864855657303553
# (96, 182)
# Query no. 1
# Embeddings training score: 0.8654148079957235
# (136, 182)
# RF R2: 0.9397971727687292
# Remaining: 3063
# Query no. 2
# Embeddings training score: 0.9208050893749093
# (176, 182)
# RF R2: 0.9492188491604435
# Remaining: 3023
# Query no. 3
# Embeddings training score: 0.9097961505470695
# (216, 182)
# RF R2: 0.955071920169412
# Remaining: 2983
# Query no. 4
# Embeddings training score: 0.9062150292921
# (256, 182)
# RF R2: 0.9637560838264224
# Remaining: 2943
# Query no. 5
# Embeddings training score: 0.9057268706969677
# (296, 182)
# RF R2: 0.9489684181397309
# Remaining: 2903
# Query no. 6
# Embeddings training score: 0.9078301316281548
# (336, 182)
# RF R2: 0.9462050854477376
# Remaining: 2863
# Query no. 7
# Embeddings training score: 0.9085943008831213
# (376, 182)
# RF R2: 0.9724217429700117
# Remaining: 2823
# Query no. 8
# Embeddings training score: 0.9269073119476013
# (416, 182)
# RF R2: 0.9760051861291806
# Remaining: 2783
# Query no. 9
# Embeddings training score: 0.9255648465008597
# (456, 182)
# RF R2: 0.9775164996971034
# Remaining: 2743
# Query no. 10
# Embeddings training score: 0.9271133549613069
# (496, 182)
# RF R2: 0.9811337633427755
# Remaining: 2703
# Query no. 11
# Embeddings training score: 0.9281888426145231
# (536, 182)
# RF R2: 0.9836564923593917
# Remaining: 2663
# Query no. 12
# Embeddings training score: 0.9294653980009839
# (576, 182)
# RF R2: 0.9875926264274011
# Remaining: 2623
# Query no. 13
# Embeddings training score: 0.929605385746096
# (616, 182)
# RF R2: 0.987726311121145
# Remaining: 2583
# Query no. 14
# Embeddings training score: 0.9297956005074962
# (656, 182)
# RF R2: 0.987230569462166
# Remaining: 2543
# Query no. 15
# Embeddings training score: 0.9298703802358222
# (696, 182)
# RF R2: 0.9867828778787388
# Remaining: 2503
# Query no. 16
# Embeddings training score: 0.930570952427808
# (736, 182)
# RF R2: 0.987054555367207
# Remaining: 2463
# Query no. 17
# Embeddings training score: 0.9316928594653786
# (776, 182)
# RF R2: 0.9868385450928973
# Remaining: 2423
# Query no. 18
# Embeddings training score: 0.931480364247942
# (816, 182)
# RF R2: 0.9876970778698804
# Remaining: 2383
# Query no. 19
# Embeddings training score: 0.9320967343735379
# (856, 182)
# RF R2: 0.98850207664527
# Remaining: 2343
# Query no. 20
# Embeddings training score: 0.9327340572008721
# (896, 182)
# RF R2: 0.988475546722935
# Remaining: 2303
# The Iteration is  19
# NN Test R2 with 5 samples -1.2200202954569899
# After Initialization RF R2: 0.8735224339641313
# NN Test R2 after Initialization -0.08352085738201882
# (96, 182)
# Query no. 1
# Embeddings training score: 0.8588419393293775
# (136, 182)
# RF R2: 0.8859479532120661
# Remaining: 3063
# Query no. 2
# Embeddings training score: 0.8709218448448296
# (176, 182)
# RF R2: 0.9395577231181174
# Remaining: 3023
# Query no. 3
# Embeddings training score: 0.879993896271598
# (216, 182)
# RF R2: 0.9622185982274736
# Remaining: 2983
# Query no. 4
# Embeddings training score: 0.8827065826169952
# (256, 182)
# RF R2: 0.972776620253151
# Remaining: 2943
# Query no. 5
# Embeddings training score: 0.877248705115997
# (296, 182)
# RF R2: 0.9733711049637825
# Remaining: 2903
# Query no. 6
# Embeddings training score: 0.8836388163911548
# (336, 182)
# RF R2: 0.9754896113478515
# Remaining: 2863
# Query no. 7
# Embeddings training score: 0.8856445616086127
# (376, 182)
# RF R2: 0.9833053400909071
# Remaining: 2823
# Query no. 8
# Embeddings training score: 0.8908575758740549
# (416, 182)
# RF R2: 0.9855775371821499
# Remaining: 2783
# Query no. 9
# Embeddings training score: 0.8950711985439938
# (456, 182)
# RF R2: 0.9836983373516304
# Remaining: 2743
# Query no. 10
# Embeddings training score: 0.89514952734786
# (496, 182)
# RF R2: 0.985743196302411
# Remaining: 2703
# Query no. 11
# Embeddings training score: 0.8952062155835463
# (536, 182)
# RF R2: 0.9864487014965362
# Remaining: 2663
# Query no. 12
# Embeddings training score: 0.8954348472976692
# (576, 182)
# RF R2: 0.9877738306310839
# Remaining: 2623
# Query no. 13
# Embeddings training score: 0.8966963649729991
# (616, 182)
# RF R2: 0.9880933337934648
# Remaining: 2583
# Query no. 14
# Embeddings training score: 0.8975228598808381
# (656, 182)
# RF R2: 0.9883946849930554
# Remaining: 2543
# Query no. 15
# Embeddings training score: 0.8981240679376343
# (696, 182)
# RF R2: 0.9881573306286995
# Remaining: 2503
# Query no. 16
# Embeddings training score: 0.8996443627107759
# (736, 182)
# RF R2: 0.9888062361455794
# Remaining: 2463
# Query no. 17
# Embeddings training score: 0.9000060858748018
# (776, 182)
# RF R2: 0.9897659890774579
# Remaining: 2423
# Query no. 18
# Embeddings training score: 0.8997851687580705
# (816, 182)
# RF R2: 0.9908736149213658
# Remaining: 2383
# Query no. 19
# Embeddings training score: 0.9001193479320839
# (856, 182)
# RF R2: 0.9908887761642575
# Remaining: 2343
# Query no. 20
# Embeddings training score: 0.9019512390999739
# (896, 182)
# RF R2: 0.9922303828489163
# Remaining: 2303
