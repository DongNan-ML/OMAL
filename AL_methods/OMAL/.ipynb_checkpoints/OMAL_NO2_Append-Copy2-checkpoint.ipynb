# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from modAL.models import ActiveLearner, CommitteeRegressor
from modAL.disagreement import vote_entropy_sampling, max_std_sampling
import matplotlib.pyplot as plt
import torch
from torch.nn import MSELoss
from skorch.regressor import NeuralNetRegressor
from copy import deepcopy
from skorch.dataset import ValidSplit
from skorch.callbacks import EarlyStopping
from sklearn.cluster import DBSCAN, OPTICS, cluster_optics_dbscan, Birch, SpectralClustering
from sklearn.neighbors import NearestNeighbors
from sklearn import metrics
import matplotlib.gridspec as gridspec
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from torch.nn import Linear
from torch.nn import Sigmoid, ReLU
from torch.nn import Module
from sklearn.metrics import r2_score
import copy
from scipy.spatial import distance
from scipy.spatial.distance import euclidean
from torch import tensor
from sklearn.metrics import mean_squared_error
from scipy.spatial.distance import cdist
from sklearn.ensemble import RandomForestRegressor
from torch.nn.init import xavier_uniform_
from model import MLP
from model_state import get_model_params, get_input_for_hidden_layers, get_model_params_gradientNorm
from functions_batch1 import get_variance, qbc, normalization, error_reduct_fuc, total_disagrement, grad_norm, averaged_grad_norm, get_avg_grad_norm, training_loss
import random
from skorch.callbacks import EarlyStopping, LRScheduler, Freezer, Unfreezer
from torch.optim.lr_scheduler import CyclicLR, ReduceLROnPlateau
from skorch.regressor import NeuralNetRegressor, NeuralNet
from model_state import features_concat, learning_state_features_concat
import gc
import warnings
from modAL.utils.selection import multi_argmax
warnings.filterwarnings("ignore")

# %%
# Hyper-params:
query_number = 30          # The number of the AL Iterations in each Exp
iteration = 20             # Total number of the Exps
batch_size = 10
total_initail_size = 12
initial_size = 5
dimensions = 15   # Total dimension of the data features + model states

seed_rf = np.load(file="..\..\seed2.npy")
seed_initial = np.load(file="..\..\seed3.npy")

seed_nn1 = np.load(file="..\..\seed4.npy")
seed_nn2 = np.load(file="..\..\seed4.npy")
seed_nn3 = np.load(file="..\..\seed5.npy")
seed_nn4 = np.load(file="..\..\seed5.npy")
seed_nn5 = np.load(file="..\..\seed6.npy")
seed_nn6 = np.load(file="..\..\seed6.npy")

seed_predictor = np.load(file="..\..\seed7.npy")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def Committee_Prediction(learner_list, X_test, y_test):
    initial_pred=[]
    for i in learner_list:
        initial_pred.append(r2_score(y_test, i.predict(X_test)))
    initial_pred=np.array(initial_pred)
    
    return initial_pred.mean()

# %%
def main_function(query_number, iters):
    # For saving results:
    rf_model_training_r2 = []
    rf_model_training_mse = []
    rf_model_testing_r2 = []
    rf_model_testing_mse = []
    
    # Number of member in committee:
    n_members = 3
    learner_list = []
    
    # The model for evaluation:
    rf_model = RandomForestRegressor(random_state=seed_rf[iters], n_estimators=100)
    gradient_norms = np.empty(shape=(0, 0))
    
    # Load the data:
    name1 = "..\..\Datasets\\NO2\X_train" + str(iters) + ".npy"
    name2 = "..\..\Datasets\\NO2\X_test" + str(iters) + ".npy"
    name3 = "..\..\Datasets\\NO2\y_train" + str(iters) + ".npy"
    name4 = "..\..\Datasets\\NO2\y_test" + str(iters) + ".npy"
    
    X_train = np.load(name1, allow_pickle=True).astype(np.float32)
    X_test = np.load(name2, allow_pickle=True).astype(np.float32)
    y_train = np.load(name3, allow_pickle=True).astype(np.float32).reshape(-1, 1)
    y_test = np.load(name4, allow_pickle=True).astype(np.float32).reshape(-1, 1)
    
    # Dimensionality of data:
    X = X_train.shape[1]
    # The index of the unlabeled pool:
    X_index = np.arange(X_train.shape[0])

    used_data = np.empty(shape=(0, X))
    used_label = np.empty(shape=(0)).reshape(-1, 1)

    X_initial = np.empty(shape=(0,X))
    y_initial = np.empty(shape=(0)).reshape(-1, 1)
    
    # Initial Stage 1:
    np.random.seed(seed_initial[iters])
    idx = np.random.choice(range(len(X_index)), size=initial_size, replace=False)
    train_idx = X_index[idx]

    X_initial = X_train[train_idx]
    y_initial = y_train[train_idx].reshape(-1, 1)

    used_data = np.append(used_data, X_initial, axis=0).astype(np.float32)
    used_label = np.append(used_label, y_initial, axis=0).astype(np.float32).reshape(-1, 1)
    X_index = np.delete(X_index, idx, axis=0)

    
    used_data = torch.from_numpy(used_data).to(device)
    used_label = torch.from_numpy(used_label).to(device)
    for member_idx in range(n_members):
        if member_idx == 0:
            np.random.seed(seed_nn1[iters])
            torch.manual_seed(seed_nn2[iters])
        if member_idx == 1:
            np.random.seed(seed_nn3[iters])
            torch.manual_seed(seed_nn4[iters])
        if member_idx == 2:
            np.random.seed(seed_nn5[iters])
            torch.manual_seed(seed_nn6[iters])
            
        regressor = NeuralNetRegressor(MLP(X),
                                   criterion=MSELoss(),
                                   optimizer=torch.optim.Adam,
                                   verbose=0,
                                   max_epochs=30,
                                   lr=0.001,
                                   # Used for the batch AL
                                   callbacks=[EarlyStopping(patience=5), ('lr_scheduler', LRScheduler(policy=ReduceLROnPlateau))],
                                   train_split=ValidSplit(cv=5),
                                   warm_start=True,
                                   device='cuda',
                                   batch_size = 200
                                   )
        regressor.fit(used_data, used_label)
        learner_list.append(regressor)
    
    print("NN Test R2 with 5 samples", Committee_Prediction(learner_list, X_test, y_test))

    # Number of LAL features:
    learning_state_features = np.empty(shape=(0, dimensions))
    loss_reduction_target = np.empty(shape=(0)).reshape(-1, 1)

    # other random samples:
    rest_initial_X = np.empty(shape=(0, X))
    rest_initial_y = np.empty(shape=(0)).reshape(-1, 1)

    # LAL Initialization: Stage 2
    predictor = RandomForestRegressor(n_estimators=1000, random_state=seed_predictor[iters])
    np.random.seed(seed_initial[iters])
    idx = np.random.choice(range(len(X_index)), size=total_initail_size-initial_size, replace=False)
    train_idx = X_index[idx]
    
    rest_initial_X = np.append(rest_initial_X, X_train[train_idx], axis=0).astype(np.float32)
    rest_initial_y = np.append(rest_initial_y, y_train[train_idx], axis=0).astype(np.float32).reshape(-1, 1)

    X_index = np.delete(X_index, idx, axis=0)

    for i in range(rest_initial_X.shape[0]):

        single_X = rest_initial_X[i],
        single_y = rest_initial_y[i].reshape(1, -1)
        single_X = single_X[0].reshape(1, -1)
        
        single_X = torch.from_numpy(single_X).to(device)
        single_y = torch.from_numpy(single_y).to(device)

        # Model params
        model_params = get_model_params_gradientNorm(learner_list)

        # updated data
        used_data = torch.cat((used_data, single_X), 0)
        used_label = torch.cat((used_label, single_y), 0)

        # Retrain the model:
        for l in learner_list:
            l.fit(X=used_data,y=used_label)
            
        single_X = single_X.cpu().numpy()
        single_y = single_y.cpu().numpy()
            
        index = train_idx[i]

        # The training sample:
        data_params = X_train[index]
      
        LALfeatures = features_concat(model_params, data_params)

        loss_reduction = get_avg_grad_norm(learner_list, single_X, single_y)
        
        learning_state_features = learning_state_features_concat(learning_state_features, LALfeatures)
        loss_reduction_target = np.append(loss_reduction_target, np.array([loss_reduction]).reshape(-1, 1), axis=0).astype(np.float32).reshape(-1, 1)

        
    used_data = used_data.cpu().numpy()
    used_label = used_label.cpu().numpy()

    # Finished the Initialization Stages:
    # RF Regressor for evaluation:
    rf_model.fit(used_data, used_label.ravel())
    # Training Scores:
    rf_training_r2 = r2_score(used_label, rf_model.predict(used_data))
    rf_training_mse = mean_squared_error(used_label, rf_model.predict(used_data))
    rf_model_training_r2.append(rf_training_r2)
    rf_model_training_mse.append(rf_training_mse)
    
    # Test Scores:
    rf_model_r2 = r2_score(y_test, rf_model.predict(X_test))
    rf_model_mse = mean_squared_error(y_test, rf_model.predict(X_test))
    rf_model_testing_r2.append(rf_model_r2)
    rf_model_testing_mse.append(rf_model_mse)
    
    print("After Initialization RF R2:", rf_model_r2)
    print("NN Test R2 after Initialization", Committee_Prediction(learner_list, X_test, y_test))
    
    print(np.unique(used_data, axis=0).shape)
    for idx in range(query_number):
        np.random.seed(None)
        print('Query no. %d' % (idx+1))
        # Reuse training data:
        learning_state_features, loss_reduction_target = reuse_labeled_data_meta(used_data, used_label, learner_list, learning_state_features, loss_reduction_target)

        print(learning_state_features.shape)

        Error_reduction_list, training_score = error_reduct_fuc(X_train, X_index, learner_list, learning_state_features, loss_reduction_target, X_index.shape[0], predictor)
    
        idx = multi_argmax(np.array(Error_reduction_list), n_instances=batch_size)
       
        X_train_indices = X_index[idx]
        
        # Update
        X_index = np.delete(X_index, idx, axis=0)

        for X_train_index in X_train_indices:

            new_X = X_train[X_train_index].reshape(1, -1)
            new_y = y_train[X_train_index].reshape(1, -1)
            
            used_data = np.append(used_data, new_X, axis=0).astype(np.float32)
            used_label = np.append(used_label, new_y, axis=0).astype(np.float32).reshape(-1, 1)
            
            used_data = torch.from_numpy(used_data).to(device)
            used_label = torch.from_numpy(used_label).to(device)

            # Model params
            model_params = get_model_params_gradientNorm(learner_list)
            data_params = X_train[X_train_index]
            LALfeatures = features_concat(model_params, data_params)
            
            for l in learner_list:
                l.fit(used_data, used_label)
            
            used_data = used_data.cpu().numpy()
            used_label = used_label.cpu().numpy()

            loss_reduction = get_avg_grad_norm(learner_list, new_X, new_y)  
            gradient_norms = np.append(gradient_norms, loss_reduction)
            
            learning_state_features = learning_state_features_concat(learning_state_features, LALfeatures)
            loss_reduction_target = np.append(loss_reduction_target, np.array([loss_reduction]).reshape(-1, 1), axis=0).astype(np.float32).reshape(-1, 1)
            
        # RF Evaluation
        rf_model.fit(used_data, used_label.ravel())
        
        # Training Evaluation:
        rf_training_r2 = r2_score(used_label, rf_model.predict(used_data))
        rf_training_mse = mean_squared_error(used_label, rf_model.predict(used_data))
        rf_model_training_r2.append(rf_training_r2)
        rf_model_training_mse.append(rf_training_mse)
        
        # Test Evaluation:
        rf_model_r2 = r2_score(y_test, rf_model.predict(X_test))
        rf_model_mse = mean_squared_error(y_test, rf_model.predict(X_test))
        rf_model_testing_r2.append(rf_model_r2)
        rf_model_testing_mse.append(rf_model_mse)

        print(np.unique(used_data, axis=0).shape)
        print("RF R2:", rf_model_r2)
        print("Remaining:", X_index.shape[0])
       
        # print('NN R2', Committee_Prediction(learner_list, X_test, y_test))

    # RF
    rf_model_testing_r2 = np.array(rf_model_testing_r2)
    rf_model_testing_mse = np.array(rf_model_testing_mse)
    rf_model_training_r2 = np.array(rf_model_training_r2)
    rf_model_training_mse = np.array(rf_model_training_mse)
    
    # Used_data and Unsed_label:
    np.save(file="..\..\Results\Res_NO2\OMAL_append\Summary\\used_data" + str(iters) + ".npy", arr=used_data)
    np.save(file="..\..\Results\Res_NO2\OMAL_append\Summary\\used_labels" + str(iters) + ".npy", arr=used_label)

    np.save(file="..\..\Results\Res_NO2\OMAL_append\Summary\\testing_rf_r2_" + str(iters) + ".npy", arr=rf_model_testing_r2)
    np.save(file="..\..\Results\Res_NO2\OMAL_append\Summary\\testing_rf_mse_" + str(iters) + ".npy", arr=rf_model_testing_mse)
    np.save(file="..\..\Results\Res_NO2\OMAL_append\Summary\\training_rf_r2_" + str(iters) + ".npy", arr=rf_model_training_r2)
    np.save(file="..\..\Results\Res_NO2\OMAL_append\Summary\\training_rf_mse_" + str(iters) + ".npy", arr=rf_model_training_mse)

# %%
def reuse_labeled_data_meta(used_data, used_label, learner_list, learning_state_features, loss_reduction_target):
    for i in range(used_data.shape[0]):
            
            new_X = used_data[i].reshape(1, -1)
            new_y = used_label[i].reshape(1, -1)
            
            used_data_ = np.append(used_data, new_X, axis=0).astype(np.float32)
            used_label_ = np.append(used_label, new_y, axis=0).astype(np.float32).reshape(-1, 1)
            
            used_data_ = torch.from_numpy(used_data_).to(device)
            used_label_ = torch.from_numpy(used_label_).to(device)

            # Model params
            model_params = get_model_params_gradientNorm(learner_list)
            data_params = new_X.reshape(-1,)
            LALfeatures = features_concat(model_params, data_params)
            
            for l in learner_list:
                l.fit(used_data_, used_label_)

            loss_reduction = get_avg_grad_norm(learner_list, new_X, new_y)  
            
            learning_state_features = learning_state_features_concat(learning_state_features, LALfeatures)
            loss_reduction_target = np.append(loss_reduction_target, np.array([loss_reduction]).reshape(-1, 1), axis=0).astype(np.float32).reshape(-1, 1)
    
    return learning_state_features, loss_reduction_target

# %%
for i in range(iteration):
    print("The Iteration is ", i)
    main_function(query_number, i)
# Out:
# The Iteration is  0
# NN Test R2 with 5 samples -15.32991684106078
# After Initialization RF R2: 0.07907253029892569
# NN Test R2 after Initialization -2.5110978712737366
# (12, 7)
# Query no. 1
# (19, 15)
# Embeddings training score: 0.8850503879979695
# (22, 7)
# RF R2: 0.0884029194977185
# Remaining: 378
# Query no. 2
# (51, 15)
# Embeddings training score: 0.878943958854772
# (32, 7)
# RF R2: 0.11307977659352597
# Remaining: 368
# Query no. 3
# (93, 15)
# Embeddings training score: 0.8633432747682617
# (42, 7)
# RF R2: 0.3237455079612169
# Remaining: 358
# Query no. 4
# (145, 15)
# Embeddings training score: 0.8696934167694952
# (52, 7)
# RF R2: 0.37469636248001703
# Remaining: 348
# Query no. 5
# (207, 15)
# Embeddings training score: 0.8959370666294704
# (62, 7)
# RF R2: 0.44773099376232184
# Remaining: 338
# Query no. 6
# (279, 15)
# Embeddings training score: 0.8982598463491714
# (72, 7)
# RF R2: 0.476720192476739
# Remaining: 328
# Query no. 7
# (361, 15)
# Embeddings training score: 0.9041469456205721
# (82, 7)
# RF R2: 0.5041608099445469
# Remaining: 318
# Query no. 8
# (453, 15)
# Embeddings training score: 0.9050741213081028
# (92, 7)
# RF R2: 0.4566748007868284
# Remaining: 308
# Query no. 9
# (555, 15)
# Embeddings training score: 0.9003997959102779
# (102, 7)
# RF R2: 0.5038920035598375
# Remaining: 298
# Query no. 10
# (667, 15)
# Embeddings training score: 0.9025618574957424
# (112, 7)
# RF R2: 0.5001068780218174
# Remaining: 288
# Query no. 11
# (789, 15)
# Embeddings training score: 0.9010395359615442
# (122, 7)
# RF R2: 0.5084035879242323
# Remaining: 278
# Query no. 12
# (921, 15)
# Embeddings training score: 0.900739648021047
# (132, 7)
# RF R2: 0.5602069367865502
# Remaining: 268
# Query no. 13
# (1063, 15)
# Embeddings training score: 0.9045614442487034
# (142, 7)
# RF R2: 0.5906646295727204
# Remaining: 258
# Query no. 14
# (1215, 15)
# Embeddings training score: 0.907532148904569
# (152, 7)
# RF R2: 0.6020123955247798
# Remaining: 248
# Query no. 15
# (1377, 15)
# Embeddings training score: 0.9027206630340513
# (162, 7)
# RF R2: 0.5831529850714344
# Remaining: 238
# Query no. 16
# (1549, 15)
# Embeddings training score: 0.9067057077732646
# (172, 7)
# RF R2: 0.5730765515350855
# Remaining: 228
# Query no. 17
# (1731, 15)
# Embeddings training score: 0.9092523094916354
# (182, 7)
# RF R2: 0.5672645654121273
# Remaining: 218
# Query no. 18
# (1923, 15)
# Embeddings training score: 0.9128841132598621
# (192, 7)
# RF R2: 0.57052116457
# Remaining: 208
# Query no. 19
# (2125, 15)
# Embeddings training score: 0.9184433301876399
# (202, 7)
# RF R2: 0.593466149289578
# Remaining: 198
# Query no. 20
# (2337, 15)
# Embeddings training score: 0.9254271387115142
# (212, 7)
# RF R2: 0.6085697283298888
# Remaining: 188
# Query no. 21
# (2559, 15)
# Embeddings training score: 0.9289199456122933
# (222, 7)
# RF R2: 0.5994481536289391
# Remaining: 178
# Query no. 22
# (2791, 15)
# Embeddings training score: 0.9332861478520313
# (232, 7)
# RF R2: 0.622791348065266
# Remaining: 168
# Query no. 23
# (3033, 15)
# Embeddings training score: 0.9373134169075987
# (242, 7)
# RF R2: 0.6273435901333702
# Remaining: 158
# Query no. 24
# (3285, 15)
# Embeddings training score: 0.9391506551205893
# (252, 7)
# RF R2: 0.6188393088477075
# Remaining: 148
# Query no. 25
# (3547, 15)
# Embeddings training score: 0.9337411605703304
# (262, 7)
# RF R2: 0.5986818469216725
# Remaining: 138
# Query no. 26
# (3819, 15)
# Embeddings training score: 0.9459701585272484
# (272, 7)
# RF R2: 0.5866667694650138
# Remaining: 128
# Query no. 27
# (4101, 15)
# Embeddings training score: 0.957980346064396
# (282, 7)
# RF R2: 0.6044031095820079
# Remaining: 118
# Query no. 28
# (4393, 15)
# Embeddings training score: 0.9691846158553806
# (292, 7)
# RF R2: 0.5911400471429322
# Remaining: 108
# Query no. 29
# (4695, 15)
# Embeddings training score: 0.9759138293114996
# (302, 7)
# RF R2: 0.6250918554471072
# Remaining: 98
# Query no. 30
# (5007, 15)
# Embeddings training score: 0.9821332811522875
# (312, 7)
# RF R2: 0.6050414936199857
# Remaining: 88
# The Iteration is  1
# NN Test R2 with 5 samples -18.296105436397866
# After Initialization RF R2: 0.0447662806614757
# NN Test R2 after Initialization -1.3998854911475742
# (12, 7)
# Query no. 1
# (19, 15)
# Embeddings training score: 0.9063096830480875
# (22, 7)
# RF R2: -0.0015153939774041891
# Remaining: 378
# Query no. 2
# (51, 15)
# Embeddings training score: 0.9408908261045175
# (32, 7)
# RF R2: 0.19986832482449968
# Remaining: 368
# Query no. 3
# (93, 15)
# Embeddings training score: 0.9363366890527539
# (42, 7)
# RF R2: 0.1259293461100771
# Remaining: 358
# Query no. 4
# (145, 15)
# Embeddings training score: 0.9402655721698567
# (52, 7)
# RF R2: 0.21468141325827372
# Remaining: 348
# Query no. 5
# (207, 15)
# Embeddings training score: 0.9247428813051233
# (62, 7)
# RF R2: 0.26678480874776445
# Remaining: 338
# Query no. 6
# (279, 15)
# Embeddings training score: 0.9230385071600965
# (72, 7)
# RF R2: 0.4373298455601039
# Remaining: 328
# Query no. 7
# (361, 15)
# Embeddings training score: 0.9231370805084014
# (82, 7)
# RF R2: 0.45606547420016674
# Remaining: 318
# Query no. 8
# (453, 15)
# Embeddings training score: 0.9238236191987104
# (92, 7)
# RF R2: 0.46495605540731166
# Remaining: 308
# Query no. 9
# (555, 15)
# Embeddings training score: 0.9109661184512005
# (102, 7)
# RF R2: 0.4442599036245666
# Remaining: 298
# Query no. 10
# (667, 15)
# Embeddings training score: 0.9145654423155501
# (112, 7)
# RF R2: 0.4860498428091071
# Remaining: 288
# Query no. 11
# (789, 15)
# Embeddings training score: 0.915051648259554
# (122, 7)
# RF R2: 0.4699116154505534
# Remaining: 278
# Query no. 12
# (921, 15)
# Embeddings training score: 0.917857243728497
# (132, 7)
# RF R2: 0.4828306647859586
# Remaining: 268
# Query no. 13
# (1063, 15)
# Embeddings training score: 0.9102936079052584
# (142, 7)
# RF R2: 0.47818989128820133
# Remaining: 258
# Query no. 14
# (1215, 15)
# Embeddings training score: 0.9057485100756963
# (152, 7)
# RF R2: 0.48204381429693244
# Remaining: 248
# Query no. 15
# (1377, 15)
# Embeddings training score: 0.913367012533304
# (162, 7)
# RF R2: 0.4784558750524127
# Remaining: 238
# Query no. 16
# (1549, 15)
# Embeddings training score: 0.917469298747918
# (172, 7)
# RF R2: 0.4774618729399698
# Remaining: 228
# Query no. 17
# (1731, 15)
# Embeddings training score: 0.9178413163086065
# (182, 7)
# RF R2: 0.47486963742819177
# Remaining: 218
# Query no. 18
# (1923, 15)
# Embeddings training score: 0.9158239600500785
# (192, 7)
# RF R2: 0.4649164169281804
# Remaining: 208
# Query no. 19
# (2125, 15)
# Embeddings training score: 0.9236986008133614
# (202, 7)
# RF R2: 0.4689766734196157
# Remaining: 198
# Query no. 20
# (2337, 15)
# Embeddings training score: 0.9281643078223748
# (212, 7)
# RF R2: 0.4911659709352376
# Remaining: 188
# Query no. 21
# (2559, 15)
# Embeddings training score: 0.9319237038873743
# (222, 7)
# RF R2: 0.48485860981604056
# Remaining: 178
# Query no. 22
# (2791, 15)
# Embeddings training score: 0.9327907521538098
# (232, 7)
# RF R2: 0.49116727212847977
# Remaining: 168
# Query no. 23
# (3033, 15)
# Embeddings training score: 0.9359304254295564
# (242, 7)
# RF R2: 0.5098311784119455
# Remaining: 158
# Query no. 24
# (3285, 15)
# Embeddings training score: 0.9390343494081879
# (252, 7)
# RF R2: 0.49818278133413996
# Remaining: 148
# Query no. 25
# (3547, 15)
# Embeddings training score: 0.934024508543722
# (262, 7)
# RF R2: 0.5156838217604149
# Remaining: 138
# Query no. 26
# (3819, 15)
# Embeddings training score: 0.9430029084027164
# (272, 7)
# RF R2: 0.5337476393700626
# Remaining: 128
# Query no. 27
# (4101, 15)
# Embeddings training score: 0.9502028736390047
# (282, 7)
# RF R2: 0.5363180414334375
# Remaining: 118
# Query no. 28
# (4393, 15)
# Embeddings training score: 0.9628772443212116
# (292, 7)
# RF R2: 0.5404408909173868
# Remaining: 108
# Query no. 29
# (4695, 15)
# Embeddings training score: 0.970967061694952
# (302, 7)
# RF R2: 0.5407995147614484
# Remaining: 98
# Query no. 30
# (5007, 15)
# Embeddings training score: 0.9758537244565577
# (312, 7)
# RF R2: 0.5182022948577532
# Remaining: 88
# The Iteration is  2
# NN Test R2 with 5 samples -15.628439141936388
# After Initialization RF R2: 0.07290729111410466
# NN Test R2 after Initialization -0.4430188525202039
# (12, 7)
# Query no. 1
# (19, 15)
# Embeddings training score: 0.8265803307174011
# (22, 7)
# RF R2: 0.08654135603571855
# Remaining: 378
# Query no. 2
# (51, 15)
# Embeddings training score: 0.8648418754316461
# (32, 7)
# RF R2: 0.13492054885807347
# Remaining: 368
# Query no. 3
# (93, 15)
# Embeddings training score: 0.8789602738739425
# (42, 7)
# RF R2: 0.332183621752951
# Remaining: 358
# Query no. 4
# (145, 15)
# Embeddings training score: 0.8738866846797533
# (52, 7)
# RF R2: 0.3480933700322908
# Remaining: 348
# Query no. 5
# (207, 15)
# Embeddings training score: 0.886880222820004
# (62, 7)
# RF R2: 0.4381897829458312
# Remaining: 338
# Query no. 6
# (279, 15)
# Embeddings training score: 0.8755073333780723
# (72, 7)
# RF R2: 0.5046866031457187
# Remaining: 328
# Query no. 7
# (361, 15)
# Embeddings training score: 0.8719296242610799
# (82, 7)
# RF R2: 0.4771186357539605
# Remaining: 318
# Query no. 8
# (453, 15)
# Embeddings training score: 0.880440377535311
# (92, 7)
# RF R2: 0.49274580239096655
# Remaining: 308
# Query no. 9
# (555, 15)
# Embeddings training score: 0.8834932449454392
# (102, 7)
# RF R2: 0.5127901422532628
# Remaining: 298
# Query no. 10
# (667, 15)
# Embeddings training score: 0.886557765939562
# (112, 7)
# RF R2: 0.47183374360148855
# Remaining: 288
# Query no. 11
# (789, 15)
# Embeddings training score: 0.9019044181748832
# (122, 7)
# RF R2: 0.45830641766384694
# Remaining: 278
# Query no. 12
# (921, 15)
# Embeddings training score: 0.9035496666494162
# (132, 7)
# RF R2: 0.43497757379381996
# Remaining: 268
# Query no. 13
# (1063, 15)
# Embeddings training score: 0.9092279358459471
# (142, 7)
# RF R2: 0.4583347884715939
# Remaining: 258
# Query no. 14
# (1215, 15)
# Embeddings training score: 0.9117241344793838
# (152, 7)
# RF R2: 0.46611357798847664
# Remaining: 248
# Query no. 15
# (1377, 15)
# Embeddings training score: 0.914402729578281
# (162, 7)
# RF R2: 0.48652985572402396
# Remaining: 238
# Query no. 16
# (1549, 15)
# Embeddings training score: 0.9153003231556373
# (172, 7)
# RF R2: 0.4711189034545147
# Remaining: 228
# Query no. 17
# (1731, 15)
# Embeddings training score: 0.924189908398001
# (182, 7)
# RF R2: 0.48135698113923886
# Remaining: 218
# Query no. 18
# (1923, 15)
# Embeddings training score: 0.9282271389434036
# (192, 7)
# RF R2: 0.4939305542229462
# Remaining: 208
# Query no. 19
# (2125, 15)
# Embeddings training score: 0.9386510837428915
# (202, 7)
# RF R2: 0.48946178967779896
# Remaining: 198
# Query no. 20
# (2337, 15)
# Embeddings training score: 0.9387810585685872
# (212, 7)
# RF R2: 0.4713788272217845
# Remaining: 188
# Query no. 21
# (2559, 15)
# Embeddings training score: 0.9441137503800268
# (222, 7)
# RF R2: 0.48797623755698416
# Remaining: 178
# Query no. 22
# (2791, 15)
# Embeddings training score: 0.9489290612301023
# (232, 7)
# RF R2: 0.48995028471949853
# Remaining: 168
# Query no. 23
# (3033, 15)
# Embeddings training score: 0.9513022416904838
# (242, 7)
# RF R2: 0.524149020404556
# Remaining: 158
# Query no. 24
# (3285, 15)
# Embeddings training score: 0.9537948220466272
# (252, 7)
# RF R2: 0.5355819367118259
# Remaining: 148
# Query no. 25
# (3547, 15)
# Embeddings training score: 0.9494134045057824
# (262, 7)
# RF R2: 0.5241469071703884
# Remaining: 138
# Query no. 26
# (3819, 15)
# Embeddings training score: 0.9557288686272093
# (272, 7)
# RF R2: 0.5645019591178064
# Remaining: 128
# Query no. 27
# (4101, 15)
# Embeddings training score: 0.9608385536842651
# (282, 7)
# RF R2: 0.642267517252786
# Remaining: 118
# Query no. 28
# (4393, 15)
# Embeddings training score: 0.970884869627502
# (292, 7)
# RF R2: 0.6643348563877358
# Remaining: 108
# Query no. 29
# (4695, 15)
# Embeddings training score: 0.9780239304836273
# (302, 7)
# RF R2: 0.6775908122655607
# Remaining: 98
# Query no. 30
# (5007, 15)
# Embeddings training score: 0.9794397382691002
# (312, 7)
# RF R2: 0.6811182892107595
# Remaining: 88
# The Iteration is  3
# NN Test R2 with 5 samples -14.146985250689417
# After Initialization RF R2: 0.3487887191231115
# NN Test R2 after Initialization -5.747415494185829
# (12, 7)
# Query no. 1
# (19, 15)
# Embeddings training score: 0.8723676580753916
# (22, 7)
# RF R2: 0.2267171279870711
# Remaining: 378
# Query no. 2
# (51, 15)
# Embeddings training score: 0.8545595614505426
# (32, 7)
# RF R2: 0.2386016318757629
# Remaining: 368
# Query no. 3
# (93, 15)
# Embeddings training score: 0.8688500222427535
# (42, 7)
# RF R2: 0.4267699155201058
# Remaining: 358
# Query no. 4
# (145, 15)
# Embeddings training score: 0.8516243992135085
# (52, 7)
# RF R2: 0.46808380687238427
# Remaining: 348
# Query no. 5
# (207, 15)
# Embeddings training score: 0.8674428231512172
# (62, 7)
# RF R2: 0.5797925597942328
# Remaining: 338
# Query no. 6
# (279, 15)
# Embeddings training score: 0.8792133823692824
# (72, 7)
# RF R2: 0.5687827161510156
# Remaining: 328
# Query no. 7
# (361, 15)
# Embeddings training score: 0.8885643193059196
# (82, 7)
# RF R2: 0.5631482671155923
# Remaining: 318
# Query no. 8
# (453, 15)
# Embeddings training score: 0.8912753383148161
# (92, 7)
# RF R2: 0.5778721840991445
# Remaining: 308
# Query no. 9
# (555, 15)
# Embeddings training score: 0.90261355546761
# (102, 7)
# RF R2: 0.5836124151470785
# Remaining: 298
# Query no. 10
# (667, 15)
# Embeddings training score: 0.9084525438076833
# (112, 7)
# RF R2: 0.5851179260865107
# Remaining: 288
# Query no. 11
# (789, 15)
# Embeddings training score: 0.9058743004794577
# (122, 7)
# RF R2: 0.5933956046311608
# Remaining: 278
# Query no. 12
# (921, 15)
# Embeddings training score: 0.9032121999501841
# (132, 7)
# RF R2: 0.5985818417673815
# Remaining: 268
# Query no. 13
# (1063, 15)
# Embeddings training score: 0.9042552529513932
# (142, 7)
# RF R2: 0.6046496361614322
# Remaining: 258
# Query no. 14
# (1215, 15)
# Embeddings training score: 0.9087666219825457
# (152, 7)
# RF R2: 0.5743452319636295
# Remaining: 248
# Query no. 15
# (1377, 15)
# Embeddings training score: 0.9119330274309744
# (162, 7)
# RF R2: 0.5953730746377515
# Remaining: 238
# Query no. 16
# (1549, 15)
# Embeddings training score: 0.9090655244362141
# (172, 7)
# RF R2: 0.616689528534641
# Remaining: 228
# Query no. 17
# (1731, 15)
# Embeddings training score: 0.9110987738992317
# (182, 7)
# RF R2: 0.5843354073243952
# Remaining: 218
# Query no. 18
# (1923, 15)
# Embeddings training score: 0.913099122307761
# (192, 7)
# RF R2: 0.5866428250405774
# Remaining: 208
# Query no. 19
# (2125, 15)
# Embeddings training score: 0.9168163240328826
# (202, 7)
# RF R2: 0.5779686966379067
# Remaining: 198
# Query no. 20
# (2337, 15)
# Embeddings training score: 0.9173179229289303
# (212, 7)
# RF R2: 0.5822920110317773
# Remaining: 188
# Query no. 21
# (2559, 15)
# Embeddings training score: 0.9205548751537149
# (222, 7)
# RF R2: 0.5819481406957363
# Remaining: 178
# Query no. 22
# (2791, 15)
# Embeddings training score: 0.9275394195608784
# (232, 7)
# RF R2: 0.5892756718085919
# Remaining: 168
# Query no. 23
# (3033, 15)
# Embeddings training score: 0.9289135500807999
# (242, 7)
# RF R2: 0.6366953374485049
# Remaining: 158
# Query no. 24
# (3285, 15)
# Embeddings training score: 0.9317662563452094
# (252, 7)
# RF R2: 0.6521616375662554
# Remaining: 148
# Query no. 25
# (3547, 15)
# Embeddings training score: 0.9323542995136066
# (262, 7)
# RF R2: 0.6577905430498515
# Remaining: 138
# Query no. 26
# (3819, 15)
# Embeddings training score: 0.9401803831212212
# (272, 7)
# RF R2: 0.648556871119427
# Remaining: 128
# Query no. 27
# (4101, 15)
# Embeddings training score: 0.9509473176700447
# (282, 7)
# RF R2: 0.6233937355586698
# Remaining: 118
# Query no. 28
# (4393, 15)
# Embeddings training score: 0.9632421781376084
# (292, 7)
# RF R2: 0.639900836041174
# Remaining: 108
# Query no. 29
# (4695, 15)
# Embeddings training score: 0.9775402537530073
# (302, 7)
# RF R2: 0.6538380429567042
# Remaining: 98
# Query no. 30
# (5007, 15)
# Embeddings training score: 0.9878225859519234
# (312, 7)
# RF R2: 0.6580741140404452
# Remaining: 88
# The Iteration is  4
# NN Test R2 with 5 samples -16.932573293067698
# After Initialization RF R2: 0.34563443362096136
# NN Test R2 after Initialization -2.2946080731140666
# (12, 7)
# Query no. 1
# (19, 15)
# Embeddings training score: 0.8510629558965515
# (22, 7)
# RF R2: 0.25062972933876504
# Remaining: 378
# Query no. 2
# (51, 15)
# Embeddings training score: 0.8788269229115081
# (32, 7)
# RF R2: 0.24803646469195717
# Remaining: 368
# Query no. 3
# (93, 15)
# Embeddings training score: 0.8951274981653009
# (42, 7)
# RF R2: 0.23161132160082276
# Remaining: 358
# Query no. 4
# (145, 15)
# Embeddings training score: 0.8951668167978186
# (52, 7)
# RF R2: 0.2991764778518472
# Remaining: 348
# Query no. 5
# (207, 15)
# Embeddings training score: 0.8824790417504492
# (62, 7)
# RF R2: 0.30842122626383406
# Remaining: 338
# Query no. 6
# (279, 15)
# Embeddings training score: 0.8932605640778224
# (72, 7)
# RF R2: 0.40254379160470466
# Remaining: 328
# Query no. 7
# (361, 15)
# Embeddings training score: 0.8988929763478527
# (82, 7)
# RF R2: 0.45042411954276984
# Remaining: 318
# Query no. 8
# (453, 15)
# Embeddings training score: 0.9036908563468494
# (92, 7)
# RF R2: 0.4860371684723588
# Remaining: 308
# Query no. 9
# (555, 15)
# Embeddings training score: 0.9032699042252921
# (102, 7)
# RF R2: 0.5253970945365537
# Remaining: 298
# Query no. 10
# (667, 15)
# Embeddings training score: 0.9134424006232787
# (112, 7)
# RF R2: 0.5258815236208931
# Remaining: 288
# Query no. 11
# (789, 15)
# Embeddings training score: 0.9134399572606098
# (122, 7)
# RF R2: 0.5465572495620521
# Remaining: 278
# Query no. 12
# (921, 15)
# Embeddings training score: 0.9176919327726984
# (132, 7)
# RF R2: 0.5671713408041885
# Remaining: 268
# Query no. 13
# (1063, 15)
# Embeddings training score: 0.9195079569190784
# (142, 7)
# RF R2: 0.555249668078144
# Remaining: 258
# Query no. 14
# (1215, 15)
# Embeddings training score: 0.9192172137320173
# (152, 7)
# RF R2: 0.5516607157142528
# Remaining: 248
# Query no. 15
# (1377, 15)
# Embeddings training score: 0.8990779513060324
# (162, 7)
# RF R2: 0.5780673027490487
# Remaining: 238
# Query no. 16
# (1549, 15)
# Embeddings training score: 0.9049972004019265
# (172, 7)
# RF R2: 0.5561953277653571
# Remaining: 228
# Query no. 17
# (1731, 15)
# Embeddings training score: 0.9114553626627642
# (182, 7)
# RF R2: 0.575814629483179
# Remaining: 218
# Query no. 18
# (1923, 15)
# Embeddings training score: 0.9170575500325859
# (192, 7)
# RF R2: 0.6045590079838008
# Remaining: 208
# Query no. 19
# (2125, 15)
# Embeddings training score: 0.9229809782051304
# (202, 7)
# RF R2: 0.6282065523734839
# Remaining: 198
# Query no. 20
# (2337, 15)
# Embeddings training score: 0.9294640245059838
# (212, 7)
# RF R2: 0.6071968500010474
# Remaining: 188
# Query no. 21
# (2559, 15)
# Embeddings training score: 0.9325728611823807
# (222, 7)
# RF R2: 0.620657048586345
# Remaining: 178
# Query no. 22
# (2791, 15)
# Embeddings training score: 0.937431562071866
# (232, 7)
# RF R2: 0.6147625124876708
# Remaining: 168
# Query no. 23
# (3033, 15)
# Embeddings training score: 0.9388125385153433
# (242, 7)
# RF R2: 0.6173011181036756
# Remaining: 158
# Query no. 24
# (3285, 15)
# Embeddings training score: 0.9434990990058875
# (252, 7)
# RF R2: 0.626096113550384
# Remaining: 148
# Query no. 25
# (3547, 15)
# Embeddings training score: 0.9402858267319321
# (262, 7)
# RF R2: 0.623109360148926
# Remaining: 138
# Query no. 26
# (3819, 15)
# Embeddings training score: 0.9432724135992974
# (272, 7)
# RF R2: 0.6259592098513084
# Remaining: 128
# Query no. 27
# (4101, 15)
# Embeddings training score: 0.94588686210764
# (282, 7)
# RF R2: 0.6445467030753353
# Remaining: 118
# Query no. 28
# (4393, 15)
# Embeddings training score: 0.9569652380785408
# (292, 7)
# RF R2: 0.6499286382682941
# Remaining: 108
# Query no. 29
# (4695, 15)
# Embeddings training score: 0.9679007243791563
# (302, 7)
# RF R2: 0.656252724681869
# Remaining: 98
# Query no. 30
# (5007, 15)
# Embeddings training score: 0.9753852433577765
# (312, 7)
# RF R2: 0.6545549235654403
# Remaining: 88
# The Iteration is  5
# NN Test R2 with 5 samples -20.625232006185183
# After Initialization RF R2: -0.34804413440975934
# NN Test R2 after Initialization -1.5861506986754819
# (12, 7)
# Query no. 1
# (19, 15)
# Embeddings training score: 0.9733538960667055
# (22, 7)
# RF R2: -0.2283624028009199
# Remaining: 378
# Query no. 2
# (51, 15)
# Embeddings training score: 0.8845754403997341
# (32, 7)
# RF R2: 0.08121016335290632
# Remaining: 368
# Query no. 3
# (93, 15)
# Embeddings training score: 0.9015989890458311
# (42, 7)
# RF R2: 0.17504109204432095
# Remaining: 358
# Query no. 4
# (145, 15)
# Embeddings training score: 0.8809814883367522
# (52, 7)
# RF R2: 0.1427903138201846
# Remaining: 348
# Query no. 5
# (207, 15)
# Embeddings training score: 0.8969953704499731
# (62, 7)
# RF R2: 0.13033626697833745
# Remaining: 338
# Query no. 6
# (279, 15)
# Embeddings training score: 0.9035184493524371
# (72, 7)
# RF R2: -0.011413341945624156
# Remaining: 328
# Query no. 7
# (361, 15)
# Embeddings training score: 0.893752175967202
# (82, 7)
# RF R2: 0.02523291423525098
# Remaining: 318
# Query no. 8
# (453, 15)
# Embeddings training score: 0.9042081487329866
# (92, 7)
# RF R2: 0.07498630061068068
# Remaining: 308
# Query no. 9
# (555, 15)
# Embeddings training score: 0.8913180043486049
# (102, 7)
# RF R2: 0.12964140744455943
# Remaining: 298
# Query no. 10
# (667, 15)
# Embeddings training score: 0.8966456401446555
# (112, 7)
# RF R2: 0.14366652636619381
# Remaining: 288
# Query no. 11
# (789, 15)
# Embeddings training score: 0.9001502980292557
# (122, 7)
# RF R2: 0.23081667254955818
# Remaining: 278
# Query no. 12
# (921, 15)
# Embeddings training score: 0.9080149751628275
# (132, 7)
# RF R2: 0.3157621674312896
# Remaining: 268
# Query no. 13
# (1063, 15)
# Embeddings training score: 0.9130273361107898
# (142, 7)
# RF R2: 0.3234300027945397
# Remaining: 258
# Query no. 14
# (1215, 15)
# Embeddings training score: 0.9162168665153251
# (152, 7)
# RF R2: 0.3427530484831999
# Remaining: 248
# Query no. 15
# (1377, 15)
# Embeddings training score: 0.9179628040387487
# (162, 7)
# RF R2: 0.3976652478018826
# Remaining: 238
# Query no. 16
# (1549, 15)
# Embeddings training score: 0.9225908042644698
# (172, 7)
# RF R2: 0.42144741304578415
# Remaining: 228
# Query no. 17
# (1731, 15)
# Embeddings training score: 0.9292985660717381
# (182, 7)
# RF R2: 0.4209450365562931
# Remaining: 218
# Query no. 18
# (1923, 15)
# Embeddings training score: 0.931697907138127
# (192, 7)
# RF R2: 0.43340958639845906
# Remaining: 208
# Query no. 19
# (2125, 15)
# Embeddings training score: 0.9376964688602236
# (202, 7)
# RF R2: 0.4288638742346548
# Remaining: 198
# Query no. 20
# (2337, 15)
# Embeddings training score: 0.9379310370664535
# (212, 7)
# RF R2: 0.45272199965009385
# Remaining: 188
# Query no. 21
# (2559, 15)
# Embeddings training score: 0.9391999895060549
# (222, 7)
# RF R2: 0.4609622987303398
# Remaining: 178
# Query no. 22
# (2791, 15)
# Embeddings training score: 0.9392682579256245
# (232, 7)
# RF R2: 0.4539366770343808
# Remaining: 168
# Query no. 23
# (3033, 15)
# Embeddings training score: 0.9438258099410556
# (242, 7)
# RF R2: 0.44855302680454046
# Remaining: 158
# Query no. 24
# (3285, 15)
# Embeddings training score: 0.9463318520622191
# (252, 7)
# RF R2: 0.4682328665183708
# Remaining: 148
# Query no. 25
# (3547, 15)
# Embeddings training score: 0.9435450949651538
# (262, 7)
# RF R2: 0.4484706398035443
# Remaining: 138
# Query no. 26
# (3819, 15)
# Embeddings training score: 0.9474897737550457
# (272, 7)
# RF R2: 0.4663048862777124
# Remaining: 128
# Query no. 27
# (4101, 15)
# Embeddings training score: 0.9651704998380297
# (282, 7)
# RF R2: 0.4510253431130181
# Remaining: 118
# Query no. 28
# (4393, 15)
# Embeddings training score: 0.9790022483898064
# (292, 7)
# RF R2: 0.4922221282692779
# Remaining: 108
# Query no. 29
# (4695, 15)
# Embeddings training score: 0.985629040949991
# (302, 7)
# RF R2: 0.5085962611397938
# Remaining: 98
# Query no. 30
# (5007, 15)
# Embeddings training score: 0.9883097845969879
# (312, 7)
# RF R2: 0.5346374644202632
# Remaining: 88
# The Iteration is  6
# NN Test R2 with 5 samples -12.212613356423835
# After Initialization RF R2: -0.22878572585498458
# NN Test R2 after Initialization -2.909387989643586
# (12, 7)
# Query no. 1
# (19, 15)
# Embeddings training score: 0.9551126005149596
# (22, 7)
# RF R2: 0.1760199343223351
# Remaining: 378
# Query no. 2
# (51, 15)
# Embeddings training score: 0.9120903020853377
# (32, 7)
# RF R2: 0.17849178707048297
# Remaining: 368
# Query no. 3
# (93, 15)
# Embeddings training score: 0.8975167594536096
# (42, 7)
# RF R2: 0.4726833001155516
# Remaining: 358
# Query no. 4
# (145, 15)
# Embeddings training score: 0.8864661992696299
# (52, 7)
# RF R2: 0.4876293814865177
# Remaining: 348
# Query no. 5
# (207, 15)
# Embeddings training score: 0.8947298142818108
# (62, 7)
# RF R2: 0.48694357504935537
# Remaining: 338
# Query no. 6
# (279, 15)
# Embeddings training score: 0.8771163458678126
# (72, 7)
# RF R2: 0.47949127434552763
# Remaining: 328
# Query no. 7
# (361, 15)
# Embeddings training score: 0.8965315574136906
# (82, 7)
# RF R2: 0.4538963474483304
# Remaining: 318
# Query no. 8
# (453, 15)
# Embeddings training score: 0.9112787701906553
# (92, 7)
# RF R2: 0.4862685072898255
# Remaining: 308
# Query no. 9
# (555, 15)
# Embeddings training score: 0.921706740369847
# (102, 7)
# RF R2: 0.5096594043462856
# Remaining: 298
# Query no. 10
# (667, 15)
# Embeddings training score: 0.9207404907386093
# (112, 7)
# RF R2: 0.5283993293210596
# Remaining: 288
# Query no. 11
# (789, 15)
# Embeddings training score: 0.9219307327142117
# (122, 7)
# RF R2: 0.5310806283796619
# Remaining: 278
# Query no. 12
# (921, 15)
# Embeddings training score: 0.9221316362479666
# (132, 7)
# RF R2: 0.539289561820429
# Remaining: 268
# Query no. 13
# (1063, 15)
# Embeddings training score: 0.9185858518335391
# (142, 7)
# RF R2: 0.5110729465627313
# Remaining: 258
# Query no. 14
# (1215, 15)
# Embeddings training score: 0.9224211740243774
# (152, 7)
# RF R2: 0.49247682371236456
# Remaining: 248
# Query no. 15
# (1377, 15)
# Embeddings training score: 0.9268305138810072
# (162, 7)
# RF R2: 0.5157926946011115
# Remaining: 238
# Query no. 16
# (1549, 15)
# Embeddings training score: 0.9297737326466724
# (172, 7)
# RF R2: 0.5256979946127884
# Remaining: 228
# Query no. 17
# (1731, 15)
# Embeddings training score: 0.9282793426443346
# (182, 7)
# RF R2: 0.5103071250660925
# Remaining: 218
# Query no. 18
# (1923, 15)
# Embeddings training score: 0.9314020748016142
# (192, 7)
# RF R2: 0.52698047046318
# Remaining: 208
# Query no. 19
# (2125, 15)
# Embeddings training score: 0.9316181397307358
# (202, 7)
# RF R2: 0.5280631237227156
# Remaining: 198
# Query no. 20
# (2337, 15)
# Embeddings training score: 0.9351176518405155
# (212, 7)
# RF R2: 0.5447907098896443
# Remaining: 188
# Query no. 21
# (2559, 15)
# Embeddings training score: 0.9374552383016423
# (222, 7)
# RF R2: 0.5414595904039124
# Remaining: 178
# Query no. 22
# (2791, 15)
# Embeddings training score: 0.9397323473355699
# (232, 7)
# RF R2: 0.5465833372567888
# Remaining: 168
# Query no. 23
# (3033, 15)
# Embeddings training score: 0.9368975680341587
# (242, 7)
# RF R2: 0.5615850982655943
# Remaining: 158
# Query no. 24
# (3285, 15)
# Embeddings training score: 0.940232303315893
# (252, 7)
# RF R2: 0.5542235989138874
# Remaining: 148
# Query no. 25
# (3547, 15)
# Embeddings training score: 0.9372296893280061
# (262, 7)
# RF R2: 0.5251673109262693
# Remaining: 138
# Query no. 26
# (3819, 15)
# Embeddings training score: 0.9495381138676203
# (272, 7)
# RF R2: 0.511548220922369
# Remaining: 128
# Query no. 27
# (4101, 15)
# Embeddings training score: 0.9545831533310218
# (282, 7)
# RF R2: 0.5551638585597326
# Remaining: 118
# Query no. 28
# (4393, 15)
# Embeddings training score: 0.9656551161304461
# (292, 7)
# RF R2: 0.5544329091906949
# Remaining: 108
# Query no. 29
# (4695, 15)
# Embeddings training score: 0.976802626455728
# (302, 7)
# RF R2: 0.5680676599634374
# Remaining: 98
# Query no. 30
# (5007, 15)
# Embeddings training score: 0.9781780359805166
# (312, 7)
# RF R2: 0.5755106367811285
# Remaining: 88
# The Iteration is  7
# NN Test R2 with 5 samples -24.427242742770147
# After Initialization RF R2: -0.2209373197216089
# NN Test R2 after Initialization -1.4252796827809258
# (12, 7)
# Query no. 1
# (19, 15)
# Embeddings training score: 0.9216705757647586
# (22, 7)
# RF R2: -0.18767812917302917
# Remaining: 378
# Query no. 2
# (51, 15)
# Embeddings training score: 0.9006644304522674
# (32, 7)
# RF R2: -0.1737567930780346
# Remaining: 368
# Query no. 3
# (93, 15)
# Embeddings training score: 0.9114652604959653
# (42, 7)
# RF R2: -0.0441853674752164
# Remaining: 358
# Query no. 4
# (145, 15)
# Embeddings training score: 0.9102888570578851
# (52, 7)
# RF R2: 0.0721162280248816
# Remaining: 348
# Query no. 5
# (207, 15)
# Embeddings training score: 0.917715441482991
# (62, 7)
# RF R2: 0.1663901065314779
# Remaining: 338
# Query no. 6
# (279, 15)
# Embeddings training score: 0.8831047676197239
# (72, 7)
# RF R2: 0.19286819140785738
# Remaining: 328
# Query no. 7
# (361, 15)
# Embeddings training score: 0.8942978008574746
# (82, 7)
# RF R2: 0.37988294311851956
# Remaining: 318
# Query no. 8
# (453, 15)
# Embeddings training score: 0.8800143229798196
# (92, 7)
# RF R2: 0.46067062019845606
# Remaining: 308
# Query no. 9
# (555, 15)
# Embeddings training score: 0.8895179887621766
# (102, 7)
# RF R2: 0.40963416130714025
# Remaining: 298
# Query no. 10
# (667, 15)
# Embeddings training score: 0.8890987208581035
# (112, 7)
# RF R2: 0.4491842000026305
# Remaining: 288
# Query no. 11
# (789, 15)
# Embeddings training score: 0.8986661659837732
# (122, 7)
# RF R2: 0.5008067390987748
# Remaining: 278
# Query no. 12
# (921, 15)
# Embeddings training score: 0.9038633038378755
# (132, 7)
# RF R2: 0.5311627967155056
# Remaining: 268
# Query no. 13
# (1063, 15)
# Embeddings training score: 0.9093467651679478
# (142, 7)
# RF R2: 0.5406933146908366
# Remaining: 258
# Query no. 14
# (1215, 15)
# Embeddings training score: 0.9138798412123009
# (152, 7)
# RF R2: 0.5167045651015874
# Remaining: 248
# Query no. 15
# (1377, 15)
# Embeddings training score: 0.9188570837587511
# (162, 7)
# RF R2: 0.4488761754709799
# Remaining: 238
# Query no. 16
# (1549, 15)
# Embeddings training score: 0.9220307982423938
# (172, 7)
# RF R2: 0.5550080008565444
# Remaining: 228
# Query no. 17
# (1731, 15)
# Embeddings training score: 0.9264136447424249
# (182, 7)
# RF R2: 0.5201108127981093
# Remaining: 218
# Query no. 18
# (1923, 15)
# Embeddings training score: 0.9307485598002163
# (192, 7)
# RF R2: 0.5117216519511893
# Remaining: 208
# Query no. 19
# (2125, 15)
# Embeddings training score: 0.9322084797228247
# (202, 7)
# RF R2: 0.511376184099452
# Remaining: 198
# Query no. 20
# (2337, 15)
# Embeddings training score: 0.9282122898738449
# (212, 7)
# RF R2: 0.5553636420379053
# Remaining: 188
# Query no. 21
# (2559, 15)
# Embeddings training score: 0.9294811016879561
# (222, 7)
# RF R2: 0.5475386251784871
# Remaining: 178
# Query no. 22
# (2791, 15)
# Embeddings training score: 0.9359170923927111
# (232, 7)
# RF R2: 0.5747178891570264
# Remaining: 168
# Query no. 23
# (3033, 15)
# Embeddings training score: 0.940146418204609
# (242, 7)
# RF R2: 0.5816932945410545
# Remaining: 158
# Query no. 24
# (3285, 15)
# Embeddings training score: 0.9423848522854511
# (252, 7)
# RF R2: 0.5651886078650599
# Remaining: 148
# Query no. 25
# (3547, 15)
# Embeddings training score: 0.9383338625595284
# (262, 7)
# RF R2: 0.5470390442360263
# Remaining: 138
# Query no. 26
# (3819, 15)
# Embeddings training score: 0.9401942294934819
# (272, 7)
# RF R2: 0.5754121917095673
# Remaining: 128
# Query no. 27
# (4101, 15)
# Embeddings training score: 0.9485889794786454
# (282, 7)
# RF R2: 0.5625801805640465
# Remaining: 118
# Query no. 28
# (4393, 15)
# Embeddings training score: 0.9608517229809002
# (292, 7)
# RF R2: 0.5561021438644281
# Remaining: 108
# Query no. 29
# (4695, 15)
# Embeddings training score: 0.9709527442615765
# (302, 7)
# RF R2: 0.5656472079561525
# Remaining: 98
# Query no. 30
# (5007, 15)
# Embeddings training score: 0.9769314645656683
# (312, 7)
# RF R2: 0.5758785273290181
# Remaining: 88
# The Iteration is  8
# NN Test R2 with 5 samples -18.274509103078277
# After Initialization RF R2: 0.22694643945555149
# NN Test R2 after Initialization -0.9873573555523274
# (12, 7)
# Query no. 1
# (19, 15)
# Embeddings training score: 0.9105871945988382
# (22, 7)
# RF R2: 0.06277306830653606
# Remaining: 378
# Query no. 2
# (51, 15)
# Embeddings training score: 0.9209035901241814
# (32, 7)
# RF R2: 0.1518339547170875
# Remaining: 368
# Query no. 3
# (93, 15)
# Embeddings training score: 0.9076644174529835
# (42, 7)
# RF R2: 0.0694174107660337
# Remaining: 358
# Query no. 4
# (145, 15)
# Embeddings training score: 0.9062704776536448
# (52, 7)
# RF R2: 0.07976257576274881
# Remaining: 348
# Query no. 5
# (207, 15)
# Embeddings training score: 0.9098236097832508
# (62, 7)
# RF R2: 0.22433584541258123
# Remaining: 338
# Query no. 6
# (279, 15)
# Embeddings training score: 0.9075186751497415
# (72, 7)
# RF R2: 0.32218644567553467
# Remaining: 328
# Query no. 7
# (361, 15)
# Embeddings training score: 0.8901708115994749
# (82, 7)
# RF R2: 0.45573126812405007
# Remaining: 318
# Query no. 8
# (453, 15)
# Embeddings training score: 0.908991726773618
# (92, 7)
# RF R2: 0.4411098838322054
# Remaining: 308
# Query no. 9
# (555, 15)
# Embeddings training score: 0.9018964818960099
# (102, 7)
# RF R2: 0.44782152205807757
# Remaining: 298
# Query no. 10
# (667, 15)
# Embeddings training score: 0.907279884988656
# (112, 7)
# RF R2: 0.38106934739576726
# Remaining: 288
# Query no. 11
# (789, 15)
# Embeddings training score: 0.9086534934234396
# (122, 7)
# RF R2: 0.3553019123586446
# Remaining: 278
# Query no. 12
# (921, 15)
# Embeddings training score: 0.91337888655535
# (132, 7)
# RF R2: 0.3492913320492541
# Remaining: 268
# Query no. 13
# (1063, 15)
# Embeddings training score: 0.9171079796448226
# (142, 7)
# RF R2: 0.3996747498964076
# Remaining: 258
# Query no. 14
# (1215, 15)
# Embeddings training score: 0.9168069736590803
# (152, 7)
# RF R2: 0.42015136565490396
# Remaining: 248
# Query no. 15
# (1377, 15)
# Embeddings training score: 0.9187727182787079
# (162, 7)
# RF R2: 0.48898439272444716
# Remaining: 238
# Query no. 16
# (1549, 15)
# Embeddings training score: 0.9210764427588385
# (172, 7)
# RF R2: 0.5387555190444439
# Remaining: 228
# Query no. 17
# (1731, 15)
# Embeddings training score: 0.9240748794030686
# (182, 7)
# RF R2: 0.5367927950776201
# Remaining: 218
# Query no. 18
# (1923, 15)
# Embeddings training score: 0.927572068551806
# (192, 7)
# RF R2: 0.5954440535008216
# Remaining: 208
# Query no. 19
# (2125, 15)
# Embeddings training score: 0.9288063976859835
# (202, 7)
# RF R2: 0.5884086604859127
# Remaining: 198
# Query no. 20
# (2337, 15)
# Embeddings training score: 0.9315599957010459
# (212, 7)
# RF R2: 0.5983142708912866
# Remaining: 188
# Query no. 21
# (2559, 15)
# Embeddings training score: 0.9333839594959659
# (222, 7)
# RF R2: 0.5942383452739866
# Remaining: 178
# Query no. 22
# (2791, 15)
# Embeddings training score: 0.9356176060447216
# (232, 7)
# RF R2: 0.5970227696879569
# Remaining: 168
# Query no. 23
# (3033, 15)
# Embeddings training score: 0.9319995152615488
# (242, 7)
# RF R2: 0.5879950722125094
# Remaining: 158
# Query no. 24
# (3285, 15)
# Embeddings training score: 0.9345509290588669
# (252, 7)
# RF R2: 0.5631526866754435
# Remaining: 148
# Query no. 25
# (3547, 15)
# Embeddings training score: 0.9305978629762565
# (262, 7)
# RF R2: 0.5118345665586295
# Remaining: 138
# Query no. 26
# (3819, 15)
# Embeddings training score: 0.9476288636276659
# (272, 7)
# RF R2: 0.5176211606608923
# Remaining: 128
# Query no. 27
# (4101, 15)
# Embeddings training score: 0.9592778769330724
# (282, 7)
# RF R2: 0.5344236770250665
# Remaining: 118
# Query no. 28
# (4393, 15)
# Embeddings training score: 0.9709023447020424
# (292, 7)
# RF R2: 0.5320667683079565
# Remaining: 108
# Query no. 29
# (4695, 15)
# Embeddings training score: 0.9791254770123263
# (302, 7)
# RF R2: 0.5414086957665847
# Remaining: 98
# Query no. 30
# (5007, 15)
# Embeddings training score: 0.9838452577230369
# (312, 7)
# RF R2: 0.5553283676617979
# Remaining: 88
# The Iteration is  9
# NN Test R2 with 5 samples -21.689888852683413
# After Initialization RF R2: -0.5616342277682393
# NN Test R2 after Initialization -2.737264910273304
# (12, 7)
# Query no. 1
# (19, 15)
# Embeddings training score: 0.791922314307218
# (22, 7)
# RF R2: 0.09358263451363569
# Remaining: 378
# Query no. 2
# (51, 15)
# Embeddings training score: 0.8410280281458518
# (32, 7)
# RF R2: 0.2140443584627727
# Remaining: 368
# Query no. 3
# (93, 15)
# Embeddings training score: 0.8519684167472004
# (42, 7)
# RF R2: 0.2620257944722644
# Remaining: 358
# Query no. 4
# (145, 15)
# Embeddings training score: 0.8597370860749701
# (52, 7)
# RF R2: 0.3124151476064707
# Remaining: 348
# Query no. 5
# (207, 15)
# Embeddings training score: 0.8642366763023168
# (62, 7)
# RF R2: 0.23125913301807866
# Remaining: 338
# Query no. 6
# (279, 15)
# Embeddings training score: 0.8801805827465393
# (72, 7)
# RF R2: 0.28477895814587995
# Remaining: 328
# Query no. 7
# (361, 15)
# Embeddings training score: 0.8761449168625047
# (82, 7)
# RF R2: 0.37537629403721595
# Remaining: 318
# Query no. 8
# (453, 15)
# Embeddings training score: 0.8953152761671705
# (92, 7)
# RF R2: 0.3362507730935733
# Remaining: 308
# Query no. 9
# (555, 15)
# Embeddings training score: 0.8990942762636024
# (102, 7)
# RF R2: 0.39826589863939277
# Remaining: 298
# Query no. 10
# (667, 15)
# Embeddings training score: 0.9052770994710445
# (112, 7)
# RF R2: 0.4177057865607561
# Remaining: 288
# Query no. 11
# (789, 15)
# Embeddings training score: 0.8991612190820705
# (122, 7)
# RF R2: 0.4432422772061191
# Remaining: 278
# Query no. 12
# (921, 15)
# Embeddings training score: 0.9037857189562998
# (132, 7)
# RF R2: 0.3737967654183091
# Remaining: 268
# Query no. 13
# (1063, 15)
# Embeddings training score: 0.9058004923491423
# (142, 7)
# RF R2: 0.38528840314081614
# Remaining: 258
# Query no. 14
# (1215, 15)
# Embeddings training score: 0.9109595869027096
# (152, 7)
# RF R2: 0.45591333480583973
# Remaining: 248
# Query no. 15
# (1377, 15)
# Embeddings training score: 0.9130396904209168
# (162, 7)
# RF R2: 0.4808002517449934
# Remaining: 238
# Query no. 16
# (1549, 15)
# Embeddings training score: 0.913187241381636
# (172, 7)
# RF R2: 0.49077533892799496
# Remaining: 228
# Query no. 17
# (1731, 15)
# Embeddings training score: 0.9188650878133298
# (182, 7)
# RF R2: 0.5045407747084576
# Remaining: 218
# Query no. 18
# (1923, 15)
# Embeddings training score: 0.9232230492509877
# (192, 7)
# RF R2: 0.5220419301555079
# Remaining: 208
# Query no. 19
# (2125, 15)
# Embeddings training score: 0.929982949559329
# (202, 7)
# RF R2: 0.5398330945769044
# Remaining: 198
# Query no. 20
# (2337, 15)
# Embeddings training score: 0.9350150074979725
# (212, 7)
# RF R2: 0.5484519770177195
# Remaining: 188
# Query no. 21
# (2559, 15)
# Embeddings training score: 0.9404190166078417
# (222, 7)
# RF R2: 0.5635345285575588
# Remaining: 178
# Query no. 22
# (2791, 15)
# Embeddings training score: 0.9446819268745045
# (232, 7)
# RF R2: 0.5618507283628442
# Remaining: 168
# Query no. 23
# (3033, 15)
# Embeddings training score: 0.946738483533246
# (242, 7)
# RF R2: 0.5680795033319519
# Remaining: 158
# Query no. 24
# (3285, 15)
# Embeddings training score: 0.9478805093493643
# (252, 7)
# RF R2: 0.5606935332524514
# Remaining: 148
# Query no. 25
# (3547, 15)
# Embeddings training score: 0.9419700494238245
# (262, 7)
# RF R2: 0.5475184993565934
# Remaining: 138
# Query no. 26
# (3819, 15)
# Embeddings training score: 0.9469148916296615
# (272, 7)
# RF R2: 0.5604912885595927
# Remaining: 128
# Query no. 27
# (4101, 15)
# Embeddings training score: 0.9540584269663197
# (282, 7)
# RF R2: 0.5624514696042655
# Remaining: 118
# Query no. 28
# (4393, 15)
# Embeddings training score: 0.9603187268902545
# (292, 7)
# RF R2: 0.5453950560015504
# Remaining: 108
# Query no. 29
# (4695, 15)
# Embeddings training score: 0.9656317183935089
# (302, 7)
# RF R2: 0.5462912750973683
# Remaining: 98
# Query no. 30
# (5007, 15)
# Embeddings training score: 0.970597672470891
# (312, 7)
# RF R2: 0.5455456783578818
# Remaining: 88
# The Iteration is  10
# NN Test R2 with 5 samples -14.151462344925166
# After Initialization RF R2: -0.05206078116945401
# NN Test R2 after Initialization -1.3242253042411136
# (12, 7)
# Query no. 1
# (19, 15)
# Embeddings training score: 0.8651545389560068
# (22, 7)
# RF R2: 0.17478311528398427
# Remaining: 378
# Query no. 2
# (51, 15)
# Embeddings training score: 0.8402165034877018
# (32, 7)
# RF R2: 0.33144227199867915
# Remaining: 368
# Query no. 3
# (93, 15)
# Embeddings training score: 0.8582249257058923
# (42, 7)
# RF R2: 0.37514133605673294
# Remaining: 358
# Query no. 4
# (145, 15)
# Embeddings training score: 0.8822994005709394
# (52, 7)
# RF R2: 0.3594394921568612
# Remaining: 348
# Query no. 5
# (207, 15)
# Embeddings training score: 0.89660449748908
# (62, 7)
# RF R2: 0.34700404211531133
# Remaining: 338
# Query no. 6
# (279, 15)
# Embeddings training score: 0.9000423696135031
# (72, 7)
# RF R2: 0.31609988518634835
# Remaining: 328
# Query no. 7
# (361, 15)
# Embeddings training score: 0.8995817865208613
# (82, 7)
# RF R2: 0.4445593244031668
# Remaining: 318
# Query no. 8
# (453, 15)
# Embeddings training score: 0.8972209576491875
# (92, 7)
# RF R2: 0.43946107964821335
# Remaining: 308
# Query no. 9
# (555, 15)
# Embeddings training score: 0.9067873628266936
# (102, 7)
# RF R2: 0.39965393408801453
# Remaining: 298
# Query no. 10
# (667, 15)
# Embeddings training score: 0.9071086846519623
# (112, 7)
# RF R2: 0.422873458955791
# Remaining: 288
# Query no. 11
# (789, 15)
# Embeddings training score: 0.9005788897977908
# (122, 7)
# RF R2: 0.4246466039608756
# Remaining: 278
# Query no. 12
# (921, 15)
# Embeddings training score: 0.9032819323362725
# (132, 7)
# RF R2: 0.5321863024808146
# Remaining: 268
# Query no. 13
# (1063, 15)
# Embeddings training score: 0.9072749600620922
# (142, 7)
# RF R2: 0.5330660000946081
# Remaining: 258
# Query no. 14
# (1215, 15)
# Embeddings training score: 0.9158932028117655
# (152, 7)
# RF R2: 0.5548627911635281
# Remaining: 248
# Query no. 15
# (1377, 15)
# Embeddings training score: 0.9167616665768266
# (162, 7)
# RF R2: 0.642002899007283
# Remaining: 238
# Query no. 16
# (1549, 15)
# Embeddings training score: 0.9195439348128971
# (172, 7)
# RF R2: 0.6440000086298887
# Remaining: 228
# Query no. 17
# (1731, 15)
# Embeddings training score: 0.9164186935022203
# (182, 7)
# RF R2: 0.6410739904909908
# Remaining: 218
# Query no. 18
# (1923, 15)
# Embeddings training score: 0.9156060358796094
# (192, 7)
# RF R2: 0.6485540649793555
# Remaining: 208
# Query no. 19
# (2125, 15)
# Embeddings training score: 0.9192159353463734
# (202, 7)
# RF R2: 0.6429644030943775
# Remaining: 198
# Query no. 20
# (2337, 15)
# Embeddings training score: 0.9232218347602171
# (212, 7)
# RF R2: 0.6249811849755955
# Remaining: 188
# Query no. 21
# (2559, 15)
# Embeddings training score: 0.9254302502282639
# (222, 7)
# RF R2: 0.6361599127460937
# Remaining: 178
# Query no. 22
# (2791, 15)
# Embeddings training score: 0.9277811492118864
# (232, 7)
# RF R2: 0.6345572436415793
# Remaining: 168
# Query no. 23
# (3033, 15)
# Embeddings training score: 0.9288168195862263
# (242, 7)
# RF R2: 0.6362292748513652
# Remaining: 158
# Query no. 24
# (3285, 15)
# Embeddings training score: 0.931281060634211
# (252, 7)
# RF R2: 0.6452285467691352
# Remaining: 148
# Query no. 25
# (3547, 15)
# Embeddings training score: 0.9246894663130288
# (262, 7)
# RF R2: 0.6353305760992732
# Remaining: 138
# Query no. 26
# (3819, 15)
# Embeddings training score: 0.9363065192522307
# (272, 7)
# RF R2: 0.6262929801272874
# Remaining: 128
# Query no. 27
# (4101, 15)
# Embeddings training score: 0.9492950921126843
# (282, 7)
# RF R2: 0.6437543813330702
# Remaining: 118
# Query no. 28
# (4393, 15)
# Embeddings training score: 0.9590376316511018
# (292, 7)
# RF R2: 0.6473980242107473
# Remaining: 108
# Query no. 29
# (4695, 15)
# Embeddings training score: 0.9676301876438798
# (302, 7)
# RF R2: 0.6647409215076072
# Remaining: 98
# Query no. 30
# (5007, 15)
# Embeddings training score: 0.9742393188515133
# (312, 7)
# RF R2: 0.6750719161971022
# Remaining: 88
# The Iteration is  11
# NN Test R2 with 5 samples -24.92922833418066
# After Initialization RF R2: 0.013822238587827385
# NN Test R2 after Initialization -10.001828401406888
# (12, 7)
# Query no. 1
# (19, 15)
# Embeddings training score: 0.8895234834190341
# (22, 7)
# RF R2: -0.06510149177948166
# Remaining: 378
# Query no. 2
# (51, 15)
# Embeddings training score: 0.89756701786424
# (32, 7)
# RF R2: 0.14111339849514837
# Remaining: 368
# Query no. 3
# (93, 15)
# Embeddings training score: 0.9004130599750703
# (42, 7)
# RF R2: 0.17275821337230846
# Remaining: 358
# Query no. 4
# (145, 15)
# Embeddings training score: 0.9080464898194653
# (52, 7)
# RF R2: 0.24524189972209287
# Remaining: 348
# Query no. 5
# (207, 15)
# Embeddings training score: 0.9154456384049158
# (62, 7)
# RF R2: 0.2177909455862067
# Remaining: 338
# Query no. 6
# (279, 15)
# Embeddings training score: 0.9204333677510536
# (72, 7)
# RF R2: 0.307806863069361
# Remaining: 328
# Query no. 7
# (361, 15)
# Embeddings training score: 0.9256106893616141
# (82, 7)
# RF R2: 0.3200183865359947
# Remaining: 318
# Query no. 8
# (453, 15)
# Embeddings training score: 0.9308045074177091
# (92, 7)
# RF R2: 0.3722192715913819
# Remaining: 308
# Query no. 9
# (555, 15)
# Embeddings training score: 0.9351832776681174
# (102, 7)
# RF R2: 0.35020271971290595
# Remaining: 298
# Query no. 10
# (667, 15)
# Embeddings training score: 0.9341592178953786
# (112, 7)
# RF R2: 0.3665600761103873
# Remaining: 288
# Query no. 11
# (789, 15)
# Embeddings training score: 0.9253802402347796
# (122, 7)
# RF R2: 0.38767971972746484
# Remaining: 278
# Query no. 12
# (921, 15)
# Embeddings training score: 0.9260845630412594
# (132, 7)
# RF R2: 0.41848953146757417
# Remaining: 268
# Query no. 13
# (1063, 15)
# Embeddings training score: 0.9264780080972345
# (142, 7)
# RF R2: 0.3599895908604246
# Remaining: 258
# Query no. 14
# (1215, 15)
# Embeddings training score: 0.9229492400450432
# (152, 7)
# RF R2: 0.34588087853075145
# Remaining: 248
# Query no. 15
# (1377, 15)
# Embeddings training score: 0.9249795560698159
# (162, 7)
# RF R2: 0.35755134398907773
# Remaining: 238
# Query no. 16
# (1549, 15)
# Embeddings training score: 0.9260489956343061
# (172, 7)
# RF R2: 0.39637868727886894
# Remaining: 228
# Query no. 17
# (1731, 15)
# Embeddings training score: 0.9230180308799429
# (182, 7)
# RF R2: 0.4215079318574795
# Remaining: 218
# Query no. 18
# (1923, 15)
# Embeddings training score: 0.9232322625710687
# (192, 7)
# RF R2: 0.3750219034856629
# Remaining: 208
# Query no. 19
# (2125, 15)
# Embeddings training score: 0.9255542797082471
# (202, 7)
# RF R2: 0.4216118361955804
# Remaining: 198
# Query no. 20
# (2337, 15)
# Embeddings training score: 0.9262883106211252
# (212, 7)
# RF R2: 0.44573265711353305
# Remaining: 188
# Query no. 21
# (2559, 15)
# Embeddings training score: 0.9329762701889822
# (222, 7)
# RF R2: 0.4663216187687198
# Remaining: 178
# Query no. 22
# (2791, 15)
# Embeddings training score: 0.9373408724688501
# (232, 7)
# RF R2: 0.4514805072988597
# Remaining: 168
# Query no. 23
# (3033, 15)
# Embeddings training score: 0.9422003005744736
# (242, 7)
# RF R2: 0.44944426286052563
# Remaining: 158
# Query no. 24
# (3285, 15)
# Embeddings training score: 0.9448506885037933
# (252, 7)
# RF R2: 0.4575953447390789
# Remaining: 148
# Query no. 25
# (3547, 15)
# Embeddings training score: 0.9421801148265861
# (262, 7)
# RF R2: 0.4382057010247138
# Remaining: 138
# Query no. 26
# (3819, 15)
# Embeddings training score: 0.955290254774328
# (272, 7)
# RF R2: 0.4609701980945312
# Remaining: 128
# Query no. 27
# (4101, 15)
# Embeddings training score: 0.9617712751421532
# (282, 7)
# RF R2: 0.48756140395623104
# Remaining: 118
# Query no. 28
# (4393, 15)
# Embeddings training score: 0.9742668060474665
# (292, 7)
# RF R2: 0.48440920076955407
# Remaining: 108
# Query no. 29
# (4695, 15)
# Embeddings training score: 0.9813440200686818
# (302, 7)
# RF R2: 0.46427287073545886
# Remaining: 98
# Query no. 30
# (5007, 15)
# Embeddings training score: 0.9856941017019313
# (312, 7)
# RF R2: 0.4615050115089565
# Remaining: 88
# The Iteration is  12
# NN Test R2 with 5 samples -22.754259247027004
# After Initialization RF R2: 0.09377955088466594
# NN Test R2 after Initialization -1.981425432983108
# (12, 7)
# Query no. 1
# (19, 15)
# Embeddings training score: 0.82882792338164
# (22, 7)
# RF R2: 0.07733709163143021
# Remaining: 378
# Query no. 2
# (51, 15)
# Embeddings training score: 0.8664212395703328
# (32, 7)
# RF R2: 0.12316564999853663
# Remaining: 368
# Query no. 3
# (93, 15)
# Embeddings training score: 0.8787049692649868
# (42, 7)
# RF R2: 0.09765329090386421
# Remaining: 358
# Query no. 4
# (145, 15)
# Embeddings training score: 0.8917922773226364
# (52, 7)
# RF R2: 0.13999182435752733
# Remaining: 348
# Query no. 5
# (207, 15)
# Embeddings training score: 0.8908276054344564
# (62, 7)
# RF R2: 0.1755030213772737
# Remaining: 338
# Query no. 6
# (279, 15)
# Embeddings training score: 0.8845325790842998
# (72, 7)
# RF R2: 0.26402490856845984
# Remaining: 328
# Query no. 7
# (361, 15)
# Embeddings training score: 0.8773975164840764
# (82, 7)
# RF R2: 0.2985633801948566
# Remaining: 318
# Query no. 8
# (453, 15)
# Embeddings training score: 0.883298190176745
# (92, 7)
# RF R2: 0.3129599077171371
# Remaining: 308
# Query no. 9
# (555, 15)
# Embeddings training score: 0.8925567307542676
# (102, 7)
# RF R2: 0.2960700638534941
# Remaining: 298
# Query no. 10
# (667, 15)
# Embeddings training score: 0.9013972514921242
# (112, 7)
# RF R2: 0.3404169190567966
# Remaining: 288
# Query no. 11
# (789, 15)
# Embeddings training score: 0.9109827875507948
# (122, 7)
# RF R2: 0.3805006536305555
# Remaining: 278
# Query no. 12
# (921, 15)
# Embeddings training score: 0.9153381288061075
# (132, 7)
# RF R2: 0.4300531063618219
# Remaining: 268
# Query no. 13
# (1063, 15)
# Embeddings training score: 0.919541332322594
# (142, 7)
# RF R2: 0.43310346845456726
# Remaining: 258
# Query no. 14
# (1215, 15)
# Embeddings training score: 0.9247424116503882
# (152, 7)
# RF R2: 0.4102460250163328
# Remaining: 248
# Query no. 15
# (1377, 15)
# Embeddings training score: 0.9261924998170459
# (162, 7)
# RF R2: 0.42163864475805934
# Remaining: 238
# Query no. 16
# (1549, 15)
# Embeddings training score: 0.9211594908339631
# (172, 7)
# RF R2: 0.445107525033981
# Remaining: 228
# Query no. 17
# (1731, 15)
# Embeddings training score: 0.9270463447843916
# (182, 7)
# RF R2: 0.4804904254700003
# Remaining: 218
# Query no. 18
# (1923, 15)
# Embeddings training score: 0.9319709898758971
# (192, 7)
# RF R2: 0.4850944698137266
# Remaining: 208
# Query no. 19
# (2125, 15)
# Embeddings training score: 0.9309912118159043
# (202, 7)
# RF R2: 0.5063178085751263
# Remaining: 198
# Query no. 20
# (2337, 15)
# Embeddings training score: 0.9363290412240939
# (212, 7)
# RF R2: 0.5209788938765729
# Remaining: 188
# Query no. 21
# (2559, 15)
# Embeddings training score: 0.9356186217030928
# (222, 7)
# RF R2: 0.5266895031513509
# Remaining: 178
# Query no. 22
# (2791, 15)
# Embeddings training score: 0.9369897348786301
# (232, 7)
# RF R2: 0.5769675949217733
# Remaining: 168
# Query no. 23
# (3033, 15)
# Embeddings training score: 0.9404808370056879
# (242, 7)
# RF R2: 0.5742545175005651
# Remaining: 158
# Query no. 24
# (3285, 15)
# Embeddings training score: 0.9411220857055209
# (252, 7)
# RF R2: 0.5714539437780444
# Remaining: 148
# Query no. 25
# (3547, 15)
# ...
# (232, 7)
# RF R2: 0.6293239770956345
# Remaining: 168
# Query no. 23
# (3033, 15)
# Embeddings training score: 0.9128449027704328
# (242, 7)
# RF R2: 0.6119200495505785
# Remaining: 158
# Query no. 24
# (3285, 15)
# Embeddings training score: 0.9184815813554148
# (252, 7)
# RF R2: 0.6201298695723623
# Remaining: 148
# Query no. 25
# (3547, 15)
# Embeddings training score: 0.9217284756162817
# (262, 7)
# RF R2: 0.6351876330198766
# Remaining: 138
# Query no. 26
# (3819, 15)
# Embeddings training score: 0.9553404991649164
# (272, 7)
# RF R2: 0.6739919953803837
# Remaining: 128
# Query no. 27
# (4101, 15)
# Embeddings training score: 0.9666648934899672
# (282, 7)
# RF R2: 0.6628968063329075
# Remaining: 118
# Query no. 28
# (4393, 15)
# Embeddings training score: 0.9765738247208884
# (292, 7)
# RF R2: 0.6545059396724389
# Remaining: 108
# Query no. 29
# (4695, 15)
# Embeddings training score: 0.9836638702015379
# (302, 7)
# RF R2: 0.6756004096974114
# Remaining: 98
# Query no. 30
# (5007, 15)
# Embeddings training score: 0.9886582240761123
# (312, 7)
# RF R2: 0.688131550142934
# Remaining: 88
# The Iteration is  16
# NN Test R2 with 5 samples -18.55884381319432
# After Initialization RF R2: 0.1155301292151576
# NN Test R2 after Initialization -0.3124160487300151
# (12, 7)
# Query no. 1
# (19, 15)
# Embeddings training score: 0.9091122149390206
# (22, 7)
# RF R2: 0.05686334766682222
# Remaining: 378
# Query no. 2
# (51, 15)
# Embeddings training score: 0.9148778398883874
# (32, 7)
# RF R2: 0.16496708347761568
# Remaining: 368
# Query no. 3
# (93, 15)
# Embeddings training score: 0.8623443419831048
# (42, 7)
# RF R2: 0.2087523687453099
# Remaining: 358
# Query no. 4
# (145, 15)
# Embeddings training score: 0.8722956132413047
# (52, 7)
# RF R2: 0.22210856061852702
# Remaining: 348
# Query no. 5
# (207, 15)
# Embeddings training score: 0.89577614665352
# (62, 7)
# RF R2: 0.25239643478532026
# Remaining: 338
# Query no. 6
# (279, 15)
# Embeddings training score: 0.8918955888922808
# (72, 7)
# RF R2: 0.4890750650634722
# Remaining: 328
# Query no. 7
# (361, 15)
# Embeddings training score: 0.8966132784778956
# (82, 7)
# RF R2: 0.5468797266574625
# Remaining: 318
# Query no. 8
# (453, 15)
# Embeddings training score: 0.9020240604968691
# (92, 7)
# RF R2: 0.5250225156822619
# Remaining: 308
# Query no. 9
# (555, 15)
# Embeddings training score: 0.8969461425726445
# (102, 7)
# RF R2: 0.5569601647141207
# Remaining: 298
# Query no. 10
# (667, 15)
# Embeddings training score: 0.9089630637408647
# (112, 7)
# RF R2: 0.5303338975164774
# Remaining: 288
# Query no. 11
# (789, 15)
# Embeddings training score: 0.9104377015453147
# (122, 7)
# RF R2: 0.5735311331024913
# Remaining: 278
# Query no. 12
# (921, 15)
# Embeddings training score: 0.9118609078824951
# (132, 7)
# RF R2: 0.5433371015163948
# Remaining: 268
# Query no. 13
# (1063, 15)
# Embeddings training score: 0.9145714278645601
# (142, 7)
# RF R2: 0.5494064390891924
# Remaining: 258
# Query no. 14
# (1215, 15)
# Embeddings training score: 0.9176188433486515
# (152, 7)
# RF R2: 0.5707122663999362
# Remaining: 248
# Query no. 15
# (1377, 15)
# Embeddings training score: 0.9215826856868354
# (162, 7)
# RF R2: 0.5574904446850326
# Remaining: 238
# Query no. 16
# (1549, 15)
# Embeddings training score: 0.9194725067842591
# (172, 7)
# RF R2: 0.5739794616573555
# Remaining: 228
# Query no. 17
# (1731, 15)
# Embeddings training score: 0.9217529643710851
# (182, 7)
# RF R2: 0.6007041654204566
# Remaining: 218
# Query no. 18
# (1923, 15)
# Embeddings training score: 0.9261256630432237
# (192, 7)
# RF R2: 0.5824404475790738
# Remaining: 208
# Query no. 19
# (2125, 15)
# Embeddings training score: 0.9314618484925098
# (202, 7)
# RF R2: 0.5654310000734653
# Remaining: 198
# Query no. 20
# (2337, 15)
# Embeddings training score: 0.9337465305819115
# (212, 7)
# RF R2: 0.5904737718620496
# Remaining: 188
# Query no. 21
# (2559, 15)
# Embeddings training score: 0.9363344488997396
# (222, 7)
# RF R2: 0.569055475125232
# Remaining: 178
# Query no. 22
# (2791, 15)
# Embeddings training score: 0.9299189889245891
# (232, 7)
# RF R2: 0.567346623172124
# Remaining: 168
# Query no. 23
# (3033, 15)
# Embeddings training score: 0.9328932349996831
# (242, 7)
# RF R2: 0.5565500701546264
# Remaining: 158
# Query no. 24
# (3285, 15)
# Embeddings training score: 0.9321266069595465
# (252, 7)
# RF R2: 0.5452856640269286
# Remaining: 148
# Query no. 25
# (3547, 15)
# Embeddings training score: 0.9324129368703789
# (262, 7)
# RF R2: 0.5298278968162974
# Remaining: 138
# Query no. 26
# (3819, 15)
# Embeddings training score: 0.9402237448409255
# (272, 7)
# RF R2: 0.5497976146648859
# Remaining: 128
# Query no. 27
# (4101, 15)
# Embeddings training score: 0.9525433817335168
# (282, 7)
# RF R2: 0.6004241681465483
# Remaining: 118
# Query no. 28
# (4393, 15)
# Embeddings training score: 0.9587409306547187
# (292, 7)
# RF R2: 0.5859075742197289
# Remaining: 108
# Query no. 29
# (4695, 15)
# Embeddings training score: 0.9685438427652749
# (302, 7)
# RF R2: 0.5969824204697998
# Remaining: 98
# Query no. 30
# (5007, 15)
# Embeddings training score: 0.9773162024733815
# (312, 7)
# RF R2: 0.6106248771429341
# Remaining: 88
# The Iteration is  17
# NN Test R2 with 5 samples -23.481107959701262
# After Initialization RF R2: -0.09619999297193083
# NN Test R2 after Initialization -3.6449304237625615
# (12, 7)
# Query no. 1
# (19, 15)
# Embeddings training score: 0.9344383506845819
# (22, 7)
# RF R2: 0.15058798113511473
# Remaining: 378
# Query no. 2
# (51, 15)
# Embeddings training score: 0.9154192733534778
# (32, 7)
# RF R2: 0.21294396872153987
# Remaining: 368
# Query no. 3
# (93, 15)
# Embeddings training score: 0.8917493498695768
# (42, 7)
# RF R2: 0.28401236820956133
# Remaining: 358
# Query no. 4
# (145, 15)
# Embeddings training score: 0.9044922586321051
# (52, 7)
# RF R2: 0.37390095429778414
# Remaining: 348
# Query no. 5
# (207, 15)
# Embeddings training score: 0.9082534369617736
# (62, 7)
# RF R2: 0.37280030131865927
# Remaining: 338
# Query no. 6
# (279, 15)
# Embeddings training score: 0.9100856248403264
# (72, 7)
# RF R2: 0.42014804414660634
# Remaining: 328
# Query no. 7
# (361, 15)
# Embeddings training score: 0.9093497418387877
# (82, 7)
# RF R2: 0.49028790183600424
# Remaining: 318
# Query no. 8
# (453, 15)
# Embeddings training score: 0.921891146269576
# (92, 7)
# RF R2: 0.48778326279000905
# Remaining: 308
# Query no. 9
# (555, 15)
# Embeddings training score: 0.9103566718304723
# (102, 7)
# RF R2: 0.48269807267511
# Remaining: 298
# Query no. 10
# (667, 15)
# Embeddings training score: 0.908236105341482
# (112, 7)
# RF R2: 0.46556111336598804
# Remaining: 288
# Query no. 11
# (789, 15)
# Embeddings training score: 0.9095397588033203
# (122, 7)
# RF R2: 0.5064646624239764
# Remaining: 278
# Query no. 12
# (921, 15)
# Embeddings training score: 0.9022686149908143
# (132, 7)
# RF R2: 0.4944419740765392
# Remaining: 268
# Query no. 13
# (1063, 15)
# Embeddings training score: 0.9066440539691037
# (142, 7)
# RF R2: 0.466455776028023
# Remaining: 258
# Query no. 14
# (1215, 15)
# Embeddings training score: 0.9154656180233393
# (152, 7)
# RF R2: 0.48208809215809345
# Remaining: 248
# Query no. 15
# (1377, 15)
# Embeddings training score: 0.921073240107535
# (162, 7)
# RF R2: 0.47848154614723504
# Remaining: 238
# Query no. 16
# (1549, 15)
# Embeddings training score: 0.9230665156696269
# (172, 7)
# RF R2: 0.46574334813893514
# Remaining: 228
# Query no. 17
# (1731, 15)
# Embeddings training score: 0.929851169451756
# (182, 7)
# RF R2: 0.5180820182810704
# Remaining: 218
# Query no. 18
# (1923, 15)
# Embeddings training score: 0.9215988995001252
# (192, 7)
# RF R2: 0.5513442615986498
# Remaining: 208
# Query no. 19
# (2125, 15)
# Embeddings training score: 0.9241452052442277
# (202, 7)
# RF R2: 0.532625293757816
# Remaining: 198
# Query no. 20
# (2337, 15)
# Embeddings training score: 0.9250191892281621
# (212, 7)
# RF R2: 0.544124100631775
# Remaining: 188
# Query no. 21
# (2559, 15)
# Embeddings training score: 0.930564515438323
# (222, 7)
# RF R2: 0.5440474955264981
# Remaining: 178
# Query no. 22
# (2791, 15)
# Embeddings training score: 0.9310187627983626
# (232, 7)
# RF R2: 0.5346647131445115
# Remaining: 168
# Query no. 23
# (3033, 15)
# Embeddings training score: 0.934063660072781
# (242, 7)
# RF R2: 0.5181612722485498
# Remaining: 158
# Query no. 24
# (3285, 15)
# Embeddings training score: 0.9346350496359552
# (252, 7)
# RF R2: 0.5376223384313257
# Remaining: 148
# Query no. 25
# (3547, 15)
# Embeddings training score: 0.9327752582510604
# (262, 7)
# RF R2: 0.5408464034695792
# Remaining: 138
# Query no. 26
# (3819, 15)
# Embeddings training score: 0.9334127762840548
# (272, 7)
# RF R2: 0.5678324313696119
# Remaining: 128
# Query no. 27
# (4101, 15)
# Embeddings training score: 0.9372119455245416
# (282, 7)
# RF R2: 0.5788931228042902
# Remaining: 118
# Query no. 28
# (4393, 15)
# Embeddings training score: 0.9425640652300862
# (292, 7)
# RF R2: 0.5712847283599636
# Remaining: 108
# Query no. 29
# (4695, 15)
# Embeddings training score: 0.951164214920346
# (302, 7)
# RF R2: 0.5610407989307724
# Remaining: 98
# Query no. 30
# (5007, 15)
# Embeddings training score: 0.9578401293052015
# (312, 7)
# RF R2: 0.5790153158699933
# Remaining: 88
# The Iteration is  18
# NN Test R2 with 5 samples -22.048963451722276
# After Initialization RF R2: 0.1392038429369471
# NN Test R2 after Initialization -4.422162799759625
# (12, 7)
# Query no. 1
# (19, 15)
# Embeddings training score: 0.8690256525196096
# (22, 7)
# RF R2: 0.11816724438348225
# Remaining: 378
# Query no. 2
# (51, 15)
# Embeddings training score: 0.8918905405374725
# (32, 7)
# RF R2: 0.26724283059976206
# Remaining: 368
# Query no. 3
# (93, 15)
# Embeddings training score: 0.8862569421895653
# (42, 7)
# RF R2: 0.212655681598247
# Remaining: 358
# Query no. 4
# (145, 15)
# Embeddings training score: 0.8878210410494796
# (52, 7)
# RF R2: 0.33919098554707705
# Remaining: 348
# Query no. 5
# (207, 15)
# Embeddings training score: 0.8885914402714584
# (62, 7)
# RF R2: 0.39374698721471457
# Remaining: 338
# Query no. 6
# (279, 15)
# Embeddings training score: 0.8933603393556256
# (72, 7)
# RF R2: 0.3753346305805334
# Remaining: 328
# Query no. 7
# (361, 15)
# Embeddings training score: 0.8961116652955652
# (82, 7)
# RF R2: 0.39275453281889783
# Remaining: 318
# Query no. 8
# (453, 15)
# Embeddings training score: 0.8983223951746772
# (92, 7)
# RF R2: 0.3900346430812368
# Remaining: 308
# Query no. 9
# (555, 15)
# Embeddings training score: 0.9041447028687652
# (102, 7)
# RF R2: 0.3934256020163659
# Remaining: 298
# Query no. 10
# (667, 15)
# Embeddings training score: 0.9089571698650166
# (112, 7)
# RF R2: 0.4718625469796788
# Remaining: 288
# Query no. 11
# (789, 15)
# Embeddings training score: 0.9141530936657293
# (122, 7)
# RF R2: 0.5042711423171794
# Remaining: 278
# Query no. 12
# (921, 15)
# Embeddings training score: 0.9167385529542432
# (132, 7)
# RF R2: 0.4977338247736329
# Remaining: 268
# Query no. 13
# (1063, 15)
# Embeddings training score: 0.9204645661353522
# (142, 7)
# RF R2: 0.5210788540395958
# Remaining: 258
# Query no. 14
# (1215, 15)
# Embeddings training score: 0.9281284528545817
# (152, 7)
# RF R2: 0.5340330363334522
# Remaining: 248
# Query no. 15
# (1377, 15)
# Embeddings training score: 0.931340850050822
# (162, 7)
# RF R2: 0.504028678859908
# Remaining: 238
# Query no. 16
# (1549, 15)
# Embeddings training score: 0.9400762396407867
# (172, 7)
# RF R2: 0.523508935220473
# Remaining: 228
# Query no. 17
# (1731, 15)
# Embeddings training score: 0.9472629797365436
# (182, 7)
# RF R2: 0.5377892974482195
# Remaining: 218
# Query no. 18
# (1923, 15)
# Embeddings training score: 0.9496219297881704
# (192, 7)
# RF R2: 0.5679669549879947
# Remaining: 208
# Query no. 19
# (2125, 15)
# Embeddings training score: 0.9506462922485535
# (202, 7)
# RF R2: 0.5741876816814415
# Remaining: 198
# Query no. 20
# (2337, 15)
# Embeddings training score: 0.9499289956910053
# (212, 7)
# RF R2: 0.5568019667241599
# Remaining: 188
# Query no. 21
# (2559, 15)
# Embeddings training score: 0.9464171189703142
# (222, 7)
# RF R2: 0.580240366894381
# Remaining: 178
# Query no. 22
# (2791, 15)
# Embeddings training score: 0.9487296270369826
# (232, 7)
# RF R2: 0.6350153890228314
# Remaining: 168
# Query no. 23
# (3033, 15)
# Embeddings training score: 0.9491028608135972
# (242, 7)
# RF R2: 0.6364386334315313
# Remaining: 158
# Query no. 24
# (3285, 15)
# Embeddings training score: 0.9502590988967774
# (252, 7)
# RF R2: 0.6198261547495616
# Remaining: 148
# Query no. 25
# (3547, 15)
# Embeddings training score: 0.9470710521416523
# (262, 7)
# RF R2: 0.616138662864491
# Remaining: 138
# Query no. 26
# (3819, 15)
# Embeddings training score: 0.9529597610398481
# (272, 7)
# RF R2: 0.5960987994208705
# Remaining: 128
# Query no. 27
# (4101, 15)
# Embeddings training score: 0.9674899223946233
# (282, 7)
# RF R2: 0.6102008996745283
# Remaining: 118
# Query no. 28
# (4393, 15)
# Embeddings training score: 0.9762305567545961
# (292, 7)
# RF R2: 0.6093348801404639
# Remaining: 108
# Query no. 29
# (4695, 15)
# Embeddings training score: 0.9812069134568894
# (302, 7)
# RF R2: 0.6046333778760176
# Remaining: 98
# Query no. 30
# (5007, 15)
# Embeddings training score: 0.9840560947114562
# (312, 7)
# RF R2: 0.6224314164707667
# Remaining: 88
# The Iteration is  19
# NN Test R2 with 5 samples -22.94582871908568
# After Initialization RF R2: 0.17171630810311156
# NN Test R2 after Initialization -0.34146828295054327
# (12, 7)
# Query no. 1
# (19, 15)
# Embeddings training score: 0.9498961105250884
# (22, 7)
# RF R2: 0.12403128184620982
# Remaining: 378
# Query no. 2
# (51, 15)
# Embeddings training score: 0.9295074019356233
# (32, 7)
# RF R2: 0.24554991297049578
# Remaining: 368
# Query no. 3
# (93, 15)
# Embeddings training score: 0.9208627829307938
# (42, 7)
# RF R2: 0.28082957743605585
# Remaining: 358
# Query no. 4
# (145, 15)
# Embeddings training score: 0.9205903567658114
# (52, 7)
# RF R2: 0.3349785841344568
# Remaining: 348
# Query no. 5
# (207, 15)
# Embeddings training score: 0.9154158814508928
# (62, 7)
# RF R2: 0.43612674894402237
# Remaining: 338
# Query no. 6
# (279, 15)
# Embeddings training score: 0.9067946599178234
# (72, 7)
# RF R2: 0.4231855603082538
# Remaining: 328
# Query no. 7
# (361, 15)
# Embeddings training score: 0.9086109493430101
# (82, 7)
# RF R2: 0.41162093513124887
# Remaining: 318
# Query no. 8
# (453, 15)
# Embeddings training score: 0.914852066692612
# (92, 7)
# RF R2: 0.4067862131199088
# Remaining: 308
# Query no. 9
# (555, 15)
# Embeddings training score: 0.9207120167220839
# (102, 7)
# RF R2: 0.4529088091868828
# Remaining: 298
# Query no. 10
# (667, 15)
# Embeddings training score: 0.9254517166773786
# (112, 7)
# RF R2: 0.46418592671826486
# Remaining: 288
# Query no. 11
# (789, 15)
# Embeddings training score: 0.9280639728236783
# (122, 7)
# RF R2: 0.4686629922076633
# Remaining: 278
# Query no. 12
# (921, 15)
# Embeddings training score: 0.9190993766443739
# (132, 7)
# RF R2: 0.45758015487426307
# Remaining: 268
# Query no. 13
# (1063, 15)
# Embeddings training score: 0.9172906233498955
# (142, 7)
# RF R2: 0.4781716479287009
# Remaining: 258
# Query no. 14
# (1215, 15)
# Embeddings training score: 0.9201961815743842
# (152, 7)
# RF R2: 0.4600238104183406
# Remaining: 248
# Query no. 15
# (1377, 15)
# Embeddings training score: 0.915521561455267
# (162, 7)
# RF R2: 0.47080775656654494
# Remaining: 238
# Query no. 16
# (1549, 15)
# Embeddings training score: 0.912059512621028
# (172, 7)
# RF R2: 0.47007982844651774
# Remaining: 228
# Query no. 17
# (1731, 15)
# Embeddings training score: 0.9149536363399484
# (182, 7)
# RF R2: 0.48864587982122953
# Remaining: 218
# Query no. 18
# (1923, 15)
# Embeddings training score: 0.92562200595081
# (192, 7)
# RF R2: 0.47998748558536997
# Remaining: 208
# Query no. 19
# (2125, 15)
# Embeddings training score: 0.9222528696853073
# (202, 7)
# RF R2: 0.4701601676642486
# Remaining: 198
# Query no. 20
# (2337, 15)
# Embeddings training score: 0.913193155513648
# (212, 7)
# RF R2: 0.4576121605330402
# Remaining: 188
# Query no. 21
# (2559, 15)
# Embeddings training score: 0.9165070845343931
# (222, 7)
# RF R2: 0.457263535019666
# Remaining: 178
# Query no. 22
# (2791, 15)
# Embeddings training score: 0.9199330766325337
# (232, 7)
# RF R2: 0.4568725422491756
# Remaining: 168
# Query no. 23
# (3033, 15)
# Embeddings training score: 0.9254569080397
# (242, 7)
# RF R2: 0.5285034184651041
# Remaining: 158
# Query no. 24
# (3285, 15)
# Embeddings training score: 0.9311869457691573
# (252, 7)
# RF R2: 0.5490454451561407
# Remaining: 148
# Query no. 25
# (3547, 15)
# Embeddings training score: 0.9240195118488796
# (262, 7)
# RF R2: 0.542904830185485
# Remaining: 138
# Query no. 26
# (3819, 15)
# Embeddings training score: 0.9309375618085566
# (272, 7)
# RF R2: 0.5590037465159154
# Remaining: 128
# Query no. 27
# (4101, 15)
# Embeddings training score: 0.9453152741568277
# (282, 7)
# RF R2: 0.5790626041764184
# Remaining: 118
# Query no. 28
# (4393, 15)
# Embeddings training score: 0.9486966011988613
# (292, 7)
# RF R2: 0.5801800178875596
# Remaining: 108
# Query no. 29
# (4695, 15)
# Embeddings training score: 0.9685667695324617
# (302, 7)
# RF R2: 0.5917069252833664
# Remaining: 98
# Query no. 30
# (5007, 15)
# Embeddings training score: 0.9793869035405599
# (312, 7)
# RF R2: 0.5737149552237548
# Remaining: 88
