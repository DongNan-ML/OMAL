# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from modAL.models import ActiveLearner, CommitteeRegressor
from modAL.disagreement import vote_entropy_sampling, max_std_sampling
import matplotlib.pyplot as plt
import torch
from torch.nn import MSELoss
from skorch.regressor import NeuralNetRegressor
from copy import deepcopy
from skorch.dataset import ValidSplit
from skorch.callbacks import EarlyStopping
from sklearn.cluster import DBSCAN, OPTICS, cluster_optics_dbscan, Birch, SpectralClustering
from sklearn.neighbors import NearestNeighbors
from sklearn import metrics
import matplotlib.gridspec as gridspec
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from torch.nn import Linear
from torch.nn import Sigmoid, ReLU
from torch.nn import Module
from sklearn.metrics import r2_score
import copy
from scipy.spatial import distance
from scipy.spatial.distance import euclidean
from torch import tensor
from sklearn.metrics import mean_squared_error
from scipy.spatial.distance import cdist
from sklearn.ensemble import RandomForestRegressor
from torch.nn.init import xavier_uniform_
from model import MLP
from model_state import get_model_params, get_input_for_hidden_layers, get_model_params_gradientNorm
from functions_batch1 import get_variance, qbc, normalization, error_reduct_fuc, total_disagrement, grad_norm, averaged_grad_norm, get_avg_grad_norm, training_loss
import random
from skorch.callbacks import EarlyStopping, LRScheduler, Freezer, Unfreezer
from torch.optim.lr_scheduler import CyclicLR, ReduceLROnPlateau
from skorch.regressor import NeuralNetRegressor, NeuralNet
from model_state import features_concat, learning_state_features_concat
import gc
import warnings
from modAL.utils.selection import multi_argmax
warnings.filterwarnings("ignore")

# %%
# Hyper-params:
query_number = 20          # The number of the AL Iterations in each Exp
iteration = 20             # Total number of the Exps
batch_size = 10
total_initail_size = 10
initial_size = 5
dimensions = 18   # Total dimension of the data features + model states

seed_rf = np.load(file="..\..\Datasets\Diabetes\seed_for_RF.npy")
seed_initial = np.load(file="..\..\Datasets\Diabetes\seed_for_initialSamples.npy")

seed_nn1 = np.random.randint(100, size=100)
seed_nn2 = np.random.randint(100, size=100)
seed_nn3 = np.random.randint(100, size=100)
seed_nn4 = np.random.randint(100, size=100)
seed_nn5 = np.random.randint(100, size=100)
seed_nn6 = np.random.randint(100, size=100)
seed_predictor = np.random.randint(100, size=100)

np.save(file="..\..\Results\Res_Diabetes\OMAL3\seed_for_nn1.npy", arr=seed_nn1)
np.save(file="..\..\Results\Res_Diabetes\OMAL3\seed_for_nn2.npy", arr=seed_nn2)
np.save(file="..\..\Results\Res_Diabetes\OMAL3\seed_for_nn3.npy", arr=seed_nn3)
np.save(file="..\..\Results\Res_Diabetes\OMAL3\seed_for_nn4.npy", arr=seed_nn4)
np.save(file="..\..\Results\Res_Diabetes\OMAL3\seed_for_nn5.npy", arr=seed_nn5)
np.save(file="..\..\Results\Res_Diabetes\OMAL3\seed_for_nn6.npy", arr=seed_nn6)

np.save(file="..\..\Results\Res_Diabetes\OMAL3\seed_predictor.npy", arr=seed_predictor)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def Committee_Prediction(learner_list, X_test, y_test):
    initial_pred=[]
    for i in learner_list:
        initial_pred.append(r2_score(y_test, i.predict(X_test)))
    initial_pred=np.array(initial_pred)
    
    return initial_pred.mean()

# %%
def main_function(query_number, iters):
    # For saving results:
    rf_model_training_r2 = []
    rf_model_training_mse = []
    rf_model_testing_r2 = []
    rf_model_testing_mse = []
    
    # Number of member in committee:
    n_members = 3
    learner_list = []
    
    # The model for evaluation:
    rf_model = RandomForestRegressor(random_state=seed_rf[iters], n_estimators=100)
    gradient_norms = np.empty(shape=(0, 0))
    
    # Load the data:
    name1 = "..\..\Datasets\Diabetes\X_train" + str(iters) + ".npy"
    name2 = "..\..\Datasets\Diabetes\X_test" + str(iters) + ".npy"
    name3 = "..\..\Datasets\Diabetes\y_train" + str(iters) + ".npy"
    name4 = "..\..\Datasets\Diabetes\y_test" + str(iters) + ".npy"
    
    X_train = np.load(name1, allow_pickle=True).astype(np.float32)
    X_test = np.load(name2, allow_pickle=True).astype(np.float32)
    y_train = np.load(name3, allow_pickle=True).astype(np.float32).reshape(-1, 1)
    y_test = np.load(name4, allow_pickle=True).astype(np.float32).reshape(-1, 1)
    
    # Dimensionality of data:
    X = X_train.shape[1]
    # The index of the unlabeled pool:
    X_index = np.arange(X_train.shape[0])

    used_data = np.empty(shape=(0, X))
    used_label = np.empty(shape=(0)).reshape(-1, 1)

    X_initial = np.empty(shape=(0,X))
    y_initial = np.empty(shape=(0)).reshape(-1, 1)
    
    # Initial Stage 1:
    np.random.seed(seed_initial[iters])
    idx = np.random.choice(range(len(X_index)), size=initial_size, replace=False)
    train_idx = X_index[idx]

    X_initial = X_train[train_idx]
    y_initial = y_train[train_idx].reshape(-1, 1)

    used_data = np.append(used_data, X_initial, axis=0).astype(np.float32)
    used_label = np.append(used_label, y_initial, axis=0).astype(np.float32).reshape(-1, 1)
    X_index = np.delete(X_index, idx, axis=0)

    
    used_data = torch.from_numpy(used_data).to(device)
    used_label = torch.from_numpy(used_label).to(device)
    for member_idx in range(n_members):
        if member_idx == 0:
            np.random.seed(seed_nn1[iters])
            torch.manual_seed(seed_nn2[iters])
        if member_idx == 1:
            np.random.seed(seed_nn3[iters])
            torch.manual_seed(seed_nn4[iters])
        if member_idx == 2:
            np.random.seed(seed_nn5[iters])
            torch.manual_seed(seed_nn6[iters])
            
        regressor = NeuralNetRegressor(MLP(X),
                                   criterion=MSELoss(),
                                   optimizer=torch.optim.Adam,
                                   verbose=0,
                                   max_epochs=30,
                                   lr=0.001,
                                   # Used for the batch AL
                                   callbacks=[EarlyStopping(patience=5), ('lr_scheduler', LRScheduler(policy=ReduceLROnPlateau))],
                                   train_split=ValidSplit(cv=5),
                                   warm_start=True,
                                   device='cuda',
                                   batch_size = -1
                                   )
        regressor.fit(used_data, used_label)
        learner_list.append(regressor)
    
    print("NN Test R2 with 5 samples", Committee_Prediction(learner_list, X_test, y_test))

    # Number of LAL features:
    learning_state_features = np.empty(shape=(0, dimensions))
    loss_reduction_target = np.empty(shape=(0)).reshape(-1, 1)

    # other random samples:
    rest_initial_X = np.empty(shape=(0, X))
    rest_initial_y = np.empty(shape=(0)).reshape(-1, 1)

    # LAL Initialization: Stage 2
    predictor = RandomForestRegressor(n_estimators=500, random_state=seed_predictor[iters])
    np.random.seed(seed_initial[iters])
    idx = np.random.choice(range(len(X_index)), size=total_initail_size-initial_size, replace=False)
    train_idx = X_index[idx]
    
    rest_initial_X = np.append(rest_initial_X, X_train[train_idx], axis=0).astype(np.float32)
    rest_initial_y = np.append(rest_initial_y, y_train[train_idx], axis=0).astype(np.float32).reshape(-1, 1)

    X_index = np.delete(X_index, idx, axis=0)

    for i in range(rest_initial_X.shape[0]):

        single_X = rest_initial_X[i],
        single_y = rest_initial_y[i].reshape(1, -1)
        single_X = single_X[0].reshape(1, -1)
        
        single_X = torch.from_numpy(single_X).to(device)
        single_y = torch.from_numpy(single_y).to(device)

        # Model params
        model_params = get_model_params_gradientNorm(learner_list)

        # updated data
        used_data = torch.cat((used_data, single_X), 0)
        used_label = torch.cat((used_label, single_y), 0)

        # Retrain the model:
        for l in learner_list:
            l.fit(X=used_data,y=used_label)
            
        single_X = single_X.cpu().numpy()
        single_y = single_y.cpu().numpy()
            
        index = train_idx[i]

        # The training sample:
        data_params = X_train[index]
      
        LALfeatures = features_concat(model_params, data_params)

        loss_reduction = get_avg_grad_norm(learner_list, single_X, single_y)
        
        learning_state_features = learning_state_features_concat(learning_state_features, LALfeatures)
        loss_reduction_target = np.append(loss_reduction_target, np.array([loss_reduction]).reshape(-1, 1), axis=0).astype(np.float32).reshape(-1, 1)

        
    used_data = used_data.cpu().numpy()
    used_label = used_label.cpu().numpy()

    # Finished the Initialization Stages:
    # RF Regressor for evaluation:
    rf_model.fit(used_data, used_label.ravel())
    # Training Scores:
    rf_training_r2 = r2_score(used_label, rf_model.predict(used_data))
    rf_training_mse = mean_squared_error(used_label, rf_model.predict(used_data))
    rf_model_training_r2.append(rf_training_r2)
    rf_model_training_mse.append(rf_training_mse)
    
    # Test Scores:
    rf_model_r2 = r2_score(y_test, rf_model.predict(X_test))
    rf_model_mse = mean_squared_error(y_test, rf_model.predict(X_test))
    rf_model_testing_r2.append(rf_model_r2)
    rf_model_testing_mse.append(rf_model_mse)
    
    print("After Initialization RF R2:", rf_model_r2)
    print("NN Test R2 after Initialization", Committee_Prediction(learner_list, X_test, y_test))

    print(np.unique(used_data, axis=0).shape)
    for idx in range(query_number):
        np.random.seed(None)
        print('Query no. %d' % (idx+1))

        Error_reduction_list, training_score = error_reduct_fuc(X_train, X_index, learner_list, learning_state_features, loss_reduction_target, X_index.shape[0], predictor)

        idx = multi_argmax(np.array(Error_reduction_list), n_instances=batch_size)
       
        X_train_indices = X_index[idx]
        
        # Update
        X_index = np.delete(X_index, idx, axis=0)

        for X_train_index in X_train_indices:

            new_X = X_train[X_train_index].reshape(1, -1)
            new_y = y_train[X_train_index].reshape(1, -1)
            
            used_data = np.append(used_data, new_X, axis=0).astype(np.float32)
            used_label = np.append(used_label, new_y, axis=0).astype(np.float32).reshape(-1, 1)
            
            used_data = torch.from_numpy(used_data).to(device)
            used_label = torch.from_numpy(used_label).to(device)

            # Model params
            model_params = get_model_params_gradientNorm(learner_list)
            data_params = X_train[X_train_index]
            LALfeatures = features_concat(model_params, data_params)
            
            for l in learner_list:
                l.fit(used_data, used_label)
            
            used_data = used_data.cpu().numpy()
            used_label = used_label.cpu().numpy()

            loss_reduction = get_avg_grad_norm(learner_list, new_X, new_y)  
            gradient_norms = np.append(gradient_norms, loss_reduction)
            
            learning_state_features = learning_state_features_concat(learning_state_features, LALfeatures)
            loss_reduction_target = np.append(loss_reduction_target, np.array([loss_reduction]).reshape(-1, 1), axis=0).astype(np.float32).reshape(-1, 1)
        

        # RF Evaluation
        rf_model.fit(used_data, used_label.ravel())
        
        # Training Evaluation:
        rf_training_r2 = r2_score(used_label, rf_model.predict(used_data))
        rf_training_mse = mean_squared_error(used_label, rf_model.predict(used_data))
        rf_model_training_r2.append(rf_training_r2)
        rf_model_training_mse.append(rf_training_mse)
        
        # Test Evaluation:
        rf_model_r2 = r2_score(y_test, rf_model.predict(X_test))
        rf_model_mse = mean_squared_error(y_test, rf_model.predict(X_test))
        rf_model_testing_r2.append(rf_model_r2)
        rf_model_testing_mse.append(rf_model_mse)

        print(np.unique(used_data, axis=0).shape)
        print("RF R2:", rf_model_r2)
        print("Remaining:", X_index.shape[0])
        # print('NN R2', Committee_Prediction(learner_list, X_test, y_test))

    # RF
    rf_model_testing_r2 = np.array(rf_model_testing_r2)
    rf_model_testing_mse = np.array(rf_model_testing_mse)
    rf_model_training_r2 = np.array(rf_model_training_r2)
    rf_model_training_mse = np.array(rf_model_training_mse)
    
    # Used_data and Unsed_label:
    np.save(file="..\..\Results\Res_Diabetes\OMAL3\Summary\\used_data" + str(iters) + ".npy", arr=used_data)
    np.save(file="..\..\Results\Res_Diabetes\OMAL3\Summary\\used_labels" + str(iters) + ".npy", arr=used_label)

    np.save(file="..\..\Results\Res_Diabetes\OMAL3\Summary\\testing_rf_r2_" + str(iters) + ".npy", arr=rf_model_testing_r2)
    np.save(file="..\..\Results\Res_Diabetes\OMAL3\Summary\\testing_rf_mse_" + str(iters) + ".npy", arr=rf_model_testing_mse)
    np.save(file="..\..\Results\Res_Diabetes\OMAL3\Summary\\training_rf_r2_" + str(iters) + ".npy", arr=rf_model_training_r2)
    np.save(file="..\..\Results\Res_Diabetes\OMAL3\Summary\\training_rf_mse_" + str(iters) + ".npy", arr=rf_model_training_mse)

# %%
for i in range(iteration):
    print("The Iteration is ", i)
    main_function(query_number, i)
# Out:
# The Iteration is  0
# NN Test R2 with 5 samples -3.2725513708342846
# After Initialization RF R2: 0.01017105099476967
# NN Test R2 after Initialization -2.2086267973281957
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8158155462742469
# (20, 10)
# RF R2: 0.11906562174625024
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8738460647912076
# (30, 10)
# RF R2: 0.25802576103092567
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8835546091051971
# (40, 10)
# RF R2: 0.29597427063287596
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.904605473752119
# (50, 10)
# RF R2: 0.38092338137187787
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.912315074143163
# (60, 10)
# RF R2: 0.486734273180254
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.9014673866987767
# (70, 10)
# RF R2: 0.509184153351444
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8937835012093279
# (80, 10)
# RF R2: 0.5103034689239556
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8874234535147696
# (90, 10)
# RF R2: 0.5475321409713905
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8888821187973664
# (100, 10)
# RF R2: 0.5290753389999815
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8843013931096779
# (110, 10)
# RF R2: 0.5256962328274917
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8903055956660331
# (120, 10)
# RF R2: 0.5072765370409649
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.89240781179412
# (130, 10)
# RF R2: 0.5570491868790781
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8874822477111535
# (140, 10)
# RF R2: 0.5436101283598289
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8780257548762747
# (150, 10)
# RF R2: 0.5674504037267668
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8765639869888531
# (160, 10)
# RF R2: 0.4772690501497495
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.878486276983432
# (170, 10)
# RF R2: 0.5360912857469425
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8747802171797343
# (180, 10)
# RF R2: 0.5647258034732976
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.876163008828658
# (190, 10)
# RF R2: 0.5292536232165546
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8704148726858115
# (200, 10)
# RF R2: 0.5191038837982382
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.871769401583625
# (210, 10)
# RF R2: 0.5380198525732501
# Remaining: 143
# The Iteration is  1
# NN Test R2 with 5 samples -3.7422284178380014
# After Initialization RF R2: 0.20844341964741697
# NN Test R2 after Initialization -0.5179029545149744
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8603686336161622
# (20, 10)
# RF R2: 0.26201126658686646
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.9447783766358941
# (30, 10)
# RF R2: 0.38287921352747567
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.9030980330299333
# (40, 10)
# RF R2: 0.3670651861610901
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8210066089303465
# (50, 10)
# RF R2: 0.41612655335753923
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8477729976392944
# (60, 10)
# RF R2: 0.4057565482613924
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8551186964989678
# (70, 10)
# RF R2: 0.4432156383287038
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8529284209265262
# (80, 10)
# RF R2: 0.44101216081370376
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8497950736673306
# (90, 10)
# RF R2: 0.4380473214856343
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8528585293726344
# (100, 10)
# RF R2: 0.44391155831347784
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8577588470528353
# (110, 10)
# RF R2: 0.4516427532001378
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8632765589133857
# (120, 10)
# RF R2: 0.43242851227966383
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8601906753770917
# (130, 10)
# RF R2: 0.44454622093661467
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8551038016400331
# (140, 10)
# RF R2: 0.39809506965467123
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8549422778077066
# (150, 10)
# RF R2: 0.43624906201941505
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8603401547892904
# (160, 10)
# RF R2: 0.43175852197951536
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8634993677167402
# (170, 10)
# RF R2: 0.45621796960630623
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8638238498547703
# (180, 10)
# RF R2: 0.4724705470424484
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8621413281047197
# (190, 10)
# RF R2: 0.4634862909541039
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8517583449606875
# (200, 10)
# RF R2: 0.4586289266242668
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8600105713525246
# (210, 10)
# RF R2: 0.4432001927189878
# Remaining: 143
# The Iteration is  2
# NN Test R2 with 5 samples -3.668608261686932
# After Initialization RF R2: 0.2925063658507443
# NN Test R2 after Initialization -3.628184242019344
# (10, 10)
# Query no. 1
# Embeddings training score: 0.9069993336896633
# (20, 10)
# RF R2: 0.30088720631429555
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.9202657382428951
# (30, 10)
# RF R2: 0.42777232955635136
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8759102798055164
# (40, 10)
# RF R2: 0.34195017850383025
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8629236486492362
# (50, 10)
# RF R2: 0.26464868229601
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8398683524437156
# (60, 10)
# RF R2: 0.40238122070402293
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8576659565642553
# (70, 10)
# RF R2: 0.42091658042312186
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8580990494598542
# (80, 10)
# RF R2: 0.44748611843666486
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8617548683260868
# (90, 10)
# RF R2: 0.39965191682053913
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8505919634576495
# (100, 10)
# RF R2: 0.37998457804496455
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8484388200888351
# (110, 10)
# RF R2: 0.38684862464945025
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8467564403411652
# (120, 10)
# RF R2: 0.4060750787969075
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8498678663938081
# (130, 10)
# RF R2: 0.43167520601169374
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8419618545647
# (140, 10)
# RF R2: 0.4736007455507121
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8465073372185654
# (150, 10)
# RF R2: 0.44860075128541
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8462783857368854
# (160, 10)
# RF R2: 0.4447538288284315
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8452305564396017
# (170, 10)
# RF R2: 0.4736645031909371
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8459798906677811
# (180, 10)
# RF R2: 0.46406554029871794
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8447011669021847
# (190, 10)
# RF R2: 0.47357880360170546
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8460044949028581
# (200, 10)
# RF R2: 0.4568595779744128
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.84541022929471
# (210, 10)
# RF R2: 0.4441021914635247
# Remaining: 143
# The Iteration is  3
# NN Test R2 with 5 samples -4.171574429878297
# After Initialization RF R2: 0.36481536421176197
# NN Test R2 after Initialization -3.968480153574019
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8152532604179142
# (20, 10)
# RF R2: 0.31105837075983
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8142182049853222
# (30, 10)
# RF R2: 0.2164587189587619
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8596382743870749
# (40, 10)
# RF R2: 0.2632991777089604
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8284282180869624
# (50, 10)
# RF R2: 0.15608634786150322
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8504190357924906
# (60, 10)
# RF R2: 0.2526871439325783
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8582751385048705
# (70, 10)
# RF R2: 0.1314045298704627
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8555358466313518
# (80, 10)
# RF R2: 0.15031306541762612
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8584247993952383
# (90, 10)
# RF R2: 0.24080058992597808
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8573897684454578
# (100, 10)
# RF R2: 0.24571391342081927
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.857894300260263
# (110, 10)
# RF R2: 0.35076996894861656
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8520674635063583
# (120, 10)
# RF R2: 0.33848911872722587
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8511911652942202
# (130, 10)
# RF R2: 0.3371261551928185
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8519134943402923
# (140, 10)
# RF R2: 0.39396018600404104
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8524517371631286
# (150, 10)
# RF R2: 0.40268510687965886
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.852427808858854
# (160, 10)
# RF R2: 0.358639108984415
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8562350385281047
# (170, 10)
# RF R2: 0.4003922329353803
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8583740504771378
# (180, 10)
# RF R2: 0.3937720008065988
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8585442647873983
# (190, 10)
# RF R2: 0.4239915004025231
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8606833872388593
# (200, 10)
# RF R2: 0.42024252804630335
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8617618887646321
# (210, 10)
# RF R2: 0.4710989153124898
# Remaining: 143
# The Iteration is  4
# NN Test R2 with 5 samples -3.963455208749363
# After Initialization RF R2: 0.2647513237024165
# NN Test R2 after Initialization -3.874994697594269
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8837147135068291
# (20, 10)
# RF R2: 0.31348161889223025
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.9475116455751623
# (30, 10)
# RF R2: 0.34681905804431823
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8874325619312272
# (40, 10)
# RF R2: 0.4282744164833394
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8912182605118444
# (50, 10)
# RF R2: 0.47483683755025263
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8888678487696275
# (60, 10)
# RF R2: 0.5277195571138489
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8853342011448224
# (70, 10)
# RF R2: 0.5404196181317538
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8757826289034545
# (80, 10)
# RF R2: 0.5531317137921111
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8792607573111658
# (90, 10)
# RF R2: 0.5644532943478502
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8795849638753044
# (100, 10)
# RF R2: 0.5818042898391842
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8843048812647063
# (110, 10)
# RF R2: 0.5694379776431386
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.889098022170466
# (120, 10)
# RF R2: 0.5666288691027174
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8868622988117424
# (130, 10)
# RF R2: 0.5451243371635262
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8923448431682907
# (140, 10)
# RF R2: 0.5555712910843155
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8902203050427768
# (150, 10)
# RF R2: 0.5407534185169094
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8893356358275453
# (160, 10)
# RF R2: 0.5484089364474481
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8893000380945983
# (170, 10)
# RF R2: 0.5569625838711849
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8875680661917217
# (180, 10)
# RF R2: 0.5825917804679683
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8873141694469229
# (190, 10)
# RF R2: 0.554909188539062
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8896276624354866
# (200, 10)
# RF R2: 0.5410655538520457
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8902410084837871
# (210, 10)
# RF R2: 0.5420964738401843
# Remaining: 143
# The Iteration is  5
# NN Test R2 with 5 samples -4.004963363250457
# After Initialization RF R2: 0.21088154412423232
# NN Test R2 after Initialization -1.1863363976124508
# (10, 10)
# Query no. 1
# Embeddings training score: 0.7743972143979779
# (20, 10)
# RF R2: 0.28538051357202
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8454622529447743
# (30, 10)
# RF R2: 0.23400586792853884
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8232693722877136
# (40, 10)
# RF R2: 0.29298817886738826
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8410329754224222
# (50, 10)
# RF R2: 0.4295151863909299
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.853114262871616
# (60, 10)
# RF R2: 0.49639819357399007
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8638930443879291
# (70, 10)
# RF R2: 0.4775582328389525
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8601758582987102
# (80, 10)
# RF R2: 0.4693565097261092
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8612453518757951
# (90, 10)
# RF R2: 0.5039010226357996
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8626246708567169
# (100, 10)
# RF R2: 0.42801475047488113
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8630844435454075
# (110, 10)
# RF R2: 0.43566031702819097
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8605999931532552
# (120, 10)
# RF R2: 0.4991645411258996
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8684147477438673
# (130, 10)
# RF R2: 0.5008631281925278
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8652595838007995
# (140, 10)
# RF R2: 0.4989445989229476
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8623804246070303
# (150, 10)
# RF R2: 0.4348047950477355
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8616382490019702
# (160, 10)
# RF R2: 0.4441374567174309
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8445846890085222
# (170, 10)
# RF R2: 0.44371682399006696
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8372747467306316
# (180, 10)
# RF R2: 0.45358633433042395
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8424434270439085
# (190, 10)
# RF R2: 0.44377556739069823
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8441656473989918
# (200, 10)
# RF R2: 0.4482330658506729
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.845187561206788
# (210, 10)
# RF R2: 0.43572206047515516
# Remaining: 143
# The Iteration is  6
# NN Test R2 with 5 samples -4.610149418313396
# After Initialization RF R2: 0.2874004649780366
# NN Test R2 after Initialization -1.2564377234220487
# (10, 10)
# Query no. 1
# Embeddings training score: 0.787379910217123
# (20, 10)
# RF R2: 0.33712689277274555
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.7914664209291004
# (30, 10)
# RF R2: 0.2574177318820188
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8587164721838554
# (40, 10)
# RF R2: 0.2750593011585001
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8558298788644413
# (50, 10)
# RF R2: 0.40879750942895854
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8465849356050956
# (60, 10)
# RF R2: 0.39780305940521743
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8557873177992339
# (70, 10)
# RF R2: 0.37704496551443245
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8590962636751239
# (80, 10)
# RF R2: 0.4061110848691396
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8601821640867421
# (90, 10)
# RF R2: 0.39958502002183904
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8544528670116087
# (100, 10)
# RF R2: 0.4510822124227507
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8485655048457273
# (110, 10)
# RF R2: 0.44011349089980967
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8530620682434177
# (120, 10)
# RF R2: 0.41635348306913667
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8624251782631915
# (130, 10)
# RF R2: 0.397176414226337
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8621341919088685
# (140, 10)
# RF R2: 0.40214929911772845
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8630886079029665
# (150, 10)
# RF R2: 0.3858164778224443
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8603503943985373
# (160, 10)
# RF R2: 0.3734932111826219
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8612710394830936
# (170, 10)
# RF R2: 0.36396207761047206
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8592636066674046
# (180, 10)
# RF R2: 0.37454507486215405
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8579311724661647
# (190, 10)
# RF R2: 0.3418242833963787
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8583254473973188
# (200, 10)
# RF R2: 0.38276656819293675
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.854842166459743
# (210, 10)
# RF R2: 0.40546909734660963
# Remaining: 143
# The Iteration is  7
# NN Test R2 with 5 samples -4.935924568834414
# After Initialization RF R2: 0.19370117539677523
# NN Test R2 after Initialization -4.0160276424390675
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8412109903842426
# (20, 10)
# RF R2: 0.19700054999396388
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.9119162494745322
# (30, 10)
# RF R2: 0.2670617144412726
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.9037944748789334
# (40, 10)
# RF R2: 0.31902660032643804
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8585542654291387
# (50, 10)
# RF R2: 0.3954505188606591
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8674153552951664
# (60, 10)
# RF R2: 0.3667014564340588
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8588651059955642
# (70, 10)
# RF R2: 0.33544833393656226
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8600243131736902
# (80, 10)
# RF R2: 0.3424078169001401
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8643359817470264
# (90, 10)
# RF R2: 0.33497176168017917
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8680287197335393
# (100, 10)
# RF R2: 0.3221031642376223
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8717876634605768
# (110, 10)
# RF R2: 0.3642753518834717
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8627396587301612
# (120, 10)
# RF R2: 0.3799875234534392
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8649950059781735
# (130, 10)
# RF R2: 0.38503655185845354
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8609103051592065
# (140, 10)
# RF R2: 0.33674781866594095
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8639824584653096
# (150, 10)
# RF R2: 0.3667178230157603
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8606707374953764
# (160, 10)
# RF R2: 0.35296864643216985
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8568407755520349
# (170, 10)
# RF R2: 0.36880544692647066
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8570407787614636
# (180, 10)
# RF R2: 0.339155518526272
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8544383365861037
# (190, 10)
# RF R2: 0.3585073251438038
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8531590510099176
# (200, 10)
# RF R2: 0.3827052200289016
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8558508755989908
# (210, 10)
# RF R2: 0.3850760342086861
# Remaining: 143
# The Iteration is  8
# NN Test R2 with 5 samples -3.3965507376420354
# After Initialization RF R2: 0.37592722084430563
# NN Test R2 after Initialization -0.5374874193274596
# (10, 10)
# Query no. 1
# Embeddings training score: 0.7723118488973717
# (20, 10)
# RF R2: 0.39484564391821564
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8931603932308144
# (30, 10)
# RF R2: 0.37671152105296557
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8343879272313051
# (40, 10)
# RF R2: 0.4856171361030267
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8440650356630405
# (50, 10)
# RF R2: 0.45820123527212475
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8340257238638995
# (60, 10)
# RF R2: 0.532044433474796
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8443958938166024
# (70, 10)
# RF R2: 0.5333115660180942
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8472055670261398
# (80, 10)
# RF R2: 0.5963216832343357
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8435739099161969
# (90, 10)
# RF R2: 0.5950892414422333
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8504205763636625
# (100, 10)
# RF R2: 0.6115036205529203
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8506868841561912
# (110, 10)
# RF R2: 0.6024308994856304
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8592296388412872
# (120, 10)
# RF R2: 0.6076940437566325
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8609701422044752
# (130, 10)
# RF R2: 0.6252547062701126
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8572357119535103
# (140, 10)
# RF R2: 0.620571034094997
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8569031296296772
# (150, 10)
# RF R2: 0.596085828770747
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.859519747755292
# (160, 10)
# RF R2: 0.6063256975013828
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8615588585824892
# (170, 10)
# RF R2: 0.6014828355541632
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.860589960569849
# (180, 10)
# RF R2: 0.5860511311084378
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8631447920469804
# (190, 10)
# RF R2: 0.6151013658725579
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8625137126371133
# (200, 10)
# RF R2: 0.588147365724107
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8626836070241153
# (210, 10)
# RF R2: 0.5924130615688057
# Remaining: 143
# The Iteration is  9
# NN Test R2 with 5 samples -4.394739039254194
# After Initialization RF R2: 0.035649981461895575
# NN Test R2 after Initialization -2.1723891572169616
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8810192535979078
# (20, 10)
# RF R2: 0.15651584388959006
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8828136366998423
# (30, 10)
# RF R2: 0.2617337931052076
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8430488203953608
# (40, 10)
# RF R2: 0.26868373846942384
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8526939437838424
# (50, 10)
# RF R2: 0.2904167840212387
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8462063013946894
# (60, 10)
# RF R2: 0.3038467950433832
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8583612214137502
# (70, 10)
# RF R2: 0.2870921065566877
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8633867166110192
# (80, 10)
# RF R2: 0.3542517787074464
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8704775978816449
# (90, 10)
# RF R2: 0.38550952792590765
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8796671248666816
# (100, 10)
# RF R2: 0.4183186563305823
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8679458865821078
# (110, 10)
# RF R2: 0.4029287059337605
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8700612849101381
# (120, 10)
# RF R2: 0.37701440291024013
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8722022713884098
# (130, 10)
# RF R2: 0.3821457006780161
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8649949135798909
# (140, 10)
# RF R2: 0.3951634273558935
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8680203745022049
# (150, 10)
# RF R2: 0.3682756477452377
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8671010839585629
# (160, 10)
# RF R2: 0.36210107493543797
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8692872409499445
# (170, 10)
# RF R2: 0.38966703586353246
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8747561139273234
# (180, 10)
# RF R2: 0.42280740717054344
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8753951956547817
# (190, 10)
# RF R2: 0.41658113168318367
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.871412726515989
# (200, 10)
# RF R2: 0.42863183921476766
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8635910157586769
# (210, 10)
# RF R2: 0.3779077765858583
# Remaining: 143
# The Iteration is  10
# NN Test R2 with 5 samples -3.8004412890157666
# After Initialization RF R2: 0.23162437973863492
# NN Test R2 after Initialization -0.830361608110858
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8397620144150046
# (20, 10)
# RF R2: 0.0755134199432218
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.9057265171873188
# (30, 10)
# RF R2: 0.2257154636224895
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.9285866773129231
# (40, 10)
# RF R2: 0.33435272877588207
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.9088528684830647
# (50, 10)
# RF R2: 0.310265806198318
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8972519401667922
# (60, 10)
# RF R2: 0.4103739944180501
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8778882102527152
# (70, 10)
# RF R2: 0.4897823436973333
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8981083526203029
# (80, 10)
# RF R2: 0.4922531770592099
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8881796782768242
# (90, 10)
# RF R2: 0.474761812523793
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8855233346802741
# (100, 10)
# RF R2: 0.43486896081726645
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8865824654357661
# (110, 10)
# RF R2: 0.43669844086186915
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8820929694993852
# (120, 10)
# RF R2: 0.44818226136266226
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8777960775110976
# (130, 10)
# RF R2: 0.4357575798692953
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8791341678326368
# (140, 10)
# RF R2: 0.44785179861512714
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8815678397185671
# (150, 10)
# RF R2: 0.4532267915195236
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8760716976071076
# (160, 10)
# RF R2: 0.4479003034138763
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8773599411955058
# (170, 10)
# RF R2: 0.4458612566107224
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8702334198483838
# (180, 10)
# RF R2: 0.428460694591314
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8672390817044235
# (190, 10)
# RF R2: 0.4496042736758127
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8704238121561677
# (200, 10)
# RF R2: 0.46492277584781116
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8690871234054836
# (210, 10)
# RF R2: 0.45658671923647676
# Remaining: 143
# The Iteration is  11
# NN Test R2 with 5 samples -4.808312149946573
# After Initialization RF R2: 0.21259635230652096
# NN Test R2 after Initialization -3.4089893040818118
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8672589402861042
# (20, 10)
# RF R2: 0.2938426043113912
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8003966142578537
# (30, 10)
# RF R2: 0.36493208744062466
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8933898737736755
# (40, 10)
# RF R2: 0.27692460820272147
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8651485989352545
# (50, 10)
# RF R2: 0.3460122555034345
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8713869102268558
# (60, 10)
# RF R2: 0.28574139134720433
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8639787757346049
# (70, 10)
# RF R2: 0.3058922151155107
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.864192217445659
# (80, 10)
# RF R2: 0.276172779776349
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8724553847481484
# (90, 10)
# RF R2: 0.2473758652955158
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.861038907311028
# (100, 10)
# RF R2: 0.2787809967039173
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8759389488176728
# (110, 10)
# RF R2: 0.2446467736458947
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8670185851022283
# (120, 10)
# RF R2: 0.33848497434517877
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8677357758033983
# (130, 10)
# RF R2: 0.32513094833415657
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8563595825302097
# (140, 10)
# RF R2: 0.36972165748847896
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8587621953906392
# (150, 10)
# RF R2: 0.3372497921653411
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8574898467153307
# (160, 10)
# RF R2: 0.3452748360796136
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8599635418947134
# (170, 10)
# RF R2: 0.38862335696619954
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8598002007446977
# (180, 10)
# RF R2: 0.3760185565483706
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8627597363307951
# (190, 10)
# RF R2: 0.36254305046160895
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8623664116049407
# (200, 10)
# RF R2: 0.4118958587426701
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8619670120009282
# (210, 10)
# RF R2: 0.42867548555370616
# Remaining: 143
# The Iteration is  12
# NN Test R2 with 5 samples -4.154291537804914
# After Initialization RF R2: 0.06185382460298916
# NN Test R2 after Initialization -1.3490131877144016
# (10, 10)
# Query no. 1
# Embeddings training score: 0.7887023166541794
# (20, 10)
# RF R2: 0.0227120116865146
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8506547284168218
# (30, 10)
# RF R2: 0.24842537499772444
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.9225493349257579
# (40, 10)
# RF R2: 0.2139340344936671
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.9101610715709583
# (50, 10)
# RF R2: 0.27308530877615866
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.9088938243336497
# (60, 10)
# RF R2: 0.25377498088295214
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.9037527051675772
# (70, 10)
# RF R2: 0.38844956572212863
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.9074029731387948
# (80, 10)
# RF R2: 0.4060764286992272
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.9055462249093734
# (90, 10)
# RF R2: 0.40608511978199957
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.9043621404204261
# (100, 10)
# RF R2: 0.40024252555100726
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.9029903839388781
# (110, 10)
# RF R2: 0.37626904199346634
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8947175267475765
# (120, 10)
# RF R2: 0.35079613242919816
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8878694927797586
# (130, 10)
# RF R2: 0.3624394597870263
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8888190325148492
# (140, 10)
# RF R2: 0.4090714596617018
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8789518088320722
# (150, 10)
# RF R2: 0.4247938577307294
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8788242762867564
# (160, 10)
# RF R2: 0.43493379403579646
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8737177438553825
# (170, 10)
# RF R2: 0.4181976749786578
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8721681403684302
# (180, 10)
# RF R2: 0.42279776058897034
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8715476121670931
# (190, 10)
# RF R2: 0.4123884355590264
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8698839463069163
# (200, 10)
# RF R2: 0.4428108507185451
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8726389397454745
# (210, 10)
# RF R2: 0.46135244966129196
# Remaining: 143
# The Iteration is  13
# NN Test R2 with 5 samples -3.864832665344044
# After Initialization RF R2: 0.10976834507123645
# NN Test R2 after Initialization -0.6927537322717435
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8135354446563515
# (20, 10)
# RF R2: 0.3378070464149109
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.9138230920499232
# (30, 10)
# RF R2: 0.3660872852194875
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.9011510651911501
# (40, 10)
# RF R2: 0.36264038084700234
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8826180495504165
# (50, 10)
# RF R2: 0.42285858861736425
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8572131385275429
# (60, 10)
# RF R2: 0.3204391128596391
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8604571930271393
# (70, 10)
# RF R2: 0.3372856594852529
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8600402615632158
# (80, 10)
# RF R2: 0.3314249899607611
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8580332764506255
# (90, 10)
# RF R2: 0.3767472908017111
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8529277969728805
# (100, 10)
# RF R2: 0.3628008418659141
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8421174863032469
# (110, 10)
# RF R2: 0.40346441475151307
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8511402366320281
# (120, 10)
# RF R2: 0.42059047751059553
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8545720301543858
# (130, 10)
# RF R2: 0.39227418778282797
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8557165589958527
# (140, 10)
# RF R2: 0.41017389278426064
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8606829876104231
# (150, 10)
# RF R2: 0.4196069724746194
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8615159983223913
# (160, 10)
# RF R2: 0.40465517252362915
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8595376908041803
# (170, 10)
# RF R2: 0.4088652168844972
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8562867641693841
# (180, 10)
# RF R2: 0.3897057370582613
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.854615621637644
# (190, 10)
# RF R2: 0.39820302675844266
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8561611822992312
# (200, 10)
# RF R2: 0.3821516447115956
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8600192004604198
# (210, 10)
# RF R2: 0.37027968374545495
# Remaining: 143
# The Iteration is  14
# NN Test R2 with 5 samples -3.4971873959145867
# After Initialization RF R2: 0.21875949583564513
# NN Test R2 after Initialization -1.5497002900225108
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8529529696205941
# (20, 10)
# RF R2: 0.29714428790422964
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8190885750275667
# (30, 10)
# RF R2: 0.3636029401347498
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8147038701369411
# (40, 10)
# RF R2: 0.24700882009144798
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8340461038109563
# (50, 10)
# RF R2: 0.294023219698069
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8316544017968657
# (60, 10)
# RF R2: 0.3940559351220577
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8366024584829055
# (70, 10)
# RF R2: 0.39127466344478923
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8431924907667269
# (80, 10)
# RF R2: 0.448037937385543
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8492929289548817
# (90, 10)
# RF R2: 0.45221646950304983
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8454225495386394
# (100, 10)
# RF R2: 0.4186937573769832
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8491158282532292
# (110, 10)
# RF R2: 0.4447669539460586
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8417536771748317
# (120, 10)
# RF R2: 0.46243361452644827
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8506189738567629
# (130, 10)
# RF R2: 0.47511284585827873
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.852042661648405
# (140, 10)
# RF R2: 0.46348455757530194
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8543592096431982
# (150, 10)
# RF R2: 0.4761664647964373
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.855261586729692
# (160, 10)
# RF R2: 0.4977519475597463
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8559189766653769
# (170, 10)
# RF R2: 0.4763290266764515
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8557070004766749
# (180, 10)
# RF R2: 0.424383362300635
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8575936952260776
# (190, 10)
# RF R2: 0.43486552286193725
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8538113779729548
# (200, 10)
# RF R2: 0.44506798434913875
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8418600410048463
# (210, 10)
# RF R2: 0.4601961745398814
# Remaining: 143
# The Iteration is  15
# NN Test R2 with 5 samples -4.2698651045994085
# After Initialization RF R2: 0.20777385009743188
# NN Test R2 after Initialization -2.0009585776937433
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8193641062870691
# (20, 10)
# RF R2: 0.1447402205617464
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.7903919833661783
# (30, 10)
# RF R2: -0.004115462543718751
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8323130508799738
# (40, 10)
# RF R2: 0.09095208098115803
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8134382091154262
# (50, 10)
# RF R2: 0.18326298064036783
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8458231356826924
# (60, 10)
# RF R2: 0.2509126951148667
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8579356818801113
# (70, 10)
# RF R2: 0.30362692597097773
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8604556924040427
# (80, 10)
# RF R2: 0.3358068786159186
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8733873056577521
# (90, 10)
# RF R2: 0.3442890941178328
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8642120043412618
# (100, 10)
# RF R2: 0.34950746134922883
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8577284733508354
# (110, 10)
# RF R2: 0.28038247054979526
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8574794169924604
# (120, 10)
# RF R2: 0.3302510444963005
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.860425087811404
# (130, 10)
# RF R2: 0.3718656359873397
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8575704835268063
# (140, 10)
# RF R2: 0.38813051057796677
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8527934527957362
# (150, 10)
# RF R2: 0.38181981055271785
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8520376541162811
# (160, 10)
# RF R2: 0.4006286451830877
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8530177539327547
# (170, 10)
# RF R2: 0.4272078725749061
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8548967126888545
# (180, 10)
# RF R2: 0.44475167560468154
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8540270107676108
# (190, 10)
# RF R2: 0.4445621317916819
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8466346895309069
# (200, 10)
# RF R2: 0.41539535047039644
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8519761837828295
# (210, 10)
# RF R2: 0.44755258864336367
# Remaining: 143
# The Iteration is  16
# NN Test R2 with 5 samples -3.4436507190135224
# After Initialization RF R2: 0.3788951332013627
# NN Test R2 after Initialization -2.609241820508681
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8687544354325888
# (20, 10)
# RF R2: 0.4636355481943186
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.9120311961518267
# (30, 10)
# RF R2: 0.47993623014543196
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8178031681645506
# (40, 10)
# RF R2: 0.42660641034473623
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8508069270790795
# (50, 10)
# RF R2: 0.4467483081500758
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8467477552087549
# (60, 10)
# RF R2: 0.5498634102700537
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8538397135629925
# (70, 10)
# RF R2: 0.54490901053645
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8573369710973083
# (80, 10)
# RF R2: 0.5417218633804941
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8606760811231253
# (90, 10)
# RF R2: 0.5303145030773737
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8592924132983166
# (100, 10)
# RF R2: 0.4821679136386171
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8575573079061704
# (110, 10)
# RF R2: 0.47123377851382153
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8638525208757332
# (120, 10)
# RF R2: 0.532391759782737
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8593073677317664
# (130, 10)
# RF R2: 0.5252501114143739
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8566429722456952
# (140, 10)
# RF R2: 0.556358001801892
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8591961039925328
# (150, 10)
# RF R2: 0.5352465273311267
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8626698802636017
# (160, 10)
# RF R2: 0.5477077653984207
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8619507645363639
# (170, 10)
# RF R2: 0.5386686521184156
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8596059827960408
# (180, 10)
# RF R2: 0.537658877200254
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8617412963362043
# (190, 10)
# RF R2: 0.5011029084864325
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8613247644338129
# (200, 10)
# RF R2: 0.5255681038173394
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8603650344648726
# (210, 10)
# RF R2: 0.5253204929191896
# Remaining: 143
# The Iteration is  17
# NN Test R2 with 5 samples -3.531825926746853
# After Initialization RF R2: 0.27409988635854254
# NN Test R2 after Initialization -2.3932556300624435
# (10, 10)
# Query no. 1
# Embeddings training score: 0.7542130223173155
# (20, 10)
# RF R2: 0.196944765283248
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8451330734703177
# (30, 10)
# RF R2: 0.17952581244698795
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8233922471492285
# (40, 10)
# RF R2: 0.1751076038438132
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8519491253299442
# (50, 10)
# RF R2: 0.1822816766444859
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8547282085778982
# (60, 10)
# RF R2: 0.3366944417031802
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.852569495582659
# (70, 10)
# RF R2: 0.42234557872810374
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8491065705737205
# (80, 10)
# RF R2: 0.37572345544232555
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8461317756572072
# (90, 10)
# RF R2: 0.47276148499975423
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8481173076403066
# (100, 10)
# RF R2: 0.4891418611659142
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.852017436744017
# (110, 10)
# RF R2: 0.4633809660846825
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8548383994012545
# (120, 10)
# RF R2: 0.46584290515447946
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8562066987673626
# (130, 10)
# RF R2: 0.45967595439694164
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8565544698827937
# (140, 10)
# RF R2: 0.4495856489265031
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8602876732309908
# (150, 10)
# RF R2: 0.4486840363314305
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8596067923899571
# (160, 10)
# RF R2: 0.42624247585309605
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8548788184667031
# (170, 10)
# RF R2: 0.44171405741798764
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8590707470901331
# (180, 10)
# RF R2: 0.4113966060682017
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8609380862544307
# (190, 10)
# RF R2: 0.421270950100217
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8579473859697206
# (200, 10)
# RF R2: 0.46187879235548646
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8602294226572543
# (210, 10)
# RF R2: 0.47207353713800915
# Remaining: 143
# The Iteration is  18
# NN Test R2 with 5 samples -4.1984492061628265
# After Initialization RF R2: 0.19165785697079374
# NN Test R2 after Initialization -1.9390426774216831
# (10, 10)
# Query no. 1
# Embeddings training score: 0.7772845404128825
# (20, 10)
# RF R2: 0.23426295869529679
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8389661614824606
# (30, 10)
# RF R2: 0.17606181771488827
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8270091792969021
# (40, 10)
# RF R2: 0.28656068518645705
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8402573884549793
# (50, 10)
# RF R2: 0.21950039199653948
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8432612635215158
# (60, 10)
# RF R2: 0.25256121514260443
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8441041801640193
# (70, 10)
# RF R2: 0.3118515333547148
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8480288904565788
# (80, 10)
# RF R2: 0.3931905215008099
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.859013231069477
# (90, 10)
# RF R2: 0.35270662532248354
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.854608316818924
# (100, 10)
# RF R2: 0.33065459112758266
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8533710757679016
# (110, 10)
# RF R2: 0.3129393457924886
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8453268305843855
# (120, 10)
# RF R2: 0.3056933666576289
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8448215170037426
# (130, 10)
# RF R2: 0.32669451793919757
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8474355906263382
# (140, 10)
# RF R2: 0.3319499528100017
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.847748329685192
# (150, 10)
# RF R2: 0.3585013514558584
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8561347694183818
# (160, 10)
# RF R2: 0.3568625363827532
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.853046755861522
# (170, 10)
# RF R2: 0.34339735862663445
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8512380167522182
# (180, 10)
# RF R2: 0.3112927043649222
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8533365283203022
# (190, 10)
# RF R2: 0.3193655394394226
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8544323541880112
# (200, 10)
# RF R2: 0.2723547805197164
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8589663330443373
# (210, 10)
# RF R2: 0.2941843068604264
# Remaining: 143
# The Iteration is  19
# NN Test R2 with 5 samples -4.38552230872066
# After Initialization RF R2: 0.2592937559558306
# NN Test R2 after Initialization -2.2233461740793863
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8645076984068765
# (20, 10)
# RF R2: 0.31167879445198166
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.7812426899698699
# (30, 10)
# RF R2: 0.27829358950904604
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.7838965770717468
# (40, 10)
# RF R2: 0.3024238381959231
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8447647298789479
# (50, 10)
# RF R2: 0.35608492380878753
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8488807430876301
# (60, 10)
# RF R2: 0.39016560228250596
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8666651725721142
# (70, 10)
# RF R2: 0.3698147694792959
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8836490903479719
# (80, 10)
# RF R2: 0.3610024716694822
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8842094484101531
# (90, 10)
# RF R2: 0.3197073942426776
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8827677332176057
# (100, 10)
# RF R2: 0.3249329045353553
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.87247459809261
# (110, 10)
# RF R2: 0.3030373156571764
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.869731574302581
# (120, 10)
# RF R2: 0.274125578075464
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8655464180649718
# (130, 10)
# RF R2: 0.3111107236243522
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8693674345921779
# (140, 10)
# RF R2: 0.3177070779208687
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8680138248052862
# (150, 10)
# RF R2: 0.34397621732877914
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8679744219344081
# (160, 10)
# RF R2: 0.3260297837878636
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.868917228369904
# (170, 10)
# RF R2: 0.29269957206042674
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8686627198903945
# (180, 10)
# RF R2: 0.32291087538051144
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8713048952643521
# (190, 10)
# RF R2: 0.31162956832242816
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8693568984137614
# (200, 10)
# RF R2: 0.30904664153444283
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8681883662698537
# (210, 10)
# RF R2: 0.3121856211101539
# Remaining: 143
