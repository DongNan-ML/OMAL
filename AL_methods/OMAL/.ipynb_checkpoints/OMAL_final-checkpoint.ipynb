# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from modAL.models import ActiveLearner, CommitteeRegressor
from modAL.disagreement import vote_entropy_sampling, max_std_sampling
import matplotlib.pyplot as plt
import torch
from torch.nn import MSELoss
from skorch.regressor import NeuralNetRegressor
from copy import deepcopy
from skorch.dataset import ValidSplit
from skorch.callbacks import EarlyStopping
from sklearn.cluster import DBSCAN, OPTICS, cluster_optics_dbscan, Birch, SpectralClustering
from sklearn.neighbors import NearestNeighbors
from sklearn import metrics
import matplotlib.gridspec as gridspec
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from torch.nn import Linear
from torch.nn import Sigmoid, ReLU
from torch.nn import Module
from sklearn.metrics import r2_score
import copy
from scipy.spatial import distance
from scipy.spatial.distance import euclidean
from torch import tensor
from sklearn.metrics import mean_squared_error
from scipy.spatial.distance import cdist
from sklearn.ensemble import RandomForestRegressor
from torch.nn.init import xavier_uniform_
from model import MLP
from model_state import get_model_params, get_input_for_hidden_layers, get_model_params_gradientNorm
from functions_batch1 import get_variance, qbc, normalization, error_reduct_fuc, total_disagrement, grad_norm, averaged_grad_norm, get_avg_grad_norm, training_loss
import random
from skorch.callbacks import EarlyStopping, LRScheduler, Freezer, Unfreezer
from torch.optim.lr_scheduler import CyclicLR, ReduceLROnPlateau
from skorch.regressor import NeuralNetRegressor, NeuralNet
from model_state import features_concat, learning_state_features_concat
import gc
import warnings
from modAL.utils.selection import multi_argmax
warnings.filterwarnings("ignore")

# %%
# Hyper-params:
query_number = 20          # The number of the AL Iterations in each Exp
iteration = 20             # Total number of the Exps
batch_size = 10
total_initail_size = 10
initial_size = 5
dimensions = 18   # Total dimension of the data features + model states

seed_rf = np.load(file="..\..\Datasets\Diabetes\seed_for_RF.npy")
seed_initial = np.load(file="..\..\Datasets\Diabetes\seed_for_initialSamples.npy")

seed_nn1 = np.random.randint(10000, size=100)
seed_nn2 = np.random.randint(10000, size=100)
seed_nn3 = np.random.randint(10000, size=100)
seed_nn4 = np.random.randint(10000, size=100)
seed_nn5 = np.random.randint(10000, size=100)
seed_nn6 = np.random.randint(10000, size=100)
seed_predictor = np.random.randint(10000, size=100)

np.save(file="..\..\Results\Res_Diabetes\OMAL1\seed_for_nn1.npy", arr=seed_nn1)
np.save(file="..\..\Results\Res_Diabetes\OMAL1\seed_for_nn2.npy", arr=seed_nn2)
np.save(file="..\..\Results\Res_Diabetes\OMAL1\seed_for_nn3.npy", arr=seed_nn3)
np.save(file="..\..\Results\Res_Diabetes\OMAL1\seed_for_nn4.npy", arr=seed_nn4)
np.save(file="..\..\Results\Res_Diabetes\OMAL1\seed_for_nn5.npy", arr=seed_nn5)
np.save(file="..\..\Results\Res_Diabetes\OMAL1\seed_for_nn6.npy", arr=seed_nn6)

np.save(file="..\..\Results\Res_Diabetes\OMAL1\seed_predictor.npy", arr=seed_predictor)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def Committee_Prediction(learner_list, X_test, y_test):
    initial_pred=[]
    for i in learner_list:
        initial_pred.append(r2_score(y_test, i.predict(X_test)))
    initial_pred=np.array(initial_pred)
    
    return initial_pred.mean()

# %%
def main_function(query_number, iters):
    # For saving results:
    rf_model_training_r2 = []
    rf_model_training_mse = []
    rf_model_testing_r2 = []
    rf_model_testing_mse = []
    
    # Number of member in committee:
    n_members = 3
    learner_list = []
    
    # The model for evaluation:
    rf_model = RandomForestRegressor(random_state=seed_rf[iters], n_estimators=100)
    gradient_norms = np.empty(shape=(0, 0))
    
    # Load the data:
    name1 = "..\..\Datasets\Diabetes\X_train" + str(iters) + ".npy"
    name2 = "..\..\Datasets\Diabetes\X_test" + str(iters) + ".npy"
    name3 = "..\..\Datasets\Diabetes\y_train" + str(iters) + ".npy"
    name4 = "..\..\Datasets\Diabetes\y_test" + str(iters) + ".npy"
    
    X_train = np.load(name1, allow_pickle=True).astype(np.float32)
    X_test = np.load(name2, allow_pickle=True).astype(np.float32)
    y_train = np.load(name3, allow_pickle=True).astype(np.float32).reshape(-1, 1)
    y_test = np.load(name4, allow_pickle=True).astype(np.float32).reshape(-1, 1)
    
    # Dimensionality of data:
    X = X_train.shape[1]
    # The index of the unlabeled pool:
    X_index = np.arange(X_train.shape[0])

    used_data = np.empty(shape=(0, X))
    used_label = np.empty(shape=(0)).reshape(-1, 1)

    X_initial = np.empty(shape=(0,X))
    y_initial = np.empty(shape=(0)).reshape(-1, 1)
    
    # Initial Stage 1:
    np.random.seed(seed_initial[iters])
    idx = np.random.choice(range(len(X_index)), size=initial_size, replace=False)
    train_idx = X_index[idx]

    X_initial = X_train[train_idx]
    y_initial = y_train[train_idx].reshape(-1, 1)

    used_data = np.append(used_data, X_initial, axis=0).astype(np.float32)
    used_label = np.append(used_label, y_initial, axis=0).astype(np.float32).reshape(-1, 1)
    X_index = np.delete(X_index, idx, axis=0)

    
    used_data = torch.from_numpy(used_data).to(device)
    used_label = torch.from_numpy(used_label).to(device)
    for member_idx in range(n_members):
        if member_idx == 0:
            np.random.seed(seed_nn1[iters])
            torch.manual_seed(seed_nn2[iters])
        if member_idx == 1:
            np.random.seed(seed_nn3[iters])
            torch.manual_seed(seed_nn4[iters])
        if member_idx == 2:
            np.random.seed(seed_nn5[iters])
            torch.manual_seed(seed_nn6[iters])
            
        regressor = NeuralNetRegressor(MLP(X),
                                   criterion=MSELoss(),
                                   optimizer=torch.optim.Adam,
                                   verbose=0,
                                   max_epochs=30,
                                   lr=0.001,
                                   # Used for the batch AL
                                   callbacks=[EarlyStopping(patience=5), ('lr_scheduler', LRScheduler(policy=ReduceLROnPlateau))],
                                   train_split=ValidSplit(cv=5),
                                   warm_start=True,
                                   device='cuda',
                                   batch_size = -1
                                   )
        regressor.fit(used_data, used_label)
        learner_list.append(regressor)
    
    print("NN Test R2 with 5 samples", Committee_Prediction(learner_list, X_test, y_test))

    # Number of LAL features:
    learning_state_features = np.empty(shape=(0, dimensions))
    loss_reduction_target = np.empty(shape=(0)).reshape(-1, 1)

    # other random samples:
    rest_initial_X = np.empty(shape=(0, X))
    rest_initial_y = np.empty(shape=(0)).reshape(-1, 1)

    # LAL Initialization: Stage 2
    predictor = RandomForestRegressor(n_estimators=500, random_state=seed_predictor[iters])
    np.random.seed(seed_initial[iters])
    idx = np.random.choice(range(len(X_index)), size=total_initail_size-initial_size, replace=False)
    train_idx = X_index[idx]
    
    rest_initial_X = np.append(rest_initial_X, X_train[train_idx], axis=0).astype(np.float32)
    rest_initial_y = np.append(rest_initial_y, y_train[train_idx], axis=0).astype(np.float32).reshape(-1, 1)

    X_index = np.delete(X_index, idx, axis=0)

    for i in range(rest_initial_X.shape[0]):

        single_X = rest_initial_X[i],
        single_y = rest_initial_y[i].reshape(1, -1)
        single_X = single_X[0].reshape(1, -1)
        
        single_X = torch.from_numpy(single_X).to(device)
        single_y = torch.from_numpy(single_y).to(device)

        # Model params
        model_params = get_model_params_gradientNorm(learner_list)

        # updated data
        used_data = torch.cat((used_data, single_X), 0)
        used_label = torch.cat((used_label, single_y), 0)

        # Retrain the model:
        for l in learner_list:
            l.fit(X=used_data,y=used_label)
            
        single_X = single_X.cpu().numpy()
        single_y = single_y.cpu().numpy()
            
        index = train_idx[i]

        # The training sample:
        data_params = X_train[index]
      
        LALfeatures = features_concat(model_params, data_params)

        loss_reduction = get_avg_grad_norm(learner_list, single_X, single_y)
        
        learning_state_features = learning_state_features_concat(learning_state_features, LALfeatures)
        loss_reduction_target = np.append(loss_reduction_target, np.array([loss_reduction]).reshape(-1, 1), axis=0).astype(np.float32).reshape(-1, 1)

        
    used_data = used_data.cpu().numpy()
    used_label = used_label.cpu().numpy()

    # Finished the Initialization Stages:
    # RF Regressor for evaluation:
    rf_model.fit(used_data, used_label.ravel())
    # Training Scores:
    rf_training_r2 = r2_score(used_label, rf_model.predict(used_data))
    rf_training_mse = mean_squared_error(used_label, rf_model.predict(used_data))
    rf_model_training_r2.append(rf_training_r2)
    rf_model_training_mse.append(rf_training_mse)
    
    # Test Scores:
    rf_model_r2 = r2_score(y_test, rf_model.predict(X_test))
    rf_model_mse = mean_squared_error(y_test, rf_model.predict(X_test))
    rf_model_testing_r2.append(rf_model_r2)
    rf_model_testing_mse.append(rf_model_mse)
    
    print("After Initialization RF R2:", rf_model_r2)
    print("NN Test R2 after Initialization", Committee_Prediction(learner_list, X_test, y_test))

    print(np.unique(used_data, axis=0).shape)
    for idx in range(query_number):
        np.random.seed(None)
        print('Query no. %d' % (idx+1))

        Error_reduction_list, training_score = error_reduct_fuc(X_train, X_index, learner_list, learning_state_features, loss_reduction_target, X_index.shape[0], predictor)

        idx = multi_argmax(np.array(Error_reduction_list), n_instances=batch_size)
       
        X_train_indices = X_index[idx]
        
        # Update
        X_index = np.delete(X_index, idx, axis=0)

        for X_train_index in X_train_indices:

            new_X = X_train[X_train_index].reshape(1, -1)
            new_y = y_train[X_train_index].reshape(1, -1)
            
            used_data = np.append(used_data, new_X, axis=0).astype(np.float32)
            used_label = np.append(used_label, new_y, axis=0).astype(np.float32).reshape(-1, 1)
            
            used_data = torch.from_numpy(used_data).to(device)
            used_label = torch.from_numpy(used_label).to(device)

            # Model params
            model_params = get_model_params_gradientNorm(learner_list)
            data_params = X_train[X_train_index]
            LALfeatures = features_concat(model_params, data_params)
            
            for l in learner_list:
                l.fit(used_data, used_label)
            
            used_data = used_data.cpu().numpy()
            used_label = used_label.cpu().numpy()

            loss_reduction = get_avg_grad_norm(learner_list, new_X, new_y)  
            gradient_norms = np.append(gradient_norms, loss_reduction)
            
            learning_state_features = learning_state_features_concat(learning_state_features, LALfeatures)
            loss_reduction_target = np.append(loss_reduction_target, np.array([loss_reduction]).reshape(-1, 1), axis=0).astype(np.float32).reshape(-1, 1)
        

        # RF Evaluation
        rf_model.fit(used_data, used_label.ravel())
        
        # Training Evaluation:
        rf_training_r2 = r2_score(used_label, rf_model.predict(used_data))
        rf_training_mse = mean_squared_error(used_label, rf_model.predict(used_data))
        rf_model_training_r2.append(rf_training_r2)
        rf_model_training_mse.append(rf_training_mse)
        
        # Test Evaluation:
        rf_model_r2 = r2_score(y_test, rf_model.predict(X_test))
        rf_model_mse = mean_squared_error(y_test, rf_model.predict(X_test))
        rf_model_testing_r2.append(rf_model_r2)
        rf_model_testing_mse.append(rf_model_mse)

        print(np.unique(used_data, axis=0).shape)
        print("RF R2:", rf_model_r2)
        print("Remaining:", X_index.shape[0])
        # print('NN R2', Committee_Prediction(learner_list, X_test, y_test))

    # RF
    rf_model_testing_r2 = np.array(rf_model_testing_r2)
    rf_model_testing_mse = np.array(rf_model_testing_mse)
    rf_model_training_r2 = np.array(rf_model_training_r2)
    rf_model_training_mse = np.array(rf_model_training_mse)
    
    # Used_data and Unsed_label:
    np.save(file="..\..\Results\Res_Diabetes\OMAL1\Summary\\used_data" + str(iters) + ".npy", arr=used_data)
    np.save(file="..\..\Results\Res_Diabetes\OMAL1\Summary\\used_labels" + str(iters) + ".npy", arr=used_label)

    np.save(file="..\..\Results\Res_Diabetes\OMAL1\Summary\\testing_rf_r2_" + str(iters) + ".npy", arr=rf_model_testing_r2)
    np.save(file="..\..\Results\Res_Diabetes\OMAL1\Summary\\testing_rf_mse_" + str(iters) + ".npy", arr=rf_model_testing_mse)
    np.save(file="..\..\Results\Res_Diabetes\OMAL1\Summary\\training_rf_r2_" + str(iters) + ".npy", arr=rf_model_training_r2)
    np.save(file="..\..\Results\Res_Diabetes\OMAL1\Summary\\training_rf_mse_" + str(iters) + ".npy", arr=rf_model_training_mse)

# %%
for i in range(iteration):
    print("The Iteration is ", i)
    main_function(query_number, i)
# Out:
# The Iteration is  0
# NN Test R2 with 5 samples -3.283305216413177
# After Initialization RF R2: 0.01017105099476967
# NN Test R2 after Initialization -2.2097240485915255
# (10, 10)
# Query no. 1
# Embeddings training score: 0.7875587237049305
# (20, 10)
# RF R2: 0.3939979019014139
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.9417138807816493
# (30, 10)
# RF R2: 0.4135758158140316
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8961846886935518
# (40, 10)
# RF R2: 0.41729207102887045
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.876361088235036
# (50, 10)
# RF R2: 0.376592016688445
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8667511576464035
# (60, 10)
# RF R2: 0.4425500670656334
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8692096169836616
# (70, 10)
# RF R2: 0.5288846916805897
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8719920658763805
# (80, 10)
# RF R2: 0.5173839741271016
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8703524145901147
# (90, 10)
# RF R2: 0.5784389931127238
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8737615595460287
# (100, 10)
# RF R2: 0.5684594194535502
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8776220686589622
# (110, 10)
# RF R2: 0.5350715740992297
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8734347411256143
# (120, 10)
# RF R2: 0.528243485580755
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8698753865135203
# (130, 10)
# RF R2: 0.5481251306715351
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8722795925430603
# (140, 10)
# RF R2: 0.556683577908327
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8769241178222695
# (150, 10)
# RF R2: 0.5550934428821617
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8793165164479673
# (160, 10)
# RF R2: 0.5455220568214034
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8807049722090625
# (170, 10)
# RF R2: 0.5499593623039116
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8731159979330915
# (180, 10)
# RF R2: 0.550540692782653
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8701305030712585
# (190, 10)
# RF R2: 0.5517999533622497
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8759286556346285
# (200, 10)
# RF R2: 0.5204121926509571
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8686080160240158
# (210, 10)
# RF R2: 0.5279227958337951
# Remaining: 143
# The Iteration is  1
# NN Test R2 with 5 samples -3.7584528064537692
# After Initialization RF R2: 0.20844341964741697
# NN Test R2 after Initialization -0.7581141075869974
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8848388252783979
# (20, 10)
# RF R2: 0.2730414356556501
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.9142090969820817
# (30, 10)
# RF R2: 0.2508170145106885
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8828299323852973
# (40, 10)
# RF R2: 0.21833964307966536
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8546596995984613
# (50, 10)
# RF R2: 0.3336020610160869
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8383510213305683
# (60, 10)
# RF R2: 0.4358832732160476
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8523618182485009
# (70, 10)
# RF R2: 0.38666284025200126
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8662314307564177
# (80, 10)
# RF R2: 0.39634773394457956
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8535947231413281
# (90, 10)
# RF R2: 0.40997139935488924
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8624704468546991
# (100, 10)
# RF R2: 0.3587513190426399
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8562765752332678
# (110, 10)
# RF R2: 0.37808247584033583
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8638275195354893
# (120, 10)
# RF R2: 0.36720532574585807
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8616161548146313
# (130, 10)
# RF R2: 0.4041187056560217
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8606602178697718
# (140, 10)
# RF R2: 0.39443886529611993
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8609270953793847
# (150, 10)
# RF R2: 0.43765081368684666
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8611293627319903
# (160, 10)
# RF R2: 0.4534981434088282
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8547851645397376
# (170, 10)
# RF R2: 0.46772845924797235
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8488470530333412
# (180, 10)
# RF R2: 0.442183960793589
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8392996372843761
# (190, 10)
# RF R2: 0.43972582461449605
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8548152404831626
# (200, 10)
# RF R2: 0.4486010658699682
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8561915563134417
# (210, 10)
# RF R2: 0.44344552738933685
# Remaining: 143
# The Iteration is  2
# NN Test R2 with 5 samples -3.6678603602072264
# After Initialization RF R2: 0.2925063658507443
# NN Test R2 after Initialization -3.6271190606176305
# (10, 10)
# Query no. 1
# Embeddings training score: 0.9135430321637574
# (20, 10)
# RF R2: 0.2750532670891622
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8881184063731353
# (30, 10)
# RF R2: 0.32935117549676574
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.9368707943555203
# (40, 10)
# RF R2: 0.25232489543442016
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.9212476666433723
# (50, 10)
# RF R2: 0.27882905707099936
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.9166582751180903
# (60, 10)
# RF R2: 0.23236098168114738
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.926292186384799
# (70, 10)
# RF R2: 0.29512446921208857
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.917909790891636
# (80, 10)
# RF R2: 0.3245627747860883
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.9140101763210599
# (90, 10)
# RF R2: 0.3046789336209207
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.9001241677690941
# (100, 10)
# RF R2: 0.24732116216954214
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8954957558293211
# (110, 10)
# RF R2: 0.24689663362595737
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8941866313919486
# (120, 10)
# RF R2: 0.34681322195410513
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8959504941239717
# (130, 10)
# RF R2: 0.3807457420304532
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8863134139806427
# (140, 10)
# RF R2: 0.3016702468472008
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8784108165470589
# (150, 10)
# RF R2: 0.36281254365796956
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.881211960108552
# (160, 10)
# RF R2: 0.36149702764625247
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8812771846123346
# (170, 10)
# RF R2: 0.38447984503898347
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8807867656452221
# (180, 10)
# RF R2: 0.37816273164561054
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8803367190251619
# (190, 10)
# RF R2: 0.3800023291738419
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8791974967495271
# (200, 10)
# RF R2: 0.3983610591038562
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8792447266513472
# (210, 10)
# RF R2: 0.3988900296261667
# Remaining: 143
# The Iteration is  3
# NN Test R2 with 5 samples -4.1728926017223165
# After Initialization RF R2: 0.36481536421176197
# NN Test R2 after Initialization -3.769562356249386
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8693000953165806
# (20, 10)
# RF R2: 0.3163146359706209
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8142275058066317
# (30, 10)
# RF R2: 0.33292396381868694
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8787076940539619
# (40, 10)
# RF R2: 0.32263371365907023
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8491720139705439
# (50, 10)
# RF R2: 0.3493961817616268
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.856854256932545
# (60, 10)
# RF R2: 0.2858389729502637
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8464721300927289
# (70, 10)
# RF R2: 0.13824450347956718
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8471914837511569
# (80, 10)
# RF R2: 0.16374109058206343
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8428066261941273
# (90, 10)
# RF R2: 0.2212239374240853
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8482180413047541
# (100, 10)
# RF R2: 0.18124558142156222
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8521078719671246
# (110, 10)
# RF R2: 0.2403395728648563
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.843837137604115
# (120, 10)
# RF R2: 0.3625685165355125
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8539126718113634
# (130, 10)
# RF R2: 0.34219743300082417
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8599598442370608
# (140, 10)
# RF R2: 0.37246422647191124
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8504003559827937
# (150, 10)
# RF R2: 0.37676587173324705
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8562915699108575
# (160, 10)
# RF R2: 0.4519963994866406
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.854477749154263
# (170, 10)
# RF R2: 0.4406752981481845
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8557198768031247
# (180, 10)
# RF R2: 0.4751780324982331
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8600895370149857
# (190, 10)
# RF R2: 0.5038343582179357
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8564797178656282
# (200, 10)
# RF R2: 0.475678848618155
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8572673944835512
# (210, 10)
# RF R2: 0.49611921247158997
# Remaining: 143
# The Iteration is  4
# NN Test R2 with 5 samples -3.972131465044969
# After Initialization RF R2: 0.2647513237024165
# NN Test R2 after Initialization -3.796866960190828
# (10, 10)
# Query no. 1
# Embeddings training score: 0.9004262280496461
# (20, 10)
# RF R2: 0.27461910444266957
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8662625669796439
# (30, 10)
# RF R2: 0.42840316868714634
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8821274311518423
# (40, 10)
# RF R2: 0.5054890282017994
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8862035475445988
# (50, 10)
# RF R2: 0.39776323951807546
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8588699854600584
# (60, 10)
# RF R2: 0.49783990758319574
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8785108048556167
# (70, 10)
# RF R2: 0.5119123334254571
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8681787184912988
# (80, 10)
# RF R2: 0.48407851154360815
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8797506157166934
# (90, 10)
# RF R2: 0.527148807990629
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.886608993741122
# (100, 10)
# RF R2: 0.5218406671762811
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8710437496449799
# (110, 10)
# RF R2: 0.5657884549071962
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8847575532291624
# (120, 10)
# RF R2: 0.5492358906986577
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.884235419338069
# (130, 10)
# RF R2: 0.5318048522327913
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8807313755468393
# (140, 10)
# RF R2: 0.5318510325517477
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8967973016151566
# (150, 10)
# RF R2: 0.5401521856732177
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8985657290972914
# (160, 10)
# RF R2: 0.5523392242172007
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8893642512370852
# (170, 10)
# RF R2: 0.5477338155167069
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8809346998439774
# (180, 10)
# RF R2: 0.5573596749316189
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8868208830640167
# (190, 10)
# RF R2: 0.563850158472208
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8876580577930637
# (200, 10)
# RF R2: 0.5516280699700338
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.884869865771239
