# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from modAL.models import ActiveLearner, CommitteeRegressor
from modAL.disagreement import vote_entropy_sampling, max_std_sampling
import matplotlib.pyplot as plt
import torch
from torch.nn import MSELoss
from skorch.regressor import NeuralNetRegressor
from copy import deepcopy
from skorch.dataset import ValidSplit
from skorch.callbacks import EarlyStopping
from sklearn.cluster import DBSCAN, OPTICS, cluster_optics_dbscan, Birch, SpectralClustering
from sklearn.neighbors import NearestNeighbors
from sklearn import metrics
import matplotlib.gridspec as gridspec
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from torch.nn import Linear
from torch.nn import Sigmoid, ReLU
from torch.nn import Module
from sklearn.metrics import r2_score
import copy
from scipy.spatial import distance
from scipy.spatial.distance import euclidean
from torch import tensor
from sklearn.metrics import mean_squared_error
from scipy.spatial.distance import cdist
from sklearn.ensemble import RandomForestRegressor
from torch.nn.init import xavier_uniform_
from model import MLP
from model_state import get_model_params, get_input_for_hidden_layers, get_model_params_gradientNorm
from functions_batch1 import get_variance, qbc, normalization, error_reduct_fuc, total_disagrement, grad_norm, averaged_grad_norm, get_avg_grad_norm, training_loss
import random
from skorch.callbacks import EarlyStopping, LRScheduler, Freezer, Unfreezer
from torch.optim.lr_scheduler import CyclicLR, ReduceLROnPlateau
from skorch.regressor import NeuralNetRegressor, NeuralNet
from model_state import features_concat, learning_state_features_concat
import gc
import warnings
from modAL.utils.selection import multi_argmax
warnings.filterwarnings("ignore")

# %%
# Hyper-params:
query_number = 20          # The number of the AL Iterations in each Exp
iteration = 20             # Total number of the Exps
batch_size = 10
total_initail_size = 10
initial_size = 5
dimensions = 18   # Total dimension of the data features + model states

seed_rf = np.load(file="..\..\Datasets\Diabetes\seed_for_RF.npy")
seed_initial = np.load(file="..\..\Datasets\Diabetes\seed_for_initialSamples.npy")

# seed_nn1 = np.random.randint(100, size=100)
# seed_nn2 = np.random.randint(100, size=100)
# seed_nn3 = np.random.randint(100, size=100)
# seed_nn4 = np.random.randint(100, size=100)
# seed_nn5 = np.random.randint(100, size=100)
# seed_nn6 = np.random.randint(100, size=100)
# seed_predictor = np.random.randint(100, size=100)

seed_nn1 = np.load(file="..\..\Results\Res_Diabetes\OMAL\seed_for_nn1.npy")
seed_nn2 = np.load(file="..\..\Results\Res_Diabetes\OMAL\seed_for_nn2.npy")
seed_nn3 = np.load(file="..\..\Results\Res_Diabetes\OMAL\seed_for_nn3.npy")
seed_nn4 = np.load(file="..\..\Results\Res_Diabetes\OMAL\seed_for_nn4.npy")
seed_nn5 = np.load(file="..\..\Results\Res_Diabetes\OMAL\seed_for_nn5.npy")
seed_nn6 = np.load(file="..\..\Results\Res_Diabetes\OMAL\seed_for_nn6.npy")

seed_predictor = np.load(file="..\..\Results\Res_Diabetes\OMAL\seed_predictor.npy")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def Committee_Prediction(learner_list, X_test, y_test):
    initial_pred=[]
    for i in learner_list:
        initial_pred.append(r2_score(y_test, i.predict(X_test)))
    initial_pred=np.array(initial_pred)
    
    return initial_pred.mean()

# %%
def main_function(query_number, iters):
    # For saving results:
    rf_model_training_r2 = []
    rf_model_training_mse = []
    rf_model_testing_r2 = []
    rf_model_testing_mse = []
    
    # Number of member in committee:
    n_members = 3
    learner_list = []
    
    # The model for evaluation:
    rf_model = RandomForestRegressor(random_state=seed_rf[iters], n_estimators=100)
    gradient_norms = np.empty(shape=(0, 0))
    
    # Load the data:
    name1 = "..\..\Datasets\Diabetes\X_train" + str(iters) + ".npy"
    name2 = "..\..\Datasets\Diabetes\X_test" + str(iters) + ".npy"
    name3 = "..\..\Datasets\Diabetes\y_train" + str(iters) + ".npy"
    name4 = "..\..\Datasets\Diabetes\y_test" + str(iters) + ".npy"
    
    X_train = np.load(name1, allow_pickle=True).astype(np.float32)
    X_test = np.load(name2, allow_pickle=True).astype(np.float32)
    y_train = np.load(name3, allow_pickle=True).astype(np.float32).reshape(-1, 1)
    y_test = np.load(name4, allow_pickle=True).astype(np.float32).reshape(-1, 1)
    
    # Dimensionality of data:
    X = X_train.shape[1]
    # The index of the unlabeled pool:
    X_index = np.arange(X_train.shape[0])

    used_data = np.empty(shape=(0, X))
    used_label = np.empty(shape=(0)).reshape(-1, 1)

    X_initial = np.empty(shape=(0,X))
    y_initial = np.empty(shape=(0)).reshape(-1, 1)
    
    # Initial Stage 1:
    np.random.seed(seed_initial[iters])
    idx = np.random.choice(range(len(X_index)), size=initial_size, replace=False)
    train_idx = X_index[idx]

    X_initial = X_train[train_idx]
    y_initial = y_train[train_idx].reshape(-1, 1)

    used_data = np.append(used_data, X_initial, axis=0).astype(np.float32)
    used_label = np.append(used_label, y_initial, axis=0).astype(np.float32).reshape(-1, 1)
    X_index = np.delete(X_index, idx, axis=0)

    
    used_data = torch.from_numpy(used_data).to(device)
    used_label = torch.from_numpy(used_label).to(device)
    for member_idx in range(n_members):
        if member_idx == 0:
            np.random.seed(seed_nn1[iters])
            torch.manual_seed(seed_nn2[iters])
        if member_idx == 1:
            np.random.seed(seed_nn3[iters])
            torch.manual_seed(seed_nn4[iters])
        if member_idx == 2:
            np.random.seed(seed_nn5[iters])
            torch.manual_seed(seed_nn6[iters])
            
        regressor = NeuralNetRegressor(MLP(X),
                                   criterion=MSELoss(),
                                   optimizer=torch.optim.Adam,
                                   verbose=0,
                                   max_epochs=30,
                                   lr=0.001,
                                   # Used for the batch AL
                                   callbacks=[EarlyStopping(patience=5), ('lr_scheduler', LRScheduler(policy=ReduceLROnPlateau))],
                                   train_split=ValidSplit(cv=5),
                                   warm_start=True,
                                   device='cuda',
                                   batch_size = -1
                                   )
        regressor.fit(used_data, used_label)
        learner_list.append(regressor)
    
    print("NN Test R2 with 5 samples", Committee_Prediction(learner_list, X_test, y_test))

    # Number of LAL features:
    learning_state_features = np.empty(shape=(0, dimensions))
    loss_reduction_target = np.empty(shape=(0)).reshape(-1, 1)

    # other random samples:
    rest_initial_X = np.empty(shape=(0, X))
    rest_initial_y = np.empty(shape=(0)).reshape(-1, 1)

    # LAL Initialization: Stage 2
    predictor = RandomForestRegressor(n_estimators=1000, random_state=seed_predictor[iters])
    np.random.seed(seed_initial[iters])
    idx = np.random.choice(range(len(X_index)), size=total_initail_size-initial_size, replace=False)
    train_idx = X_index[idx]
    
    rest_initial_X = np.append(rest_initial_X, X_train[train_idx], axis=0).astype(np.float32)
    rest_initial_y = np.append(rest_initial_y, y_train[train_idx], axis=0).astype(np.float32).reshape(-1, 1)

    X_index = np.delete(X_index, idx, axis=0)

    for i in range(rest_initial_X.shape[0]):

        single_X = rest_initial_X[i],
        single_y = rest_initial_y[i].reshape(1, -1)
        single_X = single_X[0].reshape(1, -1)
        
        single_X = torch.from_numpy(single_X).to(device)
        single_y = torch.from_numpy(single_y).to(device)

        # Model params
        model_params = get_model_params_gradientNorm(learner_list)

        # updated data
        used_data = torch.cat((used_data, single_X), 0)
        used_label = torch.cat((used_label, single_y), 0)

        # Retrain the model:
        for l in learner_list:
            l.fit(X=used_data,y=used_label)
            
        single_X = single_X.cpu().numpy()
        single_y = single_y.cpu().numpy()
            
        index = train_idx[i]

        # The training sample:
        data_params = X_train[index]
      
        LALfeatures = features_concat(model_params, data_params)

        loss_reduction = get_avg_grad_norm(learner_list, single_X, single_y)
        
        learning_state_features = learning_state_features_concat(learning_state_features, LALfeatures)
        loss_reduction_target = np.append(loss_reduction_target, np.array([loss_reduction]).reshape(-1, 1), axis=0).astype(np.float32).reshape(-1, 1)

        
    used_data = used_data.cpu().numpy()
    used_label = used_label.cpu().numpy()

    # Finished the Initialization Stages:
    # RF Regressor for evaluation:
    rf_model.fit(used_data, used_label.ravel())
    # Training Scores:
    rf_training_r2 = r2_score(used_label, rf_model.predict(used_data))
    rf_training_mse = mean_squared_error(used_label, rf_model.predict(used_data))
    rf_model_training_r2.append(rf_training_r2)
    rf_model_training_mse.append(rf_training_mse)
    
    # Test Scores:
    rf_model_r2 = r2_score(y_test, rf_model.predict(X_test))
    rf_model_mse = mean_squared_error(y_test, rf_model.predict(X_test))
    rf_model_testing_r2.append(rf_model_r2)
    rf_model_testing_mse.append(rf_model_mse)
    
    print("After Initialization RF R2:", rf_model_r2)
    print("NN Test R2 after Initialization", Committee_Prediction(learner_list, X_test, y_test))

    print(np.unique(used_data, axis=0).shape)
    for idx in range(query_number):
        np.random.seed(None)
        print('Query no. %d' % (idx+1))

        Error_reduction_list, training_score = error_reduct_fuc(X_train, X_index, learner_list, learning_state_features, loss_reduction_target, X_index.shape[0], predictor)

        idx = multi_argmax(np.array(Error_reduction_list), n_instances=batch_size)
       
        X_train_indices = X_index[idx]
        
        # Update
        X_index = np.delete(X_index, idx, axis=0)

        for X_train_index in X_train_indices:

            new_X = X_train[X_train_index].reshape(1, -1)
            new_y = y_train[X_train_index].reshape(1, -1)
            
            used_data = np.append(used_data, new_X, axis=0).astype(np.float32)
            used_label = np.append(used_label, new_y, axis=0).astype(np.float32).reshape(-1, 1)
            
            used_data = torch.from_numpy(used_data).to(device)
            used_label = torch.from_numpy(used_label).to(device)

            # Model params
            model_params = get_model_params_gradientNorm(learner_list)
            data_params = X_train[X_train_index]
            LALfeatures = features_concat(model_params, data_params)
            
            for l in learner_list:
                l.fit(used_data, used_label)
            
            used_data = used_data.cpu().numpy()
            used_label = used_label.cpu().numpy()

            loss_reduction = get_avg_grad_norm(learner_list, new_X, new_y)  
            gradient_norms = np.append(gradient_norms, loss_reduction)
            
            learning_state_features = learning_state_features_concat(learning_state_features, LALfeatures)
            loss_reduction_target = np.append(loss_reduction_target, np.array([loss_reduction]).reshape(-1, 1), axis=0).astype(np.float32).reshape(-1, 1)
        

        # RF Evaluation
        rf_model.fit(used_data, used_label.ravel())
        
        # Training Evaluation:
        rf_training_r2 = r2_score(used_label, rf_model.predict(used_data))
        rf_training_mse = mean_squared_error(used_label, rf_model.predict(used_data))
        rf_model_training_r2.append(rf_training_r2)
        rf_model_training_mse.append(rf_training_mse)
        
        # Test Evaluation:
        rf_model_r2 = r2_score(y_test, rf_model.predict(X_test))
        rf_model_mse = mean_squared_error(y_test, rf_model.predict(X_test))
        rf_model_testing_r2.append(rf_model_r2)
        rf_model_testing_mse.append(rf_model_mse)

        print(np.unique(used_data, axis=0).shape)
        print("RF R2:", rf_model_r2)
        print("Remaining:", X_index.shape[0])
        # print('NN R2', Committee_Prediction(learner_list, X_test, y_test))

    # RF
    rf_model_testing_r2 = np.array(rf_model_testing_r2)
    rf_model_testing_mse = np.array(rf_model_testing_mse)
    rf_model_training_r2 = np.array(rf_model_training_r2)
    rf_model_training_mse = np.array(rf_model_training_mse)
    
    # Used_data and Unsed_label:
    np.save(file="..\..\Results\Res_Diabetes\OMAL2\Summary\\used_data" + str(iters) + ".npy", arr=used_data)
    np.save(file="..\..\Results\Res_Diabetes\OMAL2\Summary\\used_labels" + str(iters) + ".npy", arr=used_label)

    np.save(file="..\..\Results\Res_Diabetes\OMAL2\Summary\\testing_rf_r2_" + str(iters) + ".npy", arr=rf_model_testing_r2)
    np.save(file="..\..\Results\Res_Diabetes\OMAL2\Summary\\testing_rf_mse_" + str(iters) + ".npy", arr=rf_model_testing_mse)
    np.save(file="..\..\Results\Res_Diabetes\OMAL2\Summary\\training_rf_r2_" + str(iters) + ".npy", arr=rf_model_training_r2)
    np.save(file="..\..\Results\Res_Diabetes\OMAL2\Summary\\training_rf_mse_" + str(iters) + ".npy", arr=rf_model_training_mse)

# %%
for i in range(iteration):
    print("The Iteration is ", i)
    main_function(query_number, i)
# Out:
# The Iteration is  0
# NN Test R2 with 5 samples -3.28021599721637
# After Initialization RF R2: 0.01017105099476967
# NN Test R2 after Initialization -2.2746818828180646
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8813494906502684
# (20, 10)
# RF R2: 0.2768237671663045
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.9481263087459152
# (30, 10)
# RF R2: 0.24992994698595128
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.9184005364673238
# (40, 10)
# RF R2: 0.29856750104565977
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.902316434895725
# (50, 10)
# RF R2: 0.06781219284258555
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.893592800052193
# (60, 10)
# RF R2: 0.08713464484624533
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8982382991527685
# (70, 10)
# RF R2: 0.26829904261482584
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8877496244627467
# (80, 10)
# RF R2: 0.41238680866327826
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.9078347700331864
# (90, 10)
# RF R2: 0.44913697217774684
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.9115820104304586
# (100, 10)
# RF R2: 0.5467004322712585
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.9193578513012627
# (110, 10)
# RF R2: 0.5474950332930191
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.9157389089358253
# (120, 10)
# RF R2: 0.5296478446009452
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.9119641392263629
# (130, 10)
# RF R2: 0.5086773815825911
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.91154061591493
# (140, 10)
# RF R2: 0.5205179784258631
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.910181102822368
# (150, 10)
# RF R2: 0.47533723349114765
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.9098925480758329
# (160, 10)
# RF R2: 0.4939432781860704
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.9062972154975278
# (170, 10)
# RF R2: 0.469434621191527
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.9068594105560268
# (180, 10)
# RF R2: 0.44751255560264513
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.9070036223605176
# (190, 10)
# RF R2: 0.4454522147975001
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.9054686090325126
# (200, 10)
# RF R2: 0.4399262647815031
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.9055515965466474
# (210, 10)
# RF R2: 0.44033811426585723
# Remaining: 143
# The Iteration is  1
# NN Test R2 with 5 samples -3.7535652397506545
# After Initialization RF R2: 0.20844341964741697
# NN Test R2 after Initialization -0.5887113480592167
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8686517734002394
# (20, 10)
# RF R2: 0.22975663617835596
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8927234415519444
# (30, 10)
# RF R2: 0.2928913954515967
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8308119157521816
# (40, 10)
# RF R2: 0.47132822027683074
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8473708481547007
# (50, 10)
# RF R2: 0.5065382661462208
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8462109011006937
# (60, 10)
# RF R2: 0.4786814808591252
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8304999089393114
# (70, 10)
# RF R2: 0.38246477086397435
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8359972925182334
# (80, 10)
# RF R2: 0.3945776119264889
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8442440648963427
# (90, 10)
# RF R2: 0.4151008117001562
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8496238250612835
# (100, 10)
# RF R2: 0.31614412117796586
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8547276058526092
# (110, 10)
# RF R2: 0.35116717560948185
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.859731865769479
# (120, 10)
# RF R2: 0.38921218972865523
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8651594039438717
# (130, 10)
# RF R2: 0.4244310742332106
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8552699121876292
# (140, 10)
# RF R2: 0.4454816079443802
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8573749876320845
# (150, 10)
# RF R2: 0.45534442634585637
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8507477085793489
# (160, 10)
# RF R2: 0.4686710831251907
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8488854557663791
# (170, 10)
# RF R2: 0.4602016204293736
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8503602586873215
# (180, 10)
# RF R2: 0.4739074043909649
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8530153817178665
# (190, 10)
# RF R2: 0.47305407363718277
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8532245068936474
# (200, 10)
# RF R2: 0.4595711238144361
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8543707466476769
# (210, 10)
# RF R2: 0.4831520318715533
# Remaining: 143
# The Iteration is  2
# NN Test R2 with 5 samples -3.6664832316918834
# After Initialization RF R2: 0.2925063658507443
# NN Test R2 after Initialization -3.5816631216745134
# (10, 10)
# Query no. 1
# Embeddings training score: 0.858856154094302
# (20, 10)
# RF R2: 0.32479152357596985
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8238683325277697
# (30, 10)
# RF R2: 0.39359219868206796
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.906259427551905
# (40, 10)
# RF R2: 0.3424549075951524
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.9029845573824093
# (50, 10)
# RF R2: 0.37979849383997955
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.9078769931044297
# (60, 10)
# RF R2: 0.3045207664162679
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.9055132237820532
# (70, 10)
# RF R2: 0.3412020963528505
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8924656248976061
# (80, 10)
# RF R2: 0.38261821058726286
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8854459224550503
# (90, 10)
# RF R2: 0.47184364824176983
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8933538521148653
# (100, 10)
# RF R2: 0.46137998628738086
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8913614344901418
# (110, 10)
# RF R2: 0.43578225049594177
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8864719512666784
# (120, 10)
# RF R2: 0.37435938825836623
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8828934513969077
# (130, 10)
# RF R2: 0.3852400353938489
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8832753702635571
# (140, 10)
# RF R2: 0.3895269952913949
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8824247470475458
# (150, 10)
# RF R2: 0.4068424233274125
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8827663039781789
# (160, 10)
# RF R2: 0.37261553316000473
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8809996111935552
# (170, 10)
# RF R2: 0.42198511880012035
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8790482482151117
# (180, 10)
# RF R2: 0.4074881777719289
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.879850054612168
# (190, 10)
# RF R2: 0.4316030714704555
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8799640833428668
# (200, 10)
# RF R2: 0.4086540280273814
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8778893931396944
# (210, 10)
# RF R2: 0.4299143624238625
# Remaining: 143
# The Iteration is  3
# NN Test R2 with 5 samples -4.171290441829298
# After Initialization RF R2: 0.36481536421176197
# NN Test R2 after Initialization -3.878962036565749
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8408375089789424
# (20, 10)
# RF R2: 0.2164276116894397
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8153725949513029
# (30, 10)
# RF R2: 0.45991574627793463
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8294298164191856
# (40, 10)
# RF R2: 0.46858973408057325
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8307646768905308
# (50, 10)
# RF R2: 0.46754466643801273
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8352486893402435
# (60, 10)
# RF R2: 0.39821047700436174
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8341746375196804
# (70, 10)
# RF R2: 0.4161901773483805
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8214056365349207
# (80, 10)
# RF R2: 0.45867842377690515
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8276177843839463
# (90, 10)
# RF R2: 0.4737566798399555
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8379607638571971
# (100, 10)
# RF R2: 0.4799223872916948
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.836246446266516
# (110, 10)
# RF R2: 0.49765246844120536
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8454055294561005
# (120, 10)
# RF R2: 0.42458970323493905
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8392587864719977
# (130, 10)
# RF R2: 0.350613705571047
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8389556630333386
# (140, 10)
# RF R2: 0.28383637485616486
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8425119749559524
# (150, 10)
# RF R2: 0.33878939487991355
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.837518429618902
# (160, 10)
# RF R2: 0.40253534753959275
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.842070340031678
# (170, 10)
# RF R2: 0.39601354332105976
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8429320947552501
# (180, 10)
# RF R2: 0.3740270662040386
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8416766860332126
# (190, 10)
# RF R2: 0.3415567044462332
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8423688502042384
# (200, 10)
# RF R2: 0.3239907622484449
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.845582861737972
# (210, 10)
# RF R2: 0.3727068005770907
# Remaining: 143
# The Iteration is  4
# NN Test R2 with 5 samples -3.9868464711411282
# After Initialization RF R2: 0.2647513237024165
# NN Test R2 after Initialization -3.927528525603666
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8694808953350331
# (20, 10)
# RF R2: 0.3177586144176191
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8767405641897199
# (30, 10)
# RF R2: 0.4933695687446953
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.888915940805861
# (40, 10)
# RF R2: 0.4461474632202399
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8838038783660258
# (50, 10)
# RF R2: 0.36364544124890796
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8775916775346108
# (60, 10)
# RF R2: 0.5602644112604486
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8844421201250425
# (70, 10)
# RF R2: 0.5738076276017885
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.878504795168142
# (80, 10)
# RF R2: 0.5763292205494055
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8843554652599889
# (90, 10)
# RF R2: 0.5751138653847747
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8862063313358713
# (100, 10)
# RF R2: 0.5708536943087745
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8849038147680744
# (110, 10)
# RF R2: 0.5482520379951302
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8854250561405657
# (120, 10)
# RF R2: 0.534886129551385
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8861707762464703
# (130, 10)
# RF R2: 0.5449136672360892
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8865398953082401
# (140, 10)
# RF R2: 0.5481635219011899
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8934275189090372
# (150, 10)
# RF R2: 0.5812224867381416
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8913847612697832
# (160, 10)
# RF R2: 0.551847427543279
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.890245907331294
# (170, 10)
# RF R2: 0.5647384636182771
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8907329892631738
# (180, 10)
# RF R2: 0.5660602067537909
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8918819177565748
# (190, 10)
# RF R2: 0.42048531806198575
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8918227092825953
# (200, 10)
# RF R2: 0.4012209579513776
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8928132921594425
# (210, 10)
# RF R2: 0.39770448795206526
# Remaining: 143
# The Iteration is  5
# NN Test R2 with 5 samples -4.00054600692386
# After Initialization RF R2: 0.21088154412423232
# NN Test R2 after Initialization -1.1406267027282058
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8073415230085812
# (20, 10)
# RF R2: 0.13753774421045206
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8639446131064965
# (30, 10)
# RF R2: 0.2826140835062252
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.831898495554287
# (40, 10)
# RF R2: 0.3232186035309804
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.826420459256496
# (50, 10)
# RF R2: 0.4769236578211413
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8153112610034193
# (60, 10)
# RF R2: 0.5232268889054621
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8179096632073874
# (70, 10)
# RF R2: 0.5046205624536824
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8237104424831827
# (80, 10)
# RF R2: 0.5102635535799213
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8297481578746128
# (90, 10)
# RF R2: 0.48004963565696757
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8404316143052755
# (100, 10)
# RF R2: 0.49210988875515826
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8421793920486575
# (110, 10)
# RF R2: 0.5348077903775974
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8466458763675658
# (120, 10)
# RF R2: 0.5359392481593793
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8622571676255457
# (130, 10)
# RF R2: 0.5437255405228685
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8611462215556075
# (140, 10)
# RF R2: 0.5339860634182337
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8458091002106809
# (150, 10)
# RF R2: 0.5433816330976785
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8566419070773883
# (160, 10)
# RF R2: 0.5178469844750689
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8492912020617135
# (170, 10)
# RF R2: 0.5322896943176401
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.847943014819253
# (180, 10)
# RF R2: 0.5213607919854059
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8486983273979957
# (190, 10)
# RF R2: 0.5096630544547027
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8498220025842242
# (200, 10)
# RF R2: 0.5044891432369105
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8536029226879362
# (210, 10)
# RF R2: 0.4894722079153444
# Remaining: 143
# The Iteration is  6
# NN Test R2 with 5 samples -4.618774205385075
# After Initialization RF R2: 0.2874004649780366
# NN Test R2 after Initialization -1.3164475727650535
# (10, 10)
# Query no. 1
# Embeddings training score: 0.7884809388273978
# (20, 10)
# RF R2: 0.3250365722292743
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.885434119571465
# (30, 10)
# RF R2: 0.3332058751148227
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.924158066426959
# (40, 10)
# RF R2: 0.39720701761733956
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.9013214461931373
# (50, 10)
# RF R2: 0.40516748675473635
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8884608013212594
# (60, 10)
# RF R2: 0.39708290238413335
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8857453904119241
# (70, 10)
# RF R2: 0.40574240683193596
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8776674766012166
# (80, 10)
# RF R2: 0.40399763793813026
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8644894925485883
# (90, 10)
# RF R2: 0.38273995520620296
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8732621366286604
# (100, 10)
# RF R2: 0.38606987015942784
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8668605958377376
# (110, 10)
# RF R2: 0.40274881088030656
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8677054723238096
# (120, 10)
# RF R2: 0.38690446260143685
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8669624493695611
# (130, 10)
# RF R2: 0.38023085985852223
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8665774501124844
# (140, 10)
# RF R2: 0.36676932201592516
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8713648499156876
# (150, 10)
# RF R2: 0.36627789789953225
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.866499606885694
# (160, 10)
# RF R2: 0.37868399635828776
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8648221875232595
# (170, 10)
# RF R2: 0.372879455020636
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8663810053068025
# (180, 10)
# RF R2: 0.3497990075949926
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8680234647557505
# (190, 10)
# RF R2: 0.40210460348022226
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8690390345575048
# (200, 10)
# RF R2: 0.3872946053041859
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8707515245215718
# (210, 10)
# RF R2: 0.37973702306352264
# Remaining: 143
# The Iteration is  7
# NN Test R2 with 5 samples -4.935689322814922
# After Initialization RF R2: 0.19370117539677523
# NN Test R2 after Initialization -3.4944979679755606
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8416707380798839
# (20, 10)
# RF R2: 0.22206704469034821
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8435295830959775
# (30, 10)
# RF R2: 0.13860525276204572
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8447356593115045
# (40, 10)
# RF R2: 0.027937745001903047
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8410995407161932
# (50, 10)
# RF R2: -0.11006699920277674
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8449678120497849
# (60, 10)
# RF R2: 0.25345628106258766
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8498592578626613
# (70, 10)
# RF R2: 0.3862399685615141
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8485472278160917
# (80, 10)
# RF R2: 0.3460351265748619
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8512834606996476
# (90, 10)
# RF R2: 0.367591298848042
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.849263169918213
# (100, 10)
# RF R2: 0.33621095928417677
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8522660802987929
# (110, 10)
# RF R2: 0.3344006047599034
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8548350172888087
# (120, 10)
# RF R2: 0.3480179178294679
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8573086805332822
# (130, 10)
# RF R2: 0.3820203619200423
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8435614507070216
# (140, 10)
# RF R2: 0.4138760940071179
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8607709524880698
# (150, 10)
# RF R2: 0.4047734811022249
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8555825907978009
# (160, 10)
# RF R2: 0.402965657943785
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8480181290831188
# (170, 10)
# RF R2: 0.437103322525469
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8531785367692035
# (180, 10)
# RF R2: 0.46584103397554266
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.85110118269234
# (190, 10)
# RF R2: 0.44774468741660456
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8532987143077806
# (200, 10)
# RF R2: 0.46188443938592216
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8531012435035441
# (210, 10)
# RF R2: 0.4333364668209464
# Remaining: 143
# The Iteration is  8
# NN Test R2 with 5 samples -3.405791707218531
# After Initialization RF R2: 0.37592722084430563
# NN Test R2 after Initialization -0.7685517574543678
# (10, 10)
# Query no. 1
# Embeddings training score: 0.7602065457599273
# (20, 10)
# RF R2: 0.36038948331674225
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8474896360639276
# (30, 10)
# RF R2: 0.49812415725969417
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8487075724087436
# (40, 10)
# RF R2: 0.4789989507686643
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8550533124037208
# (50, 10)
# RF R2: 0.5755296843475897
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8740658346491508
# (60, 10)
# RF R2: 0.5633600192407967
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8505570261312567
# (70, 10)
# RF R2: 0.6230825983017263
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8433149285864687
# (80, 10)
# RF R2: 0.5926650927076382
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8382046527424513
# (90, 10)
# RF R2: 0.5841712130641735
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.84556001708916
# (100, 10)
# RF R2: 0.6198759343687352
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8465037818078903
# (110, 10)
# RF R2: 0.5954474997886885
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8518792540083817
# (120, 10)
# RF R2: 0.6060703769563682
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8468282734358413
# (130, 10)
# RF R2: 0.6179071273902833
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8470854144527624
# (140, 10)
# RF R2: 0.6111926318350289
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8514354992202038
# (150, 10)
# RF R2: 0.6093098235261353
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8472224394380362
# (160, 10)
# RF R2: 0.6138463827625141
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.847504896637447
# (170, 10)
# RF R2: 0.6253574545227181
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8492278841981855
# (180, 10)
# RF R2: 0.6066652377030735
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.851391313947139
# (190, 10)
# RF R2: 0.6299453025805326
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8521426346207345
# (200, 10)
# RF R2: 0.5956358163197832
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8462827073253179
# (210, 10)
# RF R2: 0.6114951864977933
# Remaining: 143
# The Iteration is  9
# NN Test R2 with 5 samples -4.395268896182778
# After Initialization RF R2: 0.035649981461895575
# NN Test R2 after Initialization -2.493276181025848
# (10, 10)
# Query no. 1
# Embeddings training score: 0.9083212811973607
# (20, 10)
# RF R2: 0.24492492656199283
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.897694493820987
# (30, 10)
# RF R2: 0.20893096532023503
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8948845289490621
# (40, 10)
# RF R2: 0.2512229768519162
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8730354694195939
# (50, 10)
# RF R2: 0.2852584674451776
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8520846147791965
# (60, 10)
# RF R2: 0.2688937037845507
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8525111090104073
# (70, 10)
# RF R2: 0.266134445945174
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8572039232906025
# (80, 10)
# RF R2: 0.345966040666006
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8554496370332838
# (90, 10)
# RF R2: 0.3287946808346448
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8628890383079177
# (100, 10)
# RF R2: 0.2982296647497904
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8529292795308399
# (110, 10)
# RF R2: 0.28963341857584024
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8628502246499788
# (120, 10)
# RF R2: 0.37459908210645787
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8514019149381666
# (130, 10)
# RF R2: 0.2926684631176574
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8603158263699594
# (140, 10)
# RF R2: 0.3505503380173405
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8657966436290663
# (150, 10)
# RF R2: 0.3921703985312841
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8633401492621025
# (160, 10)
# RF R2: 0.35524428660573815
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.868692737875169
# (170, 10)
# RF R2: 0.40472359700408855
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8723805736669145
# (180, 10)
# RF R2: 0.40639501419019475
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8670449599795844
# (190, 10)
# RF R2: 0.38117383785177406
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8583979149631887
# (200, 10)
# RF R2: 0.3524280674817205
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.858253666487024
# (210, 10)
# RF R2: 0.3410106941771135
# Remaining: 143
# The Iteration is  10
# NN Test R2 with 5 samples -3.798379032322888
# After Initialization RF R2: 0.23162437973863492
# NN Test R2 after Initialization -0.753603829239127
# (10, 10)
# Query no. 1
# Embeddings training score: 0.7970337542791397
# (20, 10)
# RF R2: 0.14234679445116172
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.7888739088534358
# (30, 10)
# RF R2: -0.012430985125558625
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.7972571069445575
# (40, 10)
# RF R2: 0.3118945499768988
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8250729588414768
# (50, 10)
# RF R2: 0.3534291260618706
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8364170404081152
# (60, 10)
# RF R2: 0.38399312974786937
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8375286547639342
# (70, 10)
# RF R2: 0.3667031071830814
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8392218372191789
# (80, 10)
# RF R2: 0.34871383742639994
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8451184346991532
# (90, 10)
# RF R2: 0.3568496283299104
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8518325342853609
# (100, 10)
# RF R2: 0.3011265610630217
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8662509725531051
# (110, 10)
# RF R2: 0.3674315553253592
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8614105006130627
# (120, 10)
# RF R2: 0.3973047043132816
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8627251840572447
# (130, 10)
# RF R2: 0.4014671140624376
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8655424819087008
# (140, 10)
# RF R2: 0.3841984065078268
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8628885242889741
# (150, 10)
# RF R2: 0.3945240195037514
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8593644759789634
# (160, 10)
# RF R2: 0.41603864616230146
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8626083554953803
# (170, 10)
# RF R2: 0.40562686996806985
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.862082274718681
# (180, 10)
# RF R2: 0.44191372490670655
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8705284632765595
# (190, 10)
# RF R2: 0.4661648016135399
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.869693880629166
# (200, 10)
# RF R2: 0.48110836478026786
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8703391122660301
# (210, 10)
# RF R2: 0.47812989549207796
# Remaining: 143
# The Iteration is  11
# NN Test R2 with 5 samples -4.7989268485492085
# After Initialization RF R2: 0.21259635230652096
# NN Test R2 after Initialization -3.3556114821573337
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8906667169770682
# (20, 10)
# RF R2: 0.28955718774447303
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8420034472494325
# (30, 10)
# RF R2: 0.2744373054087961
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8139571641294634
# (40, 10)
# RF R2: 0.27957999308845416
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.850782165321462
# (50, 10)
# RF R2: 0.28945723932573986
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8530223812268267
# (60, 10)
# RF R2: 0.29923213720781916
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8652064534199422
# (70, 10)
# RF R2: 0.30090457659433967
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8453385866464955
# (80, 10)
# RF R2: 0.33273071303731105
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8574138657518702
# (90, 10)
# RF R2: 0.2954497793554378
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8570559853265549
# (100, 10)
# RF R2: 0.330490347212006
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.861463551085962
# (110, 10)
# RF R2: 0.3797248637941353
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8668352469419464
# (120, 10)
# RF R2: 0.39166599033804106
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8604069682804811
# (130, 10)
# RF R2: 0.428100280899375
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8597101596469534
# (140, 10)
# RF R2: 0.3598241040643382
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8562477965029357
# (150, 10)
# RF R2: 0.2998806367853456
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8591518956248752
# (160, 10)
# RF R2: 0.3429547356023642
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8530688995193767
# (170, 10)
# RF R2: 0.38672719862537264
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8562493757055725
# (180, 10)
# RF R2: 0.34077820466740694
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8549225863623848
# (190, 10)
# RF R2: 0.38204004407839753
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8569157550765699
# (200, 10)
# RF R2: 0.34829354015177205
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8618848331016297
# (210, 10)
# RF R2: 0.3835342513246415
# Remaining: 143
# The Iteration is  12
# NN Test R2 with 5 samples -4.16191316858388
# After Initialization RF R2: 0.06185382460298916
# NN Test R2 after Initialization -1.4199640849003081
# (10, 10)
# Query no. 1
# Embeddings training score: 0.7645989884278565
# (20, 10)
# RF R2: -0.0003110343936172377
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8092445161345752
# (30, 10)
# RF R2: 0.14510635853774734
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8739867013670221
# (40, 10)
# RF R2: 0.19720756972051745
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8463681810404725
# (50, 10)
# RF R2: 0.21932598065801534
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8507360382116327
# (60, 10)
# RF R2: 0.16996546570108817
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.847296656034099
# (70, 10)
# RF R2: 0.22102434983397423
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8414170203361897
# (80, 10)
# RF R2: 0.23911348698983736
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8514758325811718
# (90, 10)
# RF R2: 0.3089377650609635
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8251527194805294
# (100, 10)
# RF R2: 0.3029126005378304
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8295430580060923
# (110, 10)
# RF R2: 0.3725950767785663
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8267643407544164
# (120, 10)
# RF R2: 0.4058312381997864
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8272609107689674
# (130, 10)
# RF R2: 0.39806915418020705
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.833218267752575
# (140, 10)
# RF R2: 0.4251044925487295
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.838058657945477
# (150, 10)
# RF R2: 0.43412022021843766
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8367151696362665
# (160, 10)
# RF R2: 0.4277338261313476
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8425540265622115
# (170, 10)
# RF R2: 0.422109123539674
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8361789641328367
# (180, 10)
# RF R2: 0.41520261226229693
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8347254293086492
# (190, 10)
# RF R2: 0.4081844501310742
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8400222246303314
# (200, 10)
# RF R2: 0.41030433009584866
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8426904565410573
# (210, 10)
# RF R2: 0.42200598757863506
# Remaining: 143
# The Iteration is  13
# NN Test R2 with 5 samples -3.866964565834896
# After Initialization RF R2: 0.10976834507123645
# NN Test R2 after Initialization -0.7405702723134001
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8009344149514945
# (20, 10)
# RF R2: 0.39880836933521113
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.9012415390785132
# (30, 10)
# RF R2: 0.4285784614431688
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.881250109256305
# (40, 10)
# RF R2: 0.4599675558381051
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.854043204496691
# (50, 10)
# RF R2: 0.48562239847145083
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8637546591386965
# (60, 10)
# RF R2: 0.4919368682118218
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8488398831245825
# (70, 10)
# RF R2: 0.506306570892157
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8654577138531143
# (80, 10)
# RF R2: 0.496741747125814
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8678310140848031
# (90, 10)
# RF R2: 0.5123726106154713
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8659595095206728
# (100, 10)
# RF R2: 0.44603568597375365
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.865168009701891
# (110, 10)
# RF R2: 0.4440537531739893
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.86573446953883
# (120, 10)
# RF R2: 0.3982881985452147
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8648847384411832
# (130, 10)
# RF R2: 0.4124279630222363
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8674836368792939
# (140, 10)
# RF R2: 0.4016702613079013
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8698261161992975
# (150, 10)
# RF R2: 0.38315911049359286
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.862862037158185
# (160, 10)
# RF R2: 0.3848701780688528
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8653193088330399
# (170, 10)
# RF R2: 0.40717289787359223
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8656145806789669
# (180, 10)
# RF R2: 0.41387745996151026
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8674747845507101
# (190, 10)
# RF R2: 0.4043568701426047
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8662149725828613
# (200, 10)
# RF R2: 0.37928145738626606
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8620097159949086
# (210, 10)
# RF R2: 0.36885004495148155
# Remaining: 143
# The Iteration is  14
# NN Test R2 with 5 samples -3.4992666076673444
# After Initialization RF R2: 0.21875949583564513
# NN Test R2 after Initialization -1.3960681428494033
# (10, 10)
# Query no. 1
# Embeddings training score: 0.7901003317791924
# (20, 10)
# RF R2: 0.24720539162793875
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8568803251637851
# (30, 10)
# RF R2: 0.41068586636135795
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8874766063279828
# (40, 10)
# RF R2: 0.42534415192005803
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8609361026192391
# (50, 10)
# RF R2: 0.39434523348055683
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.839904668898339
# (60, 10)
# RF R2: 0.34384167569382373
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8335026851436962
# (70, 10)
# RF R2: 0.3476472000651133
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8364784280199115
# (80, 10)
# RF R2: 0.4095283550839749
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8384301223138043
# (90, 10)
# RF R2: 0.35579124214244917
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8403490805250184
# (100, 10)
# RF R2: 0.4061582831922793
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8428970921110707
# (110, 10)
# RF R2: 0.4523195126724189
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8389965659758374
# (120, 10)
# RF R2: 0.419733415432638
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.834332217076631
# (130, 10)
# RF R2: 0.36590363882365284
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.835007452844407
# (140, 10)
# RF R2: 0.3717708817570403
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8372672663625993
# (150, 10)
# RF R2: 0.36504893248864756
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8477849657349965
# (160, 10)
# RF R2: 0.3665127155825576
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8513763338548448
# (170, 10)
# RF R2: 0.38048673588922444
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8510883462966294
# (180, 10)
# RF R2: 0.3125957426264879
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8511419035806601
# (190, 10)
# RF R2: 0.3397759309749514
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8476474271835608
# (200, 10)
# RF R2: 0.3713998819113563
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8476656814252834
# (210, 10)
# RF R2: 0.3458893006453325
# Remaining: 143
# The Iteration is  15
# NN Test R2 with 5 samples -4.264688995963476
# After Initialization RF R2: 0.20777385009743188
# NN Test R2 after Initialization -2.0022628356158942
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8056536654884585
# (20, 10)
# RF R2: 0.13460337436770287
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8757546141324015
# (30, 10)
# RF R2: 0.16264210203373397
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.879198460835847
# (40, 10)
# RF R2: 0.11979937144708941
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8591972728825363
# (50, 10)
# RF R2: 0.25687580837568125
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.887103540694612
# (60, 10)
# RF R2: 0.29052826747597016
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8786211743567154
# (70, 10)
# RF R2: 0.3050960151846024
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8772448412134959
# (80, 10)
# RF R2: 0.28385138665048104
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8744494252077393
# (90, 10)
# RF R2: 0.35727964021623493
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.877307743814121
# (100, 10)
# RF R2: 0.3316393336271688
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8788265158441685
# (110, 10)
# RF R2: 0.32361646906502795
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8748286416539984
# (120, 10)
# RF R2: 0.3470991068175645
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8711036713732809
# (130, 10)
# RF R2: 0.35122145656620773
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8660519453934924
# (140, 10)
# RF R2: 0.3913164481950344
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8693350333339469
# (150, 10)
# RF R2: 0.39091585065081524
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8727752544132678
# (160, 10)
# RF R2: 0.3738007400328782
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8712016521588473
# (170, 10)
# RF R2: 0.38970301207485447
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8723014421495001
# (180, 10)
# RF R2: 0.39626660465102637
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8612641978622202
# (190, 10)
# RF R2: 0.3972672486794252
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.862045345299184
# (200, 10)
# RF R2: 0.4148062320361393
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8600651243023568
# (210, 10)
# RF R2: 0.42098200412781495
# Remaining: 143
# The Iteration is  16
# NN Test R2 with 5 samples -3.4440115257070882
# After Initialization RF R2: 0.3788951332013627
# NN Test R2 after Initialization -2.8628070790113154
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8931816027845813
# (20, 10)
# RF R2: 0.47142839612918175
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.9336265184408346
# (30, 10)
# RF R2: 0.43533551083429545
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8373091312807625
# (40, 10)
# RF R2: 0.4430036681304371
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8632031118054376
# (50, 10)
# RF R2: 0.39963641117882
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8609213722665204
# (60, 10)
# RF R2: 0.43142885830337685
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8630504084382815
# (70, 10)
# RF R2: 0.3853642540066291
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8710095458608353
# (80, 10)
# RF R2: 0.3727353728298822
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8675176843612362
# (90, 10)
# RF R2: 0.4080886433695933
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8723107749164583
# (100, 10)
# RF R2: 0.4872817484559281
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8714110549928354
# (110, 10)
# RF R2: 0.49495773491593975
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8725914469000702
# (120, 10)
# RF R2: 0.5120457940299907
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8727376145740314
# (130, 10)
# RF R2: 0.5355848866979507
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8714316120581848
# (140, 10)
# RF R2: 0.487686477068924
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8723041947105689
# (150, 10)
# RF R2: 0.47575515503443544
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8690312568607709
# (160, 10)
# RF R2: 0.4967481696681373
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8687323273436156
# (170, 10)
# RF R2: 0.5149012699776041
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.868935784399006
# (180, 10)
# RF R2: 0.5070360042658366
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8670023083633149
# (190, 10)
# RF R2: 0.5281357265932518
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.865922031963567
# (200, 10)
# RF R2: 0.5212228542249835
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8631411925643369
# (210, 10)
# RF R2: 0.5236664852147157
# Remaining: 143
# The Iteration is  17
# NN Test R2 with 5 samples -3.532648868410611
# After Initialization RF R2: 0.27409988635854254
# NN Test R2 after Initialization -2.3800411587428756
# (10, 10)
# Query no. 1
# Embeddings training score: 0.7832139054768115
# (20, 10)
# RF R2: 0.2528820601863576
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8843252831343984
# (30, 10)
# RF R2: 0.18045821688651253
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8836162592398978
# (40, 10)
# RF R2: 0.3856778924578097
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8970644930153687
# (50, 10)
# RF R2: 0.32881228448868627
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8751513664475227
# (60, 10)
# RF R2: 0.46732603422707397
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8704126667382451
# (70, 10)
# RF R2: 0.41075185061176045
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8564157957046651
# (80, 10)
# RF R2: 0.4308312075564543
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8553445287447994
# (90, 10)
# RF R2: 0.40213933176735006
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8518322164175371
# (100, 10)
# RF R2: 0.39938969000183777
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8513715909814705
# (110, 10)
# RF R2: 0.4476109285159483
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8452019353547378
# (120, 10)
# RF R2: 0.39747160564106854
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8453902671147073
# (130, 10)
# RF R2: 0.42965231702499396
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8465937013893484
# (140, 10)
# RF R2: 0.47923990237202496
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8463824183531636
# (150, 10)
# RF R2: 0.46794426368061215
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8435912875088689
# (160, 10)
# RF R2: 0.47359047164735957
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8479376973105561
# (170, 10)
# RF R2: 0.48132352808437817
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8606623175835977
# (180, 10)
# RF R2: 0.4526737214400619
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.860163116987889
# (190, 10)
# RF R2: 0.42260055121985984
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.860263352372599
# (200, 10)
# RF R2: 0.4588199116772478
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8641082683136792
# (210, 10)
# RF R2: 0.4752725707357437
# Remaining: 143
# The Iteration is  18
# NN Test R2 with 5 samples -4.199453752197603
# After Initialization RF R2: 0.19165785697079374
# NN Test R2 after Initialization -2.0862489299506994
# (10, 10)
# Query no. 1
# Embeddings training score: 0.78563794261198
# (20, 10)
# RF R2: 0.18762650566416494
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8495537097100607
# (30, 10)
# RF R2: 0.17855109980886608
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8386920733209587
# (40, 10)
# RF R2: 0.22103393929255033
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.837075081745709
# (50, 10)
# RF R2: 0.32402760436821665
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8454656726457103
# (60, 10)
# RF R2: 0.2790177351942975
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8407310154959655
# (70, 10)
# RF R2: 0.26536401949501587
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8413612007022837
# (80, 10)
# RF R2: 0.2749595966983812
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8580147693645547
# (90, 10)
# RF R2: 0.3131383168026308
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8556976055459465
# (100, 10)
# RF R2: 0.3311892080075204
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8501112805075841
# (110, 10)
# RF R2: 0.3484756449278259
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.851479969831551
# (120, 10)
# RF R2: 0.3367185086009091
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8520067032256808
# (130, 10)
# RF R2: 0.3600405089618496
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8476224518327294
# (140, 10)
# RF R2: 0.3750933596859216
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8461991223217786
# (150, 10)
# RF R2: 0.40134348683766363
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8463666576216886
# (160, 10)
# RF R2: 0.3778381058235838
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8483605106293324
# (170, 10)
# RF R2: 0.40651307518301516
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8478844838214702
# (180, 10)
# RF R2: 0.39110067001063276
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8490570129069243
# (190, 10)
# RF R2: 0.3920057022753397
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8510094472809384
# (200, 10)
# RF R2: 0.35541769868070006
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8545170726930892
# (210, 10)
# RF R2: 0.3867650045824834
# Remaining: 143
# The Iteration is  19
# NN Test R2 with 5 samples -4.366480033215027
# After Initialization RF R2: 0.2592937559558306
# NN Test R2 after Initialization -2.077254517508454
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8560595561125388
# (20, 10)
# RF R2: 0.30228167114047466
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8131992447667522
# (30, 10)
# RF R2: 0.35119033161610524
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8299639636564267
# (40, 10)
# RF R2: 0.34391159607522714
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8313279598490001
# (50, 10)
# RF R2: 0.288953789893423
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8483692648405317
# (60, 10)
# RF R2: 0.32556787415521515
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8617240561333858
# (70, 10)
# RF R2: 0.37885210226941524
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8792088437417731
# (80, 10)
# RF R2: 0.36532137275110477
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8766817698165454
# (90, 10)
# RF R2: 0.35277079102773523
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8725376739187518
# (100, 10)
# RF R2: 0.31593937753257484
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8709109564774146
# (110, 10)
# RF R2: 0.33117734370886
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8707144535994709
# (120, 10)
# RF R2: 0.2830673671294539
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8736477947558181
# (130, 10)
# RF R2: 0.32046068596179167
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8716023913892389
# (140, 10)
# RF R2: 0.28111054322879225
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8668447902890131
# (150, 10)
# RF R2: 0.3005699149086398
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8618995001683014
# (160, 10)
# RF R2: 0.31173910915265335
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8711740166194234
# (170, 10)
# RF R2: 0.31289002323884707
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8635409714631325
# (180, 10)
# RF R2: 0.27753505560298763
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8622644017223451
# (190, 10)
# RF R2: 0.275896830514186
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8667653412763718
# (200, 10)
# RF R2: 0.32166607963205995
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8538070260588648
# (210, 10)
# RF R2: 0.29029041554218094
# Remaining: 143
