# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from modAL.models import ActiveLearner, CommitteeRegressor
from modAL.disagreement import vote_entropy_sampling, max_std_sampling
import matplotlib.pyplot as plt
import torch
from torch.nn import MSELoss
from skorch.regressor import NeuralNetRegressor
from copy import deepcopy
from skorch.dataset import ValidSplit
from skorch.callbacks import EarlyStopping
from sklearn.cluster import DBSCAN, OPTICS, cluster_optics_dbscan, Birch, SpectralClustering
from sklearn.neighbors import NearestNeighbors
from sklearn import metrics
import matplotlib.gridspec as gridspec
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from torch.nn import Linear
from torch.nn import Sigmoid, ReLU
from torch.nn import Module
from sklearn.metrics import r2_score
import copy
from scipy.spatial import distance
from scipy.spatial.distance import euclidean
from torch import tensor
from sklearn.metrics import mean_squared_error
from scipy.spatial.distance import cdist
from sklearn.ensemble import RandomForestRegressor
from torch.nn.init import xavier_uniform_
from model import MLP
from model_state import get_model_params, get_input_for_hidden_layers, get_model_params_gradientNorm
from functions_batch1 import get_variance, qbc, normalization, error_reduct_fuc, total_disagrement, grad_norm, averaged_grad_norm, get_avg_grad_norm, training_loss
import random
from skorch.callbacks import EarlyStopping, LRScheduler, Freezer, Unfreezer
from torch.optim.lr_scheduler import CyclicLR, ReduceLROnPlateau
from skorch.regressor import NeuralNetRegressor, NeuralNet
from model_state import features_concat, learning_state_features_concat
import gc
import warnings
from modAL.utils.selection import multi_argmax
warnings.filterwarnings("ignore")

# %%
# Hyper-params:
query_number = 25          # The number of the AL Iterations in each Exp
iteration = 20             # Total number of the Exps
batch_size = 40
total_initail_size = 38
initial_size = 5
dimensions = 19   # Total dimension of the data features + model states

seed_rf = np.load(file="..\..\seed2.npy")
seed_initial = np.load(file="..\..\seed3.npy")

seed_nn1 = np.load(file="..\..\seed4.npy")
seed_nn2 = np.load(file="..\..\seed4.npy")
seed_nn3 = np.load(file="..\..\seed5.npy")
seed_nn4 = np.load(file="..\..\seed5.npy")
seed_nn5 = np.load(file="..\..\seed6.npy")
seed_nn6 = np.load(file="..\..\seed6.npy")

seed_predictor = np.load(file="..\..\seed7.npy")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def Committee_Prediction(learner_list, X_test, y_test):
    initial_pred=[]
    for i in learner_list:
        initial_pred.append(r2_score(y_test, i.predict(X_test)))
    initial_pred=np.array(initial_pred)
    
    return initial_pred.mean()

# %%
def main_function(query_number, iters):
    # For saving results:
    rf_model_training_r2 = []
    rf_model_training_mse = []
    rf_model_testing_r2 = []
    rf_model_testing_mse = []
    
    # Number of member in committee:
    n_members = 3
    learner_list = []
    
    # The model for evaluation:
    rf_model = RandomForestRegressor(random_state=seed_rf[iters], n_estimators=100)
    gradient_norms = np.empty(shape=(0, 0))
    
    # Load the data:
    name1 = "..\..\Datasets\RedWine\X_train" + str(iters) + ".npy"
    name2 = "..\..\Datasets\RedWine\X_test" + str(iters) + ".npy"
    name3 = "..\..\Datasets\RedWine\y_train" + str(iters) + ".npy"
    name4 = "..\..\Datasets\RedWine\y_test" + str(iters) + ".npy"
    
    X_train = np.load(name1, allow_pickle=True).astype(np.float32)
    X_test = np.load(name2, allow_pickle=True).astype(np.float32)
    y_train = np.load(name3, allow_pickle=True).astype(np.float32).reshape(-1, 1)
    y_test = np.load(name4, allow_pickle=True).astype(np.float32).reshape(-1, 1)
    
    # Dimensionality of data:
    X = X_train.shape[1]
    # The index of the unlabeled pool:
    X_index = np.arange(X_train.shape[0])

    used_data = np.empty(shape=(0, X))
    used_label = np.empty(shape=(0)).reshape(-1, 1)

    X_initial = np.empty(shape=(0,X))
    y_initial = np.empty(shape=(0)).reshape(-1, 1)
    
    # Initial Stage 1:
    np.random.seed(seed_initial[iters])
    idx = np.random.choice(range(len(X_index)), size=initial_size, replace=False)
    train_idx = X_index[idx]

    X_initial = X_train[train_idx]
    y_initial = y_train[train_idx].reshape(-1, 1)

    used_data = np.append(used_data, X_initial, axis=0).astype(np.float32)
    used_label = np.append(used_label, y_initial, axis=0).astype(np.float32).reshape(-1, 1)
    X_index = np.delete(X_index, idx, axis=0)

    
    used_data = torch.from_numpy(used_data).to(device)
    used_label = torch.from_numpy(used_label).to(device)
    for member_idx in range(n_members):
        if member_idx == 0:
            np.random.seed(seed_nn1[iters])
            torch.manual_seed(seed_nn2[iters])
        if member_idx == 1:
            np.random.seed(seed_nn3[iters])
            torch.manual_seed(seed_nn4[iters])
        if member_idx == 2:
            np.random.seed(seed_nn5[iters])
            torch.manual_seed(seed_nn6[iters])
            
        regressor = NeuralNetRegressor(MLP(X),
                                   criterion=MSELoss(),
                                   optimizer=torch.optim.Adam,
                                   verbose=0,
                                   max_epochs=30,
                                   lr=0.001,
                                   # Used for the batch AL
                                   callbacks=[EarlyStopping(patience=5), ('lr_scheduler', LRScheduler(policy=ReduceLROnPlateau))],
                                   train_split=ValidSplit(cv=5),
                                   warm_start=True,
                                   device='cuda',
                                   batch_size = 200
                                   )
        regressor.fit(used_data, used_label)
        learner_list.append(regressor)
    
    print("NN Test R2 with 5 samples", Committee_Prediction(learner_list, X_test, y_test))

    # Number of LAL features:
    learning_state_features = np.empty(shape=(0, dimensions))
    loss_reduction_target = np.empty(shape=(0)).reshape(-1, 1)

    # other random samples:
    rest_initial_X = np.empty(shape=(0, X))
    rest_initial_y = np.empty(shape=(0)).reshape(-1, 1)

    # LAL Initialization: Stage 2
    predictor = RandomForestRegressor(n_estimators=1000, random_state=seed_predictor[iters])
    np.random.seed(seed_initial[iters])
    idx = np.random.choice(range(len(X_index)), size=total_initail_size-initial_size, replace=False)
    train_idx = X_index[idx]
    
    rest_initial_X = np.append(rest_initial_X, X_train[train_idx], axis=0).astype(np.float32)
    rest_initial_y = np.append(rest_initial_y, y_train[train_idx], axis=0).astype(np.float32).reshape(-1, 1)

    X_index = np.delete(X_index, idx, axis=0)

    for i in range(rest_initial_X.shape[0]):

        single_X = rest_initial_X[i],
        single_y = rest_initial_y[i].reshape(1, -1)
        single_X = single_X[0].reshape(1, -1)
        
        single_X = torch.from_numpy(single_X).to(device)
        single_y = torch.from_numpy(single_y).to(device)

        # Model params
        model_params = get_model_params_gradientNorm(learner_list)

        # updated data
        used_data = torch.cat((used_data, single_X), 0)
        used_label = torch.cat((used_label, single_y), 0)

        # Retrain the model:
        for l in learner_list:
            l.fit(X=used_data,y=used_label)
            
        single_X = single_X.cpu().numpy()
        single_y = single_y.cpu().numpy()
            
        index = train_idx[i]

        # The training sample:
        data_params = X_train[index]
      
        LALfeatures = features_concat(model_params, data_params)

        loss_reduction = get_avg_grad_norm(learner_list, single_X, single_y)
        
        learning_state_features = learning_state_features_concat(learning_state_features, LALfeatures)
        loss_reduction_target = np.append(loss_reduction_target, np.array([loss_reduction]).reshape(-1, 1), axis=0).astype(np.float32).reshape(-1, 1)

        
    used_data = used_data.cpu().numpy()
    used_label = used_label.cpu().numpy()

    # Finished the Initialization Stages:
    # RF Regressor for evaluation:
    rf_model.fit(used_data, used_label.ravel())
    # Training Scores:
    rf_training_r2 = r2_score(used_label, rf_model.predict(used_data))
    rf_training_mse = mean_squared_error(used_label, rf_model.predict(used_data))
    rf_model_training_r2.append(rf_training_r2)
    rf_model_training_mse.append(rf_training_mse)
    
    # Test Scores:
    rf_model_r2 = r2_score(y_test, rf_model.predict(X_test))
    rf_model_mse = mean_squared_error(y_test, rf_model.predict(X_test))
    rf_model_testing_r2.append(rf_model_r2)
    rf_model_testing_mse.append(rf_model_mse)
    
    print("After Initialization RF R2:", rf_model_r2)
    print("NN Test R2 after Initialization", Committee_Prediction(learner_list, X_test, y_test))

    print(np.unique(used_data, axis=0).shape)
    for idx in range(query_number):
        np.random.seed(None)
        print('Query no. %d' % (idx+1))

        Error_reduction_list, training_score = error_reduct_fuc(X_train, X_index, learner_list, learning_state_features, loss_reduction_target, X_index.shape[0], predictor)

        idx = multi_argmax(np.array(Error_reduction_list), n_instances=batch_size)
       
        X_train_indices = X_index[idx]
        
        # Update
        X_index = np.delete(X_index, idx, axis=0)

        for X_train_index in X_train_indices:

            new_X = X_train[X_train_index].reshape(1, -1)
            new_y = y_train[X_train_index].reshape(1, -1)
            
            used_data = np.append(used_data, new_X, axis=0).astype(np.float32)
            used_label = np.append(used_label, new_y, axis=0).astype(np.float32).reshape(-1, 1)
            
            used_data = torch.from_numpy(used_data).to(device)
            used_label = torch.from_numpy(used_label).to(device)

            # Model params
            model_params = get_model_params_gradientNorm(learner_list)
            data_params = X_train[X_train_index]
            LALfeatures = features_concat(model_params, data_params)
            
            for l in learner_list:
                l.fit(used_data, used_label)
            
            used_data = used_data.cpu().numpy()
            used_label = used_label.cpu().numpy()

            loss_reduction = get_avg_grad_norm(learner_list, new_X, new_y)  
            gradient_norms = np.append(gradient_norms, loss_reduction)
            
            learning_state_features = learning_state_features_concat(learning_state_features, LALfeatures)
            loss_reduction_target = np.append(loss_reduction_target, np.array([loss_reduction]).reshape(-1, 1), axis=0).astype(np.float32).reshape(-1, 1)
        

        # RF Evaluation
        rf_model.fit(used_data, used_label.ravel())
        
        # Training Evaluation:
        rf_training_r2 = r2_score(used_label, rf_model.predict(used_data))
        rf_training_mse = mean_squared_error(used_label, rf_model.predict(used_data))
        rf_model_training_r2.append(rf_training_r2)
        rf_model_training_mse.append(rf_training_mse)
        
        # Test Evaluation:
        rf_model_r2 = r2_score(y_test, rf_model.predict(X_test))
        rf_model_mse = mean_squared_error(y_test, rf_model.predict(X_test))
        rf_model_testing_r2.append(rf_model_r2)
        rf_model_testing_mse.append(rf_model_mse)

        print(np.unique(used_data, axis=0).shape)
        print("RF R2:", rf_model_r2)
        print("Remaining:", X_index.shape[0])
        # print('NN R2', Committee_Prediction(learner_list, X_test, y_test))

    # RF
    rf_model_testing_r2 = np.array(rf_model_testing_r2)
    rf_model_testing_mse = np.array(rf_model_testing_mse)
    rf_model_training_r2 = np.array(rf_model_training_r2)
    rf_model_training_mse = np.array(rf_model_training_mse)
    
    # Used_data and Unsed_label:
    np.save(file="..\..\Results\Res_RedWine\OMAL\Summary\\used_data" + str(iters) + ".npy", arr=used_data)
    np.save(file="..\..\Results\Res_RedWine\OMAL\Summary\\used_labels" + str(iters) + ".npy", arr=used_label)

    np.save(file="..\..\Results\Res_RedWine\OMAL\Summary\\testing_rf_r2_" + str(iters) + ".npy", arr=rf_model_testing_r2)
    np.save(file="..\..\Results\Res_RedWine\OMAL\Summary\\testing_rf_mse_" + str(iters) + ".npy", arr=rf_model_testing_mse)
    np.save(file="..\..\Results\Res_RedWine\OMAL\Summary\\training_rf_r2_" + str(iters) + ".npy", arr=rf_model_training_r2)
    np.save(file="..\..\Results\Res_RedWine\OMAL\Summary\\training_rf_mse_" + str(iters) + ".npy", arr=rf_model_training_mse)

# %%
for i in range(iteration):
    print("The Iteration is ", i)
    main_function(query_number, i)
# Out:
# The Iteration is  0
# NN Test R2 with 5 samples -43.085339527388406
# After Initialization RF R2: 0.13644728860084332
# NN Test R2 after Initialization 0.0004745366424607396
# (38, 11)
# Query no. 1
# Embeddings training score: 0.8624339790938523
# (75, 11)
# RF R2: 0.18693821416772305
# Remaining: 1201
# Query no. 2
# Embeddings training score: 0.8541494812018019
# (107, 11)
# RF R2: 0.2067099473113133
# Remaining: 1161
# Query no. 3
# Embeddings training score: 0.8671053918222356
# (146, 11)
# RF R2: 0.2322123106038816
# Remaining: 1121
# Query no. 4
# Embeddings training score: 0.8812254536379909
# (182, 11)
# RF R2: 0.2856274191471503
# Remaining: 1081
# Query no. 5
# Embeddings training score: 0.8753343683088015
# (219, 11)
# RF R2: 0.2985670273413571
# Remaining: 1041
# Query no. 6
# Embeddings training score: 0.8736258762728109
# (257, 11)
# RF R2: 0.32652657134252205
# Remaining: 1001
# Query no. 7
# Embeddings training score: 0.8795937997306389
# (294, 11)
# RF R2: 0.31960084889220963
# Remaining: 961
# Query no. 8
# Embeddings training score: 0.8781885876771457
# (327, 11)
# RF R2: 0.337618860439448
# Remaining: 921
# Query no. 9
# Embeddings training score: 0.8803225728404848
# (360, 11)
# RF R2: 0.327570922405518
# Remaining: 881
# Query no. 10
# Embeddings training score: 0.8754497739445065
# (395, 11)
# RF R2: 0.3288152765494464
# Remaining: 841
# Query no. 11
# Embeddings training score: 0.8799021282355646
# (430, 11)
# RF R2: 0.3077509126561855
# Remaining: 801
# Query no. 12
# Embeddings training score: 0.880256986962623
# (464, 11)
# RF R2: 0.3146362403955705
# Remaining: 761
# Query no. 13
# Embeddings training score: 0.8787296750225022
# (500, 11)
# RF R2: 0.3186402429616235
# Remaining: 721
# Query no. 14
# Embeddings training score: 0.8778274462493723
# (536, 11)
# RF R2: 0.31959592270795023
# Remaining: 681
# Query no. 15
# Embeddings training score: 0.8770382627296368
# (573, 11)
# RF R2: 0.3417021745720774
# Remaining: 641
# Query no. 16
# Embeddings training score: 0.8761383403301788
# (607, 11)
# RF R2: 0.34240267797376633
# Remaining: 601
# Query no. 17
# Embeddings training score: 0.878063196210695
# (646, 11)
# RF R2: 0.35660831552264316
# Remaining: 561
# Query no. 18
# Embeddings training score: 0.8791057112634102
# (679, 11)
# RF R2: 0.36769617105373553
# Remaining: 521
# Query no. 19
# Embeddings training score: 0.8805215517788328
# (716, 11)
# RF R2: 0.3666823623331479
# Remaining: 481
# Query no. 20
# Embeddings training score: 0.8808480361081705
# (749, 11)
# RF R2: 0.3500880180368807
# Remaining: 441
# Query no. 21
# Embeddings training score: 0.8820490435503751
# (784, 11)
# RF R2: 0.3566762968654229
# Remaining: 401
# Query no. 22
# Embeddings training score: 0.8841459624288598
# (820, 11)
# RF R2: 0.3536713244671795
# Remaining: 361
# Query no. 23
# Embeddings training score: 0.8835740677449668
# (849, 11)
# RF R2: 0.33826468319585734
# Remaining: 321
# Query no. 24
# Embeddings training score: 0.8843735367629987
# (883, 11)
# RF R2: 0.3541230555637678
# Remaining: 281
# Query no. 25
# Embeddings training score: 0.883873257230092
# (918, 11)
# RF R2: 0.3586915988459499
# Remaining: 241
# The Iteration is  1
# NN Test R2 with 5 samples -40.97694168456084
# After Initialization RF R2: 0.23960010305022061
# NN Test R2 after Initialization -0.7815657601866054
# (38, 11)
# Query no. 1
# Embeddings training score: 0.8715354596646959
# (74, 11)
# RF R2: 0.15326087829155
# Remaining: 1201
# Query no. 2
# Embeddings training score: 0.8610967154138427
# (107, 11)
# RF R2: 0.22866631245822622
# Remaining: 1161
# Query no. 3
# Embeddings training score: 0.8675860777428991
# (144, 11)
# RF R2: 0.22489527578022495
# Remaining: 1121
# Query no. 4
# Embeddings training score: 0.8809874104460991
# (178, 11)
# RF R2: 0.24772777387580647
# Remaining: 1081
# Query no. 5
# Embeddings training score: 0.8752706656641754
# (213, 11)
# RF R2: 0.24968293083281157
# Remaining: 1041
# Query no. 6
# Embeddings training score: 0.8784478812660184
# (251, 11)
# RF R2: 0.27148509392109965
# Remaining: 1001
# Query no. 7
# Embeddings training score: 0.8802284611257882
# (288, 11)
# RF R2: 0.2746652574766385
# Remaining: 961
# Query no. 8
# Embeddings training score: 0.8782485368854905
# (320, 11)
# RF R2: 0.294578736834198
# Remaining: 921
# Query no. 9
# Embeddings training score: 0.8791692856000063
# (355, 11)
# RF R2: 0.3250741207367144
# Remaining: 881
# Query no. 10
# Embeddings training score: 0.8823003143713013
# (390, 11)
# RF R2: 0.3295995757764312
# Remaining: 841
# Query no. 11
# Embeddings training score: 0.8813346840383245
# (426, 11)
# RF R2: 0.3057140573661753
# Remaining: 801
# Query no. 12
# Embeddings training score: 0.8814973221001294
# (460, 11)
# RF R2: 0.3558923745954333
# Remaining: 761
# Query no. 13
# Embeddings training score: 0.8827644896355864
# (496, 11)
# RF R2: 0.3546784468679458
# Remaining: 721
# Query no. 14
# Embeddings training score: 0.8821817425407152
# (535, 11)
# RF R2: 0.37299234827255356
# Remaining: 681
# Query no. 15
# Embeddings training score: 0.8813349266555204
# (570, 11)
# RF R2: 0.3678459488889634
# Remaining: 641
# Query no. 16
# Embeddings training score: 0.8813662762811374
# (606, 11)
# RF R2: 0.358419939889824
# Remaining: 601
# Query no. 17
# Embeddings training score: 0.8828471774689095
# (643, 11)
# RF R2: 0.3717177505369561
# Remaining: 561
# Query no. 18
# Embeddings training score: 0.8830833537198206
# (676, 11)
# RF R2: 0.3852640444346953
# Remaining: 521
# Query no. 19
# Embeddings training score: 0.8853928786919761
# (709, 11)
# RF R2: 0.37594196579727457
# Remaining: 481
# Query no. 20
# Embeddings training score: 0.8844463223472789
# (744, 11)
# RF R2: 0.3820596128759125
# Remaining: 441
# Query no. 21
# Embeddings training score: 0.8846186671559035
# (780, 11)
# RF R2: 0.38710735755066283
# Remaining: 401
# Query no. 22
# Embeddings training score: 0.8860531245478912
# (815, 11)
# RF R2: 0.3938348701021279
# Remaining: 361
# Query no. 23
# Embeddings training score: 0.8863345549370574
# (850, 11)
# RF R2: 0.3916676318993818
# Remaining: 321
# Query no. 24
# Embeddings training score: 0.8878860698990063
# (887, 11)
# RF R2: 0.3953215490834663
# Remaining: 281
# Query no. 25
# Embeddings training score: 0.8886560883584319
# (923, 11)
# RF R2: 0.4027185419852929
# Remaining: 241
# The Iteration is  2
# NN Test R2 with 5 samples -32.82040829738066
# After Initialization RF R2: 0.01210607028753996
# NN Test R2 after Initialization -0.21477567834270883
# (38, 11)
# Query no. 1
# Embeddings training score: 0.8808383923327547
# (71, 11)
# RF R2: 0.24607965921192765
# Remaining: 1201
# Query no. 2
# Embeddings training score: 0.8700550261391986
# (109, 11)
# RF R2: 0.32805154419595317
# Remaining: 1161
# Query no. 3
# Embeddings training score: 0.8743080583856624
# (149, 11)
# RF R2: 0.33249968051118217
# Remaining: 1121
# Query no. 4
# Embeddings training score: 0.880504090886919
# (181, 11)
# RF R2: 0.3406019169329073
# Remaining: 1081
# Query no. 5
# Embeddings training score: 0.8751970410573955
# (217, 11)
# RF R2: 0.35500149094781674
# Remaining: 1041
# Query no. 6
# Embeddings training score: 0.8773135504408873
# (250, 11)
# RF R2: 0.38066112886048986
# Remaining: 1001
# Query no. 7
# Embeddings training score: 0.8651170398667059
# (285, 11)
# RF R2: 0.39946027689030883
# Remaining: 961
# Query no. 8
# Embeddings training score: 0.8675630459874946
# (320, 11)
# RF R2: 0.41771501597444083
# Remaining: 921
# Query no. 9
# Embeddings training score: 0.8696018302732889
# (357, 11)
# RF R2: 0.42290010649627263
# Remaining: 881
# Query no. 10
# Embeddings training score: 0.8712050388239936
# (395, 11)
# RF R2: 0.44639701810436627
# Remaining: 841
# Query no. 11
# Embeddings training score: 0.8715913829191272
# (434, 11)
# RF R2: 0.4388771033013844
# Remaining: 801
# Query no. 12
# Embeddings training score: 0.871486073375952
# (468, 11)
# RF R2: 0.44058998935037275
# Remaining: 761
# Query no. 13
# Embeddings training score: 0.8717127299126567
# (503, 11)
# RF R2: 0.4534709265175719
# Remaining: 721
# Query no. 14
# Embeddings training score: 0.8715604954578012
# (537, 11)
# RF R2: 0.45076719914802976
# Remaining: 681
# Query no. 15
# Embeddings training score: 0.8746772307991777
# (575, 11)
# RF R2: 0.46576613418530344
# Remaining: 641
# Query no. 16
# Embeddings training score: 0.8751956337177242
# (609, 11)
# RF R2: 0.4676788072417465
# Remaining: 601
# Query no. 17
# Embeddings training score: 0.8776518240225186
# (644, 11)
# RF R2: 0.4661358892438765
# Remaining: 561
# Query no. 18
# Embeddings training score: 0.8784911146104015
# (677, 11)
# RF R2: 0.46215420660276896
# Remaining: 521
# Query no. 19
# Embeddings training score: 0.875821897461508
# (715, 11)
# RF R2: 0.4504788072417465
# Remaining: 481
# Query no. 20
# Embeddings training score: 0.8749075529599963
# (744, 11)
# RF R2: 0.44953652822151235
# Remaining: 441
# Query no. 21
# Embeddings training score: 0.8759520496135329
# (777, 11)
# RF R2: 0.4621422790202343
# Remaining: 401
# Query no. 22
# Embeddings training score: 0.877237908889065
# (809, 11)
# RF R2: 0.43906964856230024
# Remaining: 361
# Query no. 23
# Embeddings training score: 0.8775816989893754
# (842, 11)
# RF R2: 0.45765580404685835
# Remaining: 321
# Query no. 24
# Embeddings training score: 0.8771504332285495
# (876, 11)
# RF R2: 0.4761797657082002
# Remaining: 281
# Query no. 25
# Embeddings training score: 0.877614076082043
# (911, 11)
# RF R2: 0.4632221512247071
# Remaining: 241
# The Iteration is  3
# NN Test R2 with 5 samples -43.69620782128686
# After Initialization RF R2: 0.16732218026834866
# NN Test R2 after Initialization -0.5902901459623291
# (38, 11)
# Query no. 1
# Embeddings training score: 0.8640501880448104
# (72, 11)
# RF R2: 0.29802182926469056
# Remaining: 1201
# Query no. 2
# Embeddings training score: 0.8721578385593974
# (108, 11)
# RF R2: 0.16741213330726012
# Remaining: 1161
# Query no. 3
# Embeddings training score: 0.8675777403794984
# (147, 11)
# RF R2: 0.22342007014670873
# Remaining: 1121
# Query no. 4
# Embeddings training score: 0.869147258780537
# (183, 11)
# RF R2: 0.26082095631954816
# Remaining: 1081
# Query no. 5
# Embeddings training score: 0.8709571734170276
# (221, 11)
# RF R2: 0.2580604562960106
# Remaining: 1041
# Query no. 6
# Embeddings training score: 0.8736675990026379
# (254, 11)
# RF R2: 0.26457358544872744
# Remaining: 1001
# Query no. 7
# Embeddings training score: 0.8776179050095503
# (286, 11)
# RF R2: 0.2655847634331976
# Remaining: 961
# Query no. 8
# Embeddings training score: 0.919759519719119
# (322, 11)
# RF R2: 0.2766870849769707
# Remaining: 921
# Query no. 9
# Embeddings training score: 0.9167377824789347
# (355, 11)
# RF R2: 0.25455281691398457
# Remaining: 881
# Query no. 10
# Embeddings training score: 0.9176321031882777
# (391, 11)
# RF R2: 0.25866102511462574
# Remaining: 841
# Query no. 11
# Embeddings training score: 0.9170986863493961
# (425, 11)
# RF R2: 0.28857834758555023
# Remaining: 801
# Query no. 12
# Embeddings training score: 0.9147556729786781
# (461, 11)
# RF R2: 0.28336001305763636
# Remaining: 761
# Query no. 13
# Embeddings training score: 0.9158731128699329
# (499, 11)
# RF R2: 0.2837378158210647
# Remaining: 721
# Query no. 14
# Embeddings training score: 0.9139941204045089
# (532, 11)
# RF R2: 0.30174376853353524
# Remaining: 681
# Query no. 15
# Embeddings training score: 0.9140265983822127
# (564, 11)
# RF R2: 0.2969101155308487
# Remaining: 641
# Query no. 16
# Embeddings training score: 0.914726730571896
# (600, 11)
# RF R2: 0.33736623021354195
# Remaining: 601
# Query no. 17
# Embeddings training score: 0.9130671013178421
# (637, 11)
# RF R2: 0.3392901669752024
# Remaining: 561
# Query no. 18
# Embeddings training score: 0.9116363968213328
# (674, 11)
# RF R2: 0.33364587835126613
# Remaining: 521
# Query no. 19
# Embeddings training score: 0.9112255329393082
# (704, 11)
# RF R2: 0.3420861190787815
# Remaining: 481
# Query no. 20
# Embeddings training score: 0.9127890903609475
# (738, 11)
# RF R2: 0.3571543113675065
# Remaining: 441
# Query no. 21
# Embeddings training score: 0.9122557281801971
# (770, 11)
# RF R2: 0.3676650593965558
# Remaining: 401
# Query no. 22
# Embeddings training score: 0.9123860947833391
# (804, 11)
# RF R2: 0.36964931760783926
# Remaining: 361
# Query no. 23
# Embeddings training score: 0.912492716599901
# (838, 11)
# RF R2: 0.3768513812115136
# Remaining: 321
# Query no. 24
# Embeddings training score: 0.9128702060102698
# (874, 11)
# RF R2: 0.3762211808036101
# Remaining: 281
# Query no. 25
# Embeddings training score: 0.912820848463747
# (910, 11)
# RF R2: 0.3844931564348085
# Remaining: 241
# The Iteration is  4
# NN Test R2 with 5 samples -40.561878703754736
# After Initialization RF R2: 0.22895978752884316
# NN Test R2 after Initialization -1.0185317845318282
# (38, 11)
# Query no. 1
# Embeddings training score: 0.8855869701943884
# (73, 11)
# RF R2: 0.2672484813777599
# Remaining: 1201
# Query no. 2
# Embeddings training score: 0.8657416465300951
# (109, 11)
# RF R2: 0.31197292691120104
# Remaining: 1161
# Query no. 3
# Embeddings training score: 0.8770438865886744
# (143, 11)
# RF R2: 0.31392606329161776
# Remaining: 1121
# Query no. 4
# Embeddings training score: 0.8690872733650442
# (178, 11)
# RF R2: 0.305521324706006
# Remaining: 1081
# Query no. 5
# Embeddings training score: 0.8700968441283021
# (217, 11)
# RF R2: 0.37451115621724773
# Remaining: 1041
# Query no. 6
# Embeddings training score: 0.8724437850753127
# (253, 11)
# RF R2: 0.3752173849715732
# Remaining: 1001
# Query no. 7
# Embeddings training score: 0.865614160463433
# (287, 11)
# RF R2: 0.3911964709765511
# Remaining: 961
# Query no. 8
# Embeddings training score: 0.8741966470885265
# (322, 11)
# RF R2: 0.400205290516611
# Remaining: 921
# Query no. 9
# Embeddings training score: 0.8758100541523182
# (357, 11)
# RF R2: 0.417522864933777
# Remaining: 881
# Query no. 10
# Embeddings training score: 0.8785754347606818
# (389, 11)
# RF R2: 0.42337390852245094
# Remaining: 841
# Query no. 11
# Embeddings training score: 0.8797766041475079
# (426, 11)
# RF R2: 0.4422686097463464
# Remaining: 801
# Query no. 12
# Embeddings training score: 0.8822535488024342
# (462, 11)
# RF R2: 0.4436216278024826
# Remaining: 761
# Query no. 13
# Embeddings training score: 0.8808229247001389
# (500, 11)
# RF R2: 0.4522178935128647
# Remaining: 721
# Query no. 14
# Embeddings training score: 0.8812083784996056
# (536, 11)
# RF R2: 0.4409534568229233
# Remaining: 681
# Query no. 15
# Embeddings training score: 0.8810326191742079
# (570, 11)
# RF R2: 0.4421171492154935
# Remaining: 641
# Query no. 16
# Embeddings training score: 0.8821604594232219
# (601, 11)
# RF R2: 0.4613464725424362
# Remaining: 601
# Query no. 17
# Embeddings training score: 0.8825987520044213
# (636, 11)
# RF R2: 0.45304124000325685
# Remaining: 561
# Query no. 18
# Embeddings training score: 0.8852830404249987
# (674, 11)
# RF R2: 0.439825868394103
# Remaining: 521
# Query no. 19
# Embeddings training score: 0.8838331196243417
# (709, 11)
# RF R2: 0.44699646782860825
# Remaining: 481
# Query no. 20
# Embeddings training score: 0.883777768934109
# (743, 11)
# RF R2: 0.4504769779925384
# Remaining: 441
# Query no. 21
# Embeddings training score: 0.88488682609796
# (780, 11)
# RF R2: 0.458207188865166
# Remaining: 401
# Query no. 22
# Embeddings training score: 0.8850431103674562
# (815, 11)
# RF R2: 0.47159207298704753
# Remaining: 361
# Query no. 23
# Embeddings training score: 0.8853686242726501
# (847, 11)
# RF R2: 0.4482112341211173
# Remaining: 321
# Query no. 24
# Embeddings training score: 0.887613149050693
# (880, 11)
# RF R2: 0.45268900621057573
# Remaining: 281
# Query no. 25
# Embeddings training score: 0.8884770358699189
# (915, 11)
# RF R2: 0.450398605973667
# Remaining: 241
# The Iteration is  5
# NN Test R2 with 5 samples -40.98238610185212
# After Initialization RF R2: 0.11315076291497816
# NN Test R2 after Initialization -0.4791404227135568
# (38, 11)
# Query no. 1
# Embeddings training score: 0.8820702906527215
# (74, 11)
# RF R2: 0.2710619528648278
# Remaining: 1201
# Query no. 2
# Embeddings training score: 0.8881525013745081
# (108, 11)
# RF R2: 0.34207203743885806
# Remaining: 1161
# Query no. 3
# Embeddings training score: 0.8868259682853877
# (142, 11)
# RF R2: 0.3506651888589023
# Remaining: 1121
# Query no. 4
# Embeddings training score: 0.8800592600065406
# (176, 11)
# RF R2: 0.3738196645408417
# Remaining: 1081
# Query no. 5
# Embeddings training score: 0.8705665979065182
# (213, 11)
# RF R2: 0.38970869029906063
# Remaining: 1041
# Query no. 6
# Embeddings training score: 0.8662287864655017
# (249, 11)
# RF R2: 0.4079423910137844
# Remaining: 1001
# Query no. 7
# Embeddings training score: 0.8672884254935146
# (287, 11)
# RF R2: 0.4180707284615085
# Remaining: 961
# Query no. 8
# Embeddings training score: 0.8737291988613956
# (322, 11)
# RF R2: 0.45030115610761
# Remaining: 921
# Query no. 9
# Embeddings training score: 0.8800553531545197
# (358, 11)
# RF R2: 0.4462327635059905
# Remaining: 881
# Query no. 10
# Embeddings training score: 0.8784624547654766
# (396, 11)
# RF R2: 0.4730606131625442
# Remaining: 841
# Query no. 11
# Embeddings training score: 0.8758615207490931
# (432, 11)
# RF R2: 0.4633961233450157
# Remaining: 801
# Query no. 12
# Embeddings training score: 0.8815824774764971
# (469, 11)
# RF R2: 0.4704899995216534
# Remaining: 761
# Query no. 13
# Embeddings training score: 0.8809317613339106
# (506, 11)
# RF R2: 0.4892414140429828
# Remaining: 721
# Query no. 14
# Embeddings training score: 0.8822654298565475
# (545, 11)
# RF R2: 0.48903791959876786
# Remaining: 681
# Query no. 15
# Embeddings training score: 0.8823382967268673
# (578, 11)
# RF R2: 0.5087713943177912
# Remaining: 641
# Query no. 16
# Embeddings training score: 0.8816361686042785
# (615, 11)
# RF R2: 0.5177191647325335
# Remaining: 601
# Query no. 17
# Embeddings training score: 0.8819374777810286
# (652, 11)
# RF R2: 0.5144238515145736
# Remaining: 561
# Query no. 18
# Embeddings training score: 0.8803585485560017
# (687, 11)
# RF R2: 0.5267008508879782
# Remaining: 521
# Query no. 19
# Embeddings training score: 0.8806682288017755
# (719, 11)
# RF R2: 0.5285357922121608
# Remaining: 481
# Query no. 20
# Embeddings training score: 0.8816808652588262
# (751, 11)
# RF R2: 0.5366840489159315
# Remaining: 441
# Query no. 21
# Embeddings training score: 0.8817425991194262
# (786, 11)
# RF R2: 0.5375219672156398
# Remaining: 401
# Query no. 22
# Embeddings training score: 0.8822485060398592
# (822, 11)
# RF R2: 0.5383075156216163
# Remaining: 361
# Query no. 23
# Embeddings training score: 0.8825580300154465
# (855, 11)
# RF R2: 0.5373678500998005
# Remaining: 321
# Query no. 24
# Embeddings training score: 0.8838343495580543
# (893, 11)
# RF R2: 0.5462956700788355
# Remaining: 281
# Query no. 25
# Embeddings training score: 0.8858262314701926
# (927, 11)
# RF R2: 0.5337827568031914
# Remaining: 241
# The Iteration is  6
# NN Test R2 with 5 samples -52.63995699917469
# After Initialization RF R2: -0.020004172314481927
# NN Test R2 after Initialization -0.9024098233677793
# (38, 11)
# Query no. 1
# Embeddings training score: 0.8501835134418394
# (74, 11)
# RF R2: -0.08900062011237453
# Remaining: 1201
# Query no. 2
# Embeddings training score: 0.8746972404483109
# (111, 11)
# RF R2: 0.23456954295841348
# Remaining: 1161
# Query no. 3
# Embeddings training score: 0.8652843786827674
# (148, 11)
# RF R2: 0.2838381546768842
# Remaining: 1121
# Query no. 4
# Embeddings training score: 0.8700544871015912
# (181, 11)
# RF R2: 0.3225193996519493
# Remaining: 1081
# Query no. 5
# Embeddings training score: 0.8753077070102363
# (216, 11)
# RF R2: 0.35065506352302145
# Remaining: 1041
# Query no. 6
# Embeddings training score: 0.8764052579266577
# (253, 11)
# RF R2: 0.3250142808958043
# Remaining: 1001
# Query no. 7
# Embeddings training score: 0.8741628271390823
# (291, 11)
# RF R2: 0.3343881926706712
# Remaining: 961
# Query no. 8
# Embeddings training score: 0.8724058611565796
# (326, 11)
# RF R2: 0.3499803647319746
# Remaining: 921
# Query no. 9
# Embeddings training score: 0.8796112574242583
# (358, 11)
# RF R2: 0.3563005819785774
# Remaining: 881
# Query no. 10
# Embeddings training score: 0.879463011640045
# (394, 11)
# RF R2: 0.37010488581488543
# Remaining: 841
# Query no. 11
# Embeddings training score: 0.8800437468629513
# (431, 11)
# RF R2: 0.36014096081151403
# Remaining: 801
# Query no. 12
# Embeddings training score: 0.8795934000194785
# (466, 11)
# RF R2: 0.38870450963017
# Remaining: 761
# Query no. 13
# Embeddings training score: 0.8793820175657809
# (497, 11)
# RF R2: 0.3795099975338473
# Remaining: 721
# Query no. 14
# Embeddings training score: 0.8795331274198036
# (529, 11)
# RF R2: 0.3794977404129529
# Remaining: 681
# Query no. 15
# Embeddings training score: 0.8913262249926612
# (563, 11)
# RF R2: 0.38548200111867914
# Remaining: 641
# Query no. 16
# Embeddings training score: 0.8983994477364545
# (600, 11)
# RF R2: 0.3746740061991757
# Remaining: 601
# Query no. 17
# Embeddings training score: 0.8977470767651242
# (637, 11)
# RF R2: 0.39176098986772845
# Remaining: 561
# Query no. 18
# Embeddings training score: 0.8998273092534488
# (671, 11)
# RF R2: 0.38826325327797406
# Remaining: 521
# Query no. 19
# Embeddings training score: 0.9000022118343471
# (702, 11)
# RF R2: 0.38728045503899267
# Remaining: 481
# Query no. 20
# Embeddings training score: 0.8994143609571086
# (738, 11)
# RF R2: 0.3964510100353855
# Remaining: 441
# Query no. 21
# Embeddings training score: 0.8980204224854025
# (774, 11)
# RF R2: 0.4047251237809161
# Remaining: 401
# Query no. 22
# Embeddings training score: 0.8970916862064218
# (807, 11)
# RF R2: 0.40941180109742026
# Remaining: 361
# Query no. 23
# Embeddings training score: 0.8980080872904972
# (843, 11)
# RF R2: 0.3982795496160758
# Remaining: 321
# Query no. 24
# Embeddings training score: 0.8961018132433081
# (877, 11)
# RF R2: 0.4173884010903338
# Remaining: 281
# Query no. 25
# Embeddings training score: 0.8936089869094813
# (908, 11)
# RF R2: 0.4015059581205783
# Remaining: 241
# The Iteration is  7
# NN Test R2 with 5 samples -40.63649479353199
# After Initialization RF R2: 0.30910939704914553
# NN Test R2 after Initialization -0.5682655983290656
# (38, 11)
# Query no. 1
# Embeddings training score: 0.884207544509264
# (75, 11)
# RF R2: 0.26034058827021567
# Remaining: 1201
# Query no. 2
# Embeddings training score: 0.8742676520908393
# (112, 11)
# RF R2: 0.2752715281203655
# Remaining: 1161
# Query no. 3
# Embeddings training score: 0.8792671013065985
# (148, 11)
# RF R2: 0.3623418691575163
# Remaining: 1121
# Query no. 4
# Embeddings training score: 0.8883338156837981
# (186, 11)
# RF R2: 0.3528005207099497
# Remaining: 1081
# Query no. 5
# Embeddings training score: 0.8853045523622887
# (221, 11)
# RF R2: 0.3582302076887116
# Remaining: 1041
# Query no. 6
# Embeddings training score: 0.8863221458904302
# (256, 11)
# RF R2: 0.35272499183389283
# Remaining: 1001
# Query no. 7
# Embeddings training score: 0.8861755022649744
# (290, 11)
# RF R2: 0.3856182835843309
# Remaining: 961
# Query no. 8
# Embeddings training score: 0.8851704347664525
# (325, 11)
# RF R2: 0.386261677713705
# Remaining: 921
# Query no. 9
# Embeddings training score: 0.8815461874650756
# (360, 11)
# RF R2: 0.37723411211437796
# Remaining: 881
# Query no. 10
# Embeddings training score: 0.8794423403247666
# (398, 11)
# RF R2: 0.3678340306386956
# Remaining: 841
# Query no. 11
# Embeddings training score: 0.8798646301915664
# (431, 11)
# RF R2: 0.3930154511616135
# Remaining: 801
# Query no. 12
# Embeddings training score: 0.8829213794128945
# (466, 11)
# RF R2: 0.41327583905007936
# Remaining: 761
# Query no. 13
# Embeddings training score: 0.8802346768052182
# (500, 11)
# RF R2: 0.40416761607076546
# Remaining: 721
# Query no. 14
# Embeddings training score: 0.8837918405445148
# (537, 11)
# RF R2: 0.40341232731019583
# Remaining: 681
# Query no. 15
# Embeddings training score: 0.8835256413063551
# (569, 11)
# RF R2: 0.4060549055169296
# Remaining: 641
# Query no. 16
# Embeddings training score: 0.8847085914106747
# (602, 11)
# RF R2: 0.4209065866699827
# Remaining: 601
# Query no. 17
# Embeddings training score: 0.8866804660506807
# (638, 11)
# RF R2: 0.40097162566724387
# Remaining: 561
# Query no. 18
# Embeddings training score: 0.8870766818292034
# (672, 11)
# RF R2: 0.40420817787457386
# Remaining: 521
# Query no. 19
# Embeddings training score: 0.8870875310219748
# (707, 11)
# RF R2: 0.40660598657556735
# Remaining: 481
# Query no. 20
# Embeddings training score: 0.8854323662410324
# (743, 11)
# RF R2: 0.4051592822397355
# Remaining: 441
# Query no. 21
# Embeddings training score: 0.8843481000835124
# (778, 11)
# RF R2: 0.41254479412626877
# Remaining: 401
# Query no. 22
# Embeddings training score: 0.8844990305606699
# (812, 11)
# RF R2: 0.42062405272621406
# Remaining: 361
# Query no. 23
# Embeddings training score: 0.8867049633994917
# (848, 11)
# RF R2: 0.42288898655266294
# Remaining: 321
# Query no. 24
# Embeddings training score: 0.8863196307961047
# (878, 11)
# RF R2: 0.4404629708371768
# Remaining: 281
# Query no. 25
# Embeddings training score: 0.8886791387212148
# (914, 11)
# RF R2: 0.454712752119924
# Remaining: 241
# The Iteration is  8
# NN Test R2 with 5 samples -39.025281407132695
# After Initialization RF R2: 0.2751941144831761
# NN Test R2 after Initialization 0.04991296882523847
# (37, 11)
# Query no. 1
# Embeddings training score: 0.8518609656524248
# (74, 11)
# RF R2: 0.32595996660836124
# Remaining: 1201
# Query no. 2
# Embeddings training score: 0.8467055583081412
# (112, 11)
# RF R2: 0.42985075829743336
# Remaining: 1161
# Query no. 3
# Embeddings training score: 0.8600130309887805
# (145, 11)
# RF R2: 0.3874453291723068
# Remaining: 1121
# Query no. 4
# Embeddings training score: 0.8665280238204855
# (178, 11)
# RF R2: 0.4215300924060952
# Remaining: 1081
# Query no. 5
# Embeddings training score: 0.8679091777302055
# (215, 11)
# RF R2: 0.40957463284998674
# Remaining: 1041
# Query no. 6
# Embeddings training score: 0.8745116938182343
# (254, 11)
# RF R2: 0.3890410801235751
# Remaining: 1001
# Query no. 7
# Embeddings training score: 0.8739632765999797
# (293, 11)
# RF R2: 0.39239956188273795
# Remaining: 961
# Query no. 8
# Embeddings training score: 0.8768970062456398
# (327, 11)
# RF R2: 0.42993275733416936
# Remaining: 921
# Query no. 9
# Embeddings training score: 0.8790413859551366
# (360, 11)
# RF R2: 0.4401801521068739
# Remaining: 881
# Query no. 10
# Embeddings training score: 0.8797992928400321
# (396, 11)
# RF R2: 0.43414701085854046
# Remaining: 841
# Query no. 11
# Embeddings training score: 0.8804610212530297
# (433, 11)
# RF R2: 0.4517087197080961
# Remaining: 801
# Query no. 12
# Embeddings training score: 0.8870863198759601
# (469, 11)
# RF R2: 0.48405858211009445
# Remaining: 761
# Query no. 13
# Embeddings training score: 0.8874440307135516
# (504, 11)
# RF R2: 0.49104241522070624
# Remaining: 721
# Query no. 14
# Embeddings training score: 0.888278387502383
# (537, 11)
# RF R2: 0.5035852860581598
# Remaining: 681
# Query no. 15
# Embeddings training score: 0.887510832868492
# (575, 11)
# RF R2: 0.4998093546574318
# Remaining: 641
# Query no. 16
# Embeddings training score: 0.8848708268074822
# (607, 11)
# RF R2: 0.5048679497782543
# Remaining: 601
# Query no. 17
# Embeddings training score: 0.8846612022137486
# (645, 11)
# RF R2: 0.5248036549822817
# Remaining: 561
# Query no. 18
# Embeddings training score: 0.8855724499369744
# (680, 11)
# RF R2: 0.5263000131617488
# Remaining: 521
# Query no. 19
# Embeddings training score: 0.884233398889963
# (715, 11)
# RF R2: 0.5253731755647026
# Remaining: 481
# Query no. 20
# Embeddings training score: 0.88496834815028
# (754, 11)
# RF R2: 0.5386714314678454
# Remaining: 441
# Query no. 21
# Embeddings training score: 0.8836665750828012
# (789, 11)
# RF R2: 0.552877143377533
# Remaining: 401
# Query no. 22
# Embeddings training score: 0.882864183887915
# (824, 11)
# RF R2: 0.5452050153221977
# Remaining: 361
# Query no. 23
# Embeddings training score: 0.8823087392938059
# (862, 11)
# RF R2: 0.5419295265274888
# Remaining: 321
# Query no. 24
# Embeddings training score: 0.8829172011311434
# (896, 11)
# RF R2: 0.5479239045948198
# Remaining: 281
# Query no. 25
# Embeddings training score: 0.8834889763522306
# (928, 11)
# RF R2: 0.5611689853650488
# Remaining: 241
# The Iteration is  9
# NN Test R2 with 5 samples -40.36643359379767
# After Initialization RF R2: 0.14640341017675862
# NN Test R2 after Initialization -0.015918987429001774
# (38, 11)
# Query no. 1
# Embeddings training score: 0.8799285977872378
# (72, 11)
# RF R2: 0.25320543295024234
# Remaining: 1201
# Query no. 2
# Embeddings training score: 0.8927431249860381
# (109, 11)
# RF R2: 0.2933701208896766
# Remaining: 1161
# Query no. 3
# Embeddings training score: 0.8785732507164036
# (143, 11)
# RF R2: 0.32650253850597943
# Remaining: 1121
# Query no. 4
# Embeddings training score: 0.8713296128611401
# (178, 11)
# RF R2: 0.3020247924806746
# Remaining: 1081
# Query no. 5
# Embeddings training score: 0.8744841330103391
# (213, 11)
# RF R2: 0.33177114676119746
# Remaining: 1041
# Query no. 6
# Embeddings training score: 0.8704175579516967
# (250, 11)
# RF R2: 0.31895650778135676
# Remaining: 1001
# Query no. 7
# Embeddings training score: 0.8737804771442599
# (286, 11)
# RF R2: 0.27984871170234016
# Remaining: 961
# Query no. 8
# Embeddings training score: 0.8773904700221128
# (321, 11)
# RF R2: 0.3100183821757432
# Remaining: 921
# Query no. 9
# Embeddings training score: 0.8821867248687797
# (357, 11)
# RF R2: 0.33088815020908846
# Remaining: 881
# Query no. 10
# Embeddings training score: 0.8831949253445668
# (393, 11)
# RF R2: 0.31929544046001734
# Remaining: 841
# Query no. 11
# Embeddings training score: 0.8834601620057986
# (428, 11)
# RF R2: 0.304639749006957
# Remaining: 801
# Query no. 12
# Embeddings training score: 0.8826384058124782
# (463, 11)
# RF R2: 0.31530144285604844
# Remaining: 761
# Query no. 13
# Embeddings training score: 0.8836414666088801
# (500, 11)
# RF R2: 0.3102533506352271
# Remaining: 721
# Query no. 14
# Embeddings training score: 0.8867114080536403
# (540, 11)
# RF R2: 0.3370994295458083
# Remaining: 681
# Query no. 15
# Embeddings training score: 0.8856226752712343
# (577, 11)
# RF R2: 0.36484202501906393
# Remaining: 641
# Query no. 16
# Embeddings training score: 0.8862127159028845
# (610, 11)
# RF R2: 0.3690248365636898
# Remaining: 601
# Query no. 17
# Embeddings training score: 0.8867143461344584
# (646, 11)
# RF R2: 0.3892293268357577
# Remaining: 561
# Query no. 18
# Embeddings training score: 0.8869345236437537
# (679, 11)
# RF R2: 0.40011153671924593
# Remaining: 521
# Query no. 19
# Embeddings training score: 0.8880289942638966
# (714, 11)
# RF R2: 0.3907039404019249
# Remaining: 481
# Query no. 20
# Embeddings training score: 0.8855218105222222
# (749, 11)
# RF R2: 0.3754901988575897
# Remaining: 441
# Query no. 21
# Embeddings training score: 0.88672150644882
# (786, 11)
# RF R2: 0.3900032308888205
# Remaining: 401
# Query no. 22
# Embeddings training score: 0.8865613501789826
# (821, 11)
# RF R2: 0.3926946454058873
# Remaining: 361
# Query no. 23
# Embeddings training score: 0.887036755768037
# (853, 11)
# RF R2: 0.41787636439512277
# Remaining: 321
# Query no. 24
# Embeddings training score: 0.8881571673589367
# (887, 11)
# RF R2: 0.4275585567891028
# Remaining: 281
# Query no. 25
# Embeddings training score: 0.8900149390310813
# (921, 11)
# RF R2: 0.4262764868216795
# Remaining: 241
# The Iteration is  10
# NN Test R2 with 5 samples -35.49131495408503
# After Initialization RF R2: 0.11101081229094789
# NN Test R2 after Initialization -1.033046363854184
# (37, 11)
# Query no. 1
# Embeddings training score: 0.8592699980478795
# (74, 11)
# RF R2: 0.18082562706232164
# Remaining: 1201
# Query no. 2
# Embeddings training score: 0.8466477684546415
# (107, 11)
# RF R2: 0.20979437727062422
# Remaining: 1161
# Query no. 3
# Embeddings training score: 0.8536885473516083
# (138, 11)
# RF R2: 0.2469558414815205
# Remaining: 1121
# Query no. 4
# Embeddings training score: 0.8569528006381991
# (175, 11)
# RF R2: 0.28952743213250354
# Remaining: 1081
# Query no. 5
# Embeddings training score: 0.8601192801323191
# (210, 11)
# RF R2: 0.2867975026139342
# Remaining: 1041
# Query no. 6
# Embeddings training score: 0.8609171106659975
# (246, 11)
# RF R2: 0.3128720107036034
# Remaining: 1001
# Query no. 7
# Embeddings training score: 0.8597761784345472
# (283, 11)
# RF R2: 0.3589551127660414
# Remaining: 961
# Query no. 8
# Embeddings training score: 0.8628203632860884
# (320, 11)
# RF R2: 0.3624763756671149
# Remaining: 921
# Query no. 9
# Embeddings training score: 0.8692423050108268
# (354, 11)
# RF R2: 0.37143068100887733
# Remaining: 881
# Query no. 10
# Embeddings training score: 0.8727360083336361
# (387, 11)
# RF R2: 0.387582073263232
# Remaining: 841
# Query no. 11
# Embeddings training score: 0.8701496318681328
# (420, 11)
# RF R2: 0.4020337808771628
# Remaining: 801
# Query no. 12
# Embeddings training score: 0.8721753842548831
# (457, 11)
# RF R2: 0.40682712559890877
# Remaining: 761
# Query no. 13
# Embeddings training score: 0.8766947027305104
# (494, 11)
# RF R2: 0.38829051898398237
# Remaining: 721
# Query no. 14
# Embeddings training score: 0.8755308133226956
# (528, 11)
# RF R2: 0.38855283405470753
# Remaining: 681
# Query no. 15
# Embeddings training score: 0.8769226407140052
# (564, 11)
# RF R2: 0.3811470652642893
# Remaining: 641
# Query no. 16
# Embeddings training score: 0.8763888768936209
# (598, 11)
# RF R2: 0.39115891965512795
# Remaining: 601
# Query no. 17
# Embeddings training score: 0.8783838641153444
# (633, 11)
# RF R2: 0.3971185425351913
# Remaining: 561
# Query no. 18
# Embeddings training score: 0.8781137296441252
# (665, 11)
# RF R2: 0.39563192794292135
# Remaining: 521
# Query no. 19
# Embeddings training score: 0.8786207769457788
# (697, 11)
# RF R2: 0.38392672737991074
# Remaining: 481
# Query no. 20
# Embeddings training score: 0.879873882398431
# (735, 11)
# RF R2: 0.38307493476177523
# Remaining: 441
# Query no. 21
# Embeddings training score: 0.8813991774288025
# (764, 11)
# RF R2: 0.4053819548375157
# Remaining: 401
# Query no. 22
# Embeddings training score: 0.8813394935238132
# (801, 11)
# RF R2: 0.4167824213499628
# Remaining: 361
# Query no. 23
# Embeddings training score: 0.8822253679751201
# (834, 11)
# RF R2: 0.43308057352306895
# Remaining: 321
# Query no. 24
# Embeddings training score: 0.8824464812606618
# (868, 11)
# RF R2: 0.4444751891417451
# Remaining: 281
# Query no. 25
# Embeddings training score: 0.8829053146963856
# (900, 11)
# RF R2: 0.42551731817531946
# Remaining: 241
# The Iteration is  11
# NN Test R2 with 5 samples -38.96780138555341
# After Initialization RF R2: 0.23980435930763455
# NN Test R2 after Initialization -0.0702055891389961
# (38, 11)
# Query no. 1
# Embeddings training score: 0.8166485984597485
# (76, 11)
# RF R2: 0.24597207079257277
# Remaining: 1201
# Query no. 2
# Embeddings training score: 0.8626921770741931
# (114, 11)
# RF R2: 0.3250842299748715
# Remaining: 1161
# Query no. 3
# Embeddings training score: 0.8614952953958832
# (149, 11)
# RF R2: 0.39067866838151
# Remaining: 1121
# Query no. 4
# Embeddings training score: 0.8703378401331682
# (181, 11)
# RF R2: 0.3847041168488816
# Remaining: 1081
# Query no. 5
# Embeddings training score: 0.8765450428924574
# (215, 11)
# RF R2: 0.4213171140818288
# Remaining: 1041
# Query no. 6
# Embeddings training score: 0.871697949565763
# (251, 11)
# RF R2: 0.41565092329569
# Remaining: 1001
# Query no. 7
# Embeddings training score: 0.8758759445730495
# (286, 11)
# RF R2: 0.43459052972500434
# Remaining: 961
# Query no. 8
# Embeddings training score: 0.8808582979074505
# (321, 11)
# RF R2: 0.43841301124912113
# Remaining: 921
# Query no. 9
# Embeddings training score: 0.8801302310688425
# (354, 11)
# RF R2: 0.4392978725216564
# Remaining: 881
# Query no. 10
# Embeddings training score: 0.8813259531064318
# (388, 11)
# RF R2: 0.4147769862363959
# Remaining: 841
# Query no. 11
# Embeddings training score: 0.8850686809109234
# (423, 11)
# RF R2: 0.451348769392115
# Remaining: 801
# Query no. 12
# Embeddings training score: 0.8842425093161452
# (460, 11)
# RF R2: 0.4588666143226331
# Remaining: 761
# Query no. 13
# Embeddings training score: 0.883057233230734
# (496, 11)
# RF R2: 0.45905977427494293
# Remaining: 721
# Query no. 14
# Embeddings training score: 0.8832385836443434
# (531, 11)
# RF R2: 0.47099149791004336
# Remaining: 681
# Query no. 15
# Embeddings training score: 0.8829253012303209
# (567, 11)
# RF R2: 0.4820661673608585
# Remaining: 641
# Query no. 16
# Embeddings training score: 0.8857377331181928
# (602, 11)
# RF R2: 0.4817116269856677
# Remaining: 601
# Query no. 17
# Embeddings training score: 0.8886706140296078
# (637, 11)
# RF R2: 0.4847833171270275
# Remaining: 561
# Query no. 18
# Embeddings training score: 0.8869321687632166
# (670, 11)
# RF R2: 0.495328658790793
# Remaining: 521
# Query no. 19
# Embeddings training score: 0.8887158250148425
# (707, 11)
# RF R2: 0.49606256729854104
# Remaining: 481
# Query no. 20
# Embeddings training score: 0.8887049105590729
# (738, 11)
# RF R2: 0.5060482913112703
# Remaining: 441
# Query no. 21
# Embeddings training score: 0.8872937493044141
# (772, 11)
# RF R2: 0.5129439526421886
# Remaining: 401
# Query no. 22
# Embeddings training score: 0.8873156200256268
# (807, 11)
# RF R2: 0.5129737459510282
# Remaining: 361
# Query no. 23
# Embeddings training score: 0.8876274311035812
# (841, 11)
# RF R2: 0.526815220682745
# Remaining: 321
# Query no. 24
# Embeddings training score: 0.8870553360940738
# (876, 11)
# RF R2: 0.5168841177362217
# Remaining: 281
# Query no. 25
# Embeddings training score: 0.8885663317526371
# (907, 11)
# RF R2: 0.5282914791357456
# Remaining: 241
# The Iteration is  12
# NN Test R2 with 5 samples -43.0583003169368
# After Initialization RF R2: 0.18116302769049053
# NN Test R2 after Initialization -0.02983102273244324
# (38, 11)
# Query no. 1
# Embeddings training score: 0.8484920678866388
# (72, 11)
# RF R2: 0.27401036837637616
# Remaining: 1201
# Query no. 2
# Embeddings training score: 0.8686186631830045
# (106, 11)
# RF R2: 0.20521448015912103
# Remaining: 1161
# Query no. 3
# Embeddings training score: 0.8569281081913807
# (142, 11)
# RF R2: 0.25585354269781657
# Remaining: 1121
# Query no. 4
# Embeddings training score: 0.8580797384172818
# (176, 11)
# RF R2: 0.2246670273160466
# Remaining: 1081
# Query no. 5
# Embeddings training score: 0.8631130044785887
# (212, 11)
# RF R2: 0.29329613030177293
# Remaining: 1041
# Query no. 6
# Embeddings training score: 0.8668383493882815
# (250, 11)
# RF R2: 0.3067248966453263
# Remaining: 1001
# Query no. 7
# Embeddings training score: 0.8617133226594047
# (286, 11)
# RF R2: 0.34252797148587155
# Remaining: 961
# Query no. 8
# Embeddings training score: 0.8987009215444793
# (322, 11)
# RF R2: 0.3838377464637679
# Remaining: 921
# Query no. 9
# Embeddings training score: 0.8992367210545207
# (354, 11)
# RF R2: 0.3942732057133407
# Remaining: 881
# Query no. 10
# Embeddings training score: 0.8977340149975951
# (388, 11)
# RF R2: 0.38989776473691495
# Remaining: 841
# Query no. 11
# Embeddings training score: 0.8942163499803859
# (422, 11)
# RF R2: 0.4000029056031539
# Remaining: 801
# Query no. 12
# Embeddings training score: 0.8939590289474771
# (457, 11)
# RF R2: 0.3842386814353813
# Remaining: 761
# Query no. 13
# Embeddings training score: 0.8902356491605787
# (491, 11)
# RF R2: 0.39617753068280004
# Remaining: 721
# Query no. 14
# Embeddings training score: 0.8895213707307584
# (528, 11)
# RF R2: 0.3835143968226986
# Remaining: 681
# Query no. 15
# Embeddings training score: 0.8899357308074196
# (561, 11)
# RF R2: 0.39617753068280015
# Remaining: 641
# Query no. 16
# Embeddings training score: 0.8903712049106538
# (592, 11)
# RF R2: 0.39924098978224287
# Remaining: 601
# Query no. 17
# Embeddings training score: 0.8893852695240156
# (628, 11)
# RF R2: 0.41114638906679235
# Remaining: 561
# Query no. 18
# Embeddings training score: 0.8882120421750409
# (664, 11)
# RF R2: 0.41232503567511625
# Remaining: 521
# Query no. 19
# Embeddings training score: 0.8877241870623088
# (699, 11)
# RF R2: 0.4115770573387342
# Remaining: 481
# Query no. 20
# Embeddings training score: 0.8870026832327074
# (732, 11)
# RF R2: 0.40925553699904427
# Remaining: 441
# Query no. 21
# Embeddings training score: 0.8877457097650444
# (764, 11)
# RF R2: 0.3881532562567196
# Remaining: 401
# Query no. 22
# Embeddings training score: 0.8896383474060198
# (804, 11)
# RF R2: 0.3988600318717874
# Remaining: 361
# Query no. 23
# Embeddings training score: 0.8912814291276004
# (837, 11)
# RF R2: 0.39927211683102404
# Remaining: 321
# Query no. 24
# Embeddings training score: 0.891991592248693
# (870, 11)
# RF R2: 0.40516256237573656
# Remaining: 281
# Query no. 25
# Embeddings training score: 0.8922985246622963
# (903, 11)
# RF R2: 0.41440636669809194
# Remaining: 241
# The Iteration is  13
# NN Test R2 with 5 samples -45.504772778099266
# After Initialization RF R2: 0.17943713136863382
# NN Test R2 after Initialization 0.04129783966768419
# (38, 11)
# Query no. 1
# Embeddings training score: 0.8694113318278662
# (72, 11)
# RF R2: 0.12037597778133147
# Remaining: 1201
# Query no. 2
# Embeddings training score: 0.8645191174834039
# (110, 11)
# RF R2: 0.15206934525104676
# Remaining: 1161
# Query no. 3
# Embeddings training score: 0.8632326554358523
# (147, 11)
# RF R2: 0.19307063683103143
# Remaining: 1121
# Query no. 4
# Embeddings training score: 0.8837233157075094
# (182, 11)
# RF R2: 0.23761327204488225
# Remaining: 1081
# Query no. 5
# Embeddings training score: 0.8775332737017147
# (219, 11)
# RF R2: 0.2478475527350431
# Remaining: 1041
# Query no. 6
# Embeddings training score: 0.8774738904729291
# (252, 11)
# RF R2: 0.21820887947391043
# Remaining: 1001
# Query no. 7
# Embeddings training score: 0.872923962170691
# (288, 11)
# RF R2: 0.24633420219030222
# Remaining: 961
# Query no. 8
# Embeddings training score: 0.8749692210253233
# (323, 11)
# RF R2: 0.26318433122090445
# Remaining: 921
# Query no. 9
# Embeddings training score: 0.8784885938945495
# (358, 11)
# RF R2: 0.25786607115345817
# Remaining: 881
# Query no. 10
# Embeddings training score: 0.8788187495885339
# (394, 11)
# RF R2: 0.27021706155545766
# Remaining: 841
# Query no. 11
# Embeddings training score: 0.879398510773388
# (434, 11)
# RF R2: 0.2763492751031432
# Remaining: 801
# Query no. 12
# Embeddings training score: 0.8781501156364225
# (471, 11)
# RF R2: 0.2812876902131447
# Remaining: 761
# Query no. 13
# Embeddings training score: 0.8807752558006007
# (505, 11)
# RF R2: 0.3238910489605843
# Remaining: 721
# Query no. 14
# Embeddings training score: 0.8787839019895763
# (542, 11)
# RF R2: 0.3141365270942258
# Remaining: 681
# Query no. 15
# Embeddings training score: 0.8775147049334144
# (580, 11)
# RF R2: 0.2992088786645696
# Remaining: 641
# Query no. 16
# Embeddings training score: 0.8757409560636975
# (617, 11)
# RF R2: 0.32063566570284463
# Remaining: 601
# Query no. 17
# Embeddings training score: 0.8773944189629557
# (654, 11)
# RF R2: 0.3307799377806405
# Remaining: 561
# Query no. 18
# Embeddings training score: 0.8769828204083436
# (689, 11)
# RF R2: 0.3296236070428402
# Remaining: 521
# Query no. 19
# Embeddings training score: 0.8784020684179908
# (724, 11)
# RF R2: 0.3525318755477942
# Remaining: 481
# Query no. 20
# Embeddings training score: 0.8801937207987599
# (759, 11)
# RF R2: 0.36304479533939116
# Remaining: 441
# Query no. 21
# Embeddings training score: 0.8800921654827284
# (794, 11)
# RF R2: 0.35811585482016506
# Remaining: 401
# Query no. 22
# Embeddings training score: 0.88063053184126
# (824, 11)
# RF R2: 0.3590956136389716
# Remaining: 361
# Query no. 23
# Embeddings training score: 0.8822128407382599
# (855, 11)
# RF R2: 0.37966839551782106
# Remaining: 321
# Query no. 24
# Embeddings training score: 0.8836337561611225
# (883, 11)
# RF R2: 0.3685460872740871
# Remaining: 281
# Query no. 25
# Embeddings training score: 0.883977822122095
# (918, 11)
# RF R2: 0.3789414360074276
# Remaining: 241
# The Iteration is  14
# NN Test R2 with 5 samples -39.961236373618554
# After Initialization RF R2: 0.21793359224165154
# NN Test R2 after Initialization 0.058900756000486644
# (38, 11)
# Query no. 1
# Embeddings training score: 0.8437695304272916
# (75, 11)
# RF R2: 0.2939323602375373
# Remaining: 1201
# Query no. 2
# Embeddings training score: 0.8603699931825791
# (111, 11)
# RF R2: 0.3278417781048476
# Remaining: 1161
# Query no. 3
# Embeddings training score: 0.8746497072127232
# (146, 11)
# RF R2: 0.33798089405010867
# Remaining: 1121
# Query no. 4
# Embeddings training score: 0.8664350970777466
# (179, 11)
# RF R2: 0.40392927979742044
# Remaining: 1081
# Query no. 5
# Embeddings training score: 0.8801219313958321
# (212, 11)
# RF R2: 0.3804312823413952
# Remaining: 1041
# Query no. 6
# Embeddings training score: 0.8687400347631021
# (250, 11)
# RF R2: 0.3674846134533364
# Remaining: 1001
# Query no. 7
# Embeddings training score: 0.8657714477201803
# (285, 11)
# RF R2: 0.3759856771883262
# Remaining: 961
# Query no. 8
# Embeddings training score: 0.8732409273982776
# (323, 11)
# RF R2: 0.3839815691897961
# Remaining: 921
# Query no. 9
# Embeddings training score: 0.88684176403017
# (359, 11)
# RF R2: 0.3902210973854121
# Remaining: 881
# Query no. 10
# Embeddings training score: 0.8884269597429927
# (396, 11)
# RF R2: 0.437714752183644
# Remaining: 841
# Query no. 11
# Embeddings training score: 0.8869078754913893
# (434, 11)
# RF R2: 0.4316174795970027
# Remaining: 801
# Query no. 12
# Embeddings training score: 0.8896930872738447
# (471, 11)
# RF R2: 0.45549764228637857
# Remaining: 761
# Query no. 13
# Embeddings training score: 0.8895163194739307
# (507, 11)
# RF R2: 0.4639315688857799
# Remaining: 721
# Query no. 14
# Embeddings training score: 0.8923410431092167
# (545, 11)
# RF R2: 0.47016452421497457
# Remaining: 681
# Query no. 15
# Embeddings training score: 0.8923251603935324
# (575, 11)
# RF R2: 0.4925817546351603
# Remaining: 641
# Query no. 16
# Embeddings training score: 0.8943550905573651
# (609, 11)
# RF R2: 0.4870408282420332
# Remaining: 601
# Query no. 17
# Embeddings training score: 0.8952602740548725
# (643, 11)
# RF R2: 0.48061960723891517
# Remaining: 561
# Query no. 18
# Embeddings training score: 0.8958036209756886
# (679, 11)
# RF R2: 0.47621860367941915
# Remaining: 521
# Query no. 19
# Embeddings training score: 0.8949291579124995
# (716, 11)
# RF R2: 0.48085810839191545
# Remaining: 481
# Query no. 20
# Embeddings training score: 0.894947086536315
# (749, 11)
# RF R2: 0.495815604914423
# Remaining: 441
# Query no. 21
# Embeddings training score: 0.8947756963425603
# (780, 11)
# RF R2: 0.49320242102151124
# Remaining: 401
# Query no. 22
# Embeddings training score: 0.8954831807944286
# (816, 11)
# RF R2: 0.48836901674958755
# Remaining: 361
# Query no. 23
# Embeddings training score: 0.8954443510322787
# (850, 11)
# RF R2: 0.49273621699605996
# Remaining: 321
# Query no. 24
# Embeddings training score: 0.8970863512919691
# (879, 11)
# RF R2: 0.5030856646668016
# Remaining: 281
# Query no. 25
# Embeddings training score: 0.8973141893333377
# (912, 11)
# RF R2: 0.5073636617261283
# Remaining: 241
# The Iteration is  15
# NN Test R2 with 5 samples -39.13317457797125
# After Initialization RF R2: 0.2393237762672673
# NN Test R2 after Initialization -0.0995031612746941
# (38, 11)
# Query no. 1
# Embeddings training score: 0.8748868525947943
# (74, 11)
# RF R2: 0.16212029862795696
# Remaining: 1201
# Query no. 2
# Embeddings training score: 0.8624257134660114
# (112, 11)
# RF R2: 0.292347272642277
# Remaining: 1161
# Query no. 3
# Embeddings training score: 0.8564631980719902
# (148, 11)
# RF R2: 0.2269111822508404
# Remaining: 1121
# Query no. 4
# Embeddings training score: 0.8660128365381493
# (183, 11)
# RF R2: 0.26551362595771555
# Remaining: 1081
# Query no. 5
# Embeddings training score: 0.8668744987706777
# (217, 11)
# RF R2: 0.307772084711452
# Remaining: 1041
# Query no. 6
# Embeddings training score: 0.8663558644548879
# (253, 11)
# RF R2: 0.36303430289664784
# Remaining: 1001
# Query no. 7
# Embeddings training score: 0.8677716099430184
# (289, 11)
# RF R2: 0.3654393780907145
# Remaining: 961
# Query no. 8
# Embeddings training score: 0.8703910568466537
# (327, 11)
# RF R2: 0.3691235886263693
# Remaining: 921
# Query no. 9
# Embeddings training score: 0.8723535860215789
# (359, 11)
# RF R2: 0.38867809995413305
# Remaining: 881
# Query no. 10
# Embeddings training score: 0.8714507442745597
# (395, 11)
# RF R2: 0.3959172917018069
# Remaining: 841
# Query no. 11
# Embeddings training score: 0.8737799117808096
# (429, 11)
# RF R2: 0.413442197761268
# Remaining: 801
# Query no. 12
# Embeddings training score: 0.8724440701339836
# (465, 11)
# RF R2: 0.41538768648800384
# Remaining: 761
# Query no. 13
# Embeddings training score: 0.8745658950051884
# (500, 11)
# RF R2: 0.4132048857305911
# Remaining: 721
# Query no. 14
# Embeddings training score: 0.8777750595552775
# (537, 11)
# RF R2: 0.40867763008001723
# Remaining: 681
# Query no. 15
# Embeddings training score: 0.877522821716171
# (571, 11)
# RF R2: 0.42028430304176967
# Remaining: 641
# Query no. 16
# Embeddings training score: 0.877675246426452
# (606, 11)
# RF R2: 0.423130637635451
# Remaining: 601
# Query no. 17
# Embeddings training score: 0.8770270672299623
# (638, 11)
# RF R2: 0.41174153986222006
# Remaining: 561
# Query no. 18
# Embeddings training score: 0.876268065798891
# (672, 11)
# RF R2: 0.4283637203554831
# Remaining: 521
# Query no. 19
# Embeddings training score: 0.878914713418925
# (707, 11)
# RF R2: 0.4365700173687662
# Remaining: 481
# Query no. 20
# Embeddings training score: 0.8787233133031631
# (742, 11)
# RF R2: 0.43127161509969636
# Remaining: 441
# Query no. 21
# Embeddings training score: 0.8794537980337397
# (776, 11)
# RF R2: 0.4355474609751967
# Remaining: 401
# Query no. 22
# Embeddings training score: 0.881187672101135
# (812, 11)
# RF R2: 0.4327518782613434
# Remaining: 361
# Query no. 23
# Embeddings training score: 0.8813227379082925
# (847, 11)
# RF R2: 0.44253853242148966
# Remaining: 321
# Query no. 24
# Embeddings training score: 0.8814052007340649
# (884, 11)
# RF R2: 0.4461428557388968
# Remaining: 281
# Query no. 25
# Embeddings training score: 0.8827065224511947
# (917, 11)
# RF R2: 0.46605732947358813
# Remaining: 241
# The Iteration is  16
# NN Test R2 with 5 samples -40.27848119830035
# After Initialization RF R2: 0.21610857087934487
# NN Test R2 after Initialization -0.0066012016155549596
# (38, 11)
# Query no. 1
# Embeddings training score: 0.8884049037853327
# (73, 11)
# RF R2: 0.19916083583442468
# Remaining: 1201
# Query no. 2
# Embeddings training score: 0.8514380627653658
# (107, 11)
# RF R2: 0.2567863625682736
# Remaining: 1161
# Query no. 3
# Embeddings training score: 0.8599823343473142
# (141, 11)
# RF R2: 0.2888254844866427
# Remaining: 1121
# Query no. 4
# Embeddings training score: 0.8602177201902568
# (177, 11)
# RF R2: 0.2867534752130587
# Remaining: 1081
# Query no. 5
# Embeddings training score: 0.8635725054770682
# (212, 11)
# RF R2: 0.3274997307439279
# Remaining: 1041
# Query no. 6
# Embeddings training score: 0.8731204466092177
# (250, 11)
# RF R2: 0.3294313891415339
# Remaining: 1001
# Query no. 7
# Embeddings training score: 0.8695825850942477
# (288, 11)
# RF R2: 0.36769778651183094
# Remaining: 961
# Query no. 8
# Embeddings training score: 0.8743280400570135
# (324, 11)
# RF R2: 0.3615262601883402
# Remaining: 921
# Query no. 9
# Embeddings training score: 0.8809373277541261
# (361, 11)
# RF R2: 0.37112048958141186
# Remaining: 881
# Query no. 10
# Embeddings training score: 0.8835137049042888
# (395, 11)
# RF R2: 0.3976702784584828
# Remaining: 841
# Query no. 11
# Embeddings training score: 0.8830479945149832
# (430, 11)
# RF R2: 0.39245333370261903
# Remaining: 801
# Query no. 12
# Embeddings training score: 0.8831162656542273
# (466, 11)
# RF R2: 0.3672136493438233
# Remaining: 761
# Query no. 13
# Embeddings training score: 0.8843510923917249
# (497, 11)
# RF R2: 0.37442631509225155
# Remaining: 721
# Query no. 14
# Embeddings training score: 0.8842681490879492
# (532, 11)
# RF R2: 0.3837554916115251
# Remaining: 681
# Query no. 15
# Embeddings training score: 0.8821840977317481
# (568, 11)
# RF R2: 0.40297231398932953
# Remaining: 641
# Query no. 16
# Embeddings training score: 0.8824885496572744
# (601, 11)
# RF R2: 0.42245467826837435
# Remaining: 601
# Query no. 17
# Embeddings training score: 0.882926303338999
# (637, 11)
# RF R2: 0.43017739963925905
# Remaining: 561
# Query no. 18
# Embeddings training score: 0.883642597592075
# (670, 11)
# RF R2: 0.4269194988177776
# Remaining: 521
# Query no. 19
# Embeddings training score: 0.8842278976457235
# (707, 11)
# RF R2: 0.448089496800655
# Remaining: 481
# Query no. 20
# Embeddings training score: 0.8835016398052251
# (738, 11)
# RF R2: 0.44072278740786075
# Remaining: 441
# Query no. 21
# Embeddings training score: 0.8866256404597472
# (771, 11)
# RF R2: 0.4342524653170442
# Remaining: 401
# Query no. 22
# Embeddings training score: 0.885688979686585
# (810, 11)
# RF R2: 0.4359239611152764
# Remaining: 361
# Query no. 23
# Embeddings training score: 0.8861081594630138
# (842, 11)
# RF R2: 0.4437718735114238
# Remaining: 321
# Query no. 24
# Embeddings training score: 0.8862697776674575
# (878, 11)
# RF R2: 0.4337101338833871
# Remaining: 281
# Query no. 25
# Embeddings training score: 0.8858346477468869
# (912, 11)
# RF R2: 0.445264385265726
# Remaining: 241
# The Iteration is  17
# NN Test R2 with 5 samples -41.01218735916858
# After Initialization RF R2: 0.22968474384832593
# NN Test R2 after Initialization -0.10491275081618423
# (38, 11)
# Query no. 1
# Embeddings training score: 0.8665061744233202
# (74, 11)
# RF R2: 0.2992353691004437
# Remaining: 1201
# Query no. 2
# Embeddings training score: 0.8433285619842013
# (111, 11)
# RF R2: 0.3452322388059703
# Remaining: 1161
# Query no. 3
# Embeddings training score: 0.8659080039315068
# (149, 11)
# RF R2: 0.3438205728116177
# Remaining: 1121
# Query no. 4
# Embeddings training score: 0.86273990640476
# (184, 11)
# RF R2: 0.34699759580476
# Remaining: 1081
# Query no. 5
# Embeddings training score: 0.8641374994207411
# (218, 11)
# RF R2: 0.37796905203711173
# Remaining: 1041
# Query no. 6
# Embeddings training score: 0.8744165414366347
# (251, 11)
# RF R2: 0.4024708027430416
# Remaining: 1001
# Query no. 7
# Embeddings training score: 0.8749395757549019
# (285, 11)
# RF R2: 0.4127629528035499
# Remaining: 961
# Query no. 8
# Embeddings training score: 0.8740469742803308
# (322, 11)
# RF R2: 0.41621260185558695
# Remaining: 921
# Query no. 9
# Embeddings training score: 0.8746624185567695
# (355, 11)
# RF R2: 0.4345337958854376
# Remaining: 881
# Query no. 10
# Embeddings training score: 0.8796463828322403
# (390, 11)
# RF R2: 0.4423671480435659
# Remaining: 841
# Query no. 11
# Embeddings training score: 0.8800354523245979
# (422, 11)
# RF R2: 0.48031018959257765
# Remaining: 801
# Query no. 12
# Embeddings training score: 0.8817497274429725
# (458, 11)
# RF R2: 0.47147049616780956
# Remaining: 761
# Query no. 13
# Embeddings training score: 0.8797317746463683
# (495, 11)
# RF R2: 0.4945967244856797
# Remaining: 721
# Query no. 14
# Embeddings training score: 0.8788254826770088
# (533, 11)
# RF R2: 0.493126196046793
# Remaining: 681
# Query no. 15
# Embeddings training score: 0.8792992891548156
# (570, 11)
# RF R2: 0.509563791851553
# Remaining: 641
# Query no. 16
# Embeddings training score: 0.8784951322590944
# (607, 11)
# RF R2: 0.496152448567971
# Remaining: 601
# Query no. 17
# Embeddings training score: 0.8790569316730219
# (644, 11)
# RF R2: 0.5131631787010892
# Remaining: 561
# Query no. 18
# Embeddings training score: 0.8787489223406467
# (681, 11)
# RF R2: 0.5190855667607907
# Remaining: 521
# Query no. 19
# Embeddings training score: 0.8795274940703495
# (715, 11)
# RF R2: 0.5179243243243243
# Remaining: 481
# Query no. 20
# Embeddings training score: 0.8805511975999565
# (749, 11)
# RF R2: 0.5103047357805567
# Remaining: 441
# Query no. 21
# Embeddings training score: 0.8816120753024357
# (782, 11)
# RF R2: 0.5253425413473174
# Remaining: 401
# Query no. 22
# Embeddings training score: 0.8822685202047761
# (814, 11)
# RF R2: 0.5207936103267445
# Remaining: 361
# Query no. 23
# Embeddings training score: 0.8822015578041319
# (849, 11)
# RF R2: 0.5259864138765631
# Remaining: 321
# Query no. 24
# Embeddings training score: 0.8822288632992743
# (886, 11)
# RF R2: 0.5332951674062121
# Remaining: 281
# Query no. 25
# Embeddings training score: 0.8823558063128663
# (923, 11)
# RF R2: 0.5444619927390075
# Remaining: 241
# The Iteration is  18
# NN Test R2 with 5 samples -37.80667737806843
# After Initialization RF R2: 0.162327352365775
# NN Test R2 after Initialization 0.16529328457524275
# (38, 11)
# Query no. 1
# Embeddings training score: 0.8625518213215662
# (72, 11)
# RF R2: 0.21213516576130353
# Remaining: 1201
# Query no. 2
# Embeddings training score: 0.8632867496911127
# (104, 11)
# RF R2: 0.2062922422659017
# Remaining: 1161
# Query no. 3
# Embeddings training score: 0.8703579464600848
# (141, 11)
# RF R2: 0.2976196469688698
# Remaining: 1121
# Query no. 4
# Embeddings training score: 0.8721911844581812
# (176, 11)
# RF R2: 0.38119121441248704
# Remaining: 1081
# Query no. 5
# Embeddings training score: 0.8744206699093743
# (210, 11)
# RF R2: 0.39271046166809054
# Remaining: 1041
# Query no. 6
# Embeddings training score: 0.8744139037190151
# (247, 11)
# RF R2: 0.4144019307721023
# Remaining: 1001
# Query no. 7
# Embeddings training score: 0.8709012199299291
# (280, 11)
# RF R2: 0.4287547503834209
# Remaining: 961
# Query no. 8
# Embeddings training score: 0.8729609315799273
# (316, 11)
# RF R2: 0.4252185218442589
# Remaining: 921
# Query no. 9
# Embeddings training score: 0.8721730186079899
# (354, 11)
# RF R2: 0.41975469306311397
# Remaining: 881
# Query no. 10
# Embeddings training score: 0.8779857121324823
# (391, 11)
# RF R2: 0.4214606192772691
# Remaining: 841
# Query no. 11
# Embeddings training score: 0.8778103964787611
# (427, 11)
# RF R2: 0.4245291752815308
# Remaining: 801
# Query no. 12
# Embeddings training score: 0.8845700632579341
# (464, 11)
# RF R2: 0.42356399830322355
# Remaining: 761
# Query no. 13
# Embeddings training score: 0.8825790603796859
# (501, 11)
# RF R2: 0.4284302710093537
# Remaining: 721
# Query no. 14
# Embeddings training score: 0.8922123995631569
# (535, 11)
# RF R2: 0.44261144240864825
# Remaining: 681
# Query no. 15
# Embeddings training score: 0.891724723632919
# (571, 11)
# RF R2: 0.4379181947718579
# Remaining: 641
# Query no. 16
# Embeddings training score: 0.8932944429199993
# (606, 11)
# RF R2: 0.448321728649304
# Remaining: 601
# Query no. 17
# Embeddings training score: 0.891913041447808
# (642, 11)
# RF R2: 0.4662406087082914
# Remaining: 561
# Query no. 18
# Embeddings training score: 0.8923910351182791
# (675, 11)
# RF R2: 0.44426826071187664
# Remaining: 521
# Query no. 19
# Embeddings training score: 0.8915291407044318
# (709, 11)
# RF R2: 0.4590341375179059
# Remaining: 481
# Query no. 20
# Embeddings training score: 0.8928527361138039
# (743, 11)
# RF R2: 0.45966703293069056
# Remaining: 441
# Query no. 21
# Embeddings training score: 0.8928488752760676
# (778, 11)
# RF R2: 0.4717998995966586
# Remaining: 401
# Query no. 22
# Embeddings training score: 0.8923162342536941
# (813, 11)
# RF R2: 0.46922471746385674
# Remaining: 361
# Query no. 23
# Embeddings training score: 0.8912630926743667
# (849, 11)
# RF R2: 0.4832842664669309
# Remaining: 321
# Query no. 24
# Embeddings training score: 0.8913545677727899
# (878, 11)
# RF R2: 0.49116952831395777
# Remaining: 281
# Query no. 25
# Embeddings training score: 0.8913587821244993
# (909, 11)
# RF R2: 0.506393898606116
# Remaining: 241
# The Iteration is  19
# NN Test R2 with 5 samples -46.556588165207096
# After Initialization RF R2: -0.05003036250900106
# NN Test R2 after Initialization -0.8167619654490235
# (38, 11)
# Query no. 1
# Embeddings training score: 0.8486283195953424
# (73, 11)
# RF R2: 0.22162266207103054
# Remaining: 1201
# Query no. 2
# Embeddings training score: 0.8541710291216743
# (109, 11)
# RF R2: 0.3081244185875204
# Remaining: 1161
# Query no. 3
# Embeddings training score: 0.8652272495891961
# (144, 11)
# RF R2: 0.3370271306701069
# Remaining: 1121
# Query no. 4
# Embeddings training score: 0.8819180248509061
# (178, 11)
# RF R2: 0.3317100672593415
# Remaining: 1081
# Query no. 5
# Embeddings training score: 0.876592155599775
# (215, 11)
# RF R2: 0.34408542358737126
# Remaining: 1041
# Query no. 6
# Embeddings training score: 0.8704024663734334
# (253, 11)
# RF R2: 0.3759591549375978
# Remaining: 1001
# Query no. 7
# Embeddings training score: 0.869562311799715
# (288, 11)
# RF R2: 0.3997029042775897
# Remaining: 961
# Query no. 8
# Embeddings training score: 0.8678732333868916
# (324, 11)
# RF R2: 0.3737945551854601
# Remaining: 921
# Query no. 9
# Embeddings training score: 0.8685082573087861
# (359, 11)
# RF R2: 0.37849300994157065
# Remaining: 881
# Query no. 10
# Embeddings training score: 0.872116280559979
# (394, 11)
# RF R2: 0.40825572599430804
# Remaining: 841
# Query no. 11
# Embeddings training score: 0.8711821621430292
# (430, 11)
# RF R2: 0.411852781464772
# Remaining: 801
# Query no. 12
# Embeddings training score: 0.8756117122476955
# (462, 11)
# RF R2: 0.42514968430492517
# Remaining: 761
# Query no. 13
# Embeddings training score: 0.8775497869786443
# (501, 11)
# RF R2: 0.44993647362352074
# Remaining: 721
# Query no. 14
# Embeddings training score: 0.8783934262821013
# (537, 11)
# RF R2: 0.45055402119986576
# Remaining: 681
# Query no. 15
# Embeddings training score: 0.8790730351534645
# (571, 11)
# RF R2: 0.43987002369777095
# Remaining: 641
# Query no. 16
# Embeddings training score: 0.8787400424316507
# (603, 11)
# RF R2: 0.44997679459929585
# Remaining: 601
# Query no. 17
# Embeddings training score: 0.8803279020007452
# (637, 11)
# RF R2: 0.4476684187361707
# Remaining: 561
# Query no. 18
# Embeddings training score: 0.8788594881108603
# (672, 11)
# RF R2: 0.4532990307875031
# Remaining: 521
# Query no. 19
# Embeddings training score: 0.8804975475340914
# (707, 11)
# RF R2: 0.4674591208327368
# Remaining: 481
# Query no. 20
# Embeddings training score: 0.8803352471644628
# (744, 11)
# RF R2: 0.4645443387155199
# Remaining: 441
# Query no. 21
# Embeddings training score: 0.881305072434964
# (781, 11)
# RF R2: 0.45453624809681303
# Remaining: 401
# Query no. 22
# Embeddings training score: 0.8819700538625534
# (814, 11)
# RF R2: 0.4668813636930117
# Remaining: 361
# Query no. 23
# Embeddings training score: 0.8830506230758415
# (847, 11)
# RF R2: 0.4671201063127327
# Remaining: 321
# Query no. 24
# Embeddings training score: 0.8830739225623307
# (883, 11)
# RF R2: 0.4801634114368267
# Remaining: 281
# Query no. 25
# Embeddings training score: 0.8843325678182089
# (916, 11)
# RF R2: 0.4939261276550134
# Remaining: 241
