# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from modAL.models import ActiveLearner, CommitteeRegressor
from modAL.disagreement import vote_entropy_sampling, max_std_sampling
import matplotlib.pyplot as plt
import torch
from torch.nn import MSELoss
from skorch.regressor import NeuralNetRegressor
from copy import deepcopy
from skorch.dataset import ValidSplit
from skorch.callbacks import EarlyStopping
from sklearn.cluster import DBSCAN, OPTICS, cluster_optics_dbscan, Birch, SpectralClustering
from sklearn.neighbors import NearestNeighbors
from sklearn import metrics
import matplotlib.gridspec as gridspec
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from torch.nn import Linear
from torch.nn import Sigmoid, ReLU
from torch.nn import Module
from sklearn.metrics import r2_score
import copy
from scipy.spatial import distance
from scipy.spatial.distance import euclidean
from torch import tensor
from sklearn.metrics import mean_squared_error
from scipy.spatial.distance import cdist
from sklearn.ensemble import RandomForestRegressor
from torch.nn.init import xavier_uniform_
from model import MLP
from model_state import get_model_params, get_input_for_hidden_layers, get_model_params_gradientNorm
from functions_batch1 import get_variance, qbc, normalization, error_reduct_fuc, total_disagrement, grad_norm, averaged_grad_norm, get_avg_grad_norm, training_loss
import random
from skorch.callbacks import EarlyStopping, LRScheduler, Freezer, Unfreezer
from torch.optim.lr_scheduler import CyclicLR, ReduceLROnPlateau
from skorch.regressor import NeuralNetRegressor, NeuralNet
from model_state import features_concat, learning_state_features_concat
import gc
import warnings
from modAL.utils.selection import multi_argmax
warnings.filterwarnings("ignore")

# %%
# Hyper-params:
query_number = 20          # The number of the AL Iterations in each Exp
iteration = 20             # Total number of the Exps
batch_size = 10
total_initail_size = 10
initial_size = 5
dimensions = 18   # Total dimension of the data features + model states

seed_rf = np.load(file="..\..\Datasets\Diabetes\seed_for_RF.npy")
seed_initial = np.load(file="..\..\Datasets\Diabetes\seed_for_initialSamples.npy")

seed_nn1 = np.random.randint(10000, size=100)
seed_nn2 = np.random.randint(10000, size=100)
seed_nn3 = np.random.randint(10000, size=100)
seed_nn4 = np.random.randint(10000, size=100)
seed_nn5 = np.random.randint(10000, size=100)
seed_nn6 = np.random.randint(10000, size=100)
seed_predictor = np.random.randint(10000, size=100)

np.save(file="..\..\Results\Res_Diabetes\OMAL2\seed_for_nn1.npy", arr=seed_nn1)
np.save(file="..\..\Results\Res_Diabetes\OMAL2\seed_for_nn2.npy", arr=seed_nn2)
np.save(file="..\..\Results\Res_Diabetes\OMAL2\seed_for_nn3.npy", arr=seed_nn3)
np.save(file="..\..\Results\Res_Diabetes\OMAL2\seed_for_nn4.npy", arr=seed_nn4)
np.save(file="..\..\Results\Res_Diabetes\OMAL2\seed_for_nn5.npy", arr=seed_nn5)
np.save(file="..\..\Results\Res_Diabetes\OMAL2\seed_for_nn6.npy", arr=seed_nn6)

np.save(file="..\..\Results\Res_Diabetes\OMAL2\seed_predictor.npy", arr=seed_predictor)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def Committee_Prediction(learner_list, X_test, y_test):
    initial_pred=[]
    for i in learner_list:
        initial_pred.append(r2_score(y_test, i.predict(X_test)))
    initial_pred=np.array(initial_pred)
    
    return initial_pred.mean()

# %%
def main_function(query_number, iters):
    # For saving results:
    rf_model_training_r2 = []
    rf_model_training_mse = []
    rf_model_testing_r2 = []
    rf_model_testing_mse = []
    
    # Number of member in committee:
    n_members = 3
    learner_list = []
    
    # The model for evaluation:
    rf_model = RandomForestRegressor(random_state=seed_rf[iters], n_estimators=100)
    gradient_norms = np.empty(shape=(0, 0))
    
    # Load the data:
    name1 = "..\..\Datasets\Diabetes\X_train" + str(iters) + ".npy"
    name2 = "..\..\Datasets\Diabetes\X_test" + str(iters) + ".npy"
    name3 = "..\..\Datasets\Diabetes\y_train" + str(iters) + ".npy"
    name4 = "..\..\Datasets\Diabetes\y_test" + str(iters) + ".npy"
    
    X_train = np.load(name1, allow_pickle=True).astype(np.float32)
    X_test = np.load(name2, allow_pickle=True).astype(np.float32)
    y_train = np.load(name3, allow_pickle=True).astype(np.float32).reshape(-1, 1)
    y_test = np.load(name4, allow_pickle=True).astype(np.float32).reshape(-1, 1)
    
    # Dimensionality of data:
    X = X_train.shape[1]
    # The index of the unlabeled pool:
    X_index = np.arange(X_train.shape[0])

    used_data = np.empty(shape=(0, X))
    used_label = np.empty(shape=(0)).reshape(-1, 1)

    X_initial = np.empty(shape=(0,X))
    y_initial = np.empty(shape=(0)).reshape(-1, 1)
    
    # Initial Stage 1:
    np.random.seed(seed_initial[iters])
    idx = np.random.choice(range(len(X_index)), size=initial_size, replace=False)
    train_idx = X_index[idx]

    X_initial = X_train[train_idx]
    y_initial = y_train[train_idx].reshape(-1, 1)

    used_data = np.append(used_data, X_initial, axis=0).astype(np.float32)
    used_label = np.append(used_label, y_initial, axis=0).astype(np.float32).reshape(-1, 1)
    X_index = np.delete(X_index, idx, axis=0)

    
    used_data = torch.from_numpy(used_data).to(device)
    used_label = torch.from_numpy(used_label).to(device)
    for member_idx in range(n_members):
        if member_idx == 0:
            np.random.seed(seed_nn1[iters])
            torch.manual_seed(seed_nn2[iters])
        if member_idx == 1:
            np.random.seed(seed_nn3[iters])
            torch.manual_seed(seed_nn4[iters])
        if member_idx == 2:
            np.random.seed(seed_nn5[iters])
            torch.manual_seed(seed_nn6[iters])
            
        regressor = NeuralNetRegressor(MLP(X),
                                   criterion=MSELoss(),
                                   optimizer=torch.optim.Adam,
                                   verbose=0,
                                   max_epochs=30,
                                   lr=0.001,
                                   # Used for the batch AL
                                   callbacks=[EarlyStopping(patience=5), ('lr_scheduler', LRScheduler(policy=ReduceLROnPlateau))],
                                   train_split=ValidSplit(cv=5),
                                   warm_start=True,
                                   device='cuda',
                                   batch_size = -1
                                   )
        regressor.fit(used_data, used_label)
        learner_list.append(regressor)
    
    print("NN Test R2 with 5 samples", Committee_Prediction(learner_list, X_test, y_test))

    # Number of LAL features:
    learning_state_features = np.empty(shape=(0, dimensions))
    loss_reduction_target = np.empty(shape=(0)).reshape(-1, 1)

    # other random samples:
    rest_initial_X = np.empty(shape=(0, X))
    rest_initial_y = np.empty(shape=(0)).reshape(-1, 1)

    # LAL Initialization: Stage 2
    predictor = RandomForestRegressor(n_estimators=1000, random_state=seed_predictor[iters])
    np.random.seed(seed_initial[iters])
    idx = np.random.choice(range(len(X_index)), size=total_initail_size-initial_size, replace=False)
    train_idx = X_index[idx]
    
    rest_initial_X = np.append(rest_initial_X, X_train[train_idx], axis=0).astype(np.float32)
    rest_initial_y = np.append(rest_initial_y, y_train[train_idx], axis=0).astype(np.float32).reshape(-1, 1)

    X_index = np.delete(X_index, idx, axis=0)

    for i in range(rest_initial_X.shape[0]):

        single_X = rest_initial_X[i],
        single_y = rest_initial_y[i].reshape(1, -1)
        single_X = single_X[0].reshape(1, -1)
        
        single_X = torch.from_numpy(single_X).to(device)
        single_y = torch.from_numpy(single_y).to(device)

        # Model params
        model_params = get_model_params_gradientNorm(learner_list)

        # updated data
        used_data = torch.cat((used_data, single_X), 0)
        used_label = torch.cat((used_label, single_y), 0)

        # Retrain the model:
        for l in learner_list:
            l.fit(X=used_data,y=used_label)
            
        single_X = single_X.cpu().numpy()
        single_y = single_y.cpu().numpy()
            
        index = train_idx[i]

        # The training sample:
        data_params = X_train[index]
      
        LALfeatures = features_concat(model_params, data_params)

        loss_reduction = get_avg_grad_norm(learner_list, single_X, single_y)
        
        learning_state_features = learning_state_features_concat(learning_state_features, LALfeatures)
        loss_reduction_target = np.append(loss_reduction_target, np.array([loss_reduction]).reshape(-1, 1), axis=0).astype(np.float32).reshape(-1, 1)

        
    used_data = used_data.cpu().numpy()
    used_label = used_label.cpu().numpy()

    # Finished the Initialization Stages:
    # RF Regressor for evaluation:
    rf_model.fit(used_data, used_label.ravel())
    # Training Scores:
    rf_training_r2 = r2_score(used_label, rf_model.predict(used_data))
    rf_training_mse = mean_squared_error(used_label, rf_model.predict(used_data))
    rf_model_training_r2.append(rf_training_r2)
    rf_model_training_mse.append(rf_training_mse)
    
    # Test Scores:
    rf_model_r2 = r2_score(y_test, rf_model.predict(X_test))
    rf_model_mse = mean_squared_error(y_test, rf_model.predict(X_test))
    rf_model_testing_r2.append(rf_model_r2)
    rf_model_testing_mse.append(rf_model_mse)
    
    print("After Initialization RF R2:", rf_model_r2)
    print("NN Test R2 after Initialization", Committee_Prediction(learner_list, X_test, y_test))

    print(np.unique(used_data, axis=0).shape)
    for idx in range(query_number):
        np.random.seed(None)
        print('Query no. %d' % (idx+1))

        Error_reduction_list, training_score = error_reduct_fuc(X_train, X_index, learner_list, learning_state_features, loss_reduction_target, X_index.shape[0], predictor)

        idx = multi_argmax(np.array(Error_reduction_list), n_instances=batch_size)
       
        X_train_indices = X_index[idx]
        
        # Update
        X_index = np.delete(X_index, idx, axis=0)

        for X_train_index in X_train_indices:

            new_X = X_train[X_train_index].reshape(1, -1)
            new_y = y_train[X_train_index].reshape(1, -1)
            
            used_data = np.append(used_data, new_X, axis=0).astype(np.float32)
            used_label = np.append(used_label, new_y, axis=0).astype(np.float32).reshape(-1, 1)
            
            used_data = torch.from_numpy(used_data).to(device)
            used_label = torch.from_numpy(used_label).to(device)

            # Model params
            model_params = get_model_params_gradientNorm(learner_list)
            data_params = X_train[X_train_index]
            LALfeatures = features_concat(model_params, data_params)
            
            for l in learner_list:
                l.fit(used_data, used_label)
            
            used_data = used_data.cpu().numpy()
            used_label = used_label.cpu().numpy()

            loss_reduction = get_avg_grad_norm(learner_list, new_X, new_y)  
            gradient_norms = np.append(gradient_norms, loss_reduction)
            
            learning_state_features = learning_state_features_concat(learning_state_features, LALfeatures)
            loss_reduction_target = np.append(loss_reduction_target, np.array([loss_reduction]).reshape(-1, 1), axis=0).astype(np.float32).reshape(-1, 1)
        

        # RF Evaluation
        rf_model.fit(used_data, used_label.ravel())
        
        # Training Evaluation:
        rf_training_r2 = r2_score(used_label, rf_model.predict(used_data))
        rf_training_mse = mean_squared_error(used_label, rf_model.predict(used_data))
        rf_model_training_r2.append(rf_training_r2)
        rf_model_training_mse.append(rf_training_mse)
        
        # Test Evaluation:
        rf_model_r2 = r2_score(y_test, rf_model.predict(X_test))
        rf_model_mse = mean_squared_error(y_test, rf_model.predict(X_test))
        rf_model_testing_r2.append(rf_model_r2)
        rf_model_testing_mse.append(rf_model_mse)

        print(np.unique(used_data, axis=0).shape)
        print("RF R2:", rf_model_r2)
        print("Remaining:", X_index.shape[0])
        # print('NN R2', Committee_Prediction(learner_list, X_test, y_test))

    # RF
    rf_model_testing_r2 = np.array(rf_model_testing_r2)
    rf_model_testing_mse = np.array(rf_model_testing_mse)
    rf_model_training_r2 = np.array(rf_model_training_r2)
    rf_model_training_mse = np.array(rf_model_training_mse)
    
    # Used_data and Unsed_label:
    np.save(file="..\..\Results\Res_Diabetes\OMAL2\Summary\\used_data" + str(iters) + ".npy", arr=used_data)
    np.save(file="..\..\Results\Res_Diabetes\OMAL2\Summary\\used_labels" + str(iters) + ".npy", arr=used_label)

    np.save(file="..\..\Results\Res_Diabetes\OMAL2\Summary\\testing_rf_r2_" + str(iters) + ".npy", arr=rf_model_testing_r2)
    np.save(file="..\..\Results\Res_Diabetes\OMAL2\Summary\\testing_rf_mse_" + str(iters) + ".npy", arr=rf_model_testing_mse)
    np.save(file="..\..\Results\Res_Diabetes\OMAL2\Summary\\training_rf_r2_" + str(iters) + ".npy", arr=rf_model_training_r2)
    np.save(file="..\..\Results\Res_Diabetes\OMAL2\Summary\\training_rf_mse_" + str(iters) + ".npy", arr=rf_model_training_mse)

# %%
for i in range(iteration):
    print("The Iteration is ", i)
    main_function(query_number, i)
# Out:
# The Iteration is  0
# NN Test R2 with 5 samples -3.2795075876774344
# After Initialization RF R2: 0.01017105099476967
# NN Test R2 after Initialization -2.2422870340871714
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8184308632440196
# (20, 10)
# RF R2: -0.003951601384070802
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8140514205574427
# (30, 10)
# RF R2: 0.1791956957470937
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8495704571651662
# (40, 10)
# RF R2: 0.15935476391608483
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8710916265877251
# (50, 10)
# RF R2: 0.24588014084271692
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8804728088999727
# (60, 10)
# RF R2: 0.3963866811230471
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8786352441888214
# (70, 10)
# RF R2: 0.21873303118265897
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8617445512090777
# (80, 10)
# RF R2: 0.29739890570921435
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8925609454829472
# (90, 10)
# RF R2: 0.3918311779257204
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8811884297288922
# (100, 10)
# RF R2: 0.3558558526890695
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8736067369035678
# (110, 10)
# RF R2: 0.4875535796481528
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8763554597628107
# (120, 10)
# RF R2: 0.42310704195273263
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8825689815167128
# (130, 10)
# RF R2: 0.48515621107197393
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8813814644391424
# (140, 10)
# RF R2: 0.5044567882393973
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8789547617124844
# (150, 10)
# RF R2: 0.49620604187481143
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8703828313950968
# (160, 10)
# RF R2: 0.4937432536966295
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8747376814756093
# (170, 10)
# RF R2: 0.49730175524158726
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8779546632838069
# (180, 10)
# RF R2: 0.4775225408024367
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.876315648667848
# (190, 10)
# RF R2: 0.4336497758541391
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8737442999513866
# (200, 10)
# RF R2: 0.4990157896759304
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8827612907198685
# (210, 10)
# RF R2: 0.49056525374773996
# Remaining: 143
# The Iteration is  1
# NN Test R2 with 5 samples -3.74770375067123
# After Initialization RF R2: 0.20844341964741697
# NN Test R2 after Initialization -0.5541944558884319
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8945579717725356
# (20, 10)
# RF R2: 0.2994134942185883
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8604679323822153
# (30, 10)
# RF R2: 0.3288986703913688
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.9028110499847637
# (40, 10)
# RF R2: 0.3894279351601393
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8734966777767887
# (50, 10)
# RF R2: 0.3769529129340814
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8670944311102424
# (60, 10)
# RF R2: 0.3732571936301302
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8655698627829511
# (70, 10)
# RF R2: 0.39270197806248197
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8698237468818536
# (80, 10)
# RF R2: 0.39186556300280273
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8743760227810558
# (90, 10)
# RF R2: 0.3667765128426659
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8651491282845974
# (100, 10)
# RF R2: 0.373207650797442
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8640884838453384
# (110, 10)
# RF R2: 0.3878944873343202
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8612995420361182
# (120, 10)
# RF R2: 0.39170081713897276
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.858076776186644
# (130, 10)
# RF R2: 0.4089739744563766
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8555372037224797
# (140, 10)
# RF R2: 0.3859655330810965
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8593656000439762
# (150, 10)
# RF R2: 0.38592766439947934
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8607596885490679
# (160, 10)
# RF R2: 0.45814240862388533
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8624803121877354
# (170, 10)
# RF R2: 0.4665457602074726
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8488601109105434
# (180, 10)
# RF R2: 0.49952237839420777
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8538298632002507
# (190, 10)
# RF R2: 0.4983965230012235
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.850575368238722
# (200, 10)
# RF R2: 0.5027866032094219
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8494848498181373
# (210, 10)
# RF R2: 0.5016284680924137
# Remaining: 143
# The Iteration is  2
# NN Test R2 with 5 samples -3.660489597139246
# After Initialization RF R2: 0.2925063658507443
# NN Test R2 after Initialization -3.6099945349432634
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8998449765359833
# (20, 10)
# RF R2: 0.29037987448622626
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.9224442020506544
# (30, 10)
# RF R2: 0.35931718754148034
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.9102963244650067
# (40, 10)
# RF R2: 0.33316852183830026
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.9087350302334898
# (50, 10)
# RF R2: 0.30561129830526546
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8900146793722571
# (60, 10)
# RF R2: 0.3814444634215953
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8937203826248513
# (70, 10)
# RF R2: 0.34936907153264896
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8888275352737289
# (80, 10)
# RF R2: 0.37613835718591004
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8801837354020867
# (90, 10)
# RF R2: 0.40369573464964303
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.876846867803768
# (100, 10)
# RF R2: 0.4438064651899344
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8769318476639927
# (110, 10)
# RF R2: 0.443456821466614
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8689292351454666
# (120, 10)
# RF R2: 0.4530153602997027
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8774772068560036
# (130, 10)
# RF R2: 0.4684143742707041
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8761645863701611
# (140, 10)
# RF R2: 0.45963304309656416
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.871088525626303
# (150, 10)
# RF R2: 0.42728635366000334
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8636993220249604
# (160, 10)
# RF R2: 0.4398784307334983
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8619717030199099
# (170, 10)
# RF R2: 0.47124197067734874
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.86211338637737
# (180, 10)
# RF R2: 0.4710852294169222
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8597810655819978
# (190, 10)
# RF R2: 0.44117761701088853
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8618824106918848
# (200, 10)
# RF R2: 0.4079963143808619
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8608251682104279
# (210, 10)
# RF R2: 0.4279713039407518
# Remaining: 143
# The Iteration is  3
# NN Test R2 with 5 samples -4.16707356284437
# After Initialization RF R2: 0.36481536421176197
# NN Test R2 after Initialization -3.9245972305657
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8440519319280982
# (20, 10)
# RF R2: 0.42111165681302354
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.9048705275198246
# (30, 10)
# RF R2: 0.421629357792922
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.9238320446883356
# (40, 10)
# RF R2: 0.30672322071556646
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8986974962575243
# (50, 10)
# RF R2: 0.2580363142819744
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8662804182049024
# (60, 10)
# RF R2: 0.3050070996932712
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8687081237583549
# (70, 10)
# RF R2: 0.369357895972232
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8697429225951121
# (80, 10)
# RF R2: 0.257274323765329
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8768305352776513
# (90, 10)
# RF R2: 0.27951847758711945
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8685463549407004
# (100, 10)
# RF R2: 0.30115177081767996
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8651304545571905
# (110, 10)
# RF R2: 0.3085706767768679
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.873158097232557
# (120, 10)
# RF R2: 0.2834246712799209
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8723679859377788
# (130, 10)
# RF R2: 0.3019948292102911
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8727858722179329
# (140, 10)
# RF R2: 0.3523235996219385
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8679134493976383
# (150, 10)
# RF R2: 0.3745851600917076
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8661847608978617
# (160, 10)
# RF R2: 0.3708663149280752
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8634216311460859
# (170, 10)
# RF R2: 0.394027401050677
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8636643615222834
# (180, 10)
# RF R2: 0.4121776173853834
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8649917927147328
# (190, 10)
# RF R2: 0.4428587205188256
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.861390970407707
# (200, 10)
# RF R2: 0.4580376269665455
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8615333025187368
# (210, 10)
# RF R2: 0.4550898674601994
# Remaining: 143
# The Iteration is  4
# NN Test R2 with 5 samples -3.9659899909422536
# After Initialization RF R2: 0.2647513237024165
# NN Test R2 after Initialization -3.5344702074134147
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8727631342412014
# (20, 10)
# RF R2: 0.2552107986567087
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.9307958512152392
# (30, 10)
# RF R2: 0.3696603651666678
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8777799551252854
# (40, 10)
# RF R2: 0.44182280108312166
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8783639405545913
# (50, 10)
# RF R2: 0.48029064255995946
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8812343853667942
# (60, 10)
# RF R2: 0.5247167976121421
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8765170580190972
# (70, 10)
# RF R2: 0.5599168121139491
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8782464013665834
# (80, 10)
# RF R2: 0.5930279863275054
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8774647306502027
# (90, 10)
# RF R2: 0.5860604480208977
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8707246902728621
# (100, 10)
# RF R2: 0.5335063196027386
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8707002960882628
# (110, 10)
# RF R2: 0.5250315642145873
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.863057571131526
# (120, 10)
# RF R2: 0.47057906455232634
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8602518698748779
# (130, 10)
# RF R2: 0.4782955085577322
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8621278012476089
# (140, 10)
# RF R2: 0.44038651297110654
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8623603722236897
# (150, 10)
# RF R2: 0.4467017821224064
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.860251255702048
# (160, 10)
# RF R2: 0.4869919932383534
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8626801583517012
# (170, 10)
# RF R2: 0.49305054778551305
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8641523632237766
# (180, 10)
# RF R2: 0.4940424993897503
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8603279538121574
# (190, 10)
# RF R2: 0.5302979297161969
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8603526329786834
# (200, 10)
# RF R2: 0.5111752132106466
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8578517166338391
# (210, 10)
# RF R2: 0.4799429016143957
# Remaining: 143
# The Iteration is  5
# NN Test R2 with 5 samples -4.008491254531637
# After Initialization RF R2: 0.21088154412423232
# NN Test R2 after Initialization -1.1698881873019715
# (10, 10)
# Query no. 1
# Embeddings training score: 0.7855582726934129
# (20, 10)
# RF R2: 0.15501417163620734
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8510846870615304
# (30, 10)
# RF R2: 0.2912006335448265
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8047190242231802
# (40, 10)
# RF R2: 0.3577644786404264
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.7961638206919769
# (50, 10)
# RF R2: 0.29248265952996655
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8265639388489383
# (60, 10)
# RF R2: 0.44701309138835743
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8262552397423312
# (70, 10)
# RF R2: 0.3694093465700772
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8218766425630154
# (80, 10)
# RF R2: 0.46274977173155174
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8283022674156519
# (90, 10)
# RF R2: 0.4440762065521662
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8317016475915295
# (100, 10)
# RF R2: 0.45775757824935814
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8334922601524895
# (110, 10)
# RF R2: 0.4942340417264679
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8367455600092875
# (120, 10)
# RF R2: 0.52314673080946
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8381461966092042
# (130, 10)
# RF R2: 0.5042579108643966
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8438289708329798
# (140, 10)
# RF R2: 0.4934283451612077
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.847173773713528
# (150, 10)
# RF R2: 0.48362679491438965
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8496572586048483
# (160, 10)
# RF R2: 0.48854783584441963
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8474678159782825
# (170, 10)
# RF R2: 0.45341957124567533
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8508693605918484
# (180, 10)
# RF R2: 0.47932860788672693
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8508744759132688
# (190, 10)
# RF R2: 0.43749391158464024
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8493561656266914
# (200, 10)
# RF R2: 0.44693087080554184
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8523344737019957
# (210, 10)
# RF R2: 0.4566011002036695
# Remaining: 143
# The Iteration is  6
# NN Test R2 with 5 samples -4.616268877400627
# After Initialization RF R2: 0.2874004649780366
# NN Test R2 after Initialization -1.4618589586357293
# (10, 10)
# Query no. 1
# Embeddings training score: 0.7716790945642705
# (20, 10)
# RF R2: 0.35599262345536964
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.778206678814708
# (30, 10)
# RF R2: 0.4320053310475316
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8165882965049535
# (40, 10)
# RF R2: 0.39755162217752305
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8506958772614991
# (50, 10)
# RF R2: 0.42033464399358256
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8561833656088655
# (60, 10)
# RF R2: 0.37662006553533534
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.834976765335176
# (70, 10)
# RF R2: 0.33926354046725604
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8419791988037267
# (80, 10)
# RF R2: 0.323773657145247
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8512169633769965
# (90, 10)
# RF R2: 0.32993499393358583
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8431885118864868
# (100, 10)
# RF R2: 0.35525873602293667
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8442663128762127
# (110, 10)
# RF R2: 0.35638855729756214
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8491588155194528
# (120, 10)
# RF R2: 0.3801821127334646
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.855932194850976
# (130, 10)
# RF R2: 0.39890813972913375
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8595057217720041
# (140, 10)
# RF R2: 0.4100934274774547
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8584783846447668
# (150, 10)
# RF R2: 0.38245614072897605
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8609183697570083
# (160, 10)
# RF R2: 0.3717460218359733
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8562497189846445
# (170, 10)
# RF R2: 0.36799074844584945
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8541141716968524
# (180, 10)
# RF R2: 0.3611425843409274
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8587607880148168
# (190, 10)
# RF R2: 0.34732670592924497
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8531003481847842
# (200, 10)
# RF R2: 0.3502244424415254
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8541470781948204
# (210, 10)
# RF R2: 0.3793203648851712
# Remaining: 143
# The Iteration is  7
# NN Test R2 with 5 samples -4.940698581981196
# After Initialization RF R2: 0.19370117539677523
# NN Test R2 after Initialization -3.8507032228515694
# (10, 10)
# Query no. 1
# Embeddings training score: 0.822164195322912
# (20, 10)
# RF R2: 0.21469813911058966
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8367788792709507
# (30, 10)
# RF R2: 0.1400760974936308
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8678468910246266
# (40, 10)
# RF R2: 0.0965942608318161
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8642819742827873
# (50, 10)
# RF R2: 0.03627217724347165
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8627916637942998
# (60, 10)
# RF R2: 0.30960342404935426
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8604934952892178
# (70, 10)
# RF R2: 0.3367852106196543
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8481679756003926
# (80, 10)
# RF R2: 0.37080338239135124
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8471604515138483
# (90, 10)
# RF R2: 0.3849449974279693
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8507698715370974
# (100, 10)
# RF R2: 0.3440336678437059
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8491009602063031
# (110, 10)
# RF R2: 0.42458159468711376
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8480914922920135
# (120, 10)
# RF R2: 0.4244307241613865
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8482851946575605
# (130, 10)
# RF R2: 0.44534324662759084
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8503828374494378
# (140, 10)
# RF R2: 0.4223849012242944
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8556844666586597
# (150, 10)
# RF R2: 0.4370213047015853
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8490274402105653
# (160, 10)
# RF R2: 0.4341227781676401
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8459870037228034
# (170, 10)
# RF R2: 0.4414091912924212
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8523826199332697
# (180, 10)
# RF R2: 0.4415487570704659
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8548465897576695
# (190, 10)
# RF R2: 0.44939269813415805
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8522842915215311
# (200, 10)
# RF R2: 0.44449561765623324
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8514131044955476
# (210, 10)
# RF R2: 0.4339963467672099
# Remaining: 143
# The Iteration is  8
# NN Test R2 with 5 samples -3.393999837282484
# After Initialization RF R2: 0.37592722084430563
# NN Test R2 after Initialization -0.630585426608607
# (10, 10)
# Query no. 1
# Embeddings training score: 0.730800069304615
# (20, 10)
# RF R2: 0.35962584566721
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8464194558064512
# (30, 10)
# RF R2: 0.41996126720423466
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.852103468071457
# (40, 10)
# RF R2: 0.4409254067359607
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8483584818869061
# (50, 10)
# RF R2: 0.5086304623671649
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8383997251514528
# (60, 10)
# RF R2: 0.5662802977684531
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8417341213854139
# (70, 10)
# RF R2: 0.5775865822927762
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8426321195215845
# (80, 10)
# RF R2: 0.5979906345297334
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.839954219365975
# (90, 10)
# RF R2: 0.5887691362502118
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8436418338724712
# (100, 10)
# RF R2: 0.55948079405862
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8484012189770727
# (110, 10)
# RF R2: 0.5346493530870187
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8481089772696716
# (120, 10)
# RF R2: 0.5811347057475127
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8545804426745751
# (130, 10)
# RF R2: 0.5834805065780269
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.849874987570263
# (140, 10)
# RF R2: 0.6011832993106117
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.844079829231841
# (150, 10)
# RF R2: 0.6091682971486991
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8458346152122963
# (160, 10)
# RF R2: 0.615455881852667
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8474850217402051
# (170, 10)
# RF R2: 0.5883866117071969
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8472576257213547
# (180, 10)
# RF R2: 0.5880996453449406
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8495071630215282
# (190, 10)
# RF R2: 0.5842847329304397
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8472038095817975
# (200, 10)
# RF R2: 0.6056634613765534
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8488863347266649
# (210, 10)
# RF R2: 0.6207648072967247
# Remaining: 143
# The Iteration is  9
# NN Test R2 with 5 samples -4.389401572240451
# After Initialization RF R2: 0.035649981461895575
# NN Test R2 after Initialization -2.207082840532792
# (10, 10)
# Query no. 1
# Embeddings training score: 0.9037604684041558
# (20, 10)
# RF R2: 0.22861850121668792
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8595998531777278
# (30, 10)
# RF R2: 0.1115938322112946
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8933046292493106
# (40, 10)
# RF R2: 0.14178976391947062
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8802012730153876
# (50, 10)
# RF R2: 0.2678295960842576
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8581219523197751
# (60, 10)
# RF R2: 0.3094506584564438
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8542183438258739
# (70, 10)
# RF R2: 0.3170063682672619
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8581555783233055
# (80, 10)
# RF R2: 0.3240514014655784
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8674710925166039
# (90, 10)
# RF R2: 0.3388811510896126
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8719306795422913
# (100, 10)
# RF R2: 0.4126059747310804
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8706258226192051
# (110, 10)
# RF R2: 0.40404466294450503
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8679381321378548
# (120, 10)
# RF R2: 0.427072187656081
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.872431467805683
# (130, 10)
# RF R2: 0.41707557959056685
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8702026847615499
# (140, 10)
# RF R2: 0.42298184017970775
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8645560281632376
# (150, 10)
# RF R2: 0.4021489975206619
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8667699010667742
# (160, 10)
# RF R2: 0.40264218406554453
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8621304675145016
# (170, 10)
# RF R2: 0.4114696790990424
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8584304686183528
# (180, 10)
# RF R2: 0.47668916216690127
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8568744613511347
# (190, 10)
# RF R2: 0.44362459786719177
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8540199501363954
# (200, 10)
# RF R2: 0.4284388251812822
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8517810877800267
# (210, 10)
# RF R2: 0.4109863325401182
# Remaining: 143
# The Iteration is  10
# NN Test R2 with 5 samples -3.7957339309374714
# After Initialization RF R2: 0.23162437973863492
# NN Test R2 after Initialization -1.2620272154534204
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8466145390136457
# (20, 10)
# RF R2: 0.1901476988372066
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.9058044440086045
# (30, 10)
# RF R2: 0.2254676605744096
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8460906791060738
# (40, 10)
# RF R2: 0.24755726501134567
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8342214604206205
# (50, 10)
# RF R2: 0.26482122967963906
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8464833885478871
# (60, 10)
# RF R2: 0.2310236356265879
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8445856862029043
# (70, 10)
# RF R2: 0.3559211931170172
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8534903778151773
# (80, 10)
# RF R2: 0.47007898945891813
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8614026745988671
# (90, 10)
# RF R2: 0.4707631171054233
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8596767933016031
# (100, 10)
# RF R2: 0.4735375285691833
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.85965765024767
# (110, 10)
# RF R2: 0.45650062884707043
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8556160406506992
# (120, 10)
# RF R2: 0.4574139176816323
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8588342012872763
# (130, 10)
# RF R2: 0.4221724516292309
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.858076538936863
# (140, 10)
# RF R2: 0.42602300269569304
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8498459624687172
# (150, 10)
# RF R2: 0.4247679155040388
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8442169321441337
# (160, 10)
# RF R2: 0.4490964430470459
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8491754514411322
# (170, 10)
# RF R2: 0.45622480304387214
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.84686440864202
# (180, 10)
# RF R2: 0.46285654334647275
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8469647809697104
# (190, 10)
# RF R2: 0.4941412497802624
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8481587900054104
# (200, 10)
# RF R2: 0.447946289679126
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.84804196951473
# (210, 10)
# RF R2: 0.4401965425289628
# Remaining: 143
# The Iteration is  11
# NN Test R2 with 5 samples -4.81422748740592
# After Initialization RF R2: 0.21259635230652096
# NN Test R2 after Initialization -3.404154179885022
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8743223836118363
# (20, 10)
# RF R2: 0.16973071056610012
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8556953576450514
# (30, 10)
# RF R2: 0.3794259243789332
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8619089999161368
# (40, 10)
# RF R2: 0.37817285517582644
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8304290646972555
# (50, 10)
# RF R2: 0.3234108991209004
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8395837734423004
# (60, 10)
# RF R2: 0.37086776134155286
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8476339456347015
# (70, 10)
# RF R2: 0.38894317534910694
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8680048717360014
# (80, 10)
# RF R2: 0.38378404406961075
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8746583721371184
# (90, 10)
# RF R2: 0.36805469401922186
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8601368998548127
# (100, 10)
# RF R2: 0.3632270694742886
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8622660057043845
# (110, 10)
# RF R2: 0.36791839831341133
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8634906993072544
# (120, 10)
# RF R2: 0.3969557205760621
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8642048777356839
# (130, 10)
# RF R2: 0.356611038919207
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8665993468785783
# (140, 10)
# RF R2: 0.35563734888792176
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8634096800988639
# (150, 10)
# RF R2: 0.36886296276236685
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8594058035202957
# (160, 10)
# RF R2: 0.366098008025207
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8593209905863243
# (170, 10)
# RF R2: 0.4196006136287468
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8621214509149969
# (180, 10)
# RF R2: 0.4183238776613656
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8626995969132449
# (190, 10)
# RF R2: 0.43957313164676926
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8624282741501048
# (200, 10)
# RF R2: 0.4113828115880367
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8626761850273892
# (210, 10)
# RF R2: 0.39991280139452534
# Remaining: 143
# The Iteration is  12
# NN Test R2 with 5 samples -4.151857962206722
# After Initialization RF R2: 0.06185382460298916
# NN Test R2 after Initialization -1.2438340604131224
# (10, 10)
# Query no. 1
# Embeddings training score: 0.7923946059611278
# (20, 10)
# RF R2: -0.04068565048774353
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8311498989977946
# (30, 10)
# RF R2: 0.15435199316451487
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8306941988636941
# (40, 10)
# RF R2: 0.2568334563306912
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8284647112617156
# (50, 10)
# RF R2: 0.2377704334370324
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8678891546376165
# (60, 10)
# RF R2: 0.29253155454873336
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8690662387439151
# (70, 10)
# RF R2: 0.3296782019912925
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8653132213920317
# (80, 10)
# RF R2: 0.30665833107927376
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8644221120221545
# (90, 10)
# RF R2: 0.3371814435454694
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8662741457125636
# (100, 10)
# RF R2: 0.35939946951135393
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8633096750655161
# (110, 10)
# RF R2: 0.32197193424734216
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8611028137400858
# (120, 10)
# RF R2: 0.3547354604613261
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8590959905744352
# (130, 10)
# RF R2: 0.35431317280486274
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8573781742674478
# (140, 10)
# RF R2: 0.33426757794192397
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.866430046618424
# (150, 10)
# RF R2: 0.3348028584949535
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8671390575475018
# (160, 10)
# RF R2: 0.36746513766310474
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8701536646065862
# (170, 10)
# RF R2: 0.35965647245648424
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8666280379245357
# (180, 10)
# RF R2: 0.354685359885224
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8666226156034867
# (190, 10)
# RF R2: 0.32266767203894087
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8700457241063603
# (200, 10)
# RF R2: 0.33614164842698857
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8641058607486733
# (210, 10)
# RF R2: 0.30700968430255093
# Remaining: 143
# The Iteration is  13
# NN Test R2 with 5 samples -3.8846246677200433
# After Initialization RF R2: 0.10976834507123645
# NN Test R2 after Initialization -0.9221079425525435
# (10, 10)
# Query no. 1
# Embeddings training score: 0.800269779330314
# (20, 10)
# RF R2: 0.31876639722674893
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.896557220801356
# (30, 10)
# RF R2: 0.42358158914542243
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8769636479126528
# (40, 10)
# RF R2: 0.47229524030578396
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8757608179051318
# (50, 10)
# RF R2: 0.49417448026678
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.883871028940693
# (60, 10)
# RF R2: 0.46849118285019054
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8813379666317178
# (70, 10)
# RF R2: 0.49272323295184484
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.872992893124727
# (80, 10)
# RF R2: 0.45826937970386317
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8690897804469583
# (90, 10)
# RF R2: 0.45825530565942907
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8666801374435071
# (100, 10)
# RF R2: 0.47744449210844486
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8630482122265075
# (110, 10)
# RF R2: 0.4737543998307666
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8593588926232572
# (120, 10)
# RF R2: 0.46648019900715865
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8605039648702386
# (130, 10)
# RF R2: 0.4583991355853255
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8587992903137164
# (140, 10)
# RF R2: 0.4442900021414685
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8633192326464447
# (150, 10)
# RF R2: 0.4433553704138835
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.872939321429393
# (160, 10)
# RF R2: 0.40221202330982964
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8792925024822622
# (170, 10)
# RF R2: 0.414327193096241
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8778405038814039
# (180, 10)
# RF R2: 0.41555654225230876
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8851086219996601
# (190, 10)
# RF R2: 0.40034232153953486
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8812073117584028
# (200, 10)
# RF R2: 0.35704799335458626
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8855724764227872
# (210, 10)
# RF R2: 0.3619684170757862
# Remaining: 143
# The Iteration is  14
# NN Test R2 with 5 samples -3.5050869955875488
# After Initialization RF R2: 0.21875949583564513
# NN Test R2 after Initialization -1.4515306430133783
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8154646753158429
# (20, 10)
# RF R2: 0.3051258931682648
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.9183335307895536
# (30, 10)
# RF R2: 0.2617561218835667
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8632463576644543
# (40, 10)
# RF R2: 0.400670430134657
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8524295182307104
# (50, 10)
# RF R2: 0.26684668333905615
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8347337465384741
# (60, 10)
# RF R2: 0.39521744584244334
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8462488314908719
# (70, 10)
# RF R2: 0.35009964381275094
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8525230491098805
# (80, 10)
# RF R2: 0.32655937452748895
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.848230823661961
# (90, 10)
# RF R2: 0.4030293562825059
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8507981333785815
# (100, 10)
# RF R2: 0.37706667520481063
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8551984712479028
# (110, 10)
# RF R2: 0.38148577728724664
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8621096139360014
# (120, 10)
# RF R2: 0.4279549891404053
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8572985851722577
# (130, 10)
# RF R2: 0.40845832652332026
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8612385286449713
# (140, 10)
# RF R2: 0.4239294475721671
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8639913860216879
# (150, 10)
# RF R2: 0.46025971712709224
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8596765758840524
# (160, 10)
# RF R2: 0.4608897858369242
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8550473110660968
# (170, 10)
# RF R2: 0.46508167338151996
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8588944894967321
# (180, 10)
# RF R2: 0.4273565741117725
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8602229711290673
# (190, 10)
# RF R2: 0.4270007752554599
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8584879210124038
# (200, 10)
# RF R2: 0.45793348184449634
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8580677917955746
# (210, 10)
# RF R2: 0.4438789893901789
# Remaining: 143
# The Iteration is  15
# NN Test R2 with 5 samples -4.258470845582028
# After Initialization RF R2: 0.20777385009743188
# NN Test R2 after Initialization -2.0424025686938427
# (10, 10)
# Query no. 1
# Embeddings training score: 0.7500736938109305
# (20, 10)
# RF R2: 0.25556929455161814
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.833037355048192
# (30, 10)
# RF R2: 0.15390608103621384
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8350917426580048
# (40, 10)
# RF R2: 0.1343412944647171
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.7965896548289608
# (50, 10)
# RF R2: 0.27815792825484675
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8388077304843679
# (60, 10)
# RF R2: 0.21215018676418185
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8422763887336877
# (70, 10)
# RF R2: 0.32851487595046613
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8532418086477218
# (80, 10)
# RF R2: 0.38579660467520793
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.854866921605722
# (90, 10)
# RF R2: 0.38230693475696387
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8568073632836084
# (100, 10)
# RF R2: 0.3693905396379228
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8589672470224783
# (110, 10)
# RF R2: 0.39162932431520536
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8564220485075598
# (120, 10)
# RF R2: 0.396680740979519
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8570226516722832
# (130, 10)
# RF R2: 0.44081956557325574
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8574758351796979
# (140, 10)
# RF R2: 0.4431505149766227
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8607384407820864
# (150, 10)
# RF R2: 0.4301278243937785
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8635769729243135
# (160, 10)
# RF R2: 0.4237479340760446
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8589244643764005
# (170, 10)
# RF R2: 0.39827680844686664
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8599291286390959
# (180, 10)
# RF R2: 0.38614109121863704
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.864390837540235
# (190, 10)
# RF R2: 0.424166145016423
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8667068904331008
# (200, 10)
# RF R2: 0.44096726765046124
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8665584680718375
# (210, 10)
# RF R2: 0.40060836627173046
# Remaining: 143
# The Iteration is  16
# NN Test R2 with 5 samples -3.4450447480402198
# After Initialization RF R2: 0.3788951332013627
# NN Test R2 after Initialization -2.3952303810382154
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8922365103742154
# (20, 10)
# RF R2: 0.42625578066183345
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8812839912294214
# (30, 10)
# RF R2: 0.41835061936253337
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8507285580851769
# (40, 10)
# RF R2: 0.4176886518449665
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8674354561485313
# (50, 10)
# RF R2: 0.32956907991622
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8650268168678137
# (60, 10)
# RF R2: 0.43976719397147823
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8575344544022513
# (70, 10)
# RF R2: 0.3649758147084067
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8576738635529425
# (80, 10)
# RF R2: 0.46446354189613237
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8593921061672716
# (90, 10)
# RF R2: 0.39772001590229444
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8629292412922195
# (100, 10)
# RF R2: 0.4217690087449808
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8605520054294928
# (110, 10)
# RF R2: 0.4790687465901061
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8565876723953258
# (120, 10)
# RF R2: 0.4971463497870857
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8577876774104931
# (130, 10)
# RF R2: 0.4664310559465954
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8592145970837928
# (140, 10)
# RF R2: 0.46464089433560074
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8611069991374275
# (150, 10)
# RF R2: 0.47530841977946936
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8594489907232666
# (160, 10)
# RF R2: 0.44507812129327684
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8577380261717433
# (170, 10)
# RF R2: 0.4463143670412113
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8531191458475378
# (180, 10)
# RF R2: 0.41306946390150046
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8580955078806365
# (190, 10)
# RF R2: 0.4089699667863711
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8609223820731107
# (200, 10)
# RF R2: 0.4340419765034611
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8564226515987682
# (210, 10)
# RF R2: 0.43012105026739345
# Remaining: 143
# The Iteration is  17
# NN Test R2 with 5 samples -3.5403061649992655
# After Initialization RF R2: 0.27409988635854254
# NN Test R2 after Initialization -2.3854183991507605
# (10, 10)
# Query no. 1
# Embeddings training score: 0.7781145083251579
# (20, 10)
# RF R2: 0.27252308598435415
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.9282387438369106
# (30, 10)
# RF R2: 0.06221006715530353
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8740888207940726
# (40, 10)
# RF R2: 0.3487948818514791
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8793803407875264
# (50, 10)
# RF R2: 0.38989687247964155
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8752814839925265
# (60, 10)
# RF R2: 0.45939648914103737
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8622272270591376
# (70, 10)
# RF R2: 0.4124535687290515
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8540454528196516
# (80, 10)
# RF R2: 0.38256921958163725
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8470011069885743
# (90, 10)
# RF R2: 0.3184863918858466
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.857137010369391
# (100, 10)
# RF R2: 0.37869059612134326
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8605591896994254
# (110, 10)
# RF R2: 0.4007743242216617
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8668374876399662
# (120, 10)
# RF R2: 0.4136638352788443
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8692960957758906
# (130, 10)
# RF R2: 0.445853835027471
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8659297639622625
# (140, 10)
# RF R2: 0.4267685959840606
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.858148749115051
# (150, 10)
# RF R2: 0.4364569253302927
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8562705113201365
# (160, 10)
# RF R2: 0.41038086765635995
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8602343902795012
# (170, 10)
# RF R2: 0.4470108521677334
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8633627340714541
# (180, 10)
# RF R2: 0.41390400170716846
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8599113318847982
# (190, 10)
# RF R2: 0.4230071632930936
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8633090095188887
# (200, 10)
# RF R2: 0.4573514935928059
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8618129769034698
# (210, 10)
# RF R2: 0.4739795777152631
# Remaining: 143
# The Iteration is  18
# NN Test R2 with 5 samples -4.196331138019983
# After Initialization RF R2: 0.19165785697079374
# NN Test R2 after Initialization -1.9361178959215648
# (10, 10)
# Query no. 1
# Embeddings training score: 0.7707259414243892
# (20, 10)
# RF R2: 0.22514748908019788
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8474786565518506
# (30, 10)
# RF R2: 0.2934597839520944
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8436375941576392
# (40, 10)
# RF R2: 0.26441319641924754
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8533309968625558
# (50, 10)
# RF R2: 0.27575594042436447
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8549229706527789
# (60, 10)
# RF R2: 0.24931460352226864
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8628727633951473
# (70, 10)
# RF R2: 0.26648260525653966
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8785860940173713
# (80, 10)
# RF R2: 0.3185947000256907
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8704193156667902
# (90, 10)
# RF R2: 0.31359846757100607
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.869987637403203
# (100, 10)
# RF R2: 0.29863214320944786
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8691919943399112
# (110, 10)
# RF R2: 0.27449242082514147
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8754930020836088
# (120, 10)
# RF R2: 0.309246969875033
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8652704567932434
# (130, 10)
# RF R2: 0.3122403191509989
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.872172128635902
# (140, 10)
# RF R2: 0.3246206331117448
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8685224297135796
# (150, 10)
# RF R2: 0.3264501724679101
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8705386229019823
# (160, 10)
# RF R2: 0.34945210031098883
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8629487261893718
# (170, 10)
# RF R2: 0.3596703428019098
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8591459591229695
# (180, 10)
# RF R2: 0.34568495785908415
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8611724856804718
# (190, 10)
# RF R2: 0.3460293514655227
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8588786812011062
# (200, 10)
# RF R2: 0.34542530947131556
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8624116632647526
# (210, 10)
# RF R2: 0.3562439120847216
# Remaining: 143
# The Iteration is  19
# NN Test R2 with 5 samples -4.383176729078603
# After Initialization RF R2: 0.2592937559558306
# NN Test R2 after Initialization -2.1699515227800625
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8255250971673337
# (20, 10)
# RF R2: 0.312207758071786
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.7334640987703849
# (30, 10)
# RF R2: 0.28523479862244994
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.789033420414174
# (40, 10)
# RF R2: 0.2620617276059879
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.842602782299239
# (50, 10)
# RF R2: 0.3771196043421057
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8744925683775912
# (60, 10)
# RF R2: 0.3947297870302757
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8786034867147469
# (70, 10)
# RF R2: 0.38538180289664514
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8546535123451099
# (80, 10)
# RF R2: 0.29625496534493145
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8587326173844834
# (90, 10)
# RF R2: 0.2849781455461484
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8595908205823599
# (100, 10)
# RF R2: 0.2668449663767555
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8621575809824507
# (110, 10)
# RF R2: 0.32866703411461473
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8577749764368526
# (120, 10)
# RF R2: 0.30026191846133055
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8602895206023105
# (130, 10)
# RF R2: 0.33045637356520474
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8618921928034669
# (140, 10)
# RF R2: 0.31703274300189677
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8645825831233016
# (150, 10)
# RF R2: 0.326913382693789
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8606442886007555
# (160, 10)
# RF R2: 0.33819802920651254
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8614474819495761
# (170, 10)
# RF R2: 0.33714744056091484
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8529833744039345
# (180, 10)
# RF R2: 0.36380306422996855
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8554732718134374
# (190, 10)
# RF R2: 0.3489919181137112
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8544970681696002
# (200, 10)
# RF R2: 0.3335902910226043
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8526112276009504
# (210, 10)
# RF R2: 0.3254437105614898
# Remaining: 143
