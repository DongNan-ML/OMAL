# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from modAL.models import ActiveLearner, CommitteeRegressor
from modAL.disagreement import vote_entropy_sampling, max_std_sampling
import matplotlib.pyplot as plt
import torch
from torch.nn import MSELoss
from skorch.regressor import NeuralNetRegressor
from copy import deepcopy
from skorch.dataset import ValidSplit
from skorch.callbacks import EarlyStopping
from sklearn.cluster import DBSCAN, OPTICS, cluster_optics_dbscan, Birch, SpectralClustering
from sklearn.neighbors import NearestNeighbors
from sklearn import metrics
import matplotlib.gridspec as gridspec
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from torch.nn import Linear
from torch.nn import Sigmoid, ReLU
from torch.nn import Module
from sklearn.metrics import r2_score
import copy
from scipy.spatial import distance
from scipy.spatial.distance import euclidean
from torch import tensor
from sklearn.metrics import mean_squared_error
from scipy.spatial.distance import cdist
from sklearn.ensemble import RandomForestRegressor
from torch.nn.init import xavier_uniform_
from model import MLP
from model_state import get_model_params, get_input_for_hidden_layers, get_model_params_gradientNorm
from functions_batch1 import get_variance, qbc, normalization, error_reduct_fuc, total_disagrement, grad_norm, averaged_grad_norm, get_avg_grad_norm, training_loss
import random
from skorch.callbacks import EarlyStopping, LRScheduler, Freezer, Unfreezer
from torch.optim.lr_scheduler import CyclicLR, ReduceLROnPlateau
from skorch.regressor import NeuralNetRegressor, NeuralNet
from model_state import features_concat, learning_state_features_concat
import gc
import warnings
from modAL.utils.selection import multi_argmax
warnings.filterwarnings("ignore")

# %%
# Hyper-params:
query_number = 20          # The number of the AL Iterations in each Exp
iteration = 20             # Total number of the Exps
batch_size = 10
total_initail_size = 10
initial_size = 5
dimensions = 18   # Total dimension of the data features + model states

seed_rf = np.load(file="..\..\seed2.npy")
seed_initial = np.load(file="..\..\seed3.npy")

seed_nn1 = np.load(file="..\..\seed4.npy")
seed_nn2 = np.load(file="..\..\seed4.npy")
seed_nn3 = np.load(file="..\..\seed5.npy")
seed_nn4 = np.load(file="..\..\seed5.npy")
seed_nn5 = np.load(file="..\..\seed6.npy")
seed_nn6 = np.load(file="..\..\seed6.npy")

seed_predictor = np.load(file="..\..\seed7.npy")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def Committee_Prediction(learner_list, X_test, y_test):
    initial_pred=[]
    for i in learner_list:
        initial_pred.append(r2_score(y_test, i.predict(X_test)))
    initial_pred=np.array(initial_pred)
    
    return initial_pred.mean()

# %%
def main_function(query_number, iters):
    # For saving results:
    rf_model_training_r2 = []
    rf_model_training_mse = []
    rf_model_testing_r2 = []
    rf_model_testing_mse = []
    
    # Number of member in committee:
    n_members = 3
    learner_list = []
    
    # The model for evaluation:
    rf_model = RandomForestRegressor(random_state=seed_rf[iters], n_estimators=100)
    gradient_norms = np.empty(shape=(0, 0))
    
    # Load the data:
    name1 = "..\..\Datasets\Diabetes\X_train" + str(iters) + ".npy"
    name2 = "..\..\Datasets\Diabetes\X_test" + str(iters) + ".npy"
    name3 = "..\..\Datasets\Diabetes\y_train" + str(iters) + ".npy"
    name4 = "..\..\Datasets\Diabetes\y_test" + str(iters) + ".npy"
    
    X_train = np.load(name1, allow_pickle=True).astype(np.float32)
    X_test = np.load(name2, allow_pickle=True).astype(np.float32)
    y_train = np.load(name3, allow_pickle=True).astype(np.float32).reshape(-1, 1)
    y_test = np.load(name4, allow_pickle=True).astype(np.float32).reshape(-1, 1)
    
    # Dimensionality of data:
    X = X_train.shape[1]
    # The index of the unlabeled pool:
    X_index = np.arange(X_train.shape[0])

    used_data = np.empty(shape=(0, X))
    used_label = np.empty(shape=(0)).reshape(-1, 1)

    X_initial = np.empty(shape=(0,X))
    y_initial = np.empty(shape=(0)).reshape(-1, 1)
    
    # Initial Stage 1:
    np.random.seed(seed_initial[iters])
    idx = np.random.choice(range(len(X_index)), size=initial_size, replace=False)
    train_idx = X_index[idx]

    X_initial = X_train[train_idx]
    y_initial = y_train[train_idx].reshape(-1, 1)

    used_data = np.append(used_data, X_initial, axis=0).astype(np.float32)
    used_label = np.append(used_label, y_initial, axis=0).astype(np.float32).reshape(-1, 1)
    X_index = np.delete(X_index, idx, axis=0)

    
    used_data = torch.from_numpy(used_data).to(device)
    used_label = torch.from_numpy(used_label).to(device)
    for member_idx in range(n_members):
        if member_idx == 0:
            np.random.seed(seed_nn1[iters])
            torch.manual_seed(seed_nn2[iters])
        if member_idx == 1:
            np.random.seed(seed_nn3[iters])
            torch.manual_seed(seed_nn4[iters])
        if member_idx == 2:
            np.random.seed(seed_nn5[iters])
            torch.manual_seed(seed_nn6[iters])
            
        regressor = NeuralNetRegressor(MLP(X),
                                   criterion=MSELoss(),
                                   optimizer=torch.optim.Adam,
                                   verbose=0,
                                   max_epochs=30,
                                   lr=0.001,
                                   # Used for the batch AL
                                   callbacks=[EarlyStopping(patience=5), ('lr_scheduler', LRScheduler(policy=ReduceLROnPlateau))],
                                   train_split=ValidSplit(cv=5),
                                   warm_start=True,
                                   device='cuda',
                                   batch_size = 200
                                   )
        regressor.fit(used_data, used_label)
        learner_list.append(regressor)
    
    print("NN Test R2 with 5 samples", Committee_Prediction(learner_list, X_test, y_test))

    # Number of LAL features:
    learning_state_features = np.empty(shape=(0, dimensions))
    loss_reduction_target = np.empty(shape=(0)).reshape(-1, 1)

    # other random samples:
    rest_initial_X = np.empty(shape=(0, X))
    rest_initial_y = np.empty(shape=(0)).reshape(-1, 1)

    # LAL Initialization: Stage 2
    predictor = RandomForestRegressor(n_estimators=1000, random_state=seed_predictor[iters])
    np.random.seed(seed_initial[iters])
    idx = np.random.choice(range(len(X_index)), size=total_initail_size-initial_size, replace=False)
    train_idx = X_index[idx]
    
    rest_initial_X = np.append(rest_initial_X, X_train[train_idx], axis=0).astype(np.float32)
    rest_initial_y = np.append(rest_initial_y, y_train[train_idx], axis=0).astype(np.float32).reshape(-1, 1)

    X_index = np.delete(X_index, idx, axis=0)

    for i in range(rest_initial_X.shape[0]):

        single_X = rest_initial_X[i],
        single_y = rest_initial_y[i].reshape(1, -1)
        single_X = single_X[0].reshape(1, -1)
        
        single_X = torch.from_numpy(single_X).to(device)
        single_y = torch.from_numpy(single_y).to(device)

        # Model params
        model_params = get_model_params_gradientNorm(learner_list)

        # updated data
        used_data = torch.cat((used_data, single_X), 0)
        used_label = torch.cat((used_label, single_y), 0)

        # Retrain the model:
        for l in learner_list:
            l.fit(X=used_data,y=used_label)
            
        single_X = single_X.cpu().numpy()
        single_y = single_y.cpu().numpy()
            
        index = train_idx[i]

        # The training sample:
        data_params = X_train[index]
      
        LALfeatures = features_concat(model_params, data_params)

        loss_reduction = get_avg_grad_norm(learner_list, single_X, single_y)
        
        learning_state_features = learning_state_features_concat(learning_state_features, LALfeatures)
        loss_reduction_target = np.append(loss_reduction_target, np.array([loss_reduction]).reshape(-1, 1), axis=0).astype(np.float32).reshape(-1, 1)

        
    used_data = used_data.cpu().numpy()
    used_label = used_label.cpu().numpy()

    # Finished the Initialization Stages:
    # RF Regressor for evaluation:
    rf_model.fit(used_data, used_label.ravel())
    # Training Scores:
    rf_training_r2 = r2_score(used_label, rf_model.predict(used_data))
    rf_training_mse = mean_squared_error(used_label, rf_model.predict(used_data))
    rf_model_training_r2.append(rf_training_r2)
    rf_model_training_mse.append(rf_training_mse)
    
    # Test Scores:
    rf_model_r2 = r2_score(y_test, rf_model.predict(X_test))
    rf_model_mse = mean_squared_error(y_test, rf_model.predict(X_test))
    rf_model_testing_r2.append(rf_model_r2)
    rf_model_testing_mse.append(rf_model_mse)
    
    print("After Initialization RF R2:", rf_model_r2)
    print("NN Test R2 after Initialization", Committee_Prediction(learner_list, X_test, y_test))

    print(np.unique(used_data, axis=0).shape)
    for idx in range(query_number):
        np.random.seed(None)
        print('Query no. %d' % (idx+1))

        Error_reduction_list, training_score = error_reduct_fuc(X_train, X_index, learner_list, learning_state_features, loss_reduction_target, X_index.shape[0], predictor)

        idx = multi_argmax(np.array(Error_reduction_list), n_instances=batch_size)
       
        X_train_indices = X_index[idx]
        
        # Update
        X_index = np.delete(X_index, idx, axis=0)

        for X_train_index in X_train_indices:

            new_X = X_train[X_train_index].reshape(1, -1)
            new_y = y_train[X_train_index].reshape(1, -1)
            
            used_data = np.append(used_data, new_X, axis=0).astype(np.float32)
            used_label = np.append(used_label, new_y, axis=0).astype(np.float32).reshape(-1, 1)
            
            used_data = torch.from_numpy(used_data).to(device)
            used_label = torch.from_numpy(used_label).to(device)

            # Model params
            model_params = get_model_params_gradientNorm(learner_list)
            data_params = X_train[X_train_index]
            LALfeatures = features_concat(model_params, data_params)
            
            for l in learner_list:
                l.fit(used_data, used_label)
            
            used_data = used_data.cpu().numpy()
            used_label = used_label.cpu().numpy()

            loss_reduction = get_avg_grad_norm(learner_list, new_X, new_y)  
            gradient_norms = np.append(gradient_norms, loss_reduction)
            
            learning_state_features = learning_state_features_concat(learning_state_features, LALfeatures)
            loss_reduction_target = np.append(loss_reduction_target, np.array([loss_reduction]).reshape(-1, 1), axis=0).astype(np.float32).reshape(-1, 1)
        

        # RF Evaluation
        rf_model.fit(used_data, used_label.ravel())
        
        # Training Evaluation:
        rf_training_r2 = r2_score(used_label, rf_model.predict(used_data))
        rf_training_mse = mean_squared_error(used_label, rf_model.predict(used_data))
        rf_model_training_r2.append(rf_training_r2)
        rf_model_training_mse.append(rf_training_mse)
        
        # Test Evaluation:
        rf_model_r2 = r2_score(y_test, rf_model.predict(X_test))
        rf_model_mse = mean_squared_error(y_test, rf_model.predict(X_test))
        rf_model_testing_r2.append(rf_model_r2)
        rf_model_testing_mse.append(rf_model_mse)

        print(np.unique(used_data, axis=0).shape)
        print("RF R2:", rf_model_r2)
        print("Remaining:", X_index.shape[0])
        # print('NN R2', Committee_Prediction(learner_list, X_test, y_test))

    # RF
    rf_model_testing_r2 = np.array(rf_model_testing_r2)
    rf_model_testing_mse = np.array(rf_model_testing_mse)
    rf_model_training_r2 = np.array(rf_model_training_r2)
    rf_model_training_mse = np.array(rf_model_training_mse)
    
    # Used_data and Unsed_label:
    np.save(file="..\..\Results\Res_Diabetes\OMAL\Summary\\used_data" + str(iters) + ".npy", arr=used_data)
    np.save(file="..\..\Results\Res_Diabetes\OMAL\Summary\\used_labels" + str(iters) + ".npy", arr=used_label)

    np.save(file="..\..\Results\Res_Diabetes\OMAL\Summary\\testing_rf_r2_" + str(iters) + ".npy", arr=rf_model_testing_r2)
    np.save(file="..\..\Results\Res_Diabetes\OMAL\Summary\\testing_rf_mse_" + str(iters) + ".npy", arr=rf_model_testing_mse)
    np.save(file="..\..\Results\Res_Diabetes\OMAL\Summary\\training_rf_r2_" + str(iters) + ".npy", arr=rf_model_training_r2)
    np.save(file="..\..\Results\Res_Diabetes\OMAL\Summary\\training_rf_mse_" + str(iters) + ".npy", arr=rf_model_training_mse)

# %%
for i in range(iteration):
    print("The Iteration is ", i)
    main_function(query_number, i)
# Out:
# The Iteration is  0
# NN Test R2 with 5 samples -3.6201832160011382
# After Initialization RF R2: 0.16584832639415037
# NN Test R2 after Initialization -2.259528248456164
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8201052335851722
# (20, 10)
# RF R2: 0.4077358930163947
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8722831588171613
# (30, 10)
# RF R2: 0.40719271350182273
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8735422840829608
# (40, 10)
# RF R2: 0.44256669530228776
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8756029046183009
# (50, 10)
# RF R2: 0.504804142577316
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8944237809020226
# (60, 10)
# RF R2: 0.4321629563722946
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8981219910103618
# (70, 10)
# RF R2: 0.38074888201179047
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.9039783122942167
# (80, 10)
# RF R2: 0.39160764843012785
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.9017323857166222
# (90, 10)
# RF R2: 0.4556724438652292
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8971039416037956
# (100, 10)
# RF R2: 0.4673289125403418
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8948437680830675
# (110, 10)
# RF R2: 0.4790528454110795
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8914730430143656
# (120, 10)
# RF R2: 0.5302034449386146
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.881204111127908
# (130, 10)
# RF R2: 0.5190865879542739
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8787620293293879
# (140, 10)
# RF R2: 0.5103209088763134
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8802921030646164
# (150, 10)
# RF R2: 0.5011394288530491
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8796393901774961
# (160, 10)
# RF R2: 0.5173942162974811
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8761910044397451
# (170, 10)
# RF R2: 0.5409800570688807
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8692853048800266
# (180, 10)
# RF R2: 0.5225030802425719
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8739612509368138
# (190, 10)
# RF R2: 0.5039388788735517
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8723205853466458
# (200, 10)
# RF R2: 0.4902489232193793
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8676334889541498
# (210, 10)
# RF R2: 0.5089280584074476
# Remaining: 143
# The Iteration is  1
# NN Test R2 with 5 samples -3.732916535640977
# After Initialization RF R2: 0.29296532043561385
# NN Test R2 after Initialization -1.2584569079661878
# (10, 10)
# Query no. 1
# Embeddings training score: 0.833625616023979
# (20, 10)
# RF R2: 0.31141018218175454
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8705441001825964
# (30, 10)
# RF R2: 0.39843708499766983
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8667605244517176
# (40, 10)
# RF R2: 0.43564076809030416
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8634704781737605
# (50, 10)
# RF R2: 0.47333167987049973
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8571098230945708
# (60, 10)
# RF R2: 0.5035892680921684
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8632659384550433
# (70, 10)
# RF R2: 0.5164594992081515
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8655460994653738
# (80, 10)
# RF R2: 0.5055232676323926
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8713438056678526
# (90, 10)
# RF R2: 0.5063435790323998
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8681654046762767
# (100, 10)
# RF R2: 0.5185037642530285
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8702982451736834
# (110, 10)
# RF R2: 0.5552713860792224
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8651327493718611
# (120, 10)
# RF R2: 0.5191782531302565
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8671982214099188
# (130, 10)
# RF R2: 0.5304779038085159
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.866769386422414
# (140, 10)
# RF R2: 0.5468768283525705
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8730616069952248
# (150, 10)
# RF R2: 0.5294457037600175
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8758578223852189
# (160, 10)
# RF R2: 0.5296194921787774
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8740246677395733
# (170, 10)
# RF R2: 0.5278757666410605
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.872310223093272
# (180, 10)
# RF R2: 0.5577766794071636
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8668728204227255
# (190, 10)
# RF R2: 0.5170454162169804
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8647563451548053
# (200, 10)
# RF R2: 0.508649466139449
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8632776765668259
# (210, 10)
# RF R2: 0.503993690218578
# Remaining: 143
# The Iteration is  2
# NN Test R2 with 5 samples -4.086714365117955
# After Initialization RF R2: 0.3173782812345456
# NN Test R2 after Initialization -1.2303113644542407
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8482925064885086
# (20, 10)
# RF R2: 0.23271996733282196
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8586219578907058
# (30, 10)
# RF R2: 0.46290521956291963
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8877048179300449
# (40, 10)
# RF R2: 0.5099043059191375
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8828136592640925
# (50, 10)
# RF R2: 0.479302607494289
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8663840495255566
# (60, 10)
# RF R2: 0.562067269516735
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8649874933336085
# (70, 10)
# RF R2: 0.5460341350925018
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8665978568623516
# (80, 10)
# RF R2: 0.5511597081489839
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8646946498490277
# (90, 10)
# RF R2: 0.6047291351587516
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8642148071225022
# (100, 10)
# RF R2: 0.5959925268488049
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8644016715912921
# (110, 10)
# RF R2: 0.6094081385340652
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8678762058279957
# (120, 10)
# RF R2: 0.608447738816019
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8678203170130301
# (130, 10)
# RF R2: 0.5987012778931636
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8652181103025121
# (140, 10)
# RF R2: 0.6106535628786862
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.867014594808353
# (150, 10)
# RF R2: 0.6035268780752757
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8625091015060345
# (160, 10)
# RF R2: 0.617347248882463
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8580426786409088
# (170, 10)
# RF R2: 0.6107337861589773
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8613861560787093
# (180, 10)
# RF R2: 0.6062904719352704
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8657704579473409
# (190, 10)
# RF R2: 0.6102192834683302
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8643827867386231
# (200, 10)
# RF R2: 0.5698916310802932
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8625676098347466
# (210, 10)
# RF R2: 0.6189731947970775
# Remaining: 143
# The Iteration is  3
# NN Test R2 with 5 samples -3.6091164048323052
# After Initialization RF R2: 0.48625584811940625
# NN Test R2 after Initialization -0.4606057286655871
# (10, 10)
# Query no. 1
# Embeddings training score: 0.7899610972490839
# (20, 10)
# RF R2: 0.5554743918632694
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8165213130717387
# (30, 10)
# RF R2: 0.4594634821765362
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.796989505137516
# (40, 10)
# RF R2: 0.5082800118368327
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8236758323064988
# (50, 10)
# RF R2: 0.5809879926860961
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8321557382870108
# (60, 10)
# RF R2: 0.589424721780271
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8358510274614981
# (70, 10)
# RF R2: 0.5656064746462254
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8584953450923783
# (80, 10)
# RF R2: 0.6201441963188465
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8628832044893147
# (90, 10)
# RF R2: 0.6186865131118214
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8605981718780028
# (100, 10)
# RF R2: 0.5985992208593687
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8559005307320138
# (110, 10)
# RF R2: 0.6204093605337154
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8570275596356827
# (120, 10)
# RF R2: 0.6134860994468785
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8584470217793199
# (130, 10)
# RF R2: 0.6058903097482807
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.855225025537354
# (140, 10)
# RF R2: 0.5982828581705824
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8594729251216194
# (150, 10)
# RF R2: 0.5975051683472152
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.861124025438314
# (160, 10)
# RF R2: 0.608780774855139
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8586754511990999
# (170, 10)
# RF R2: 0.6113957856638021
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8588434907263652
# (180, 10)
# RF R2: 0.6296532320389672
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8497711151522279
# (190, 10)
# RF R2: 0.629458850483441
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8563367055669606
# (200, 10)
# RF R2: 0.6229834240298682
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8481961734607112
# (210, 10)
# RF R2: 0.620157560749284
# Remaining: 143
# The Iteration is  4
# NN Test R2 with 5 samples -3.761875933948321
# After Initialization RF R2: -0.036428631530183164
# NN Test R2 after Initialization -1.9894830630740292
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8483078155593854
# (20, 10)
# RF R2: 0.3441739784600337
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.9111112851076192
# (30, 10)
# RF R2: 0.29641389117098915
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.882982056564209
# (40, 10)
# RF R2: 0.35010383546111234
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8535231527978275
# (50, 10)
# RF R2: 0.3373381890073047
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.869139906420973
# (60, 10)
# RF R2: 0.4271966346208306
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8519698270594042
# (70, 10)
# RF R2: 0.513437467200202
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8426812890352681
# (80, 10)
# RF R2: 0.513292124628731
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8522258178736701
# (90, 10)
# RF R2: 0.4410022919067629
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8440292067748911
# (100, 10)
# RF R2: 0.4599996100737408
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8532203281154058
# (110, 10)
# RF R2: 0.46434417227159264
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8550758450518866
# (120, 10)
# RF R2: 0.4725887397109847
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8527700270595067
# (130, 10)
# RF R2: 0.4791846558208315
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8551123207297643
# (140, 10)
# RF R2: 0.4672418828201679
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8541299598398485
# (150, 10)
# RF R2: 0.4558978038114585
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8587714563460531
# (160, 10)
# RF R2: 0.4397930236884998
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8540319188000207
# (170, 10)
# RF R2: 0.4636819114904642
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8570755413826162
# (180, 10)
# RF R2: 0.4808992791321476
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8536933030975106
# (190, 10)
# RF R2: 0.49894878175044144
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.850770205788173
# (200, 10)
# RF R2: 0.4976210641161751
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8520743177529154
# (210, 10)
# RF R2: 0.4891607537733188
# Remaining: 143
# The Iteration is  5
# NN Test R2 with 5 samples -3.7900538793240375
# After Initialization RF R2: 0.28919529062439076
# NN Test R2 after Initialization -0.7726468728817218
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8392073274610912
# (20, 10)
# RF R2: 0.30091183411856604
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8208170032200567
# (30, 10)
# RF R2: 0.40280276379938496
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8597901109442648
# (40, 10)
# RF R2: 0.3730594579798321
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8432301646552552
# (50, 10)
# RF R2: 0.34514284547756113
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8584313443420672
# (60, 10)
# RF R2: 0.39804176843215366
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8574975982750914
# (70, 10)
# RF R2: 0.4339527222548376
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8592110244882304
# (80, 10)
# RF R2: 0.44952298916468425
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8572282270265941
# (90, 10)
# RF R2: 0.3915696233316076
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8659056639701898
# (100, 10)
# RF R2: 0.34300000645811013
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8643379376437846
# (110, 10)
# RF R2: 0.42745526732654726
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8618808157097209
# (120, 10)
# RF R2: 0.4236548207661276
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8669327462125217
# (130, 10)
# RF R2: 0.4223897819452146
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.866797626307441
# (140, 10)
# RF R2: 0.4239166583208892
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8687177057598869
# (150, 10)
# RF R2: 0.45269938451164493
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8714254468827725
# (160, 10)
# RF R2: 0.42670305427618216
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8713579273057945
# (170, 10)
# RF R2: 0.4430392607407325
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8723451036794734
# (180, 10)
# RF R2: 0.4226984660466655
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8715185887033793
# (190, 10)
# RF R2: 0.42861415235700784
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.866104107866719
# (200, 10)
# RF R2: 0.4150336621026173
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8673737293175025
# (210, 10)
# RF R2: 0.43284941328489934
# Remaining: 143
# The Iteration is  6
# NN Test R2 with 5 samples -3.318710947329382
# After Initialization RF R2: 0.4330375487004837
# NN Test R2 after Initialization -3.0576721732842125
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8145939793540065
# (20, 10)
# RF R2: 0.46797383789744995
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8691364175735632
# (30, 10)
# RF R2: 0.40630884856056815
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8607751191593255
# (40, 10)
# RF R2: 0.434721927364387
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8679808682887147
# (50, 10)
# RF R2: 0.4169913354286645
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8633296611029151
# (60, 10)
# RF R2: 0.43859798336070566
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8679525476269738
# (70, 10)
# RF R2: 0.46629062920826503
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.864871580915597
# (80, 10)
# RF R2: 0.41710724768720153
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8604632520926516
# (90, 10)
# RF R2: 0.5006222213436645
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8693732109419977
# (100, 10)
# RF R2: 0.5265512754657751
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8696791232958074
# (110, 10)
# RF R2: 0.5185034229969379
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8761300188450275
# (120, 10)
# RF R2: 0.5265852172465947
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8804077766559963
# (130, 10)
# RF R2: 0.5777918809981615
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8817603783414322
# (140, 10)
# RF R2: 0.5873627592356291
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8798983299425939
# (150, 10)
# RF R2: 0.5972613343437541
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8757671668798785
# (160, 10)
# RF R2: 0.6322704748230225
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8741165261585374
# (170, 10)
# RF R2: 0.6081214039189944
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8767677109456644
# (180, 10)
# RF R2: 0.5758418246354198
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8740248658237877
# (190, 10)
# RF R2: 0.5644183031113479
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.871061936737144
# (200, 10)
# RF R2: 0.5527406816659226
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8831168751959315
# (210, 10)
# RF R2: 0.5595860852765497
# Remaining: 143
# The Iteration is  7
# NN Test R2 with 5 samples -4.3275230899153145
# After Initialization RF R2: 0.15212668144309682
# NN Test R2 after Initialization -1.9036244645914397
# (10, 10)
# Query no. 1
# Embeddings training score: 0.9001825988479178
# (20, 10)
# RF R2: 0.29064400184171046
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8512361649944881
# (30, 10)
# RF R2: 0.18688832052338555
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8212270718710089
# (40, 10)
# RF R2: 0.06688709034561102
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8512480393965839
# (50, 10)
# RF R2: 0.04573791837857877
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8706683360597636
# (60, 10)
# RF R2: -0.07734450667399617
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8555188407240868
# (70, 10)
# RF R2: 0.07999518569989572
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8619568169239307
# (80, 10)
# RF R2: 0.13426237357170556
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8627009477595278
# (90, 10)
# RF R2: 0.1616048523009026
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8656367669538789
# (100, 10)
# RF R2: 0.17566416402879703
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8572601413967074
# (110, 10)
# RF R2: 0.24557424699408703
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8554448162684516
# (120, 10)
# RF R2: 0.2683785858287129
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8520839596493986
# (130, 10)
# RF R2: 0.25179621605748614
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8572795891147652
# (140, 10)
# RF R2: 0.2909542307740547
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8634388029938314
# (150, 10)
# RF R2: 0.35512582070659604
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8655635818989852
# (160, 10)
# RF R2: 0.2929276568334843
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8667743254840857
# (170, 10)
# RF R2: 0.3160947022901045
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8659925839082412
# (180, 10)
# RF R2: 0.2998010449607452
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8673923839975857
# (190, 10)
# RF R2: 0.31149652473522704
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8679619667537026
# (200, 10)
# RF R2: 0.3374012046220761
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8693383198350216
# (210, 10)
# RF R2: 0.3313687318647326
# Remaining: 143
# The Iteration is  8
# NN Test R2 with 5 samples -4.637575736063636
# After Initialization RF R2: -0.013648235879520243
# NN Test R2 after Initialization -0.9048868854030353
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8791080778641398
# (20, 10)
# RF R2: 0.31193707295044326
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.9015842572106842
# (30, 10)
# RF R2: 0.2574629061086714
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8807023339205355
# (40, 10)
# RF R2: 0.3325279592917185
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8695530517657316
# (50, 10)
# RF R2: 0.3345233762735017
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.872888670256955
# (60, 10)
# RF R2: 0.34430813501192636
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.878716525021613
# (70, 10)
# RF R2: 0.3513360837954347
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8815988732209736
# (80, 10)
# RF R2: 0.28740942416067716
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8758065915998237
# (90, 10)
# RF R2: 0.33340390972509615
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8753229577707172
# (100, 10)
# RF R2: 0.27206610273695087
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8726152353046751
# (110, 10)
# RF R2: 0.29496817268375386
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8726725811344579
# (120, 10)
# RF R2: 0.3597061053947057
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8682192416655006
# (130, 10)
# RF R2: 0.36486286916356325
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8728924491745848
# (140, 10)
# RF R2: 0.36695646513957203
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8718605999430702
# (150, 10)
# RF R2: 0.3961358882113717
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8731740659615381
# (160, 10)
# RF R2: 0.37564823380176726
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8647663253599351
# (170, 10)
# RF R2: 0.4090332152564914
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8644356292143971
# (180, 10)
# RF R2: 0.3734374810605663
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8596709407126046
# (190, 10)
# RF R2: 0.3346374928829111
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8632506563459771
# (200, 10)
# RF R2: 0.3727040043360672
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.860042470582085
# (210, 10)
# RF R2: 0.37276758793930187
# Remaining: 143
# The Iteration is  9
# NN Test R2 with 5 samples -4.2210370835714714
# After Initialization RF R2: 0.3066022409096445
# NN Test R2 after Initialization -1.5353964046298223
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8015619504543697
# (20, 10)
# RF R2: 0.3115590210733671
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8430853753124096
# (30, 10)
# RF R2: 0.438188777635768
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8468179221720067
# (40, 10)
# RF R2: 0.459385897787418
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8403761340975712
# (50, 10)
# RF R2: 0.390414177368953
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8463113012308718
# (60, 10)
# RF R2: 0.4251018650182735
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8499851002315751
# (70, 10)
# RF R2: 0.3469185213323922
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8391349192321178
# (80, 10)
# RF R2: 0.371934180155684
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8562363213778598
# (90, 10)
# RF R2: 0.3992979681675194
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8628048647919402
# (100, 10)
# RF R2: 0.40989259749819973
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8560622820247911
# (110, 10)
# RF R2: 0.40562309359000714
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8522268096840651
# (120, 10)
# RF R2: 0.3896054872495873
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8573968308438823
# (130, 10)
# RF R2: 0.36682010350648275
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8592654404041183
# (140, 10)
# RF R2: 0.36591575846795443
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8591309028201197
# (150, 10)
# RF R2: 0.3369773605373879
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8473575321532757
# (160, 10)
# RF R2: 0.330452249757092
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8593876070268278
# (170, 10)
# RF R2: 0.3650136373536016
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.868863549266701
# (180, 10)
# RF R2: 0.41115528856991157
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8672230006575885
# (190, 10)
# RF R2: 0.42745620324917055
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8670659844571635
# (200, 10)
# RF R2: 0.4027012481272292
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8613481969841761
# (210, 10)
# RF R2: 0.38935707879016557
# Remaining: 143
# The Iteration is  10
# NN Test R2 with 5 samples -4.625894689491992
# After Initialization RF R2: 0.5299386219749151
# NN Test R2 after Initialization -1.3853205766628254
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8163156249159116
# (20, 10)
# RF R2: 0.3688331529804526
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8773884812457251
# (30, 10)
# RF R2: 0.40036576950369196
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8657278568224543
# (40, 10)
# RF R2: 0.3320115478611414
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8507079328291183
# (50, 10)
# RF R2: 0.38730121729067857
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8531826577940128
# (60, 10)
# RF R2: 0.328964481195578
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8433526090048711
# (70, 10)
# RF R2: 0.2996010569166827
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8473521546120713
# (80, 10)
# RF R2: 0.486288776516727
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8483672188557361
# (90, 10)
# RF R2: 0.46290434119979607
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8506824814893775
# (100, 10)
# RF R2: 0.5051749760368579
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8479559677844323
# (110, 10)
# RF R2: 0.5089696297460488
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8399678842394185
# (120, 10)
# RF R2: 0.45645640706853663
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8387619672426903
# (130, 10)
# RF R2: 0.4812880214578761
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8361775971312413
# (140, 10)
# RF R2: 0.5271062646082987
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8356508175402462
# (150, 10)
# RF R2: 0.510574989206158
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8347786874624564
# (160, 10)
# RF R2: 0.522897412918147
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8400175137942711
# (170, 10)
# RF R2: 0.5432568371111688
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8385705823366529
# (180, 10)
# RF R2: 0.5151183494382506
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8437314648750933
# (190, 10)
# RF R2: 0.49558146854426
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8437508247837229
# (200, 10)
# RF R2: 0.4670065602099335
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8443044759747829
# (210, 10)
# RF R2: 0.47132124652158225
# Remaining: 143
# The Iteration is  11
# NN Test R2 with 5 samples -4.079912715947571
# After Initialization RF R2: 0.04756560905808249
# NN Test R2 after Initialization -1.8791760816095373
# (10, 10)
# Query no. 1
# Embeddings training score: 0.825559379778483
# (20, 10)
# RF R2: 0.0684698408309582
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8918695932667782
# (30, 10)
# RF R2: 0.17762357739131607
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8613526069931079
# (40, 10)
# RF R2: 0.1978375631830167
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8523709965488513
# (50, 10)
# RF R2: 0.2605497819904641
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8606575037297712
# (60, 10)
# RF R2: 0.31214820748219463
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8586010359908203
# (70, 10)
# RF R2: 0.23322695045742836
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8532697696789022
# (80, 10)
# RF R2: 0.2534663519003528
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8558195336534227
# (90, 10)
# RF R2: 0.3340945220492979
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.860873139415546
# (100, 10)
# RF R2: 0.29036141637285506
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8564290742469081
# (110, 10)
# RF R2: 0.31772610296827763
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8556414468930194
# (120, 10)
# RF R2: 0.3448502187849214
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8552115541110537
# (130, 10)
# RF R2: 0.24360707060197995
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8536417223301248
# (140, 10)
# RF R2: 0.2504560140763278
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.861822592920744
# (150, 10)
# RF R2: 0.322596409217771
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8595268342080139
# (160, 10)
# RF R2: 0.36027057530856244
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8598821284353644
# (170, 10)
# RF R2: 0.28429144157871045
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8580645334862145
# (180, 10)
# RF R2: 0.23338077486842235
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8542434944219939
# (190, 10)
# RF R2: 0.22000654477777026
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8546478702498927
# (200, 10)
# RF R2: 0.25276560111568325
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8603908190407017
# (210, 10)
# RF R2: 0.26435220108533874
# Remaining: 143
# The Iteration is  12
# NN Test R2 with 5 samples -4.018626802915413
# After Initialization RF R2: 0.41544683109792646
# NN Test R2 after Initialization -0.8280201310744729
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8100336774303054
# (20, 10)
# RF R2: 0.42085476019619306
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8490224520123374
# (30, 10)
# RF R2: 0.39508446472298453
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8622643196691435
# (40, 10)
# RF R2: 0.4359410742160046
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8809598207574798
# (50, 10)
# RF R2: 0.3762421589370658
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8999727489592292
# (60, 10)
# RF R2: 0.4311749424811169
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8892238823145501
# (70, 10)
# RF R2: 0.45647950330317455
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8855101585257843
# (80, 10)
# RF R2: 0.4719031774096898
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8804775857915131
# (90, 10)
# RF R2: 0.49801217143956256
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.877842869676293
# (100, 10)
# RF R2: 0.4998774601806575
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8736974878354539
# (110, 10)
# RF R2: 0.487200477166298
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8684756703819154
# (120, 10)
# RF R2: 0.4723923457347251
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8626807515956728
# (130, 10)
# RF R2: 0.4357231188920865
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8650244273376421
# (140, 10)
# RF R2: 0.42473211458649296
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8694166848516733
# (150, 10)
# RF R2: 0.42691172904352204
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8727239302612784
# (160, 10)
# RF R2: 0.4502591223839081
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8744104323620452
# (170, 10)
# RF R2: 0.41214843774274457
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8768312220805222
# (180, 10)
# RF R2: 0.41569617675127435
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8789553142184274
# (190, 10)
# RF R2: 0.4421953012066019
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8801521804965986
# (200, 10)
# RF R2: 0.4470757092762607
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8769100094171642
# (210, 10)
# RF R2: 0.46359092533272184
# Remaining: 143
# The Iteration is  13
# NN Test R2 with 5 samples -3.807043219739219
# After Initialization RF R2: 0.2950272412049104
# NN Test R2 after Initialization -3.147430561385807
# (10, 10)
# Query no. 1
# Embeddings training score: 0.821444080051833
# (20, 10)
# RF R2: 0.3148568760219571
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8508120409745925
# (30, 10)
# RF R2: 0.4412604363952538
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8262747599329631
# (40, 10)
# RF R2: 0.40847881962532817
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8463519487105122
# (50, 10)
# RF R2: 0.42980419777235124
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.842344411675872
# (60, 10)
# RF R2: 0.4206333771877071
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8900579523112586
# (70, 10)
# RF R2: 0.41106447740424445
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.9176147973864961
# (80, 10)
# RF R2: 0.3949737834852257
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8998878686390075
# (90, 10)
# RF R2: 0.41195369803056325
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8954147026766844
# (100, 10)
# RF R2: 0.42575433100469484
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.9011581887486335
# (110, 10)
# RF R2: 0.45331484060181804
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.9031689801619713
# (120, 10)
# RF R2: 0.45082860561165905
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.9037322671906098
# (130, 10)
# RF R2: 0.4111644990490423
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.9040109132498649
# (140, 10)
# RF R2: 0.4282717768418929
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.9056002349750871
# (150, 10)
# RF R2: 0.4236426782291065
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8985400881139032
# (160, 10)
# RF R2: 0.43557931263805383
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8976802589411742
# (170, 10)
# RF R2: 0.43066894085761565
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8799887877086852
# (180, 10)
# RF R2: 0.4723452040891747
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8838496129040689
# (190, 10)
# RF R2: 0.4570914529028598
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8826213512166144
# (200, 10)
# RF R2: 0.47748598060077885
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8759018122343645
# (210, 10)
# RF R2: 0.4678353787571299
# Remaining: 143
# The Iteration is  14
# NN Test R2 with 5 samples -3.833286648274218
# After Initialization RF R2: 0.206942240484295
# NN Test R2 after Initialization -1.3698289396015113
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8417088818955758
# (20, 10)
# RF R2: 0.05457760877029072
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.9023894146355154
# (30, 10)
# RF R2: 0.2750634723230595
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8889722259891211
# (40, 10)
# RF R2: 0.12853706626573735
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8707273330818637
# (50, 10)
# RF R2: 0.15929842749252532
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8586588875362521
# (60, 10)
# RF R2: 0.23381361895470676
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8549017406211148
# (70, 10)
# RF R2: 0.3684134391043057
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8588795142345456
# (80, 10)
# RF R2: 0.39958154895062414
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.876718998615677
# (90, 10)
# RF R2: 0.3846594657429038
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8743964217622133
# (100, 10)
# RF R2: 0.3615146459010966
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8669525440851183
# (110, 10)
# RF R2: 0.3282868415251391
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8677026233612127
# (120, 10)
# RF R2: 0.3869610552205739
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.870574895440465
# (130, 10)
# RF R2: 0.37459156225614965
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.87458946297175
# (140, 10)
# RF R2: 0.41156469008246854
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8647718041103691
# (150, 10)
# RF R2: 0.41462112939273665
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8681705959375795
# (160, 10)
# RF R2: 0.43233040117391386
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8667259556374534
# (170, 10)
# RF R2: 0.4142653733887759
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8689548748028508
# (180, 10)
# RF R2: 0.4181503204250451
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8705562353574179
# (190, 10)
# RF R2: 0.39368008890224027
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8675025286866882
# (200, 10)
# RF R2: 0.3953933034425192
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8661840044824096
# (210, 10)
# RF R2: 0.4050598501656949
# Remaining: 143
# The Iteration is  15
# NN Test R2 with 5 samples -4.143740026235879
# After Initialization RF R2: 0.2745059012293305
# NN Test R2 after Initialization -1.4361376905394991
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8418326404506593
# (20, 10)
# RF R2: 0.3429009286113729
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8284975405675999
# (30, 10)
# RF R2: 0.4125298680804004
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8208517166097837
# (40, 10)
# RF R2: 0.40636047819804577
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.830519543827855
# (50, 10)
# RF R2: 0.41593830291430045
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8410108217211578
# (60, 10)
# RF R2: 0.4010125120841922
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8395935431636217
# (70, 10)
# RF R2: 0.43002595561721724
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8327684252803367
# (80, 10)
# RF R2: 0.4231197387290836
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8350387449245442
# (90, 10)
# RF R2: 0.4040765386378915
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8429164570619742
# (100, 10)
# RF R2: 0.4101282699865839
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8471821569483821
# (110, 10)
# RF R2: 0.4419386266317552
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8448258628423668
# (120, 10)
# RF R2: 0.41930900014931916
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8409981733943255
# (130, 10)
# RF R2: 0.4191312142887126
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8419743186354305
# (140, 10)
# RF R2: 0.4245022494466878
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8486395095398518
# (150, 10)
# RF R2: 0.4256556776720425
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.83991603275425
# (160, 10)
# RF R2: 0.4173181519781447
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8442446741828045
# (170, 10)
# RF R2: 0.38557890231761416
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8437647153928458
# (180, 10)
# RF R2: 0.38702906431467465
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8507755191481575
# (190, 10)
# RF R2: 0.3666184530934997
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8432702766480791
# (200, 10)
# RF R2: 0.41963298346707534
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8456703811606827
# (210, 10)
# RF R2: 0.4303339954739037
# Remaining: 143
# The Iteration is  16
# NN Test R2 with 5 samples -3.7399678367908193
# After Initialization RF R2: 0.06221806216068704
# NN Test R2 after Initialization -2.314247822785765
# (10, 10)
# Query no. 1
# Embeddings training score: 0.7076354831737105
# (20, 10)
# RF R2: 0.3611672581798323
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8302224132251619
# (30, 10)
# RF R2: 0.3028350089190126
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.873563364003769
# (40, 10)
# RF R2: 0.266515514316241
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8577126181346315
# (50, 10)
# RF R2: 0.3095296974649414
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8643440362201271
# (60, 10)
# RF R2: 0.3210637984939696
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8625518664896878
# (70, 10)
# RF R2: 0.32391810010678335
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8691149927797588
# (80, 10)
# RF R2: 0.28522923354451923
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.871408628341472
# (90, 10)
# RF R2: 0.368592012836074
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8710988821570396
# (100, 10)
# RF R2: 0.4565025932852659
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.864900798571611
# (110, 10)
# RF R2: 0.4870105360731527
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8675852668297169
# (120, 10)
# RF R2: 0.48984302698375737
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8657106023039006
# (130, 10)
# RF R2: 0.4960490597630103
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8673805557273533
# (140, 10)
# RF R2: 0.4932959757434503
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8627861318458414
# (150, 10)
# RF R2: 0.44737279803020125
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8661316669081742
# (160, 10)
# RF R2: 0.45325393618956167
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8636535006544517
# (170, 10)
# RF R2: 0.4638304960738808
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8627885973068963
# (180, 10)
# RF R2: 0.46109967452798906
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8611544833640503
# (190, 10)
# RF R2: 0.4508668255734336
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8610667674930723
# (200, 10)
# RF R2: 0.42174703974609296
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8610398976604786
# (210, 10)
# RF R2: 0.41999713360735236
# Remaining: 143
# The Iteration is  17
# NN Test R2 with 5 samples -3.6960201942973065
# After Initialization RF R2: 0.3158630810517554
# NN Test R2 after Initialization -2.523437833351679
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8258425453764257
# (20, 10)
# RF R2: 0.3770354781572499
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.9141221211353534
# (30, 10)
# RF R2: 0.38679295222165644
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.8765610322799882
# (40, 10)
# RF R2: 0.48746496458808175
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.8748942489657376
# (50, 10)
# RF R2: 0.47579483817919843
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.860808346188225
# (60, 10)
# RF R2: 0.4409616637772581
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8702752574156146
# (70, 10)
# RF R2: 0.4220491254004005
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8713059725306678
# (80, 10)
# RF R2: 0.4628299782552233
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8751117994919916
# (90, 10)
# RF R2: 0.4473855597470724
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8732550049295984
# (100, 10)
# RF R2: 0.3853278958445093
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8745947205056217
# (110, 10)
# RF R2: 0.3368612379526392
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8732415162686947
# (120, 10)
# RF R2: 0.3545154013222771
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8720813608614488
# (130, 10)
# RF R2: 0.43437906014970784
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8751901917276884
# (140, 10)
# RF R2: 0.4373547378999634
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8732448795570706
# (150, 10)
# RF R2: 0.3974050021198775
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8743111408765182
# (160, 10)
# RF R2: 0.40355630939151366
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8713146241943261
# (170, 10)
# RF R2: 0.4058234809701804
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.867287663493256
# (180, 10)
# RF R2: 0.4188811250105644
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8660252863210716
# (190, 10)
# RF R2: 0.37858964804934003
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.8675796216701319
# (200, 10)
# RF R2: 0.3752458094213438
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8666675985584047
# (210, 10)
# RF R2: 0.37695676152182456
# Remaining: 143
# The Iteration is  18
# NN Test R2 with 5 samples -4.009430374539497
# After Initialization RF R2: 0.28871207407203614
# NN Test R2 after Initialization -2.5524534937898857
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8309437201417176
# (20, 10)
# RF R2: 0.3314099148253844
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.8443847604588357
# (30, 10)
# RF R2: 0.14311590168583332
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.9501352900029084
# (40, 10)
# RF R2: 0.3725932575398079
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.9129267286452811
# (50, 10)
# RF R2: 0.36852249540461757
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.8807500901026326
# (60, 10)
# RF R2: 0.3439507275186282
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.8792329216920972
# (70, 10)
# RF R2: 0.3097174452266185
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8815716579804345
# (80, 10)
# RF R2: 0.3619847338871758
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8659795725838846
# (90, 10)
# RF R2: 0.4324371593952605
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8663324521352687
# (100, 10)
# RF R2: 0.42605292595888966
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.8705970917579484
# (110, 10)
# RF R2: 0.446442603595018
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8737714307593113
# (120, 10)
# RF R2: 0.44803256353657706
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8711015147172957
# (130, 10)
# RF R2: 0.4655862289643202
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8657633510385575
# (140, 10)
# RF R2: 0.44395243543506424
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.8693004971170355
# (150, 10)
# RF R2: 0.49091237179593417
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8674405922361949
# (160, 10)
# RF R2: 0.5005322348093066
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8643230423150735
# (170, 10)
# RF R2: 0.5043869505332291
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8589264221525218
# (180, 10)
# RF R2: 0.470196387416872
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.858081662285393
# (190, 10)
# RF R2: 0.5096174703375588
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.854435230937799
# (200, 10)
# RF R2: 0.5373180608837366
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8567952866599183
# (210, 10)
# RF R2: 0.5033410654033521
# Remaining: 143
# The Iteration is  19
# NN Test R2 with 5 samples -4.077887221165926
# After Initialization RF R2: 0.047433339911635786
# NN Test R2 after Initialization -2.57524688621633
# (10, 10)
# Query no. 1
# Embeddings training score: 0.8284618601453002
# (20, 10)
# RF R2: 0.18099017738973455
# Remaining: 333
# Query no. 2
# Embeddings training score: 0.9394649172152049
# (30, 10)
# RF R2: 0.32605459462441966
# Remaining: 323
# Query no. 3
# Embeddings training score: 0.9264157361657858
# (40, 10)
# RF R2: 0.24917026260460928
# Remaining: 313
# Query no. 4
# Embeddings training score: 0.9271582112923786
# (50, 10)
# RF R2: 0.16049595768690594
# Remaining: 303
# Query no. 5
# Embeddings training score: 0.9202925533698547
# (60, 10)
# RF R2: 0.18608804081862296
# Remaining: 293
# Query no. 6
# Embeddings training score: 0.9085805711240712
# (70, 10)
# RF R2: 0.08933253187237311
# Remaining: 283
# Query no. 7
# Embeddings training score: 0.8993100318700624
# (80, 10)
# RF R2: 0.32691144926892524
# Remaining: 273
# Query no. 8
# Embeddings training score: 0.8963574532107882
# (90, 10)
# RF R2: 0.3316825816312009
# Remaining: 263
# Query no. 9
# Embeddings training score: 0.8899477094072737
# (100, 10)
# RF R2: 0.3487884532610712
# Remaining: 253
# Query no. 10
# Embeddings training score: 0.896237240627727
# (110, 10)
# RF R2: 0.3153892970872081
# Remaining: 243
# Query no. 11
# Embeddings training score: 0.8866304047215222
# (120, 10)
# RF R2: 0.3577534627671729
# Remaining: 233
# Query no. 12
# Embeddings training score: 0.8880865396939952
# (130, 10)
# RF R2: 0.34230655969687585
# Remaining: 223
# Query no. 13
# Embeddings training score: 0.8861384663719241
# (140, 10)
# RF R2: 0.33202961486807425
# Remaining: 213
# Query no. 14
# Embeddings training score: 0.889887378436685
# (150, 10)
# RF R2: 0.3315534554165903
# Remaining: 203
# Query no. 15
# Embeddings training score: 0.8779514278808555
# (160, 10)
# RF R2: 0.3669419602032836
# Remaining: 193
# Query no. 16
# Embeddings training score: 0.8830013252604988
# (170, 10)
# RF R2: 0.3762357866736231
# Remaining: 183
# Query no. 17
# Embeddings training score: 0.8842548626107316
# (180, 10)
# RF R2: 0.3585980277527445
# Remaining: 173
# Query no. 18
# Embeddings training score: 0.8860544093951312
# (190, 10)
# RF R2: 0.34866916059207287
# Remaining: 163
# Query no. 19
# Embeddings training score: 0.885777418668604
# (200, 10)
# RF R2: 0.33727367317484513
# Remaining: 153
# Query no. 20
# Embeddings training score: 0.8836813730994137
# (210, 10)
# RF R2: 0.35262651141387513
# Remaining: 143
